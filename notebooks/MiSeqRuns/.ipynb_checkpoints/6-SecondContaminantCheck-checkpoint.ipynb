# %%
figDir = '~/Hyphosphere/data/3Exp/figures'

work_dir = '~/Hyphosphere/data/3Exp/Composition'

# phyloseq - full object without tree (includes archaea)
physeq_file = '~/Hyphosphere/data/3Exp/phyloseq/3Exp_phyloseq_thresh_woTree_woContam.rds'

# %%
library(RColorBrewer)
library(tidyr)
library(dplyr)
library(reshape2)
library(phyloseq)
library(gridExtra)
library(ggplot2)
library(DESeq2)

# %%
theme_pub = function (base_size = 11, base_family = "Arial") 
{
    theme_grey(base_size = base_size, base_family = base_family) %+replace% 
        theme(
            axis.line.x = element_line(size = .5),
            axis.line.y = element_line(size = .5),
            panel.background = element_rect(fill = "white", colour = NA), 
            panel.border = element_rect(fill = NA, color = "black", size = .5), 
            panel.grid.major = element_blank(), 
            panel.grid.minor = element_blank(), 
            strip.background = element_rect(fill = "grey85", 
                colour = "grey20"), 
            legend.key = element_rect(fill = "white", 
                colour = NA), complete = TRUE)
    }

# %%
ps = readRDS(physeq_file) %>% subset_taxa(., !is.na(Phylum)) %>%
    # remove non-experimental controls
    subset_samples(., !SampleType %in% c("EB", "PB", "MK")) %>%
    # T0R1 has all NaN for some reason
    subset_samples(!Sample == "T0R1") %>%
     # re-normalize after subsetting taxa
    transform_sample_counts(., function(x) x/sum(x))
sample_data(ps)$Rep = as.factor(sample_data(ps)$Rep)

ps
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 15128 taxa and 398 samples ]
# sample_data() Sample Data:       [ 398 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 15128 taxa by 6 taxonomic ranks ]

# %%
ps.m = psmelt(ps)
# Out:
# Warning message in psmelt(ps):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”

# %%
ps.m1 = ps.m %>% filter(Experiment == 1)
ps.m2 = ps.m %>% filter(Experiment == 2)
ps.m3 = ps.m %>% filter(Experiment == 3)

# %% [markdown]
# # Resume here, finding way to efficiently convert low abundance groups to same color

# %%
# Identify phyla with max abundance less than 0.01

ps.m1 %>% 
    group_by(Phylum) %>%
    summarize(mAbundance = max(Abundance)) %>%
    mutate(graphRank = factor(ifelse(mAbundance > 0.01, as.character(Phylum), 'Max less than 2% rel abundance')))
str
# Out:
#    Phylum              mAbundance   graphRank
# 1  Acidobacteria       0.0649475840 Acidobacteria
# 2  Actinobacteria      0.0456599000 Actinobacteria
# 3  Armatimonadetes     0.0149415592 Armatimonadetes
# 4  Bacteroidetes       0.1085221003 Bacteroidetes
# 5  BRC1                0.0008400538 Max less than 2% rel abundance
# 6  Chlamydiae          0.0174339503 Chlamydiae
# 7  Chloroflexi         0.0313738174 Chloroflexi
# 8  Cyanobacteria       0.0203448821 Cyanobacteria
# 9  Deinococcus-Thermus 0.0002250731 Max less than 2% rel abundance
# 10 Dependentiae        0.0089330272 Max less than 2% rel abundance
# 11 Diapherotrites      0.0028667377 Max less than 2% rel abundance
# 12 Elusimicrobia       0.0017468827 Max less than 2% rel abundance
# 13 Entotheonellaeota   0.0027106801 Max less than 2% rel abundance
# 14 Euryarchaeota       0.0015971824 Max less than 2% rel abundance
# 15 FBP                 0.0200566751 FBP
# 16 FCPU426             0.0082064173 Max less than 2% rel abundance
# 17 Fibrobacteres       0.2113507652 Fibrobacteres
# 18 Firmicutes          0.0077211680 Max less than 2% rel abundance
# 19 GAL15               0.0006269592 Max less than 2% rel abundance
# 20 Gemmatimonadetes    0.0080111459 Max less than 2% rel abundance
# 21 Hydrogenedentes     0.0001110833 Max less than 2% rel abundance
# 22 Kiritimatiellaeota  0.0000000000 Max less than 2% rel abundance
# 23 Latescibacteria     0.0039069041 Max less than 2% rel abundance
# 24 Nanoarchaeaeota     0.0015793011 Max less than 2% rel abundance
# 25 Nitrospirae         0.0055729711 Max less than 2% rel abundance
# 26 Omnitrophicaeota    0.0014681208 Max less than 2% rel abundance
# 27 Patescibacteria     0.0046910869 Max less than 2% rel abundance
# 28 Planctomycetes      0.0788677615 Planctomycetes
# 29 Proteobacteria      0.6017542949 Proteobacteria
# 30 Rokubacteria        0.0064520511 Max less than 2% rel abundance
# 31 Spirochaetes        0.0084767206 Max less than 2% rel abundance
# 32 Tenericutes         0.0100266839 Tenericutes
# 33 Thaumarchaeota      0.0463087248 Thaumarchaeota
# 34 Verrucomicrobia     0.0193418576 Verrucomicrobia
# 35 WPS-2               0.0003806210 Max less than 2% rel abundance
# 36 WS2                 0.0007612419 Max less than 2% rel abundance
# 37 Zixibacteria        0.0000000000 Max less than 2% rel abundance
# NULL

# %%
#generate data frame of core plants aggregated at the phylum level 
Rank = "Phylum"
Rank.df = ps.m1 %>% 
    group_by(Sample,SampleType,Soil, Rep, paste(Rank)) %>%
    summarize(s.Abundance = sum(Abundance)) %>%
    mutate(graphRank = ifelse(Abundance > 0.01))

#head(mdf)
head(Rank2.df)

#goal is to calculate relative abundance 
  # cast by Rank2
#   R2.c = dcast(Rank2.df, Soil + SampleType ~ Phylum)
#   head(R2.c)
#   #Calculate relative abundance using 
#   R2.c[,3:23] = sweep(R2.c[,3:23], 1, rowSums(R2.c[,3:23]), '/')
#   head(R2.c)
# R2.m = melt(R2.c, id.vars = c("Soil", "SampleType"))
  

##getPalette = colorRampPalette(brewer.pal(colorCount, "Set2"))

ggplot(Rank2.df, aes(x = Rep, y = s.Abundance, fill=Phylum)) + 
    geom_bar(stat = "identity")+
    theme(axis.text.x = element_text(angle = 60))+
    #scale_fill_manual(values = getPalette(colourCount))+
    facet_grid(SampleType~Soil, scales = 'free_x')
# Out:
#   Sample     SampleType Soil     Rep Phylum          s.Abundance
# 1 HCBF1_S247 CS         Florence 7   Acidobacteria   0.110342133
# 2 HCBF1_S247 CS         Florence 7   Actinobacteria  0.164369035
# 3 HCBF1_S247 CS         Florence 7   Armatimonadetes 0.005860356
# 4 HCBF1_S247 CS         Florence 7   Bacteroidetes   0.042808506
# 5 HCBF1_S247 CS         Florence 7   BRC1            0.000000000
# 6 HCBF1_S247 CS         Florence 7   Chlamydiae      0.001674387
# plot without title
