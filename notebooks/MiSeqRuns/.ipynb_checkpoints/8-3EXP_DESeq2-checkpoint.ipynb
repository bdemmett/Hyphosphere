# %% [markdown]
# # Differential abundance analysis

# %%
figDir = '~/Hyphosphere/data/3Exp/figures'

work_dir = '~/Hyphosphere/data/3Exp/DESeq'

# phyloseq - full object without tree (includes archaea)
physeq_file = '~/Hyphosphere/data/3Exp/phyloseq/3Exp_phyloseq_thresh_woTree_experimental_woContam.rds'

# %%
library(RColorBrewer)
library(vegan)
library(tidyr)
library(dplyr)
library(reshape2)
library(phyloseq)
library(gridExtra)
library(ggplot2)
library(DESeq2)
# Out:
# Warning message:
# “package ‘RColorBrewer’ was built under R version 3.6.1”Warning message:
# “package ‘vegan’ was built under R version 3.6.1”Loading required package: permute
# Warning message:
# “package ‘permute’ was built under R version 3.6.1”Loading required package: lattice
# Warning message:
# “package ‘lattice’ was built under R version 3.6.1”This is vegan 2.5-5
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Warning message:
# “package ‘reshape2’ was built under R version 3.6.1”
# Attaching package: ‘reshape2’
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
# Warning message:
# “package ‘phyloseq’ was built under R version 3.6.1”
# Attaching package: ‘gridExtra’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
# Warning message:
# “package ‘ggplot2’ was built under R version 3.6.1”Loading required package: S4Vectors
# Warning message:
# “package ‘S4Vectors’ was built under R version 3.6.1”Loading required package: stats4
# Loading required package: BiocGenerics
# Warning message:
# “package ‘BiocGenerics’ was built under R version 3.6.1”Loading required package: parallel
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
# The following object is masked from ‘package:gridExtra’:
#
#     combine
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which, which.max, which.min
#
#
# Attaching package: ‘S4Vectors’
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
# Loading required package: IRanges
# Warning message:
# “package ‘IRanges’ was built under R version 3.6.1”
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:phyloseq’:
#
#     distance
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
# Loading required package: GenomicRanges
# Loading required package: GenomeInfoDb
# Loading required package: SummarizedExperiment
# Loading required package: Biobase
# Warning message:
# “package ‘Biobase’ was built under R version 3.6.1”Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘Biobase’
#
# The following object is masked from ‘package:phyloseq’:
#
#     sampleNames
#
# Loading required package: DelayedArray
# Loading required package: matrixStats
#
# Attaching package: ‘matrixStats’
#
# The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
# Loading required package: BiocParallel
# Warning message:
# “multiple methods tables found for ‘lengths’”Warning message:
# “multiple methods tables found for ‘rowSums’”Warning message:
# “multiple methods tables found for ‘colSums’”Warning message:
# “multiple methods tables found for ‘rowMeans’”Warning message:
# “multiple methods tables found for ‘colMeans’”
# Attaching package: ‘DelayedArray’
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colMaxs, colMins, colRanges, rowMaxs, rowMins, rowRanges
#
# The following objects are masked from ‘package:base’:
#
#     aperm, apply
#
# Warning message:
# “multiple methods tables found for ‘toTable’”

# %%
theme_pub = function (base_size = 11, base_family = "Helvetica") 
{
    theme_grey(base_size = base_size, base_family = base_family) %+replace% 
        theme(
            axis.line.x = element_line(size = .5),
            axis.line.y = element_line(size = .5),
            panel.background = element_rect(fill = "white", colour = NA), 
            panel.border = element_rect(fill = NA, color = "black", size = .5), 
            panel.grid.major = element_blank(), 
            panel.grid.minor = element_blank(), 
            strip.background = element_rect(fill = "grey85", 
                colour = "grey20"), 
            legend.key = element_rect(fill = "white", 
                colour = NA), complete = TRUE)
    }

# %%
ps = readRDS(physeq_file) %>% subset_taxa(., !is.na(Phylum)) %>%
    # remove non-experimental controls
    
    subset_samples(., SampleType != "GV") 
    # T0R1 has all NaN for some reason
    #subset_samples(!Sample == "T0R1") #%>%
     # re-normalize after subsetting taxa
    #transform_sample_counts(., function(x) x/sum(x))
sample_data(ps)$Rep = as.factor(sample_data(ps)$Rep)

ps
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 18876 taxa and 384 samples ]
# sample_data() Sample Data:       [ 384 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 18876 taxa by 6 taxonomic ranks ]

# %%
taxa = tax_table(ps) %>% as.data.frame() %>% mutate(ASV = row.names(.))
head(taxa)
# Out:
#   Kingdom  Phylum         Class               Order
# 1 Bacteria Actinobacteria Actinobacteria      Micrococcales
# 2 Bacteria Proteobacteria Gammaproteobacteria Cellvibrionales
# 3 Bacteria Proteobacteria Alphaproteobacteria Caulobacterales
# 4 Bacteria Proteobacteria Gammaproteobacteria Xanthomonadales
# 5 Bacteria Proteobacteria Deltaproteobacteria Myxococcales
# 6 Bacteria Proteobacteria Gammaproteobacteria Betaproteobacteriales
#   Family           Genus             ASV
# 1 Micrococcaceae   Pseudarthrobacter ASV5
# 2 Cellvibrionaceae Cellvibrio        ASV6
# 3 Caulobacteraceae Asticcacaulis     ASV8
# 4 Xanthomonadaceae Luteimonas        ASV13
# 5 Sandaracinaceae  NA                ASV14
# 6 Burkholderiaceae NA                ASV15

# %%
sample_data(ps)[,'Soil'] %>% unique()
# Out:
#            Soil
# 1.1BP      Lansing
# GVCLHN1-BH Pendelton
# GVFLHN1-BH Florence
# HCBS1      Sand

# %%
sample_data(ps)$SoilxFungus = paste(sample_data(ps)$Soil,"-",sample_data(ps)$Fungus, sep = "")
sample_data(ps) %>% head()
# Out:
#       Sample Experiment Plant Fungus Soil    SampleType Treatment TimePoint DAI
# 1.1BP 1.1BP  3          1.1   Gv     Lansing BP         HN        1         14
# 1.1BS 1.1BS  3          1.1   Gv     Lansing BS         HN        1         14
# 1.1CH 1.1CH  3          1.1   Gv     Lansing CH         HN        1         14
# 1.1CS 1.1CS  3          1.1   Gv     Lansing CS         HN        1         14
# 1.1RH 1.1RH  3          1.1   Gv     Lansing RH         HN        1         14
# 1.1RT 1.1RT  3          1.1   Gv     Lansing RT         HN        1         14
#       Rep Concentration_ng.ul SoilxFungus
# 1.1BP 1   1.067               Lansing-Gv
# 1.1BS 1   4.421               Lansing-Gv
# 1.1CH 1   0.325               Lansing-Gv
# 1.1CS 1   2.116               Lansing-Gv
# 1.1RH 1   0.174               Lansing-Gv
# 1.1RT 1   1.561               Lansing-Gv

# %% [markdown]
# # Experiment 2

# %%
tmp = ps %>% subset_samples(Experiment == 2)

# %% [markdown]
# ## Loop script for sample type contrasts in experiment 2
# * Fertilizer treatments grouped together

# %%
sample_data(tmp)$SampleType %>% unique
# Out:
# [1] "BH" "BP" "BS" "CH" "CS" "RH" "RS"

# %%
library("BiocParallel")
register(MulticoreParam(20))

# %%
sample_data(tmp)$DAI %>% unique()
# Out:
# [1] 27

# %%
sample_data(tmp) %>% as.data.frame() %>% filter(., Fungus == "RI") %>% .$SampleType  %>% unique()
# Out:
# Warning message in class(x) <- c(subclass, tibble_class):
# “Setting class(x) to multiple strings ("tbl_df", "tbl", ...); result will no longer be an S4 object”
# [1] "BH" "BS" "CH" "CS" "RH" "RS"

# %%
#sample_data(tmp)$SoilxFungus = paste(sample_data(tmp)$Soil, sample_data(tmp)$Fungus, sep = '-')
df.l2fc = NULL
Grouplist = c('Lansing-Gv', 'Florence-Gv', 'Pendelton-Gv')
ContrastList = list(c("CH","CS"), c("CH", "BS"), c("CH", "BP"), c("RH", "RS"), c("BH","BS"), c("BP", "CS"), c("BP", "BS")) 

    for (i in Grouplist) {
            print(i)
          for (j in ContrastList) { 
                phy = subset_samples(tmp, SoilxFungus == i & SampleType %in% j)
                diag
                numerator = j[1]
                denom<-j[2]
                print(paste(numerator, denom, sep = "_"))
                #make DESeq object
                diagdds = phyloseq_to_deseq2(phy, ~ Rep + SampleType)
                diagdds = DESeq(diagdds, fitType="local")
#               for (k in (j+1):length(GenoList)) { # k = index of 2nd genotype
#                 geno2<-GenoList[k]
#               #  print(paste0(geno1,".",geno2)) # debugging line to make sure all pairwise comparisons are represented
           # get log2 fold change between this pair of genotypes
              r =  results(diagdds,contrast=c('SampleType',numerator,denom),parallel=TRUE) %>% as.data.frame %>% 
                    mutate(OTU=row.names(.),Subset = i, Term='SampleType',Contrast=paste0(numerator,'_',denom),DAI='27') 
             df.l2fc = rbind(df.l2fc, r)
                     }
          }

i = "Lansing-RI"
RIContrastList = list(c("CH","CS"), c("CH", "BS"), c("RH", "RS"), c("BH","BS"))

    for (j in RIContrastList) { 
                phy = subset_samples(tmp, SoilxFungus == i & SampleType %in% j)
                diag
                numerator = j[1]
                denom<-j[2]
                print(paste(numerator, denom, sep = "_"))
                #make DESeq object
                diagdds = phyloseq_to_deseq2(phy, ~ Rep + SampleType)
                diagdds = DESeq(diagdds, fitType="local")
#               for (k in (j+1):length(GenoList)) { # k = index of 2nd genotype
#                 geno2<-GenoList[k]
#               #  print(paste0(geno1,".",geno2)) # debugging line to make sure all pairwise comparisons are represented
           # get log2 fold change between this pair of genotypes
              r =  results(diagdds,contrast=c('SampleType',numerator,denom),parallel=TRUE) %>% as.data.frame %>% 
                    mutate(OTU=row.names(.),Subset = i, Term='SampleType',Contrast=paste0(numerator,'_',denom),DAI='27') 
             df.l2fc = rbind(df.l2fc, r)
        }

df.l2fc.Exp2 = df.l2fc
# #cleanup
diagdds = NULL
df.l2fc = NULL
r = NULL
# Out:
# [1] "Lansing-Gv"
# [1] "CH_CS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "CH_BS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "CH_BP"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "RH_RS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "BH_BS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "BP_CS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "BP_BS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "Florence-Gv"
# [1] "CH_CS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "CH_BS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "CH_BP"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "RH_RS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "BH_BS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "BP_CS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "BP_BS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "Pendelton-Gv"
# [1] "CH_CS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "CH_BS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "CH_BP"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "RH_RS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "BH_BS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "BP_CS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "BP_BS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "CH_CS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "CH_BS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "RH_RS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "BH_BS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing

# %%
taxa %>% head()
# Out:
#   Kingdom  Phylum         Class               Order
# 1 Bacteria Actinobacteria Actinobacteria      Micrococcales
# 2 Bacteria Proteobacteria Gammaproteobacteria Cellvibrionales
# 3 Bacteria Proteobacteria Alphaproteobacteria Caulobacterales
# 4 Bacteria Proteobacteria Gammaproteobacteria Xanthomonadales
# 5 Bacteria Proteobacteria Deltaproteobacteria Myxococcales
# 6 Bacteria Proteobacteria Gammaproteobacteria Betaproteobacteriales
#   Family           Genus             ASV
# 1 Micrococcaceae   Pseudarthrobacter ASV5
# 2 Cellvibrionaceae Cellvibrio        ASV6
# 3 Caulobacteraceae Asticcacaulis     ASV8
# 4 Xanthomonadaceae Luteimonas        ASV13
# 5 Sandaracinaceae  NA                ASV14
# 6 Burkholderiaceae NA                ASV15

# %%
out = df.l2fc.Exp2  %>% left_join(., taxa, by = c("OTU" = "ASV"))
out$Experiment = 2
head(out)
outfile = file.path(work_dir, 'dfl2fc-Exp2.txt')
# Out:
# Warning message:
# “`chr_along()` is deprecated as of rlang 0.2.0.
# This warning is displayed once per session.”
#   baseMean   log2FoldChange lfcSE     stat       pvalue       padj
# 1 977.381944 -1.084927      0.6141637 -1.7665109 7.731017e-02 9.393601e-01
# 2 772.320938  8.411572      1.4161221  5.9398638 2.852590e-09 3.099449e-07
# 3  56.195482  8.815929      1.4665514  6.0113328 1.840042e-09 2.079248e-07
# 4   3.676573  1.393277      3.0166225  0.4618665 6.441770e-01 9.694757e-01
# 5 284.185280  5.948495      0.5893526 10.0932700 5.916508e-24 1.671413e-20
# 6  49.214540  4.239251      2.4298523  1.7446536 8.104519e-02 9.646906e-01
#   OTU   Subset     Term       Contrast DAI Kingdom  Phylum
# 1 ASV5  Lansing-Gv SampleType CH_CS    27  Bacteria Actinobacteria
# 2 ASV6  Lansing-Gv SampleType CH_CS    27  Bacteria Proteobacteria
# 3 ASV8  Lansing-Gv SampleType CH_CS    27  Bacteria Proteobacteria
# 4 ASV13 Lansing-Gv SampleType CH_CS    27  Bacteria Proteobacteria
# 5 ASV14 Lansing-Gv SampleType CH_CS    27  Bacteria Proteobacteria
# 6 ASV15 Lansing-Gv SampleType CH_CS    27  Bacteria Proteobacteria
#   Class               Order                 Family           Genus
# 1 Actinobacteria      Micrococcales         Micrococcaceae   Pseudarthrobacter
# 2 Gammaproteobacteria Cellvibrionales       Cellvibrionaceae Cellvibrio
# 3 Alphaproteobacteria Caulobacterales       Caulobacteraceae Asticcacaulis
# 4 Gammaproteobacteria Xanthomonadales       Xanthomonadaceae Luteimonas
# 5 Deltaproteobacteria Myxococcales          Sandaracinaceae  NA
# 6 Gammaproteobacteria Betaproteobacteriales Burkholderiaceae NA
#   Experiment
# 1 2
# 2 2
# 3 2
# 4 2
# 5 2
# 6 2

# %%
write.table(out, file = outfile, row.names = FALSE, sep = '\t')

# %% [markdown]
# ## Get Ri CH vs Gv BPOM contrasts

# %%
#sample_data(tmp)$SoilxFungus = paste(sample_data(tmp)$Soil, sample_data(tmp)$Fungus, sep = '-')
df.l2fc = NULL

phy = subset_samples(tmp, Soil == "Lansing")
phy = subset_samples(phy, SampleType == "BP" | Fungus == "RI" & SampleType == "CH")
    numerator = "CH"
    denom<-"BP"
              
#make DESeq object
    diagdds = phyloseq_to_deseq2(phy, ~ Rep + SampleType)
    diagdds = DESeq(diagdds, fitType="local")

r =  results(diagdds,contrast=c('SampleType',numerator,denom),parallel=TRUE) %>% as.data.frame %>% 
                    mutate(OTU=row.names(.),Subset = "Lansing-RI", Term='SampleType',Contrast=paste0(numerator,'_',denom),DAI='27') 

df.l2fc = rbind(df.l2fc, r)
        

#df.l2fc.Exp2 = df.l2fc
# #cleanup
diagdds = NULL
#df.l2fc = NULL
r = NULL
# Out:
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing

# %%
out = df.l2fc  %>% left_join(., taxa, by = c("OTU" = "ASV"))
out$Experiment = 2
head(out)
outfile = file.path(work_dir, 'dfl2fc-Exp2.txt')
# Out:
#   baseMean   log2FoldChange lfcSE     stat         pvalue       padj
# 1 274.702041 -0.551309056   0.4572841 -1.205616089 2.279656e-01 4.083063e-01
# 2  23.248492  4.002684320   1.8949944  2.112240720 3.466581e-02 1.128407e-01
# 3   7.282954  0.002838641   2.4148387  0.001175499 9.990621e-01 9.994113e-01
# 4   6.377796  1.043387463   3.0151832  0.346044471 7.293093e-01 8.530268e-01
# 5  94.301853  6.113858301   0.8984791  6.804675040 1.012776e-11 2.524027e-10
# 6  61.314695  5.402290262   2.9476484  1.832745783 6.684039e-02 1.802995e-01
#   OTU   Subset     Term       Contrast DAI Kingdom  Phylum
# 1 ASV5  Lansing-RI SampleType CH_BP    27  Bacteria Actinobacteria
# 2 ASV6  Lansing-RI SampleType CH_BP    27  Bacteria Proteobacteria
# 3 ASV8  Lansing-RI SampleType CH_BP    27  Bacteria Proteobacteria
# 4 ASV13 Lansing-RI SampleType CH_BP    27  Bacteria Proteobacteria
# 5 ASV14 Lansing-RI SampleType CH_BP    27  Bacteria Proteobacteria
# 6 ASV15 Lansing-RI SampleType CH_BP    27  Bacteria Proteobacteria
#   Class               Order                 Family           Genus
# 1 Actinobacteria      Micrococcales         Micrococcaceae   Pseudarthrobacter
# 2 Gammaproteobacteria Cellvibrionales       Cellvibrionaceae Cellvibrio
# 3 Alphaproteobacteria Caulobacterales       Caulobacteraceae Asticcacaulis
# 4 Gammaproteobacteria Xanthomonadales       Xanthomonadaceae Luteimonas
# 5 Deltaproteobacteria Myxococcales          Sandaracinaceae  NA
# 6 Gammaproteobacteria Betaproteobacteriales Burkholderiaceae NA
#   Experiment
# 1 2
# 2 2
# 3 2
# 4 2
# 5 2
# 6 2

# %%
write.table(out, file = outfile, row.names = FALSE, col.names = FALSE, sep = '\t', append = TRUE)

# %%
tmp = read.delim(outfile, header= TRUE, sep = '\t')
head(tmp)
tail(tmp)
# Out:
#   baseMean   log2FoldChange lfcSE     stat       pvalue       padj
# 1 977.381944 -1.084927      0.6141637 -1.7665109 7.731017e-02 9.393601e-01
# 2 772.320938  8.411572      1.4161221  5.9398638 2.852590e-09 3.099449e-07
# 3  56.195482  8.815929      1.4665514  6.0113328 1.840042e-09 2.079248e-07
# 4   3.676573  1.393277      3.0166225  0.4618665 6.441770e-01 9.694757e-01
# 5 284.185280  5.948495      0.5893526 10.0932700 5.916508e-24 1.671413e-20
# 6  49.214540  4.239251      2.4298523  1.7446536 8.104519e-02 9.646906e-01
#   OTU   Subset     Term       Contrast DAI Kingdom  Phylum
# 1 ASV5  Lansing-Gv SampleType CH_CS    27  Bacteria Actinobacteria
# 2 ASV6  Lansing-Gv SampleType CH_CS    27  Bacteria Proteobacteria
# 3 ASV8  Lansing-Gv SampleType CH_CS    27  Bacteria Proteobacteria
# 4 ASV13 Lansing-Gv SampleType CH_CS    27  Bacteria Proteobacteria
# 5 ASV14 Lansing-Gv SampleType CH_CS    27  Bacteria Proteobacteria
# 6 ASV15 Lansing-Gv SampleType CH_CS    27  Bacteria Proteobacteria
#   Class               Order                 Family           Genus
# 1 Actinobacteria      Micrococcales         Micrococcaceae   Pseudarthrobacter
# 2 Gammaproteobacteria Cellvibrionales       Cellvibrionaceae Cellvibrio
# 3 Alphaproteobacteria Caulobacterales       Caulobacteraceae Asticcacaulis
# 4 Gammaproteobacteria Xanthomonadales       Xanthomonadaceae Luteimonas
# 5 Deltaproteobacteria Myxococcales          Sandaracinaceae  NA
# 6 Gammaproteobacteria Betaproteobacteriales Burkholderiaceae NA
#   Experiment
# 1 2
# 2 2
# 3 2
# 4 2
# 5 2
# 6 2
#        baseMean  log2FoldChange lfcSE    stat       pvalue    padj OTU
# 490771 0.0000000         NA           NA         NA        NA NA   ASV36849
# 490772 0.0000000         NA           NA         NA        NA NA   ASV36865
# 490773 0.2477641 -0.9202897     3.044699 -0.3022597 0.7624541 NA   ASV36871
# 490774 0.0000000         NA           NA         NA        NA NA   ASV36896
# 490775 0.0000000         NA           NA         NA        NA NA   ASV37791
# 490776 0.0000000         NA           NA         NA        NA NA   ASV38128
#        Subset     Term       Contrast DAI Kingdom  Phylum
# 490771 Lansing-RI SampleType CH_BP    27  Bacteria Patescibacteria
# 490772 Lansing-RI SampleType CH_BP    27  Bacteria Dependentiae
# 490773 Lansing-RI SampleType CH_BP    27  Bacteria Bacteroidetes
# 490774 Lansing-RI SampleType CH_BP    27  Bacteria Acidobacteria
# 490775 Lansing-RI SampleType CH_BP    27  Archaea  Nanoarchaeaeota
# 490776 Lansing-RI SampleType CH_BP    27  Bacteria Patescibacteria
#        Class                       Order                      Family
# 490771 Microgenomatia              Candidatus_Roizmanbacteria NA
# 490772 Babeliae                    Babeliales                 NA
# 490773 Bacteroidia                 Sphingobacteriales         AKYH767
# 490774 Blastocatellia_(Subgroup_4) Blastocatellales           Blastocatellaceae
# 490775 Woesearchaeia               NA                         NA
# 490776 WWE3                        NA                         NA
#        Genus           Experiment
# 490771 NA              2
# 490772 NA              2
# 490773 NA              2
# 490774 JGI_0001001-H03 2
# 490775 NA              2
# 490776 NA              2

# %% [markdown]
# # Experiment 1

# %%
tmp = ps %>% subset_samples(Experiment == 1)

# %%
sample_data(tmp)$DAI %>% unique
# Out:
# [1] 81

# %%
colnames(sample_data(tmp))
# Out:
#  [1] "Sample"              "Experiment"          "Plant"
#  [4] "Fungus"              "Soil"                "SampleType"
#  [7] "Treatment"           "TimePoint"           "DAI"
# [10] "Rep"                 "Concentration_ng.ul" "SoilxFungus"

# %%
#sample_data(tmp)$SoilxFungus = paste(sample_data(tmp)$Soil, sample_data(tmp)$Fungus, sep = '-')
df.l2fc = NULL
Grouplist = c('Lansing-Gv', 'Florence-Gv', 'Pendelton-Gv')
ContrastList = list(c("CH","CS"), c("CH", "RT"), c("RT", "CS")) 

    for (i in Grouplist) {
            print(i)
          for (j in ContrastList) { 
                phy = subset_samples(tmp, SoilxFungus == i & SampleType %in% j)
                diag
                numerator = j[1]
                denom<-j[2]
                print(paste(numerator, denom, sep = "_"))
                #make DESeq object
                diagdds = phyloseq_to_deseq2(phy, ~ Rep + SampleType)
                diagdds = DESeq(diagdds, fitType="local")
#               for (k in (j+1):length(GenoList)) { # k = index of 2nd genotype
#                 geno2<-GenoList[k]
#               #  print(paste0(geno1,".",geno2)) # debugging line to make sure all pairwise comparisons are represented
           # get log2 fold change between this pair of genotypes
              r =  results(diagdds,contrast=c('SampleType',numerator,denom),parallel=TRUE) %>% as.data.frame %>% 
                    mutate(OTU=row.names(.),Subset = i, Term='SampleType',Contrast=paste0(numerator,'_',denom),DAI='81') 
             df.l2fc = rbind(df.l2fc, r)
                     }
          }



df.l2fc.Exp1 = df.l2fc
# #cleanup
diagdds = NULL
df.l2fc = NULL
r = NULL
# Out:
# [1] "Lansing-Gv"
# [1] "CH_CS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "CH_RT"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "RT_CS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "Florence-Gv"
# [1] "CH_CS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "CH_RT"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "RT_CS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "Pendelton-Gv"
# [1] "CH_CS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "CH_RT"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# [1] "RT_CS"
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing

# %%
out = df.l2fc.Exp1  %>% left_join(., taxa, by = c("OTU" = "ASV"))
out$Experiment = 1
head(out)
outfile = file.path(work_dir, 'dfl2fc-Exp1.txt')
# Out:
#   baseMean  log2FoldChange lfcSE     stat      pvalue       padj         OTU
# 1 331.72029 -2.716566      0.5217389 -5.206754 1.921730e-07 1.885675e-05 ASV5
# 2 136.95264  4.977612      1.1905977  4.180767 2.905274e-05 1.192425e-03 ASV6
# 3   0.00000        NA             NA        NA           NA           NA ASV8
# 4   0.00000        NA             NA        NA           NA           NA ASV13
# 5  26.70389  8.430000      1.7857267  4.720767 2.349571e-06 1.478663e-04 ASV14
# 6   0.00000        NA             NA        NA           NA           NA ASV15
#   Subset     Term       Contrast DAI Kingdom  Phylum
# 1 Lansing-Gv SampleType CH_CS    81  Bacteria Actinobacteria
# 2 Lansing-Gv SampleType CH_CS    81  Bacteria Proteobacteria
# 3 Lansing-Gv SampleType CH_CS    81  Bacteria Proteobacteria
# 4 Lansing-Gv SampleType CH_CS    81  Bacteria Proteobacteria
# 5 Lansing-Gv SampleType CH_CS    81  Bacteria Proteobacteria
# 6 Lansing-Gv SampleType CH_CS    81  Bacteria Proteobacteria
#   Class               Order                 Family           Genus
# 1 Actinobacteria      Micrococcales         Micrococcaceae   Pseudarthrobacter
# 2 Gammaproteobacteria Cellvibrionales       Cellvibrionaceae Cellvibrio
# 3 Alphaproteobacteria Caulobacterales       Caulobacteraceae Asticcacaulis
# 4 Gammaproteobacteria Xanthomonadales       Xanthomonadaceae Luteimonas
# 5 Deltaproteobacteria Myxococcales          Sandaracinaceae  NA
# 6 Gammaproteobacteria Betaproteobacteriales Burkholderiaceae NA
#   Experiment
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 1

# %%
write.table(out, file = outfile, row.names = FALSE, sep = '\t')

# %% [markdown]
# # Experiment 3 sample type

# %%
tmp = ps %>% subset_samples(Experiment == 3)
sample_data(tmp)$DAI %>% unique
sample_data(tmp)$SampleType %>% unique()
colnames(sample_data(tmp))
# Out:
# [1] 14 65 24 35 45 NA
#  [1] RH BP CS BS RT CH T0 EB GV MK
# Levels: BP BS CH CS EB GV MK RH RT T0
#  [1] "Sample"              "Experiment"          "Plant"
#  [4] "Fungus"              "Soil"                "SampleType"
#  [7] "Treatment"           "TimePoint"           "DAI"
# [10] "Rep"                 "Concentration_ng.ul"

# %%
sample_data(tmp)$SoilxFungus = paste(sample_data(tmp)$Soil, sample_data(tmp)$Fungus, sep = '-')
sample_data(tmp)$Rep = factor(sample_data(tmp)$Rep)
sample_data(tmp)$DAI = factor(sample_data(tmp)$DAI)
df.l2fc = NULL

Grouplist = c('Lansing-Gv')

# Date 65 does not have root hyphae samples, so run in separate loop
DateList = c(14, 24, 35, 45)
# Contrasts for first for sampling dates
ContrastList = list(c("CH","CS"), c("CH", "BS"), c("CH", "BP"), c("RH", "RT"), c("RH","CS"), c("BP", "CS"), c("BP", "BS")) 


    for (i in Grouplist) {
            print(i)
        for (k in DateList) {
                print(k)
          for (j in ContrastList) { 
              print(j)
                phy = subset_samples(tmp, SoilxFungus == i & SampleType %in% j & DAI == k)
                diag
                numerator = j[1]
                denom<-j[2]
                print(paste(numerator, denom, sep = "_"))
                #make DESeq object
                diagdds = phyloseq_to_deseq2(phy, ~ Rep + SampleType)
                diagdds = DESeq(diagdds, fitType="local", parallel = TRUE)
#               for (k in (j+1):length(GenoList)) { # k = index of 2nd genotype
#                 geno2<-GenoList[k]
#               #  print(paste0(geno1,".",geno2)) # debugging line to make sure all pairwise comparisons are represented
           # get log2 fold change between this pair of genotypes
              r =  results(diagdds,contrast=c('SampleType',numerator,denom),parallel=TRUE) %>% as.data.frame %>% 
                    mutate(OTU=row.names(.),Subset = i, Term='SampleType',Contrast=paste0(numerator,'_',denom),DAI=k) 
             df.l2fc = rbind(df.l2fc, r)
                     }
            }
          }



# Date 65 does not have root hyphae samples, so run in separate loop
DateList = 65
# Contrast list for day 65
ContrastList = list(c("CH","CS"), c("CH", "BS"), c("CH", "BP"), c("BP", "CS"), c("BP", "BS")) 

    for (i in Grouplist) {
            print(i)
        for (k in DateList) {
                print(k)
          for (j in ContrastList) { 
              print(j)
                phy = subset_samples(tmp, SoilxFungus == i & SampleType %in% j & DAI == k)
                numerator = j[1]
                denom<-j[2]
                print(paste(numerator, denom, sep = "_"))
                #make DESeq object
                diagdds = phyloseq_to_deseq2(phy, ~ Rep + SampleType)
                diagdds = DESeq(diagdds, fitType="local", parallel = TRUE)
#               for (k in (j+1):length(GenoList)) { # k = index of 2nd genotype
#                 geno2<-GenoList[k]
#               #  print(paste0(geno1,".",geno2)) # debugging line to make sure all pairwise comparisons are represented
           # get log2 fold change between this pair of genotypes
              r =  results(diagdds,contrast=c('SampleType',numerator,denom),parallel=TRUE) %>% as.data.frame %>% 
                    mutate(OTU=row.names(.),Subset = i, Term='SampleType',Contrast=paste0(numerator,'_',denom),DAI=k) 
             df.l2fc = rbind(df.l2fc, r)
                     }
            }
          }

df.l2fc.Exp3 = df.l2fc
# #cleanup
diagdds = NULL
df.l2fc = NULL
r = NULL
# Out:
# [1] "Lansing-Gv"
# [1] 14
# [1] "CH" "CS"
# [1] "CH_CS"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "CH" "BS"
# [1] "CH_BS"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "CH" "BP"
# [1] "CH_BP"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "RH" "RT"
# [1] "RH_RT"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "RH" "CS"
# [1] "RH_CS"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "BP" "CS"
# [1] "BP_CS"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "BP" "BS"
# [1] "BP_BS"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] 24
# [1] "CH" "CS"
# [1] "CH_CS"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "CH" "BS"
# [1] "CH_BS"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "CH" "BP"
# [1] "CH_BP"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "RH" "RT"
# [1] "RH_RT"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "RH" "CS"
# [1] "RH_CS"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "BP" "CS"
# [1] "BP_CS"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "BP" "BS"
# [1] "BP_BS"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] 35
# [1] "CH" "CS"
# [1] "CH_CS"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "CH" "BS"
# [1] "CH_BS"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "CH" "BP"
# [1] "CH_BP"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "RH" "RT"
# [1] "RH_RT"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "RH" "CS"
# [1] "RH_CS"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "BP" "CS"
# [1] "BP_CS"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers

# %%
out = df.l2fc.Exp3  %>% left_join(., taxa, by = c("OTU" = "ASV"))
out$Experiment = 3
head(out)
outfile = file.path(work_dir, 'dfl2fc-Exp3.txt')

# %%
write.table(out, file = outfile, row.names = FALSE, sep = '\t')

# %% [markdown]
# # Experiment 3 time

# %%
tmp = ps %>% subset_samples(Experiment == 3)
sample_data(tmp)$DAI %>% unique
sample_data(tmp)$SampleType %>% unique()
colnames(sample_data(tmp))
# Out:
# [1] 14 65 24 35 45 NA
#  [1] RH BP CS BS RT CH T0 EB GV MK
# Levels: BP BS CH CS EB GV MK RH RT T0
#  [1] "Sample"              "Experiment"          "Plant"
#  [4] "Fungus"              "Soil"                "SampleType"
#  [7] "Treatment"           "TimePoint"           "DAI"
# [10] "Rep"                 "Concentration_ng.ul"

# %%
sample_data(tmp)$SoilxFungus = paste(sample_data(tmp)$Soil, sample_data(tmp)$Fungus, sep = '-')
sample_data(tmp)$Rep = factor(sample_data(tmp)$Rep)
sample_data(tmp)$DAI = factor(sample_data(tmp)$DAI)
df.l2fc = NULL

Grouplist = c("BS", "CS", "RH", "CH", "BP")

# Date 65 does not have root hyphae samples, so run in separate loop
#DateList = c(14, 24, 35, 45)
# Contrasts for first for sampling dates
ContrastList = list(c("24","14"), c("35","14"), c("45","14"), c("65","14")) 


    for (i in Grouplist) {
            print(i)
          for (j in ContrastList) { 
              print(j)
    phy = subset_samples(tmp, SampleType == i & DAI %in% j )
                numerator = j[1]
                denom<-j[2]
                print(paste(numerator, denom, sep = "_"))
                #make DESeq object
                diagdds = phyloseq_to_deseq2(phy, ~ Rep + DAI)
                diagdds = DESeq(diagdds, fitType="local", parallel = TRUE)
#               for (k in (j+1):length(GenoList)) { # k = index of 2nd genotype
#                 geno2<-GenoList[k]
#               #  print(paste0(geno1,".",geno2)) # debugging line to make sure all pairwise comparisons are represented
           # get log2 fold change between this pair of genotypes
              r =  results(diagdds,contrast=c('DAI',numerator,denom),parallel=TRUE) %>% as.data.frame %>% 
                    mutate(OTU=row.names(.),Subset = "Lansing-Gv", SampleType = i, Term='TimePoint',Contrast=paste0(numerator,'_',denom)) 
             df.l2fc = rbind(df.l2fc, r)
            }
         } 




df.l2fc.Exp3.time = df.l2fc
# #cleanup
diagdds = NULL
df.l2fc = NULL
r = NULL
# Out:
# [1] "BS"
# [1] "24" "14"
# [1] "24_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "35" "14"
# [1] "35_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "45" "14"
# [1] "45_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "65" "14"
# [1] "65_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "CS"
# [1] "24" "14"
# [1] "24_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "35" "14"
# [1] "35_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "45" "14"
# [1] "45_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "65" "14"
# [1] "65_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "RH"
# [1] "24" "14"
# [1] "24_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "35" "14"
# [1] "35_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "45" "14"
# [1] "45_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "65" "14"
# [1] "65_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "CH"
# [1] "24" "14"
# [1] "24_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "35" "14"
# [1] "35_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "45" "14"
# [1] "45_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "65" "14"
# [1] "65_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "BP"
# [1] "24" "14"
# [1] "24_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "35" "14"
# [1] "35_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "45" "14"
# [1] "45_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers
# [1] "65" "14"
# [1] "65_14"
# converting counts to integer mode
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates: 20 workers
# mean-dispersion relationship
# final dispersion estimates, fitting model and testing: 20 workers

# %%
out = df.l2fc.Exp3.time  %>% left_join(., taxa, by = c("OTU" = "ASV"))
out$Experiment = 3
head(out)
outfile = file.path(work_dir, 'dfl2fc-Exp3-time.txt')

# %%
write.table(out, file = outfile, row.names = FALSE, sep = '\t')

# %% [markdown]
# # Checkpoint
# read back in log2foldchange files

# %%
readfile = file.path(work_dir, 'dfl2fc-Exp1.txt')
df.l2fc.Exp1 = read.table(readfile, header = TRUE, sep= '\t')

readfile = file.path(work_dir, 'dfl2fc-Exp2.txt')
df.l2fc.Exp2 = read.table(readfile, header = TRUE, sep= '\t')

readfile = file.path(work_dir, 'dfl2fc-Exp3.txt')
df.l2fc.Exp3 = read.table(readfile, header = TRUE, sep= '\t')

readfile = file.path(work_dir, 'dfl2fc-Exp3-time.txt')
df.l2fc.Exp3.time = read.table(readfile, header = TRUE, sep= '\t')

head(df.l2fc.Exp1)
# Out:
#   baseMean  log2FoldChange lfcSE     stat      pvalue       padj         OTU
# 1 331.72029 -2.716566      0.5217389 -5.206754 1.921730e-07 1.885675e-05 ASV5
# 2 136.95264  4.977612      1.1905977  4.180767 2.905274e-05 1.192425e-03 ASV6
# 3   0.00000        NA             NA        NA           NA           NA ASV8
# 4   0.00000        NA             NA        NA           NA           NA ASV13
# 5  26.70389  8.430000      1.7857267  4.720767 2.349571e-06 1.478663e-04 ASV14
# 6   0.00000        NA             NA        NA           NA           NA ASV15
#   Subset     Term       Contrast DAI Kingdom  Phylum
# 1 Lansing-Gv SampleType CH_CS    81  Bacteria Actinobacteria
# 2 Lansing-Gv SampleType CH_CS    81  Bacteria Proteobacteria
# 3 Lansing-Gv SampleType CH_CS    81  Bacteria Proteobacteria
# 4 Lansing-Gv SampleType CH_CS    81  Bacteria Proteobacteria
# 5 Lansing-Gv SampleType CH_CS    81  Bacteria Proteobacteria
# 6 Lansing-Gv SampleType CH_CS    81  Bacteria Proteobacteria
#   Class               Order                 Family           Genus
# 1 Actinobacteria      Micrococcales         Micrococcaceae   Pseudarthrobacter
# 2 Gammaproteobacteria Cellvibrionales       Cellvibrionaceae Cellvibrio
# 3 Alphaproteobacteria Caulobacterales       Caulobacteraceae Asticcacaulis
# 4 Gammaproteobacteria Xanthomonadales       Xanthomonadaceae Luteimonas
# 5 Deltaproteobacteria Myxococcales          Sandaracinaceae  NA
# 6 Gammaproteobacteria Betaproteobacteriales Burkholderiaceae NA
#   Experiment
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 1

# %%
df.l2fc.Exp1$Contrast %>% levels()
df.l2fc.Exp1$Subset %>% levels()

df.l2fc.Exp2$Contrast %>% levels()
df.l2fc.Exp2$Subset %>% levels()
# Out:
# [1] "CH_CS" "CH_RT" "RT_CS"
# [1] "Florence-Gv"  "Lansing-Gv"   "Pendelton-Gv"
# [1] "BH_BS" "BP_BS" "BP_CS" "CH_BP" "CH_BS" "CH_CS" "RH_RS"
# [1] "Florence-Gv"  "Lansing-Gv"   "Lansing-RI"   "Pendelton-Gv"

# %% [markdown]
# ## Identify how many ASVs are enriched in multiple soils

# %%
tmp = df.l2fc.Exp1 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0) %>%
    group_by(OTU) %>%
    summarize(nSig = length(padj)) %>%
    group_by(nSig) %>%
    summarize(nGroup = length(OTU))
head(tmp)
range(tmp$nSig)
# Out:
#   nSig nGroup
# 1 1    85
# 2 2    13
# 3 3     3
# [1] 1 3

# %%
tmp = df.l2fc.Exp1 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0) %>%
    group_by(OTU, Phylum, Class, Order, Family, Genus) %>%
    summarize(nSig = length(padj)) %>%
    filter(nSig > 1)
tmp
# Out:
#    OTU     Phylum         Class
# 1  ASV14   Proteobacteria Deltaproteobacteria
# 2  ASV148  Proteobacteria Gammaproteobacteria
# 3  ASV17   Proteobacteria Gammaproteobacteria
# 4  ASV18   Proteobacteria Deltaproteobacteria
# 5  ASV1847 Fibrobacteres  Fibrobacteria
# 6  ASV247  Proteobacteria Gammaproteobacteria
# 7  ASV3052 Fibrobacteres  Fibrobacteria
# 8  ASV383  Proteobacteria Deltaproteobacteria
# 9  ASV47   Fibrobacteres  Fibrobacteria
# 10 ASV509  Proteobacteria Deltaproteobacteria
# 11 ASV6    Proteobacteria Gammaproteobacteria
# 12 ASV61   Proteobacteria Gammaproteobacteria
# 13 ASV66   Proteobacteria Deltaproteobacteria
# 14 ASV718  Proteobacteria Deltaproteobacteria
# 15 ASV77   Proteobacteria Gammaproteobacteria
# 16 ASV95   Proteobacteria Deltaproteobacteria
#    Order                              Family           Genus             nSig
# 1  Myxococcales                       Sandaracinaceae  NA                3
# 2  Betaproteobacteriales              Burkholderiaceae Ideonella         2
# 3  Betaproteobacteriales              Burkholderiaceae Paucibacter       2
# 4  Myxococcales                       Sandaracinaceae  NA                3
# 5  Fibrobacterales                    Fibrobacteraceae NA                2
# 6  Betaproteobacteriales              Burkholderiaceae Limnohabitans     2
# 7  Fibrobacterales                    Fibrobacteraceae NA                2
# 8  Myxococcales                       Haliangiaceae    Haliangium        2
# 9  Fibrobacterales                    Fibrobacteraceae possible_genus_04 2
# 10 Myxococcales                       Haliangiaceae    Haliangium        2
# 11 Cellvibrionales                    Cellvibrionaceae Cellvibrio        2
# 12 Betaproteobacteriales              Burkholderiaceae NA                2
# 13 Myxococcales                       Haliangiaceae    Haliangium        3
# 14 Myxococcales                       Sandaracinaceae  NA                2
# 15 Gammaproteobacteria_Incertae_Sedis Unknown_Family   Acidibacter       2
# 16 Myxococcales                       Haliangiaceae    Haliangium        2

# %%
tmp = df.l2fc.Exp2 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset != "Lansing-RI") %>%
    group_by(OTU) %>%
    summarize(nSig = length(padj)) %>%
    group_by(nSig) %>%
    summarize(nGroup = length(OTU))
head(tmp)
range(tmp$nSig)
# Out:
#   nSig nGroup
# 1 1    208
# 2 2     11
# 3 3      2
# [1] 1 3

# %%
tmp = df.l2fc.Exp2 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset != "Lansing-RI") %>%
    group_by(OTU, Phylum, Class, Order, Family, Genus) %>%
    summarize(nSig = length(padj)) %>%
    filter(nSig > 1)
tmp
range(tmp)
# Out:
#    OTU     Phylum         Class               Order
# 1  ASV125  Proteobacteria Deltaproteobacteria Myxococcales
# 2  ASV14   Proteobacteria Deltaproteobacteria Myxococcales
# 3  ASV16   Proteobacteria Alphaproteobacteria Rhizobiales
# 4  ASV1700 Proteobacteria Deltaproteobacteria Myxococcales
# 5  ASV18   Proteobacteria Deltaproteobacteria Myxococcales
# 6  ASV190  Chloroflexi    Chloroflexia        Chloroflexales
# 7  ASV23   Fibrobacteres  Fibrobacteria       Fibrobacterales
# 8  ASV30   Proteobacteria Alphaproteobacteria Rhizobiales
# 9  ASV57   Proteobacteria Gammaproteobacteria Betaproteobacteriales
# 10 ASV6    Proteobacteria Gammaproteobacteria Cellvibrionales
# 11 ASV66   Proteobacteria Deltaproteobacteria Myxococcales
# 12 ASV708  Proteobacteria Deltaproteobacteria Myxococcales
# 13 ASV8    Proteobacteria Alphaproteobacteria Caulobacterales
#    Family             Genus                                              nSig
# 1  Sandaracinaceae    NA                                                 2
# 2  Sandaracinaceae    NA                                                 3
# 3  Xanthobacteraceae  Bradyrhizobium                                     2
# 4  BIrii41            NA                                                 2
# 5  Sandaracinaceae    NA                                                 3
# 6  Herpetosiphonaceae Herpetosiphon                                      2
# 7  Fibrobacteraceae   possible_genus_04                                  2
# 8  Rhizobiaceae       Allorhizobium-Neorhizobium-Pararhizobium-Rhizobium 2
# 9  Burkholderiaceae   NA                                                 2
# 10 Cellvibrionaceae   Cellvibrio                                         2
# 11 Haliangiaceae      Haliangium                                         2
# 12 Haliangiaceae      Haliangium                                         2
# 13 Caulobacteraceae   Asticcacaulis                                      2

# %% [markdown]
# ## Number of ASVs enriched in any soil, either experiment

# %%
HA.exp1 = df.l2fc.Exp1 %>%
  filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset != "Lansing-RI") %>%
    .$OTU %>%
    unique() 

HA.exp1 %>%
    length() %>%
    paste(., "ASVs enriched in hyphal samples in any soil in experiment 1")

HA.exp2 = df.l2fc.Exp2 %>%
  filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset != "Lansing-RI") %>%
    .$OTU %>%
    unique() 

HA.exp2 %>%
    length() %>%
    paste(., "ASVs enriched in hyphal samples in any soil in experiment 2")

append(HA.exp1, HA.exp2) %>% unique() %>% length() %>%
    paste(., "ASVs enriched in hyphal samples in a particular soil in at least one of the two experiments")
# Out:
# [1] "101 ASVs enriched in hyphal samples in any soil in experiment 1"
# [1] "221 ASVs enriched in hyphal samples in any soil in experiment 2"
# [1] "298 ASVs enriched in hyphal samples in a particular soil in at least one of the two experiments"

# %% [markdown]
# ## Which ASVs are shared between Ri And Gv

# %%
df.l2fc.Exp2 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset %in% c("Lansing-RI")) %>%
    .$OTU %>%
    unique() %>%
    length() %>%
    paste(., "ASVs enriched in Ri hyphal samples")

df.l2fc.Exp2 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset %in% c("Lansing-Gv")) %>%
    .$OTU %>%
    unique() %>%
    length() %>%
    paste(., "ASVs enriched in Gv hyphal samples")

tmp = df.l2fc.Exp2 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset %in% c("Lansing-RI", 
                                                                                 "Lansing-Gv")) %>%
    group_by(OTU, Phylum, Class, Order, Family, Genus) %>%
    summarize(nSig = length(padj)) %>%
    filter(nSig > 1)
           
paste(dim(tmp)[1], 'ASVs enriched in both Ri and Gv', sep = '')
# Out:
# [1] "236 ASVs enriched in Ri hyphal samples"
# [1] "88 ASVs enriched in Gv hyphal samples"
# [1] "38ASVs enriched in both Ri and Gv"

# %% [markdown]
# ## Which ASVs are enriched in both experiments in the same soil

# %%
# Get lists of experiment 1 and three lists of experiment 2, see which match
HA1.Lansing = df.l2fc.Exp1 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset == "Lansing-Gv")
HA2.Lansing = df.l2fc.Exp2 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset == "Lansing-Gv")

ConsistentLansingASVs = inner_join(HA1.Lansing, HA2.Lansing, by = "OTU")
ConsistentLansingASVs
# Out:
#    baseMean.x log2FoldChange.x lfcSE.x  stat.x   pvalue.x     padj.x
# 1  136.95264   4.977612        1.190598 4.180767 2.905274e-05 1.192425e-03
# 2   26.70389   8.430000        1.785727 4.720767 2.349571e-06 1.478663e-04
# 3  159.58144  11.082384        1.362924 8.131328 4.246114e-16 2.004166e-13
# 4   70.80453   8.223574        2.360521 3.483796 4.943559e-04 8.484944e-03
# 5   97.21443   2.890655        0.773702 3.736134 1.868708e-04 4.302586e-03
# 6   36.28464   4.431347        1.337195 3.313913 9.200005e-04 1.149737e-02
# 7   53.23993   9.229180        2.006168 4.600402 4.216764e-06 2.487891e-04
# 8   41.01157   7.246386        2.361361 3.068732 2.149691e-03 2.070723e-02
# 9  113.38638   8.225041        1.827274 4.501263 6.755095e-06 3.751064e-04
# 10  11.05237   7.191267        2.125415 3.383465 7.157740e-04 1.008493e-02
#    OTU    Subset.x   Term.x     Contrast.x ⋯ Term.y     Contrast.y DAI.y
# 1  ASV6   Lansing-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
# 2  ASV14  Lansing-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
# 3  ASV18  Lansing-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
# 4  ASV23  Lansing-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
# 5  ASV47  Lansing-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
# 6  ASV61  Lansing-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
# 7  ASV66  Lansing-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
# 8  ASV77  Lansing-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
# 9  ASV509 Lansing-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
# 10 ASV708 Lansing-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
#    Kingdom.y Phylum.y       Class.y
# 1  Bacteria  Proteobacteria Gammaproteobacteria
# 2  Bacteria  Proteobacteria Deltaproteobacteria
# 3  Bacteria  Proteobacteria Deltaproteobacteria
# 4  Bacteria  Fibrobacteres  Fibrobacteria
# 5  Bacteria  Fibrobacteres  Fibrobacteria
# 6  Bacteria  Proteobacteria Gammaproteobacteria
# 7  Bacteria  Proteobacteria Deltaproteobacteria
# 8  Bacteria  Proteobacteria Gammaproteobacteria
# 9  Bacteria  Proteobacteria Deltaproteobacteria
# 10 Bacteria  Proteobacteria Deltaproteobacteria
#    Order.y                            Family.y         Genus.y
# 1  Cellvibrionales                    Cellvibrionaceae Cellvibrio
# 2  Myxococcales                       Sandaracinaceae  NA
# 3  Myxococcales                       Sandaracinaceae  NA
# 4  Fibrobacterales                    Fibrobacteraceae possible_genus_04
# 5  Fibrobacterales                    Fibrobacteraceae possible_genus_04
# 6  Betaproteobacteriales              Burkholderiaceae NA
# 7  Myxococcales                       Haliangiaceae    Haliangium
# 8  Gammaproteobacteria_Incertae_Sedis Unknown_Family   Acidibacter
# 9  Myxococcales                       Haliangiaceae    Haliangium
# 10 Myxococcales                       Haliangiaceae    Haliangium
#    Experiment.y
# 1  2
# 2  2
# 3  2
# 4  2
# 5  2
# 6  2
# 7  2
# 8  2
# 9  2
# 10 2

# %%
# Get lists of experiment 1 and three lists of experiment 2, see which match
HA1.Florence = df.l2fc.Exp1 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset == "Florence-Gv")
HA2.Florence = df.l2fc.Exp2 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset == "Florence-Gv")

ConsistentFlorenceASVs  = inner_join(HA1.Florence, HA2.Florence, by = "OTU")
ConsistentFlorenceASVs
# Out:
#   baseMean.x log2FoldChange.x lfcSE.x  stat.x   pvalue.x     padj.x
# 1 112.59177  5.606874         1.445703 3.878302 1.051880e-04 0.0045087431
# 2  27.26155  7.877057         2.215345 3.555680 3.770032e-04 0.0113949114
# 3  70.48888  9.215780         2.005356 4.595582 4.315422e-06 0.0003463126
# 4 104.95389  8.419238         2.651464 3.175317 1.496729e-03 0.0320300102
# 5  61.26840  7.838941         2.527283 3.101727 1.923954e-03 0.0385993296
# 6  34.00978  8.514978         1.743000 4.885243 1.033013e-06 0.0001105324
#   OTU    Subset.x    Term.x     Contrast.x ⋯ Term.y     Contrast.y DAI.y
# 1 ASV14  Florence-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
# 2 ASV18  Florence-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
# 3 ASV118 Florence-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
# 4 ASV143 Florence-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
# 5 ASV341 Florence-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
# 6 ASV528 Florence-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
#   Kingdom.y Phylum.y       Class.y             Order.y
# 1 Bacteria  Proteobacteria Deltaproteobacteria Myxococcales
# 2 Bacteria  Proteobacteria Deltaproteobacteria Myxococcales
# 3 Bacteria  Proteobacteria Gammaproteobacteria Betaproteobacteriales
# 4 Bacteria  Proteobacteria Gammaproteobacteria Betaproteobacteriales
# 5 Bacteria  Proteobacteria Gammaproteobacteria Betaproteobacteriales
# 6 Bacteria  Proteobacteria Deltaproteobacteria Oligoflexales
#   Family.y         Genus.y            Experiment.y
# 1 Sandaracinaceae  NA                 2
# 2 Sandaracinaceae  NA                 2
# 3 Burkholderiaceae Noviherbaspirillum 2
# 4 Burkholderiaceae NA                 2
# 5 Burkholderiaceae Azohydromonas      2
# 6 0319-6G20        NA                 2

# %%
# Get lists of experiment 1 and three lists of experiment 2, see which match
HA1.Pendelton = df.l2fc.Exp1 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset == "Pendelton-Gv")
HA2.Pendelton = df.l2fc.Exp2 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset == "Pendelton-Gv")

ConsistentPendeltonASVs = inner_join(HA1.Pendelton, HA2.Pendelton, by = "OTU")

ConsistentPendeltonASVs
# Out:
#   baseMean.x log2FoldChange.x lfcSE.x   stat.x   pvalue.x     padj.x
# 1  72.29974  3.921081         0.8914609 4.398489 1.090074e-05 1.978903e-04
# 2 242.22552  6.014579         0.6040114 9.957724 2.333428e-23 1.101378e-20
# 3 232.77291  4.922357         0.5099702 9.652245 4.809100e-22 1.513263e-19
# 4  11.52715  7.077820         2.0168512 3.509342 4.492170e-04 3.339062e-03
#   OTU   Subset.x     Term.x     Contrast.x ⋯ Term.y     Contrast.y DAI.y
# 1 ASV6  Pendelton-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
# 2 ASV14 Pendelton-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
# 3 ASV18 Pendelton-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
# 4 ASV66 Pendelton-Gv SampleType CH_CS      ⋯ SampleType CH_CS      27
#   Kingdom.y Phylum.y       Class.y             Order.y         Family.y
# 1 Bacteria  Proteobacteria Gammaproteobacteria Cellvibrionales Cellvibrionaceae
# 2 Bacteria  Proteobacteria Deltaproteobacteria Myxococcales    Sandaracinaceae
# 3 Bacteria  Proteobacteria Deltaproteobacteria Myxococcales    Sandaracinaceae
# 4 Bacteria  Proteobacteria Deltaproteobacteria Myxococcales    Haliangiaceae
#   Genus.y    Experiment.y
# 1 Cellvibrio 2
# 2 NA         2
# 3 NA         2
# 4 Haliangium 2

# %%
SuperConsistentASVs = inner_join(ConsistentLansingASVs, ConsistentFlorenceASVs, by = "OTU") %>% 
        select(OTU, Phylum.x.x, Class.x.x, Order.x.x, Family.x.x, Genus.x.x) %>%
        inner_join(., ConsistentPendeltonASVs, by = "OTU") %>% 
        select(OTU, Phylum.x.x, Class.x.x, Order.x.x, Family.x.x, Genus.x.x)
SuperConsistentASVs
# Out:
#   OTU   Phylum.x.x     Class.x.x           Order.x.x    Family.x.x
# 1 ASV14 Proteobacteria Deltaproteobacteria Myxococcales Sandaracinaceae
# 2 ASV18 Proteobacteria Deltaproteobacteria Myxococcales Sandaracinaceae
#   Genus.x.x
# 1 NA
# 2 NA

# %% [markdown]
# # Compare consistently enriched ASVs with spore community

# %%
#Read in phyloseq object and subset to just GV spores
ps.spore = readRDS(physeq_file) %>% subset_taxa(., !is.na(Phylum)) %>%
    # remove non-experimental controls
    
    subset_samples(., SampleType == "GV") %>%
    filter_taxa(., function(x) max(x) > 0, TRUE)
    # T0R1 has all NaN for some reason
    #subset_samples(!Sample == "T0R1") #%>%
     # re-normalize after subsetting taxa
    #transform_sample_counts(., function(x) x/sum(x))
sample_data(ps.spore)$Rep = as.factor(sample_data(ps.spore)$Rep)

ps.spore
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 298 taxa and 1 samples ]
# sample_data() Sample Data:       [ 1 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 298 taxa by 6 taxonomic ranks ]

# %%
#Join counts from spore sample with table of OTUs occuring in each soil
TS.spore = taxa_sums(ps.spore) %>% as.data.frame()
colnames(TS.spore) = "Counts"
TS.spore$OTU = row.names(TS.spore)
arrange(TS.spore, desc(Counts))
#sample_sums(ps.spore)
# Out:
#     Counts OTU
# 1   76     ASV34
# 2   61     ASV58
# 3   56     ASV109
# 4   51     ASV148
# 5   49     ASV77
# 6   45     ASV68
# 7   38     ASV381
# 8   36     ASV8
# 9   34     ASV55
# 10  33     ASV235
# 11  32     ASV28
# 12  30     ASV828
# 13  29     ASV149
# 14  28     ASV24
# 15  28     ASV80
# 16  28     ASV219
# 17  28     ASV273
# 18  28     ASV1621
# 19  27     ASV323
# 20  27     ASV1636
# 21  26     ASV230
# 22  26     ASV5189
# 23  25     ASV5
# 24  25     ASV16
# 25  25     ASV249
# 26  25     ASV472
# 27  24     ASV71
# 28  24     ASV92
# 29  24     ASV234
# 30  24     ASV265
# ⋮   ⋮      ⋮
# 269 5      ASV5119
# 270 5      ASV8938
# 271 5      ASV11097
# 272 5      ASV12833
# 273 5      ASV13520
# 274 5      ASV15902
# 275 5      ASV22044
# 276 4      ASV43
# 277 4      ASV130
# 278 4      ASV327
# 279 4      ASV1061
# 280 4      ASV1702
# 281 4      ASV1986
# 282 4      ASV2407
# 283 4      ASV3072
# 284 4      ASV3423
# 285 4      ASV3971
# 286 4      ASV4414
# 287 4      ASV5186
# 288 4      ASV9694
# 289 4      ASV9996
# 290 4      ASV10808
# 291 4      ASV13946
# 292 3      ASV1648
# 293 3      ASV6297
# 294 3      ASV8282
# 295 2      ASV5375
# 296 2      ASV8189
# 297 2      ASV8439
# 298 1      ASV1999

# %%
inner_join(SuperConsistentASVs, TS.spore, by = "OTU")
# Out:
# Warning message:
# “Column `OTU` joining factor and character vector, coercing into character vector”
#   OTU   Phylum.x.x     Class.x.x           Order.x.x    Family.x.x
# 1 ASV18 Proteobacteria Deltaproteobacteria Myxococcales Sandaracinaceae
#   Genus.x.x Counts
# 1 NA        12

# %% [markdown]
# ## Review ASV found enriched in both experiments in all soils for signature of contamination
# * Sandaracinaceae ASV14 and ASV18 is enriched in all soils in all experiments and is present on spores

# %%
physeq_file = "~/Hyphosphere/data/3Exp/phyloseq/3Exp_phyloseq_thresh_woTree_woContam.rds"

ps = readRDS(physeq_file) %>% subset_taxa(., !is.na(Phylum))
    
    # T0R1 has all NaN for some reason
    #subset_samples(!Sample == "T0R1") #%>%
     # re-normalize after subsetting taxa
    #transform_sample_counts(., function(x) x/sum(x))
sample_data(ps)$Rep = as.factor(sample_data(ps)$Rep)

ps
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 15128 taxa and 429 samples ]
# sample_data() Sample Data:       [ 429 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 15128 taxa by 6 taxonomic ranks ]

# %%
ps %>% 
    subset_samples(SampleType == "T0") %>%
    transform_sample_counts(., function(x) x/sum(x)) %>%
   prune_taxa(c('ASV14', "ASV18"), .) %>%
   otu_table()
# Out:
#          ASV14        ASV18
# 147_T0R1          NaN          NaN
# 148_T0R2 0.0000000000 0.0000000000
# 149_T0R3 0.0003185347 0.0000000000
# 150_T0R4 0.0000000000 0.0001932527
# 153_T0R5 0.0000000000 0.0000000000
# 154_T0R6 0.0000000000 0.0003554081

# %%
ps %>% 
    subset_samples(Experiment == 2 & SampleType %in% c("BS", "BH", "CH", "CS", "RH", "RS") & Fungus == "Gv") %>%
    transform_sample_counts(., function(x) x/sum(x)) %>%
   prune_taxa("ASV18",.)  %>%
    psmelt() %>%
    mutate(AbundScale = log2(Abundance + .000001)) %>% 
    ggplot(., aes(x = SampleType, y= AbundScale)) +
    geom_boxplot()+
    geom_point()+
    facet_grid(Soil~SampleType, scales = 'free_x')+
    #ggtitle(as.character(cTax))+
    ylab('Relative abundance (log2)')
# Out:
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”
# plot without title

# %% [markdown]
# * ASV18 is detected in Bulk hyphal samples that are not otherwise low biomass and prone to contamination.  In contrast it is absent from all bulk soil samples without the hyphal influence.  Suggests clear hyphal signal.  Also less abundant in the root compartment slurry samples which had the lowest DNA yields of any sampletype

# %%
ps %>% 
    subset_samples(Experiment == 2 & SampleType %in% c("BS", "BH", "CH", "CS", "RH", "RS") & Fungus == "RI") %>%
    transform_sample_counts(., function(x) x/sum(x)) %>%
   prune_taxa("ASV18",.)  %>%
    psmelt() %>%
    mutate(AbundScale = log2(Abundance + .000001)) %>% 
    ggplot(., aes(x = SampleType, y= AbundScale)) +
    geom_point()+
    geom_boxplot()+
    facet_grid(Soil~SampleType, scales = 'free_x')+
    #ggtitle(as.character(cTax))+
    ylab('Relative abundance (log2)')
# Out:
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”
# plot without title

# %% [markdown]
# * Ri would not have carried ASV14 or ASV18 in on spores.  Suggesting that it may also have come from the soil or at least cross contamination in the experiment.  Root slurry is still lower than root hyphae.  RH had higher DNA yields, so this is not consistent with contamination.

# %% [markdown]
# # Which ASVs are time specific

# %%
df.l2fc.Exp3 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset == "Lansing-Gv") %>%
        .$OTU %>%
        unique() %>%
        length() %>%
paste(., "ASVs enriched in at least one timepoint")

df.l2fc.Exp3 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset == "Lansing-Gv") %>%
     group_by(OTU, Phylum, Class, Order, Family, Genus) %>%
     summarize(nSig = length(padj)) %>%
     filter(nSig > 1) %>%
     .$OTU %>%
        unique() %>%
        length() %>%
paste(.,'ASVs enriched in more than one time point')

df.l2fc.Exp3 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset == "Lansing-Gv") %>%
     group_by(OTU, Phylum, Class, Order, Family, Genus) %>%
     summarize(nSig = length(padj)) %>%
     filter(nSig > 2) %>%
     .$OTU %>%
        unique() %>%
        length() %>%
paste(.,'ASVs enriched in more than two time points')

df.l2fc.Exp3 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset == "Lansing-Gv") %>%
     group_by(OTU, Phylum, Class, Order, Family, Genus) %>%
     summarize(nSig = length(padj)) %>%
     filter(nSig > 3) %>%
     .$OTU %>%
        unique() %>%
        length() %>%
paste(.,'ASVs enriched in more than three time points')

tmp = df.l2fc.Exp3 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset == "Lansing-Gv") %>%
     group_by(OTU, Phylum, Class, Order, Family, Genus) %>%
     summarize(nSig = length(padj)) %>%
     filter(nSig > 4)

tmp %>%
     .$OTU %>%
        unique() %>%
        length() %>%
paste(.,'ASVs enriched in more than four time points')

tmp
# Out:
# [1] "105 ASVs enriched in at least one timepoint"
# [1] "34 ASVs enriched in more than one time point"
# [1] "15 ASVs enriched in more than two time points"
# [1] "6 ASVs enriched in more than three time points"
# [1] "6 ASVs enriched in more than four time points"
#   OTU    Phylum         Class               Order        Family
# 1 ASV14  Proteobacteria Deltaproteobacteria Myxococcales Sandaracinaceae
# 2 ASV18  Proteobacteria Deltaproteobacteria Myxococcales Sandaracinaceae
# 3 ASV382 Proteobacteria Deltaproteobacteria Myxococcales Haliangiaceae
# 4 ASV509 Proteobacteria Deltaproteobacteria Myxococcales Haliangiaceae
# 5 ASV66  Proteobacteria Deltaproteobacteria Myxococcales Haliangiaceae
# 6 ASV708 Proteobacteria Deltaproteobacteria Myxococcales Haliangiaceae
#   Genus      nSig
# 1 NA         5
# 2 NA         5
# 3 Haliangium 5
# 4 Haliangium 5
# 5 Haliangium 5
# 6 Haliangium 5

# %% [markdown]
# # Which Hyphal ASVs change with time

# %%
HASVs = df.l2fc.Exp3 %>%
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset == "Lansing-Gv") %>%
    .$OTU %>%
    unique()
length(HASVs)

df.THASVs = df.l2fc.Exp3.time %>%
    filter(SampleType == "CH" & padj < 0.05 & OTU %in% HASVs)
dim(df.THASVs)
# Out:
# [1] 105
# [1] 60 18

# %%
df.l2fc.Exp3.time %>% filter(padj < 0.05 & Contrast == "24_14" & OTU %in% HASVs)
# Out:
#   baseMean  log2FoldChange lfcSE     stat      pvalue       padj         OTU
# 1 181.44246 -0.8287896     0.2096873 -3.952502 7.733829e-05 2.571154e-02 ASV16
# 2  37.28681 11.0664226     3.0009573  3.687631 2.263517e-04 2.571154e-02 ASV292
# 3 435.86963  5.3912876     1.1050374  4.878828 1.067180e-06 2.193056e-03 ASV23
# 4 483.93925  6.3092037     1.0750066  5.868991 4.384559e-09 1.802054e-05 ASV45
#   Subset     SampleType Term      Contrast Kingdom  Phylum
# 1 Lansing-Gv BS         TimePoint 24_14    Bacteria Proteobacteria
# 2 Lansing-Gv BS         TimePoint 24_14    Bacteria Proteobacteria
# 3 Lansing-Gv RH         TimePoint 24_14    Bacteria Fibrobacteres
# 4 Lansing-Gv RH         TimePoint 24_14    Bacteria Fibrobacteres
#   Class               Order                 Family            Genus
# 1 Alphaproteobacteria Rhizobiales           Xanthobacteraceae Bradyrhizobium
# 2 Gammaproteobacteria Betaproteobacteriales Burkholderiaceae  Piscinibacter
# 3 Fibrobacteria       Fibrobacterales       Fibrobacteraceae  possible_genus_04
# 4 Fibrobacteria       Fibrobacterales       Fibrobacteraceae  possible_genus_04
#   Experiment
# 1 3
# 2 3
# 3 3
# 4 3

# %%
df.THASVs %>% head()
# Out:
#   baseMean  log2FoldChange lfcSE    stat      pvalue       padj         OTU
# 1  47.61213 -5.668830      1.572039 -3.606037 3.109089e-04 3.922634e-02 ASV292
# 2  46.25518 -7.899768      2.126378 -3.715129 2.030997e-04 3.074930e-02 ASV487
# 3 170.02341  9.970861      1.894614  5.262739 1.419246e-07 5.371847e-05 ASV494
# 4  38.28737 -6.277833      1.516239 -4.140397 3.467047e-05 8.748515e-03 ASV516
# 5  40.87403  4.935372      1.271329  3.882056 1.035770e-04 1.960194e-02 ASV645
# 6  15.88647 19.257913      3.124679  6.163165 7.130497e-10 5.397786e-07 ASV2404
#   Subset     SampleType Term      Contrast Kingdom  Phylum
# 1 Lansing-Gv CH         TimePoint 35_14    Bacteria Proteobacteria
# 2 Lansing-Gv CH         TimePoint 35_14    Bacteria Proteobacteria
# 3 Lansing-Gv CH         TimePoint 35_14    Bacteria Proteobacteria
# 4 Lansing-Gv CH         TimePoint 35_14    Bacteria Proteobacteria
# 5 Lansing-Gv CH         TimePoint 35_14    Bacteria FCPU426
# 6 Lansing-Gv CH         TimePoint 35_14    Bacteria Proteobacteria
#   Class               Order                 Family           Genus
# 1 Gammaproteobacteria Betaproteobacteriales Burkholderiaceae Piscinibacter
# 2 Deltaproteobacteria Myxococcales          BIrii41          NA
# 3 Gammaproteobacteria Betaproteobacteriales NA               NA
# 4 Deltaproteobacteria Desulfarculales       Desulfarculaceae NA
# 5 NA                  NA                    NA               NA
# 6 Deltaproteobacteria Myxococcales          Haliangiaceae    Haliangium
#   Experiment
# 1 3
# 2 3
# 3 3
# 4 3
# 5 3
# 6 3

# %%
dft.CH.padj = df.THASVs %>%
    select(OTU,padj,Contrast) %>% 
    dcast(OTU ~ Contrast, value.var = "padj") 
colnames(dft.CH.padj)[-1] = c(paste(colnames(dft.CH.padj)[-1],'padj', sep = '.'))

dft.CH.l2fc = df.THASVs %>%
    select(OTU,log2FoldChange,Contrast) %>% 
    dcast(OTU ~ Contrast, value.var = "log2FoldChange") 
colnames(dft.CH.l2fc)[-1] = c(paste(colnames(dft.CH.l2fc)[-1],'l2fc', sep = '.'))

dft = full_join(dft.CH.padj, dft.CH.l2fc, by = "OTU")
head(dft)
# Out:
#   OTU     35_14.padj 45_14.padj 65_14.padj   35_14.l2fc 45_14.l2fc 65_14.l2fc
# 1 ASV1053 NA         NA         3.789583e-04 NA         NA          8.039158
# 2 ASV1080 NA         NA         2.093598e-02 NA         NA         -6.319868
# 3 ASV117  NA         NA         2.776481e-02 NA         NA         -7.569677
# 4 ASV1182 NA         NA         1.394117e-05 NA         NA          8.238464
# 5 ASV14   NA         NA         2.242494e-06 NA         NA          2.793061
# 6 ASV141  NA         NA         2.361775e-02 NA         NA         -4.762268

# %% [markdown]
# # Which hyphal ASVs are associated with POM

# %% [markdown]
# ### Gv

# %%
HASVs = df.l2fc.Exp2 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset %in% c("Lansing-Gv", "Florence-Gv", "Pendelton-Gv")) %>%
    .$OTU %>%
    unique() 
paste(length(HASVs), 'enriched in hyphal samples compared to core slurry in at least one of three soils')

#Currently cannot check Ri as BPOM was not collected in those mesocosms.  
#Could run Deseq model against Gv BPOM in lansing soil since it was from the bulk compartment anyway

BPASVs = df.l2fc.Exp2 %>% 
    filter(Contrast == "BP_CS" & padj < 0.05 & log2FoldChange > 0 & Subset %in% c("Lansing-Gv", "Florence-Gv", "Pendelton-Gv")) %>%
    .$OTU %>%
    unique() 
paste(length(BPASVs), 'enriched in BP samples compared to CS in at least one of three soils')

NonSpecificASVs = intersect(HASVs, BPASVs) 
NonSpecificASVs %>% length() %>% paste(., "Gv ASVs also enriched BPOM samples compared to CS")



tmp = df.l2fc.Exp2 %>%
    filter(Contrast == "CH_BP" & OTU %in% GvASVs) %>%
    filter(OTU %in% BPASVs)

dim(tmp)

tmp %>% 
    group_by(Order) %>%
    summarise(count = length(Order))

tmp
# Out:
# [1] "221 enriched in hyphal samples compared to core slurry in at least one of three soils"
# [1] "299 enriched in BP samples compared to CS in at least one of three soils"
# [1] "34 Gv ASVs also enriched BPOM samples compared to CS"
# [1] 136  18
# Warning message:
# “Factor `Order` contains implicit NA, consider using `forcats::fct_explicit_na`”
#    Order                              count
# 1  Betaproteobacteriales               4
# 2  Caulobacterales                     4
# 3  Cellvibrionales                     4
# 4  Chitinophagales                     4
# 5  Chloroflexales                     16
lansing-Gv SampleType CH_BP    27  Bacteria Chloroflexi
# 19  ASV1067 Lansing-Gv SampleType CH_BP    27  Bacteria Proteobacteria
# 20  ASV1139 Lansing-Gv SampleType CH_BP    27  Bacteria Actinobacteria
# 21  ASV1142 Lansing-Gv SampleType CH_BP    27  Bacteria Verrucomicrobia
# 22  ASV1146 Lansing-Gv SampleType CH_BP    27  Bacteria Acidobacteria
# 23  ASV1248 Lansing-Gv SampleType CH_BP    27  Bacteria Chloroflexi
# 24  ASV1370 Lansing-Gv SampleType CH_BP    27  Bacteria Planctomycetes
# 25  ASV1417 Lansing-Gv SampleType CH_BP    27  Bacteria Actinobacteria
# 26  ASV1433 Lansing-Gv SampleType CH_BP    27  Bacteria Chloroflexi
# 27  ASV1523 Lansing-Gv SampleType CH_BP    27  Bacteria Acidobacteria
# 28  ASV1550 Lansing-Gv SampleType CH_BP    27  Bacteria Chloroflexi
# 29  ASV1692 Lansing-Gv SampleType CH_BP    27  Bacteria Acidobacteria
# 30  ASV3056 Lansing-Gv SampleType CH_BP    27  Bacteria Bacteroidetes
# ⋮   ⋮       ⋮          ⋮          ⋮        ⋮   ⋮        ⋮
# 107 ASV117  Lansing-RI SampleType CH_BP    27  Bacteria Proteobacteria
# 108 ASV280  Lansing-RI SampleType CH_BP    27  Bacteria Proteobacteria
# 109 ASV312  Lansing-RI SampleType CH_BP    27  Bacteria Chloroflexi
# 110 ASV386  Lansing-RI SampleType CH_BP    27  Bacteria Proteobacteria
# 111 ASV390  Lansing-RI SampleType CH_BP    27  Bacteria Proteobacteria
# 112 ASV416  Lansing-RI SampleType CH_BP    27  Bacteria Proteobacteria
# 113 ASV487  Lansing-RI SampleType CH_BP    27  Bacteria Proteobacteria
# 114 ASV541  Lansing-RI SampleType CH_BP    27  Bacteria Proteobacteria
# 115 ASV575  Lansing-RI SampleType CH_BP    27  Bacteria Chloroflexi
# 116 ASV657  Lansing-RI SampleType CH_BP    27  Bacteria Proteobacteria
# 117 ASV978  Lansing-RI SampleType CH_BP    27  Bacteria Bacteroidetes
# 118 ASV1017 Lansing-RI SampleType CH_BP    27  Bacteria Proteobacteria
# 119 ASV1032 Lansing-RI SampleType CH_BP    27  Bacteria Proteobacteria
# 120 ASV1038 Lansing-RI SampleType CH_BP    27  Bacteria Chloroflexi
# 121 ASV1067 Lansing-RI SampleType CH_BP    27  Bacteria Proteobacteria
# 122 ASV1139 Lansing-RI SampleType CH_BP    27  Bacteria Actinobacteria
# 123 ASV1142 Lansing-RI SampleType CH_BP    27  Bacteria Verrucomicrobia
# 124 ASV1146 Lansing-RI SampleType CH_BP    27  Bacteria Acidobacteria
# 125 ASV1248 Lansing-RI SampleType CH_BP    27  Bacteria Chloroflexi
# 126 ASV1370 Lansing-RI SampleType CH_BP    27  Bacteria Planctomycetes
# 127 ASV1417 Lansing-RI SampleType CH_BP    27  Bacteria Actinobacteria
# 128 ASV1433 Lansing-RI SampleType CH_BP    27  Bacteria Chloroflexi
# 129 ASV1523 Lansing-RI SampleType CH_BP    27  Bacteria Acidobacteria
# 130 ASV1550 Lansing-RI SampleType CH_BP    27  Bacteria Chloroflexi
# 131 ASV1692 Lansing-RI SampleType CH_BP    27  Bacteria Acidobacteria
# 132 ASV3056 Lansing-RI SampleType CH_BP    27  Bacteria Bacteroidetes
# 133 ASV3065 Lansing-RI SampleType CH_BP    27  Bacteria Bacteroidetes
# 134 ASV3476 Lansing-RI SampleType CH_BP    27  Bacteria Chloroflexi
# 135 ASV3807 Lansing-RI SampleType CH_BP    27  Bacteria Chloroflexi
# 136 ASV4780 Lansing-RI SampleType CH_BP    27  Bacteria Chloroflexi
#     Class                       Order
# 1   Gammaproteobacteria         Cellvibrionales
# 2   Alphaproteobacteria         Rhizobiales
# 3   Alphaproteobacteria         Rhizobiales
# 4   Gammaproteobacteria         Gammaproteobacteria_Incertae_Sedis
# 5   Gammaproteobacteria         Gammaproteobacteria_Incertae_Sedis
# 6   Gammaproteobacteria         Gammaproteobacteria_Incertae_Sedis
# 7   Chloroflexia                Kallotenuales
# 8   Gammaproteobacteria         Xanthomonadales
# 9   Alphaproteobacteria         Caulobacterales
# 10  Alphaproteobacteria         Dongiales
# 11  Deltaproteobacteria         Myxococcales
# 12  Gammaproteobacteria         Betaproteobacteriales
# 13  Anaerolineae                SBR1031
# 14  Alphaproteobacteria         Rhizobiales
# 15  Bacteroidia                 Cytophagales
# 16  Deltaproteobacteria         Myxococcales
# 17  Alphaproteobacteria         Rhizobiales
# 18  Anaerolineae                SBR1031
# 19  Alphaproteobacteria         Rhizobiales
# 20  Actinobacteria              Micromonosporales
# 21  Verrucomicrobiae            Opitutales
# 112 Dongiaceae             Dongia            2
# 113 BIrii41                NA                2
# 114 Burkholderiaceae       Leptothrix        2
# 115 A4b                    NA                2
# 116 Xanthobacteraceae      Pseudorhodoplanes 2
# 117 Microscillaceae        Ohtaekwangia      2
# 118 BIrii41                NA                2
# 119 NA                     NA                2
# 120 A4b                    NA                2
# 121 Xanthobacteraceae      Rhodoplanes       2
# 122 Micromonosporaceae     Dactylosporangium 2
# 123 Opitutaceae            Lacunisphaera     2
# 124 NA                     NA                2
# 125 NA                     NA                2
# 126 Pirellulaceae          Pirellula         2
# 127 NA                     NA                2
# 128 Roseiflexaceae         NA                2
# 129 Thermoanaerobaculaceae Subgroup_10       2
# 130 Roseiflexaceae         NA                2
# 131 NA                     NA                2
# 132 Chitinophagaceae       NA                2
# 133 NA                     NA                2
# 134 NA                     NA                2
# 135 Roseiflexaceae         NA                2
# 136 Roseiflexaceae         NA                2

# %%
library(VennDiagram)
# Out:
# Warning message:
# “package ‘VennDiagram’ was built under R version 3.6.3”Loading required package: grid
# Loading required package: futile.logger
# Warning message:
# “package ‘futile.logger’ was built under R version 3.6.3”

# %%
#area 1 = hybrid
#area 2 = Fert
#area 3 = Enzyme
draw.pairwise.venn(area1 = 221, area2 = 299, 
cross.area = 34, category = c("Hyphae", "POM"), lty = rep(2, 2), 
                 fill = c("blue",  "red"), cex = 2, cat.cex = 2, scaled = TRUE, rotation.degree = 180, 
                   euler.d = TRUE, cat.pos = c(0,0))

outfile = file.path(figDir,'CH-BP_Venn_Gv.pdf')
pdf(file = outfile, width = 3, height = 3)

draw.pairwise.venn(area1 = 221, area2 = 299, 
cross.area = 34, category = c("Hyphae", "POM"), lty = rep(2, 2), 
                 fill = c("blue",  "red"), cex = 2, cat.cex = 2, scaled = TRUE, rotation.degree = 180, 
                   euler.d = TRUE, cat.pos = c(0,0))
dev.off()
# Out:
# (polygon[GRID.polygon.236], polygon[GRID.polygon.237], polygon[GRID.polygon.238], polygon[GRID.polygon.239], text[GRID.text.240], text[GRID.text.241], text[GRID.text.242], text[GRID.text.243], text[GRID.text.244])
# (polygon[GRID.polygon.245], polygon[GRID.polygon.246], polygon[GRID.polygon.247], polygon[GRID.polygon.248], text[GRID.text.249], text[GRID.text.250], text[GRID.text.251], text[GRID.text.252], text[GRID.text.253])
# png
#   2
# plot without title

# %% [markdown]
# ### Ri

# %%
HASVs = df.l2fc.Exp2 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset %in% c("Lansing-RI")) %>%
    .$OTU %>%
    unique() 
paste(length(HASVs), 'enriched in Ri hyphal samples compared to core slurry in Lansing soils')

#Currently cannot check Ri as BPOM was not collected in those mesocosms.  
#Could run Deseq model against Gv BPOM in lansing soil since it was from the bulk compartment anyway

BPASVs = df.l2fc.Exp2 %>% 
    filter(Contrast == "BP_CS" & padj < 0.05 & log2FoldChange > 0 & Subset %in% c("Lansing-Gv")) %>%
    .$OTU %>%
    unique() 
paste(length(BPASVs), 'enriched in BP samples compared to CS in Lansing soils')

NonSpecificASVs = intersect(HASVs, BPASVs) 
NonSpecificASVs %>% length() %>% paste(., "Ri ASVs also enriched BPOM samples compared to CS")
# Out:
# [1] "236 enriched in Ri hyphal samples compared to core slurry in Lansing soils"
# [1] "191 enriched in BP samples compared to CS in Lansing soils"
# [1] "35 Ri ASVs also enriched BPOM samples compared to CS"

# %%
draw.pairwise.venn(area1 = 236, area2 = 191, 
cross.area = 35, category = c("Hyphae", "POM"), lty = rep(2, 2), 
                 fill = c("blue",  "red"), cex = 2, cat.cex = 2, scaled = TRUE, rotation.degree = 0, 
                   euler.d = TRUE, cat.pos = c(0,0))

outfile = file.path(figDir,'CH-BP_Venn_Ri.pdf')
pdf(file = outfile, width = 3, height = 3)

draw.pairwise.venn(area1 = 236, area2 = 191, 
cross.area = 35, category = c("Hyphae", "POM"), lty = rep(2, 2), 
                 fill = c("blue",  "red"), cex = 2, cat.cex = 2, scaled = TRUE, rotation.degree = 0, 
                   euler.d = TRUE, cat.pos = c(0,0))
dev.off()
# Out:
# (polygon[GRID.polygon.218], polygon[GRID.polygon.219], polygon[GRID.polygon.220], polygon[GRID.polygon.221], text[GRID.text.222], text[GRID.text.223], text[GRID.text.224], text[GRID.text.225], text[GRID.text.226])
# (polygon[GRID.polygon.227], polygon[GRID.polygon.228], polygon[GRID.polygon.229], polygon[GRID.polygon.230], text[GRID.text.231], text[GRID.text.232], text[GRID.text.233], text[GRID.text.234], text[GRID.text.235])
# png
#   2
# plot without title

# %% [markdown]
# ## Overlap between enriched ASVs in hyphal compartment and root compartment

# %% [markdown]
# ### Gv

# %%
HASVs = df.l2fc.Exp2 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset %in% c("Lansing-Gv", "Florence-Gv", "Pendelton-Gv")) %>%
    .$OTU %>%
    unique() 
paste(length(HASVs), 'enriched in hyphal samples compared to core slurry in at least one of three soils')

#Currently cannot check Ri as BPOM was not collected in those mesocosms.  
#Could run Deseq model against Gv BPOM in lansing soil since it was from the bulk compartment anyway

RHASVs = df.l2fc.Exp2 %>% 
    filter(Contrast == "RH_RS" & padj < 0.05 & log2FoldChange > 0 & Subset %in% c("Lansing-Gv", "Florence-Gv", "Pendelton-Gv")) %>%
    .$OTU %>%
    unique() 
paste(length(RHASVs), 'enriched in root hyphal samples compared to root sand slurry in at least one of three soils')

SharedASVs = intersect(HASVs, RHASVs) 
SharedASVs %>% length() %>% paste(., "Gv ASVs also enriched in root hyphal samples compared to root sand slurry")


draw.pairwise.venn(area1 = length(HASVs), area2 = length(RHASVs), 
cross.area = length(SharedASVs), category = c("Core Hyphae", "Root Hyphae"), lty = rep(2, 2), 
                 fill = c("blue",  "red"), cex = 2, cat.cex = 2, scaled = TRUE, rotation.degree = 0, 
                   euler.d = TRUE, cat.pos = c(0,0))


df.l2fc.Exp2 %>%
    filter(OTU %in% RHASVs) %>%
        select(OTU, Phylum, Class, Order, Family, Genus) %>%
        unique()
#outfile = file.path(figDir,'CH-BP_Venn_Ri.pdf')
# pdf(file = outfile, width = 3, height = 3)

# draw.pairwise.venn(area1 = 236, area2 = 191, 
# cross.area = 35, category = c("Hyphae", "POM"), lty = rep(2, 2), 
#                  fill = c("blue",  "red"), cex = 2, cat.cex = 2, scaled = TRUE, rotation.degree = 0, 
#                    euler.d = TRUE, cat.pos = c(0,0))
# dev.off()
# Out:
# [1] "221 enriched in hyphal samples compared to core slurry in at least one of three soils"
# [1] "41 enriched in root hyphal samples compared to root sand slurry in at least one of three soils"
# [1] "18 Gv ASVs also enriched in root hyphal samples compared to root sand slurry"
# (polygon[GRID.polygon.301], polygon[GRID.polygon.302], polygon[GRID.polygon.303], polygon[GRID.polygon.304], text[GRID.text.305], text[GRID.text.306], text[GRID.text.307], text[GRID.text.308], text[GRID.text.309])
#    OTU     Phylum         Class               Order
# 1  ASV6    Proteobacteria Gammaproteobacteria Cellvibrionales
# 2  ASV13   Proteobacteria Gammaproteobacteria Xanthomonadales
# 3  ASV14   Proteobacteria Deltaproteobacteria Myxococcales
# 4  ASV17   Proteobacteria Gammaproteobacteria Betaproteobacteriales
# 5  ASV18   Proteobacteria Deltaproteobacteria Myxococcales
# 6  ASV19   Planctomycetes Planctomycetacia    Pirellulales
# 7  ASV23   Fibrobacteres  Fibrobacteria       Fibrobacterales
# 8  ASV30   Proteobacteria Alphaproteobacteria Rhizobiales
# 9  ASV32   Proteobacteria Gammaproteobacteria Betaproteobacteriales
#
allorhizobium-Neorhizobium-Pararhizobium-Rhizobium
# 15 Sandaracinaceae    NA
# 16 Xanthobacteraceae  Afipia
# 17 Gemmataceae        Gemmata
# 18 Herpetosiphonaceae Herpetosiphon
# 19 Pirellulaceae      Pir4_lineage
# 20 0319-6G20          NA
# 21 Sandaracinaceae    NA
# 22 Sandaracinaceae    NA
# 23 Fibrobacteraceae   possible_genus_04
# 24 Sandaracinaceae    NA
# 25 Rhizobiaceae       Mesorhizobium
# 26 Microbacteriaceae  Galbitalea
# 27 Cytophagaceae      NA
# 28 0319-6G20          NA
# 29 Oligoflexaceae     Oligoflexus
# 30 Devosiaceae        Devosia
# 31 Chitinophagaceae   Terrimonas
# 32 Caulobacteraceae   Phenylobacterium
# 33 Devosiaceae        Devosia
# 34 Rubinisphaeraceae  Rubinisphaera
# 35 Rhizobiaceae       NA
# 36 Cellvibrionaceae   Cellvibrio
# 37 Fibrobacteraceae   possible_genus_04
# 38 Sphingomonadaceae  Sphingomonas
# 39 Cytophagaceae      Cytophaga
# 40 NA                 NA
# 41 Microscillaceae    Ohtaekwangia
# plot without title

# %% [markdown]
# ### Ri

# %%
HASVs = df.l2fc.Exp2 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset %in% c("Lansing-RI")) %>%
    .$OTU %>%
    unique() 
paste(length(HASVs), 'enriched in RI hyphal samples from Lansing')

#Currently cannot check Ri as BPOM was not collected in those mesocosms.  
#Could run Deseq model against Gv BPOM in lansing soil since it was from the bulk compartment anyway

RHASVs = df.l2fc.Exp2 %>% 
    filter(Contrast == "RH_RS" & padj < 0.05 & log2FoldChange > 0 & Subset %in% c("Lansing-RI")) %>%
    .$OTU %>%
    unique() 
paste(length(RHASVs), 'enriched in root hyphal samples compared to root sand slurry from Lansing')

SharedASVs = intersect(HASVs, RHASVs) 
SharedASVs %>% length() %>% paste(., "ASVs enriched in hyphal samples of both root and soil compartments")


draw.pairwise.venn(area1 = length(HASVs), area2 = length(RHASVs), 
cross.area = length(SharedASVs), category = c("Core Hyphae", "Root Hyphae"), lty = rep(2, 2), 
                 fill = c("blue",  "red"), cex = 2, cat.cex = 2, scaled = TRUE, rotation.degree = 0, 
                   euler.d = TRUE, cat.pos = c(0,0))
# Out:
# [1] "236 enriched in RI hyphal samples from Lansing"
# [1] "19 enriched in root hyphal samples compared to root sand slurry from Lansing"
# [1] "10 ASVs enriched in hyphal samples of both root and soil compartments"
# (polygon[GRID.polygon.272], polygon[GRID.polygon.273], polygon[GRID.polygon.274], polygon[GRID.polygon.275], text[GRID.text.276], text[GRID.text.277], lines[GRID.lines.278], text[GRID.text.279], lines[GRID.lines.280], text[GRID.text.281], text[GRID.text.282])
# plot without title

# %% [markdown]
# # Check hyphal ASVs can be detected in targeted hypothesis test

# %%
RiASVs = df.l2fc.Exp2 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset %in% c("Lansing-RI")) %>%
    .$OTU %>%
    unique() 
length(RiASVs)

GvASVs = df.l2fc.Exp2 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset %in% c("Lansing-Gv")) %>%
    .$OTU %>%
    unique() 
length(GvASVs)
# Out:
# [1] 236
# [1] 88

# %%
df.l2fc.Exp2 %>% 
    filter(Contrast == "BH_BS" & OTU %in% RiASVs & Subset %in% c("Lansing-RI")) %>%
    arrange(pvalue)
# Out:
#     baseMean  log2FoldChange lfcSE     stat       pvalue     padj      OTU
# 1    7.628263  5.9105101     2.9798749  1.9834760 0.04731429 0.9999796 ASV1310
# 2   18.160871  4.5918979     2.4107625  1.9047492 0.05681268 0.9999796 ASV27
# 3   21.693302  1.2182342     0.7167407  1.6996862 0.08918996 0.9999796 ASV932
# 4   18.128149  3.1964250     1.9988917  1.5990986 0.10979869 0.9999796 ASV226
# 219 0         NA             NA        NA         NA         NA        ASV5970
# 220 0         NA             NA        NA         NA         NA        ASV6000
# 221 0         NA             NA        NA         NA         NA        ASV6162
# 222 0         NA             NA        NA         NA         NA        ASV6456
# 223 0         NA             NA        NA         NA         NA        ASV6587
# 224 0         NA             NA        NA         NA         NA        ASV6772
# 225 0         NA             NA        NA         NA         NA        ASV6797
# 226 0         NA             NA        NA         NA         NA        ASV6916
# 227 0         NA             NA        NA         NA         NA        ASV7106
# 228 0         NA             NA        NA         NA         NA        ASV7404
# 229 0         NA             NA        NA         NA         NA        ASV7513
# 230 0         NA             NA        NA         NA         NA        ASV7540
# 231 0         NA             NA        NA         NA         NA        ASV7544
# 232 0         NA             NA        NA         NA         NA        ASV8082
# 233 0         NA             NA        NA         NA         NA        ASV8313
# 234 0         NA             NA        NA         NA         NA        ASV9239
# 235 0         NA             NA        NA         NA         NA        ASV9677
# 236 0         NA             NA        NA         NA         NA        ASV10437
#     Subset     Term       Contrast DAI Kingdom  Phylum
# 1   Lansing-RI SampleType BH_BS    27  Bacteria Acidobacteria
# 2   Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 3   Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 4   Lansing-RI SampleType BH_BS    27  Bacteria Verrucomicrobia
# 5   Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 6   Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 7   Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 8   Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 9   Lansing-RI SampleType BH_BS    27  Bacteria Verrucomicrobia
# 10  Lansing-RI SampleType BH_BS    27  Bacteria Bacteroidetes
# 11  Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 12  Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 13  Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 14  Lansing-RI SampleType BH_BS    27  Bacteria Fibrobacteres
# 15  Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 16  Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 17  Lansing-RI SampleType BH_BS    27  Bacteria Chloroflexi
# 18  Lansing-RI SampleType BH_BS    27  Bacteria Chloroflexi
# 19  Lansing-RI SampleType BH_BS    27  Bacteria Fibrobacteres
# 20  Lansing-RI SampleType BH_BS    27  Bacteria Armatimonadetes
# 21  Lansing-RI SampleType BH_BS    27  Bacteria Chloroflexi
# 22  Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 23  Lansing-RI SampleType BH_BS    27  Bacteria Acidobacteria
# 24  Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 25  Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 26  Lansing-RI SampleType BH_BS    27  Bacteria Bacteroidetes
# 27  Lansing-RI SampleType BH_BS    27  Bacteria Chloroflexi
# 28  Lansing-RI SampleType BH_BS    27  Bacteria Actinobacteria
# 29  Lansing-RI SampleType BH_BS    27  Bacteria Chloroflexi
# 30  Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# ⋮   ⋮          ⋮          ⋮        ⋮   ⋮        ⋮
# 207 Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 208 Lansing-RI SampleType BH_BS    27  Bacteria Chloroflexi
# 209 Lansing-RI SampleType BH_BS    27  Bacteria Acidobacteria
# 210 Lansing-RI SampleType BH_BS    27  Bacteria Acidobacteria
# 211 Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 212 Lansing-RI SampleType BH_BS    27  Bacteria Bacteroidetes
# 213 Lansing-RI SampleType BH_BS    27  Bacteria Acidobacteria
# 214 Lansing-RI SampleType BH_BS    27  Bacteria Planctomycetes
# 215 Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 216 Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 217 Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 218 Lansing-RI SampleType BH_BS    27  Bacteria Acidobacteria
# 219 Lansing-RI SampleType BH_BS    27  Bacteria Planctomycetes
# 220 Lansing-RI SampleType BH_BS    27  Bacteria Verrucomicrobia
# 221 Lansing-RI SampleType BH_BS    27  Bacteria Actinobacteria
# 222 Lansing-RI SampleType BH_BS    27  Bacteria Chloroflexi
# 223 Lansing-RI SampleType BH_BS    27  Bacteria Fibrobacteres
# 224 Lansing-RI SampleType BH_BS    27  Bacteria Bacteroidetes
# 225 Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 226 Lansing-RI SampleType BH_BS    27  Bacteria Fibrobacteres
# 227 Lansing-RI SampleType BH_BS    27  Bacteria Bacteroidetes
# 228 Lansing-RI SampleType BH_BS    27  Bacteria Elusimicrobia
# 229 Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 230 Lansing-RI SampleType BH_BS    27  Bacteria Chloroflexi
# 231 Lansing-RI SampleType BH_BS    27  Bacteria Chloroflexi
# 232 Lansing-RI SampleType BH_BS    27  Bacteria Chloroflexi
# 233 Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 234 Lansing-RI SampleType BH_BS    27  Bacteria Gemmatimonadetes
# 235 Lansing-RI SampleType BH_BS    27  Bacteria Proteobacteria
# 236 Lansing-RI SampleType BH_BS    27  Bacteria Bacteroidetes
#     Class                       Order
# 1   Subgroup_17                 NA
# 2   Gammaproteobacteria         Betaproteobacteriales
# 3   Gammaproteobacteria         Betaproteobacteriales
# 4   Verrucomicrobiae            Opitutales
# 5   Alphaproteobacteria         Sphingomonadales
# 15  Burkholderiaceae       Aquabacterium
# 16  Rhodanobacteraceae     NA
# 17  Roseiflexaceae         NA
# 18  Roseiflexaceae         NA
# 19  Fibrobacteraceae       possible_genus_04
# 20  Fimbriimonadaceae      NA
# 21  A4b                    NA
# 22  Burkholderiaceae       Variovorax
# 23  Thermoanaerobaculaceae Subgroup_10
# 24  Rhizobiaceae           Allorhizobium-Neorhizobium-Pararhizobium-Rhizobium
# 25  Rhizobiaceae           Mesorhizobium
# 26  Microscillaceae        NA
# 27  Roseiflexaceae         NA
# 28  Nocardioidaceae        Aeromicrobium
# 29  A4b                    NA
# 30  Haliangiaceae          Haliangium
# ⋮   ⋮                      ⋮
# 207 Haliangiaceae          Haliangium
# 208 A4b                    NA
# 209 NA                     NA
# 210 NA                     NA
# 211 Unknown_Family         Candidatus_Ovatusbacter
# 212 Microscillaceae        Ohtaekwangia
# 213 NA                     NA
# 214 Phycisphaeraceae       AKYG587
# 215 Methylophilaceae       MM1
# 216 Dongiaceae             Dongia
# 217 Acetobacteraceae       Roseomonas
# 218 NA                     NA
# 219 Phycisphaeraceae       SM1A02
# 220 Pedosphaeraceae        NA
# 221 Solirubrobacteraceae   Conexibacter
# 222 Roseiflexaceae         NA
# 223 Fibrobacteraceae       possible_genus_04
# 224 Chitinophagaceae       Ferruginibacter
# 225 Bdellovibrionaceae     Bdellovibrio
# 226 Fibrobacteraceae       possible_genus_04
# 227 Chitinophagaceae       Ferruginibacter
# 228 NA                     NA
# 229 Rhizobiaceae           Aminobacter
# 230 Roseiflexaceae         NA
# 231 NA                     NA
# 232 NA                     NA
# 233 Caulobacteraceae       Caulobacter
# 234 Gemmatimonadaceae      NA
# 235 MSB-4B10               NA
# 236 Cytophagaceae          NA
#     Experiment
# 1   2
# 2   2
# 3   2
# 4   2
# 5   2
# 6   2
# 7   2
# 8   2
# 9   2
# 10  2
# 11  2
# 12  2
# 13  2
# 14  2
# 15  2
# 16  2
# 17  2
# 18  2
# 19  2
# 20  2
# 21  2
# 22  2
# 23  2
# 24  2
# 25  2
# 26  2
# 27  2
# 28  2
# 29  2
# 30  2
# ⋮   ⋮
# 207 2
# 208 2
# 209 2
# 210 2
# 211 2
# 212 2
# 213 2
# 214 2
# 215 2
# 216 2
# 217 2
# 218 2
# 219 2
# 220 2
# 221 2
# 222 2
# 223 2
# 224 2
# 225 2
# 226 2
# 227 2
# 228 2
# 229 2
# 230 2
# 231 2
# 232 2
# 233 2
# 234 2
# 235 2
# 236 2

# %%
df.l2fc.Exp2 %>% 
    filter(Contrast == "BH_BS" & OTU %in% GvASVs & Subset %in% c("Lansing-Gv")) %>%
    arrange(pvalue)
# Out:
#    baseMean    log2FoldChange lfcSE     stat       pvalue       padj
# 1   16.4344448  7.40593026    1.3789456  5.3707198 7.842298e-08 1.987462e-05
# 2   17.5089858  7.02216431    1.7032496  4.1228041 3.742879e-05 8.299835e-03
# 3   10.8116142  6.71372805    1.8144472  3.7001507 2.154715e-04 3.185386e-02
# 4    6.2732592  6.02819515    1.7998997  3.3491840 8.104996e-04 1.027019e-01
# 17 Fibrobacteraceae       possible_genus_04 2
# 18 Roseiflexaceae         NA                2
# 19 Fibrobacteraceae       possible_genus_04 2
# 20 Cellvibrionaceae       Cellvibrio        2
# 21 Xanthobacteraceae      Bradyrhizobium    2
# 22 Xanthobacteraceae      Pseudorhodoplanes 2
# 23 Rhodanobacteraceae     NA                2
# 24 Chitinophagaceae       NA                2
# 25 Devosiaceae            Devosia           2
# 26 Xanthobacteraceae      NA                2
# 27 NA                     NA                2
# 28 Fibrobacteraceae       possible_genus_04 2
# 29 Herpetosiphonaceae     Herpetosiphon     2
# 30 Haliangiaceae          Haliangium        2
# ⋮  ⋮                      ⋮                 ⋮
# 59 Burkholderiaceae       NA                2
# 60 Cytophagaceae          NA                2
# 61 Haliangiaceae          Haliangium        2
# 62 Cellvibrionaceae       Cellvibrio        2
# 63 Spirochaetaceae        Salinispira       2
# 64 Xanthobacteraceae      Rhodoplanes       2
# 65 Chthoniobacteraceae    Chthoniobacter    2
# 66 Cytophagaceae          NA                2
# 67 Sandaracinaceae        NA                2
# 68 Fibrobacteraceae       possible_genus_04 2
# 69 Acidiferrobacteraceae  Sulfurifustis     2
# 70 Microscillaceae        Ohtaekwangia      2
# 71 NA                     NA                2
# 72 Haliangiaceae          Haliangium        2
# 73 Fibrobacteraceae       possible_genus_04 2
# 74 Acidiferrobacteraceae  Sulfurifustis     2
# 75 BIrii41                NA                2
# 76 Burkholderiaceae       NA                2
# 77 Haliangiaceae          Haliangium        2
# 78 Chitinophagaceae       Niastella         2
# 79 Flavobacteriaceae      Flavobacterium    2
# 80 Micromonosporaceae     Luedemannella     2
# 81 NA                     NA                2
# 82 NA                     NA                2
# 83 A4b                    NA                2
# 84 Herpetosiphonaceae     Herpetosiphon     2
# 85 Burkholderiaceae       Actimicrobium     2
# 86 NA                     NA                2
# 87 Fibrobacteraceae       possible_genus_04 2
# 88 Chthoniobacteraceae    Chthoniobacter    2

# %% [markdown]
# # Check against abundance of MREs in BH samples

# %% [markdown]
# ### Get MRE table from original phyloseq object

# %%
ps.MRE = readRDS("~/Hyphosphere/data/3Exp/phyloseq/3Exp_phyloseq_thresh_woTree_experimental_woContam.rds") %>%
        subset_samples(Fungus == "Gv" & Experiment == 2) %>%
        
         transform_sample_counts(., function(x) x/sum(x)) %>% 
         prune_taxa(c("ASV2", "ASV4", "ASV11"),.)

tax_table(ps.MRE)
# Out:
#       Kingdom  Phylum Class Order Family Genus
# ASV2  Bacteria NA     NA    NA    NA     NA
# ASV4  Bacteria NA     NA    NA    NA     NA
# ASV11 Bacteria NA     NA    NA    NA     NA

# %%
ps.MRE %>% 
    psmelt() %>% 
    #filter(Soil %in% c("Lansing", "Pendelton", "Florence") & Fungus == "Gv")  %>%                                     
    group_by(sample_Sample, Soil, SampleType, Treatment, Rep) %>%
    summarise(sAbund = sum(Abundance)) %>%
    ggplot(., aes(x=interaction(Treatment,Rep), y= log2(sAbund))) +
    geom_point()+
    facet_grid(Soil~SampleType, scales = 'free_x')+
    ggtitle(as.character("MREs"))+
    theme(axis.text.x = element_blank())+
    ylab('Relative abundance (log2)')
# Out:
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”
# plot without title

# %%
MREtab = ps.MRE %>% 
    psmelt() %>% 
    filter(Soil != "Sand", Experiment == 2, SampleType %in% c("BS","BH") & Fungus == "Gv") %>%
    group_by(sample_Sample, Soil) %>%
    summarise(sAbund = sum(Abundance))
# Out:
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”

# %% [markdown]
# ### Get groups - Myxococcales, Fibrobacteres, Burkholderiaceae, Chloroflexaceae, Oli

# %%
TopHASVOrderList = df.l2fc.Exp2 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset %in% 
           c("Lansing-Gv", "Florence-Gv", "Pendelton-Gv")) %>%
    group_by(Order) %>% 
    summarize(sL2FC = sum(log2FoldChange), n = length(Order)) %>%
    arrange(desc(sL2FC)) %>%
    filter(!is.na(Order))%>%
    .$Order %>%  
   as.character()
TopHASVOrderList[1:10]
# Out:
# Warning message:
# “Factor `Order` contains implicit NA, consider using `forcats::fct_explicit_na`”
#  [1] "Myxococcales"          "Betaproteobacteriales" "Fibrobacterales"
#  [4] "Chloroflexales"        "Rhizobiales"           "Cytophagales"
#  [7] "Caulobacterales"       "SBR1031"               "Flavobacteriales"
# [10] "Chthoniobacterales"

# %% [markdown]
# ## Get taxa relative abundance from phyloseq object without MREs

# %%
ps.rel = ps %>% 
transform_sample_counts(., function(x) x/sum(x))

# %%
TaxList = df.l2fc.Exp2 %>% 
    filter(Contrast == "CH_CS" & padj < 0.05 & log2FoldChange > 0 & Subset %in% 
           c("Lansing-Gv", "Florence-Gv", "Pendelton-Gv") & Order %in% TopHASVOrderList[1:4]) %>%
    .$OTU %>%
    as.character()%>%
    unique() 
 

Taxtab = ps.rel %>% 
    prune_taxa(TaxList, .) %>%
    subset_samples(Experiment == 2 & SampleType %in% c("BS","BH") & Fungus == "Gv") %>%
      psmelt() %>% 
     group_by(sample_Sample, Soil, SampleType, Order) %>%
    summarise(sAbund = sum(Abundance))
 head(Taxtab)
# Out:
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”
#   sample_Sample Soil      SampleType Order                 sAbund
# 1 GVCLHN1-BH    Pendelton BH         Betaproteobacteriales 0.0000000000
# 2 GVCLHN1-BH    Pendelton BH         Chloroflexales        0.0017359963
# 3 GVCLHN1-BH    Pendelton BH         Fibrobacterales       0.0002314662
# 4 GVCLHN1-BH    Pendelton BH         Myxococcales          0.0002810661
# 5 GVCLHN1-BS    Pendelton BS         Betaproteobacteriales 0.0000000000
# 6 GVCLHN1-BS    Pendelton BS         Chloroflexales        0.0010350048

# %%
cs = brewer.pal(3,"Set2")
df = full_join(MREtab,Taxtab, by = "sample_Sample") 
head(df)
# Out:
#   sample_Sample Soil.x    sAbund.x     Soil.y    SampleType
# 1 GVCLHN1-BH    Pendelton 0.0002145994 Pendelton BH
# 2 GVCLHN1-BH    Pendelton 0.0002145994 Pendelton BH
# 3 GVCLHN1-BH    Pendelton 0.0002145994 Pendelton BH
# 4 GVCLHN1-BH    Pendelton 0.0002145994 Pendelton BH
# 5 GVCLHN1-BS    Pendelton 0.0000000000 Pendelton BS
# 6 GVCLHN1-BS    Pendelton 0.0000000000 Pendelton BS
#   Order                 sAbund.y
# 1 Betaproteobacteriales 0.0000000000
# 2 Chloroflexales        0.0017359963
# 3 Fibrobacterales       0.0002314662
# 4 Myxococcales          0.0002810661
# 5 Betaproteobacteriales 0.0000000000
# 6 Chloroflexales        0.0010350048

# %%
df = full_join(MREtab,Taxtab, by = "sample_Sample")
#tmp = df %>% filter(SampleType == "BH")

# %%
p1 = df %>%
    #filter(OTU %in% c("ASV14", "ASV18")) %>%
    ggplot(.,aes(x = sAbund.x, y = sAbund.y, fill = Soil.x)) +
        geom_jitter(aes(fill = Soil.x), shape = 21, pch = 2) +
        theme_pub()+
        #scale_x_continuous(trans='log2')+
        #scale_y_continuous(trans='log2')+
        scale_fill_manual(values = cs) +#, labels = c("Bulk hyphosphere", "Bulk soil"))+
        ylab("Hyphal associated taxa relative abundance") +
        xlab("MRE relative abundance")+
       #annotate(geom="text", x=0.0005, y=.0020, label=EqLabel,
       #      color="black")+
        geom_smooth(aes(x = sAbund.x, y = sAbund.y), method='lm', se = FALSE,  lty = 2)+
       facet_wrap(~Order, scales = "free_y")
p1
# Out:
# Warning message:
# “Duplicated aesthetics after name standardisation: shape”
# plot without title

# %%
tmp = df %>% filter(Order == "Betaproteobacteriales")
m1 = lm(sAbund.y~Soil.x + SampleType + sAbund.x, data = tmp)
anova(m1)
summary(m1)
# Out:
#            Df Sum Sq       Mean Sq      F value    Pr(>F)
# Soil.x      2 3.378791e-05 1.689396e-05  6.8388011 0.0031112162
# SampleType  1 4.131791e-05 4.131791e-05 16.7258020 0.0002406376
# sAbund.x    1 1.989734e-06 1.989734e-06  0.8054594 0.3755983913
# Residuals  35 8.646084e-05 2.470310e-06         NA           NA
# Call:
# lm(formula = sAbund.y ~ Soil.x + SampleType + sAbund.x, data = tmp)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0028569 -0.0009130 -0.0002459  0.0005743  0.0065731
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)      0.0033555  0.0008074   4.156 0.000198 ***
# Soil.xLansing   -0.0014020  0.0006094  -2.301 0.027492 *
# Soil.xPendelton -0.0019269  0.0007537  -2.556 0.015071 *
# SampleTypeBS    -0.0015882  0.0007017  -2.263 0.029914 *
# sAbund.x         0.5096067  0.5678234   0.897 0.375598
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.001572 on 35 degrees of freedom
# Multiple R-squared:  0.4714,	Adjusted R-squared:  0.411
# F-statistic: 7.802 on 4 and 35 DF,  p-value: 0.0001322

# %%
tmp = df %>% filter(Order == "Myxococcales")
m1 = lm(sAbund.y~Soil.x + SampleType + sAbund.x, data = tmp)
anova(m1)
summary(m1)
# Out:
#            Df Sum Sq       Mean Sq      F value   Pr(>F)
# Soil.x      2 6.888453e-06 3.444226e-06  9.756817 4.288948e-04
# SampleType  1 1.157191e-05 1.157191e-05 32.780938 1.776559e-06
# sAbund.x    1 4.857225e-06 4.857225e-06 13.759566 7.171122e-04
# Residuals  35 1.235525e-05 3.530072e-07        NA           NA
# Call:
# lm(formula = sAbund.y ~ Soil.x + SampleType + sAbund.x, data = tmp)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -1.186e-03 -3.443e-04 -4.085e-05  2.559e-04  2.009e-03
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)      0.0011703  0.0003052   3.834 0.000503 ***
# Soil.xLansing   -0.0001702  0.0002304  -0.739 0.465071
# Soil.xPendelton -0.0006648  0.0002849  -2.333 0.025515 *
# SampleTypeBS    -0.0003812  0.0002652  -1.437 0.159512
# sAbund.x         0.7962174  0.2146492   3.709 0.000717 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0005941 on 35 degrees of freedom
# Multiple R-squared:  0.6537,	Adjusted R-squared:  0.6141
# F-statistic: 16.51 on 4 and 35 DF,  p-value: 1.087e-07

# %%
tmp = df %>% filter(Order == "Fibrobacterales")
m1 = lm(sAbund.y~Soil.x + SampleType + sAbund.x, data = tmp)
anova(m1)
summary(m1)
plot(m1)
# Out:
#            Df Sum Sq       Mean Sq      F value   Pr(>F)
# Soil.x      2 5.544934e-06 2.772467e-06 12.018798 0.000106277
# SampleType  1 1.643891e-06 1.643891e-06  7.126358 0.011438853
# sAbund.x    1 2.964732e-06 2.964732e-06 12.852277 0.001017312
# Residuals  35 8.073714e-06 2.306776e-07        NA          NA
# Call:
# lm(formula = sAbund.y ~ Soil.x + SampleType + sAbund.x, data = tmp)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -1.496e-03 -2.020e-04 -2.093e-05  1.278e-04  1.789e-03
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)      0.0005143  0.0002467   2.085  0.04447 *
# Soil.xLansing   -0.0004494  0.0001862  -2.413  0.02118 *
# Soil.xPendelton -0.0004673  0.0002303  -2.029  0.05013 .
# SampleTypeBS     0.0001371  0.0002144   0.640  0.52662
# sAbund.x         0.6220571  0.1735163   3.585  0.00102 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0004803 on 35 degrees of freedom
# Multiple R-squared:  0.5571,	Adjusted R-squared:  0.5064
# F-statistic:    11 on 4 and 35 DF,  p-value: 6.958e-06
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
tmp = df %>% filter(Order == "Chloroflexales")
m1 = lm(sAbund.y~Soil.x + SampleType + sAbund.x, data = tmp)
anova(m1)
summary(m1)
# Out:
#           Df Sum Sq       Mean Sq      F value   Pr(>F)
# Soil.x     2 1.933308e-05 9.666542e-06 22.041724 5.619211e-07
# sAbund.x   1 1.816161e-06 1.816161e-06  4.141224 4.926528e-02
# Residuals 36 1.578803e-05 4.385565e-07        NA           NA
# Call:
# lm(formula = sAbund.y ~ Soil.x + sAbund.x, data = tmp)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0012036 -0.0004059 -0.0001311  0.0003879  0.0015989
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)      0.0019417  0.0002063   9.411 3.07e-11 ***
# Soil.xLansing   -0.0013570  0.0002458  -5.522 3.03e-06 ***
# Soil.xPendelton -0.0009756  0.0003026  -3.224  0.00269 **
# sAbund.x         0.3448750  0.1694718   2.035  0.04927 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0006622 on 36 degrees of freedom
# Multiple R-squared:  0.5726,	Adjusted R-squared:  0.537
# F-statistic: 16.07 on 3 and 36 DF,  p-value: 8.545e-07

# %% [markdown]
# #Just sandaracinaceae

# %%
df = full_join(MREtab,Taxtab, by = "sample_Sample")
tmp = df %>% filter(SampleType == "BH")
m1 = lm(sAbund.y~sAbund.x , data = tmp)
summary(m1)

# %%
# Out:
# [1] 0.4643765
# [1] 0.0009379328

# %%
b = round(m1$coefficients[[1]],4)
m = round(m1$coefficients[[2]],4)
eq1 = paste('y = ',m,'x + ', b, sep = '')

r1 = round(summary(m1)$r.squared, 2)
p1 = round(summary(m1)$coefficients[2,4], 3)

EqLabel = paste(eq1, '\n R2 = ', r1, '\n p = ', p1, sep = '')

# %%
cs = brewer.pal(3,"Set2")
 
p1 = df %>%
    #filter(OTU %in% c("ASV14", "ASV18")) %>%
    ggplot(.,aes(x = sAbund.x, y = sAbund.y)) +
        geom_jitter(aes(fill = Soil.x), shape = 21, pch = 2) +
        theme_pub()+
        scale_fill_manual(values = cs) +#, labels = c("Bulk hyphosphere", "Bulk soil"))+
        ylab("Sandaracinus relative abundance") +
        xlab("MRE relative abundance")+
       annotate(geom="text", x=0.0005, y=.0020, label=EqLabel,
             color="black")+
        geom_smooth(aes(x = sAbund.x, y = sAbund.y), method='lm', se = FALSE, color = "Black", lty = 2)
       # facet_grid(Soil.x~OTU)
p1

outfile = file.path(figDir, 'MRExSandaracinus.pdf')
pdf(outfile, width = 4.5, height = 3)
p1
dev.off()
# Out:
# Warning message:
# “Duplicated aesthetics after name standardisation: shape”
# png
#   2
# plot without title

# %% [markdown]
# ### Fibrobacteres

# %%
HASVs
# Out:
#   [1] ASV6     ASV8     ASV14    ASV16    ASV17    ASV18    ASV21    ASV23
#   [9] ASV27    ASV45    ASV47    ASV53    ASV57    ASV61    ASV66    ASV77
#  [17] ASV117   ASV125   ASV190   ASV251   ASV280   ASV283   ASV287   ASV300
#  [25] ASV382   ASV386   ASV412   ASV416   ASV440   ASV462   ASV487   ASV509
#  [33] ASV541   ASV616   ASV638   ASV645   ASV657   ASV672   ASV708   ASV789
#  [41] ASV846   ASV884   ASV894   ASV895   ASV903   ASV910   ASV978   ASV991
#  [49] ASV1017  ASV1032  ASV1067  ASV1146  ASV1182  ASV1199  ASV1263  ASV1370
#  [57] ASV1389  ASV1523  ASV1550  ASV1596  ASV1597  ASV1629  ASV1666  ASV1692
#  [65] ASV1700  ASV1719  ASV1742  ASV1772  ASV1808  ASV1885  ASV2063  ASV2347
#  [73] ASV2472  ASV2577  ASV2641  ASV3040  ASV3056  ASV3191  ASV3374  ASV3640
#  [81] ASV4976  ASV4988  ASV6042  ASV6169  ASV7002  ASV7018  ASV7843  ASV8223
#  [89] ASV30    ASV118   ASV143   ASV157   ASV169   ASV193   ASV214   ASV221
#  [97] ASV247   ASV282   ASV301   ASV312   ASV330   ASV338   ASV341   ASV390
# [105] ASV420   ASV423   ASV428   ASV503   ASV528   ASV561   ASV575   ASV615
# [113] ASV713   ASV770   ASV803   ASV820   ASV838   ASV920   ASV1038  ASV1043
# [121] ASV1075  ASV1103  ASV1139  ASV1141  ASV1142  ASV1194  ASV1248  ASV1417
# [129] ASV1433  ASV1445  ASV1460  ASV1472  ASV1534  ASV1546  ASV1667  ASV1674
# [137] ASV1711  ASV1721  ASV1909  ASV1941  ASV1984  ASV2029  ASV2139  ASV2140
# [145] ASV2161  ASV2353  ASV2374  ASV2448  ASV2457  ASV2518  ASV2579  ASV2606
# [153] ASV2618  ASV2627  ASV2642  ASV2667  ASV2793  ASV2823  ASV2871  ASV2994
# [161] ASV3065  ASV3091  ASV3194  ASV3227  ASV3342  ASV3448  ASV3462  ASV3475
# [169] ASV3476  ASV3679  ASV3807  ASV3909  ASV3973  ASV4048  ASV4150  ASV4264
# [177] ASV4276  ASV4422  ASV4499  ASV4579  ASV4588  ASV4674  ASV4780  ASV5028
# [185] ASV5058  ASV5084  ASV5279  ASV5311  ASV5319  ASV5496  ASV5738  ASV5772
# [193] ASV5898  ASV5915  ASV6051  ASV6267  ASV6358  ASV6501  ASV6574  ASV6682
# [201] ASV6988  ASV7072  ASV7604  ASV8115  ASV8482  ASV9170  ASV9397  ASV9482
# [209] ASV9532  ASV9960  ASV10153 ASV11194 ASV12043 ASV648   ASV1412  ASV1790
# [217] ASV2026  ASV2288  ASV3002  ASV3041  ASV5052
# 18876 Levels: ASV100 ASV1000 ASV10000 ASV10001 ASV10002 ASV10003 ... ASV9999

# %%
ps.tax = ps %>% 
transform_sample_counts(., function(x) x/sum(x)) %>% 
                        #subset_taxa(Phylum == "Fibrobacteres")
                        prune_taxa(c("ASV23", "ASV45", "ASV47"),.)
                        #prune_taxa(c("ASV17"),.)
tax_table(ps.tax)
Taxtab = ps.tax %>% 
    psmelt() %>% 
    filter(Soil != "Sand", Experiment == 2, SampleType %in% c("BS","BH") & Fungus == "Gv") %>%
    group_by(sample_Sample, Soil, SampleType) %>%
    summarise(sAbund = sum(Abundance))
head(Taxtab)
# Out:
#       Kingdom  Phylum        Class         Order           Family
# ASV23 Bacteria Fibrobacteres Fibrobacteria Fibrobacterales Fibrobacteraceae
# ASV45 Bacteria Fibrobacteres Fibrobacteria Fibrobacterales Fibrobacteraceae
# ASV47 Bacteria Fibrobacteres Fibrobacteria Fibrobacterales Fibrobacteraceae
#       Genus
# ASV23 possible_genus_04
# ASV45 possible_genus_04
# ASV47 possible_genus_04
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”
#   sample_Sample Soil      SampleType sAbund
# 1 GVCLHN1-BH    Pendelton BH         0
# 2 GVCLHN1-BS    Pendelton BS         0
# 3 GVCLHN2-BH    Pendelton BH         0
# 4 GVCLHN2-BS    Pendelton BS         0
# 5 GVCLHN3-BH    Pendelton BH         0
# 6 GVCLHN3-BS    Pendelton BS         0

# %%
df = full_join(MREtab,Taxtab, by = "sample_Sample")
tmp = df %>% filter(SampleType == "BH")
m1 = lm(sAbund.y~sAbund.x , data = tmp)
summary(m1)
# Out:
# Call:
# lm(formula = sAbund.y ~ sAbund.x, data = tmp)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -5.812e-04 -2.575e-04 -9.581e-05  1.148e-04  1.263e-03
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.0001713  0.0001605   1.067    0.300
# sAbund.x    0.1645379  0.1385965   1.187    0.251
#
# Residual standard error: 0.0004509 on 18 degrees of freedom
# Multiple R-squared:  0.07261,	Adjusted R-squared:  0.02109
# F-statistic: 1.409 on 1 and 18 DF,  p-value: 0.2506

# %%
b = round(m1$coefficients[[1]],4)
m = round(m1$coefficients[[2]],4)
eq1 = paste('y = ',m,'x + ', b, sep = '')

r1 = round(summary(m1)$r.squared, 2)
p1 = round(summary(m1)$coefficients[2,4], 3)

EqLabel = paste(eq1, '\n R2 = ', r1, '\n p = ', p1, sep = '')

# %%
cs = brewer.pal(3,"Set2")
 
p2 = df %>%
    #filter(OTU %in% c("ASV14", "ASV18")) %>%
    ggplot(.,aes(x = sAbund.x, y = sAbund.y)) +
        geom_jitter(aes(fill = Soil.x), shape = 21, pch = 2) +
        theme_pub()+
        scale_fill_manual(values = cs) +#, labels = c("Bulk hyphosphere", "Bulk soil"))+
        ylab("Fibrobacteres relative abundance") +
        xlab("MRE relative abundance")+
       annotate(geom="text", x=0.0005, y=.0020, label=EqLabel,
             color="black")+
        geom_smooth(aes(x = sAbund.x, y = sAbund.y), method='lm', se = FALSE, color = "Black", lty = 2)
       # facet_grid(Soil.x~OTU)
p2
# Out:
# Warning message:
# “Duplicated aesthetics after name standardisation: shape”
# plot without title

# %%
DC = read.delim(file = '~/Hyphosphere/Exp11/QuickDirtyDNAconc.txt', header = TRUE)
head(DC)

# %%
df.2 = left_join(df, DC, by = c('sample_Sample' = "Sample"))
head(df.2)

# %%
p1 = df.2 %>%
    ggplot(.,aes(x = DNA_conc, y = sAbund.y, fill = Soil.x)) +
        geom_point(pch = 21) +
        theme_pub()

outfile = file.path(figDir, 'SandaracinusxDNAconc.pdf')
pdf(outfile, width = 4.5, height = 3)
p1
dev.off()

# %%
df.2 %>%
    ggplot(.,aes(x = DNA_conc, y = sAbund )) +
        geom_point() +
        facet_wrap(~Soil.x)

# %%
tmp = filter(df.2, OTU == "ASV14")
m1 = lm(sAbund~DNA_conc , data = tmp)
summary(m1)

# %%
df.2 %>% 
    select(sample_Sample, Soil.x, sAbund, Abundance, OTU) %>%
    dcast(., sample_Sample + Soil.x ~ OTU, value.var = "Abundance", fun.aggregate = mean)

# %%
df.2 %>% 
    select(sample_Sample, Soil.x, sAbund, Abundance, OTU) %>%
    dcast(., sample_Sample + Soil.x ~ OTU, value.var = "Abundance", fun.aggregate = mean) %>%
    ggplot(.,aes(x = ASV14, y = ASV18)) +
        geom_point() +
        facet_wrap(~Soil.x)

# %%
ps.m %>% filter(OTU == "ASV14" & SampleType %in% c("BP", "CS")) %>%
 left_join(., DC, by = c('sample_Sample' = "Sample")) %>%
     ggplot(.,aes(x = DNA_conc, y = Abundance)) +
        geom_point() +
        facet_grid(SampleType~Soil)

# %%
# Check ASV 14 in all samples

# %%
Taxtab = ps %>% 
transform_sample_counts(., function(x) x/sum(x)) %>% 
                        prune_taxa(c("ASV14","ASV18"),.) %>%
                        psmelt()
                        #prune_taxa(c("ASV17"),.)
head(Taxtab)

# %%
df.2 = left_join(Taxtab, DC, by = c('sample_Sample' = "Sample"))
df.2 %>% filter(sample_Sample == "GVFLHP1-CH")

# %%
df.2 %>% 
    filter(OTU == "ASV14" & SampleType %in% c("BP", "BH", "CS", "RH", "RS", "CH", "BS")) %>%
    ggplot(., aes(x = DNA_conc, y = Abundance)) +
        geom_point(aes(color = Fungus, shape = Soil))+
        facet_wrap(~SampleType, scales = "free", ncol = 2) +
        theme(legend.position = "bottom") #+
        #scale_y_continuous(trans = "log2")

# %%
tmp = ps %>% 
    subset_samples(Sample == "GVFLHP1-CH") %>%
    transform_sample_counts(., function(x) x/sum(x)) %>% 
    psmelt() %>% 
    arrange(desc(Abundance)) %>% select(Abundance, OTU, Phylum, Class, Order, Family)
tmp[1:100,]

# %%
tmp %>% group_by(Family) %>% summarise(sAbund = sum(Abundance)) %>% arrange(desc(sAbund))

# %% [markdown]
# # Save deseqtable

# %%
write.table(df.l2fc.CHCS, file = '~/Hyphosphere/Exp11/df_l2fc_CHCS_bothtreatments.txt', sep = '\t')
