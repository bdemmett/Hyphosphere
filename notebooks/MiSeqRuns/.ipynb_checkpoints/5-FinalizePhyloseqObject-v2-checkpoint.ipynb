# %% [markdown]
# # Finalize merged dataset
# * Incorporate phylogenetic tree into phyloseq object
# * Save master and split versions

# %%
library(dada2)
library(tidyr)
library(dplyr)
library(phyloseq)
library(ggplot2)
library(ape)
# Out:
# Loading required package: Rcpp
# Warning message:
# “package ‘Rcpp’ was built under R version 3.6.1”Warning message:
# “multiple methods tables found for ‘lengths’”Warning message:
# “multiple methods tables found for ‘rowSums’”Warning message:
# “multiple methods tables found for ‘colSums’”Warning message:
# “multiple methods tables found for ‘rowMeans’”Warning message:
# “multiple methods tables found for ‘colMeans’”
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Warning message:
# “package ‘phyloseq’ was built under R version 3.6.1”Warning message:
# “package ‘ggplot2’ was built under R version 3.6.1”Warning message:
# “package ‘ape’ was built under R version 3.6.1”

# %%
ps.thresh = readRDS('~/Hyphosphere/data/3Exp/phyloseq/3Exp_phyloseq_thresh.rds')
ps.thresh
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 19559 taxa and 434 samples ]
# sample_data() Sample Data:       [ 434 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 19559 taxa by 6 taxonomic ranks ]

# %% [markdown]
# # Remove duplicate samples from experiment 3

# %%
samples = sample_names(ps.thresh)
# These samples have higher contaminants than the replicates on plate 1 and so
# rather than merging the samples they are removed here
Duplicates = c('155_1.3RH', '156_2.3RH','157_3.3RH','158_1.4RH', '159_2.4RH')
samplestokeep = samples[!(samples %in% Duplicates)]
ps.thresh = prune_samples(samplestokeep, ps.thresh)
sample_names(ps.thresh)
# allTaxa = taxa_names(ps)
# allTaxa <- allTaxa[!(allTaxa %in% FC)]
# ps.sub = prune_taxa(allTaxa, ps)
# ps.thresh %>% subset_samples(Experiment == 3) %>% subset_samples(!sample_names(ps.thresh) %in% ) %>% sample_names()
# Out:
#   [1] "10xBLS156_S303"        "2xBLS143_S297"         "5xBLS120_S300"
#   [4] "BaseA_S310"            "BaseB_S291"            "BaseC_S294"
#   [7] "HCBF1_S247"            "HCBF2_S259"            "HCBF3_S271"
#  [10] "HCBN1_S211"            "HCBN2_S223"            "HCBN3_S235"
#  [13] "HCBP1_S283"            "HCBP2_S200"            "HCBP3_S212"
#  [16] "HCBS1_S224"            "HCBS2_S236"            "HCBS3_S248"
#  [19] "HCHF1_S250"            "HCHF2_S262"            "HCHF3_S274"
#  [22] "HCHN1_S214"            "HCHN2_S226"            "HCHN3_S238"
#  [25] "HCHP1_S286"            "HCHP2_S203"            "HCHP3_S215"
#  [28] "HCHS1_S227"            "HCHS2_S239"            "HCHS3_S251"
#  [31] "HCRF1_S201"            "HCRF2_S213"            "HCRF3_S225"
#  [34] "HCRN1_S260"            "HCRN2_S272"            "HCRN3_S284"
#  [37] "HCRP1_S237"            "HCRP2_S249"            "HCRP3_S261"
#  [40] "HCRS1_S273"            "HCRS2_S285"            "HCRS3_S202"
#  [43] "Hneg1_S263"            "NegativeH2O_S282"      "UMGC_H2O_001_A04_S4"
#  [46] "UMGC_H2O_001_A06_S6"   "UMGC_H2O_002_B04_S112" "UMGC_H2O_002_B06_S114"
#  [49] "UMGC_H2O_003_A07_S199" "UMGC_H2O_003_G11_S275" "UMGC_H2O_004_F03_S306"
#  [52] "1_3.1RH"               "10_2.1RH"              "100_5.5BP"
#  [55] "101_5.5CS"             "102_5.5BS"             "103_6.5BP"
#  [58] "104_6.5CS"             "105_6.5BS"             "106_6.1BP"
#  [61] "107_5.1BP"             "108_6.1RT"             "109_5.1RT"
#  [64] "11_1.1CS"              "110_4.1RT"             "111_4.2BP"
#  [67] "112_4.2BS"             "113_4.2CS"             "114_3.2CS"
#  [70] "115_5.2BS"             "116_5.2BP"             "117_6.2BP"
#  [73] "118_6.2BS"             "119_4.3BP"             "12_3.1CS"
#  [76] "120_6.2CS"             "121_4.3BS"             "122_4.3CS"
#  [79] "123_5.3BP"             "124_5.3BS"             "125_5.3CS"
#  [82] "126_6.3BP"             "127_6.3BS"             "128_6.3CS"
#  [85] "129_5.2RT"             "13_1.2RH"              "130_4.3RT"
#  [88] "131_5.3RT"             "132_6.3RT"             "133_4.2RT"
#  [91] "134_6.2RT"             "135_4.4RT"             "136_5.4RT"
#  [94] "137_6.4RT"             "138_4.4BP"             "139_4.4CS"
#  [97] "14_1.2CH"              "140_4.4BS"             "141_5.4BS"
# [100] "142_5.4BP"             "143_5.4CS"             "144_6.4BP"
# [103] "145_6.4CS"             "146_6.4BS"             "147_T0R1"
# [106] "148_T0R2"              "149_T0R3"              "15_1.2BP"
# [109] "150_T0R4"              "151_ExtractionBlank"   "152_GvSpores"
# [112] "153_T0R5"              "154_T0R6"              "16_2.2RH"
# [115] "161_4.1CH"             "162_4.1RH"             "163_4.4CH"
# [118] "164_4.4RH"             "165_5.1CH"             "166_5.1RH"
# [121] "167_5.4CH"             "168_5.4RH"             "169_6.1CH"
# [124] "17_2.2CH"              "170_6.1RH"             "171_6.4CH"
# [127] "172_6.4RH"             "173_4.2CH"             "174_4.2RH"
# [130] "175_4.5CH"             "176_4.5RH"             "177_5.2CH"
# [133] "178_5.2RH"             "179_5.5CH"             "18_2.2BP"
# [136] "180_5.5RH"             "181_6.2CH"             "182_6.2RH"
# [139] "183_6.5CH"             "184_6.5RH"             "185_4.3CH"
# [142] "186_4.3RH"             "187_5.3CH"             "188_5.3RH"
# [145] "189_6.3CH"             "19_3.2RH"              "190_6.3RH"
# [148] "191_Mock-2"            "192_ExtractionBlank"   "2_3.1BP"
# [151] "20_3.2CH"              "21_3.2BP"              "22_1.3RH"
# [154] "23_1.3CH"              "24_1.3BP"              "25_2.3CH"
# [157] "26_2.3CH"              "27_2.3RH"              "28_2.3BP"
# [160] "29_3.3CH"              "3_2.1CH"               "30_3.3RH"
# [163] "31_3.3BP"              "32_1.4CH"              "33_1.4RH"
# [166] "34_1.4BP"              "35_2.4CH"              "36_2.4RH"
# [169] "37_2.4BP"              "38_3.4CH"              "39_3.4RH"
# [172] "4_2.1BP"               "40_3.4BP"              "41_1.5CH"
# [175] "42_1.5BP"              "43_2.5CH"              "44_2.5RH"
# [178] "45_2.5BP"              "46_3.5CH"              "47_3.5RH"
# [181] "48_3.5BP"              "49_3.5BS"              "5_1.1RH"
# [184] "50_2.5BS"              "51_1.5BS"              "52_2.5CS"
# [187] "53_1.3BS"              "54_1.3BS"              "55_2.3BS"
# [190] "56_3.3BS"              "57_1.3CS"              "58_2.3CS"
# [193] "59_3.3CS"              "6_3.1CH"               "60_2.4BS"
# [196] "61_2.4CS"              "62_1.5CS"              "63_1.4BS"
# [199] "64_1.4CS"              "65_3.4CS"              "66_4.1BP"
# [202] "67_4.1BS"              "68_5.1BS"              "69_6.1BS"
# [205] "7_2.1CS"               "70_4.1CS"              "71_6.1CS"
# [208] "72_5.1CS"              "73_1.3RT"              "74_2.3RT"
# [211] "75_3.3RT"              "76_1.4RT"              "77_2.4RT"
# [214] "78_3.4RT"              "79_1.2RT"              "8_1.1BP"
# [217] "80_2.2RT"              "81_3.2RT"              "82_1.1RT"
# [220] "83_2.1RT"              "84_3.1RT"              "85_1.2CS"
# [223] "86_2.2CS"              "87_5.2CS"              "88_1.1BS"
# [226] "89_2.2BS"              "9_1.1CH"               "90_2.1BS"
# [229] "91_1.2BS"              "92_3.2BS"              "93_3.1BS"
# [232] "94_ExtractionBlank"    "95_Mock"               "96_ExtractionBlank"
# [235] "97_4.5BP"              "98_4.5CS"              "99_4.5BS"
# [238] "1_GVCLHN1-BH"          "10_GVFLHP1-BS"         "100_GVCLHN4-BS"
# [241] "101_GVFLHN3-BH"        "102_GVFLHN3-BS"        "103_GVFLHN4-BH"
# [244] "104_GVFLHN4-BS"        "105_GVFLHP3-BH"        "106_GVFLHP3-BS"
# [247] "107_GVFLHP4-BH"        "108_GVFLHP4-BS"        "109_GVN7HN3-BH"
# [250] "11_GVFLHP2-BH"         "110_GVN7HN3-BS"        "111_GVN7HN4-BH"
# [253] "112_GVN7HN4-BS"        "113_GVN7HP3-BH"        "114_GVN7HP3-BS"
# [256] "115_GVN7HP4-BH"        "116_GVN7HP4-BS"        "117_RIFLHN3-BH"
# [259] "118_RIFLHN3-BS"        "119_RIFLHN4-BH"        "12_GVFLHP2-BS"
# [262] "120_RIFLHN4-BS"        "121_RIFLHP3-BH"        "122_RIFLHP3-BS"
# [265] "123_RIFLHP4-BH"        "124_RIFLHP4-BS"        "125_RIN7HN3-BH"
# [268] "126_RIN7HN3-BS"        "127_RIN7HN4-BH"        "128_RIN7HN4-BS"
# [271] "129_RIN7HP3-BH"        "13_GVN7HN1-BH"         "130_RIN7HP3-BS"
# [274] "131_RIN7HP4-BH"        "132_RIN7HP4-BS"        "133_GVCLHN3-BP"
# [277] "134_GVCLHN3-CS"        "135_GVCLHN4-BP"        "136_GVCLHN4-CS"
# [280] "137_GVFLHN3-BP"        "138_GVFLHN3-CS"        "139_GVFLHN4-BP"
# [283] "14_GVN7HN1-BS"         "140_GVFLHN4-CS"        "141_GVFLHP3-BP"
# [286] "142_GVFLHP3-CS"        "143_GVFLHP4-BP"        "144_GVFLHP4-CS"
# [289] "145_GVN7HN3-BP"        "146_GVN7HN3-CS"        "147_GVN7HN4-BP"
# [292] "148_GVN7HN4-CS"        "149_GVN7HP3BP"         "15_GVN7HN2-BH"
# [295] "150_GVN7HP3-CS"        "151_GVN7HP4-BP"        "152_GVN7HP4-CS"
# [298] "153_RIN7HN3-CS"        "154_RIN7HN4-CS"        "155_RIN7HP3-CS"
# [301] "156_RIN7HP4-CS"        "157_GVCLHN3-CH"        "158_GVCLHN3-RH"
# [304] "159_GVCLHN3-RS"        "16_GVN7HN2-BS"         "160_GVCLHN4-CH"
# [307] "161_GVCLHN4-RH"        "162_GVCLHN4-RS"        "163_GVFLHN3-CH"
# [310] "164_GVFLHN3-RH"        "165_GVFLHN3-RS"        "166_GVFLHN4-CH"
# [313] "167_GVFLHN4-RH"        "168_GVFLHN4-RS"        "169_GVFLHP3-CH"
# [316] "17_GVN7HP1-BH"         "170_GVFLHP4-CH"        "171_GVN7HN3-CH"
# [319] "172_GVN7HN3-RH"        "173_GVN7HN4-CH"        "174_GVN7HN4-RH"
# [322] "175_GVN7HN4-RS"        "176_GVN7HP3-CH"        "177_GVN7HP4-CH"
# [325] "178_RIN7HN3-CH"        "179_RIN7HN3-RH"        "18_GVN7HP1-BS"
# [328] "180_RIN7HN3-RS"        "181_RIN7HN4-CH"        "182_RIN7HN4-RH"
# [331] "183_RIN7HN4-RS"        "184_RIN7HP3-CH"        "185_RIN7HP4-CH"
# [334] "186_Unknown-RS"        "187_139-BK"            "188_155-BK"
# [337] "189_187-BK"            "19_GVN7HP2-BH"         "190_GVN7HP2-BH"
# [340] "191_GVCLHN2-BS"        "192_MockComm"          "2_GVCLHN1-BS"
# [343] "20_GVN7HP2-BS"         "21_RIFLHN1-BH"         "22_RIFLHN1-BS"
# [346] "23_RIFLHN2-BH"         "24_RIFLHN2-BS"         "25_RIFLHP1-BH"
# [349] "26_RIFLHP1-BS"         "27_RIFLHP2-BH"         "28_RIFLHP2-BS"
# [352] "29_RIN7HN1-BH"         "3_GVCLHN2-BH"          "30_RIN7HN1-BS"
# [355] "31_RIN7HN2-BH"         "32_RIN7HN2-BS"         "33_RIN7HP1-BH"
# [358] "34_RIN7HP1-BS"         "35_RIN7HP2-BH"         "36_RIN7HP2-BS"
# [361] "37_GVCLHN1-BP"         "38_GVCLHN1-CS"         "39_GVCLHN2-BP"
# [364] "4_GVCLHN2-BS"          "40_GVCLHN2-CS"         "41_GVFLHN1-BP"
# [367] "42_GVFLHN1-CS"         "43_GVFLHN2-BP"         "44_GVFLHN2-CS"
# [370] "45_GVFLHP1-BP"         "46_GVFLHP1-CS"         "47_GVFLHP2-BP"
# [373] "48_GVFLHP2-CS"         "49_GVN7HN1-BP"         "5_GVFLHN1-BH"
# [376] "50_GVN7HN1-CS"         "51_GVN7HN2-BP"         "52_GVN7HN2-CS"
# [379] "53_GVN7HP1-BP"         "54_GVN7HP1-CS"         "55_GVN7HP2-BP"
# [382] "56_GVN7HP2-CS"         "57_RIN7HN1-CS"         "58_RIN7HN2-CS"
# [385] "59_RIN7HP1-CS"         "6_GVFLHN1-BS"          "60_RIN7HP2-CS"
# [388] "61_GVCLHN1-CH"         "62_GVCLHN1-RH"         "63_GVCLHN1-RS"
# [391] "64_GVCLHN2-CH"         "65_GVCLHN2-RH"         "66_GVCLHN2-RS"
# [394] "67_GVFLHN1-CH"         "68_GVFLHN1-RH"         "69_GVFLHN1-RS"
# [397] "7_GVFLHN2-BH"          "70_GVFLHN2-CH"         "71_GVFLHN2-RH"
# [400] "72_GVFLHN2-RS"         "73_GVFLHP1-CH"         "74_GVFLHP2-CH"
# [403] "75_GVN7HN1-CH"         "76_GVN7HN1-RS"         "77_GVN7HN1-RH"
# [406] "78_GVN7HN2-CH"         "79_GVN7HN2-RH"         "8_GVFLHN2-BS"
# [409] "80_GVN7HN2-RS"         "81_GVN7HP1-CH"         "82_GVN7HP2-CH"
# [412] "83_RIN7HN1-CH"         "84_RIN7HN1-RH"         "85_RIN7HN2-CH"
# [415] "86_RIN7HN2-RH"         "87_RIN7HP1-CH"         "88_RIN7HP2-CH"
# [418] "89_125-BK"             "9_GVFLHP1-BH"          "90_29-BK"
# [421] "91_77-BK"              "92_PCRblank"           "93_PCRblank"
# [424] "94_GVN7HP2-BS"         "95_GVCLHN2-CH"         "96_GVFLHN2-RS"
# [427] "97_GVCLHN3-BH"         "98_GVCLHN3-BS"         "99_GVCLHN4-BH"

# %%
thresh.tree = read_tree(treefile = '~/Hyphosphere/data/3Exp/Fasttree/Master_wSulfo.tree')
#is.rooted(thresh.tree)
thresh.tree = root(thresh.tree, outgroup = 'X90478', r = TRUE)
is.rooted(thresh.tree)
thresh.tree

# root.by.outgroup <- function(tree.unrooted) {
#   longest.edge <- which.max(tree.unrooted$edge.length)
#   long.nodes <- tree.unrooted$edge[longest.edge,]     #this should usually include one tip
#   new.outgroup <- long.nodes[long.nodes < Ntip(tree.unrooted)]
#   tree.rooted <- root(tree.unrooted, outgroup=new.outgroup, resolve.root=T)
#   tree.rooted
# }

# require(ape)
# thresh.tree = root.by.outgroup(thresh.tree)
# Out:
# [1] TRUE
# Phylogenetic tree with 19309 tips and 19245 internal nodes.
#
# Tip labels:
# 	X90478, ASV6971, ASV2480, ASV5742, ASV15180, ASV9985, ...
# Node labels:
# 	Root, 0.804, 0.000, 0.876.74, 0.947, 0.950, ...
#
# Rooted; includes branch lengths.

# %% [markdown]
# # join bacterial tree with physeq object

# %%
ps = merge_phyloseq(ps.thresh, thresh.tree)
#force polytomies to dichotomies
phy_tree(ps) = multi2di(phy_tree(ps), random = FALSE)
ps
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 19308 taxa and 429 samples ]
# sample_data() Sample Data:       [ 429 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 19308 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 19308 tips and 19307 internal nodes ]

# %%
#remove mitochondria
ps = subset_taxa(ps, Family != "Mitochondria" | is.na(Family))
ps = subset_taxa(ps, Order != "Chloroplast" | is.na(Order))
ps
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 19241 taxa and 429 samples ]
# sample_data() Sample Data:       [ 429 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 19241 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 19241 tips and 19240 internal nodes ]

# %%
saveRDS(ps, '~/Hyphosphere/data/3Exp/phyloseq/final/3Exp_phyloseq_thresh_wtree.rds')

# %% [markdown]
# ## save with contaminants removed see notebook 6

# %%
FC = c("ASV1", 
"ASV54" ,
"ASV78", 
"ASV136", 
"ASV3", 
"ASV12",
"ASV2516",
"ASV681", 
"ASV447",
"ASV49", 
"ASV12695", 
"ASV2395", 
"ASV284", 
"ASV1706", 
"ASV1900", 
"ASV26", 
"ASV14332", 
"ASV2962",
"ASV9101",
"ASV2180", 
"ASV8061", 
"ASV4437", 
"ASV6987", 
"ASV2714",
"ASV2160", 
"ASV2117", 
"ASV2704", 
"ASV1002", 
"ASV4083",
"ASV7871", 
"ASV1900", 
"ASV171", 
"ASV2516", 
"ASV8536",
"ASV285", 
"ASV3225", 
"ASV5265", 
"ASV2962", 
"ASV14282")

# %%
allTaxa = taxa_names(ps)
allTaxa <- allTaxa[!(allTaxa %in% FC)]
ps.sub = prune_taxa(allTaxa, ps)
# new phyloseq object with just the taxa you kept.
ps.sub
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 19205 taxa and 429 samples ]
# sample_data() Sample Data:       [ 429 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 19205 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 19205 tips and 19204 internal nodes ]

# %%
saveRDS(ps.sub, '~/Hyphosphere/data/3Exp/phyloseq/final/3Exp_phyloseq_thresh_wtree_woContam.rds')

# %% [markdown]
# ### merge duplicates and save experimental samples

# %%
ps.sub.m = ps.sub %>% merge_samples(., "Sample")

# %% [markdown]
# ### re-map factors

# %%
sample_data(ps.sub.m)$Sample <- sample_names(ps.sub.m)
sample_data(ps.sub.m)$Fungus <- levels(sample_data(ps.sub)$Fungus)[get_variable(ps.sub.m, "Fungus")]
sample_data(ps.sub.m)$Plant <- levels(sample_data(ps.sub)$Plant)[get_variable(ps.sub.m, "Plant")]
sample_data(ps.sub.m)$Soil <- levels(sample_data(ps.sub)$Soil)[get_variable(ps.sub.m, "Soil")]
sample_data(ps.sub.m)$SampleType <- levels(sample_data(ps.sub)$SampleType)[get_variable(ps.sub.m, "SampleType")]
sample_data(ps.sub.m)$Treatment <- levels(sample_data(ps.sub)$Treatment)[get_variable(ps.sub.m, "Treatment")]

# %%
sample_data(ps.sub.m)[sample_data(ps.sub.m)$Experiment == 3,] %>% head()
# Out:
#       Sample Experiment Plant Fungus Soil   SampleType Treatment TimePoint DAI
# 1.1BP 1.1BP  3          1.1   Gv     Dryden BP         HN        1         14
# 1.1BS 1.1BS  3          1.1   Gv     Dryden BS         HN        1         14
# 1.1CH 1.1CH  3          1.1   Gv     Dryden CH         HN        1         14
# 1.1CS 1.1CS  3          1.1   Gv     Dryden CS         HN        1         14
# 1.1RH 1.1RH  3          1.1   Gv     Dryden RH         HN        1         14
# 1.1RT 1.1RT  3          1.1   Gv     Dryden RT         HN        1         14
#       Rep Concentration_ng.ul
# 1.1BP 1   1.067
# 1.1BS 1   4.421
# 1.1CH 1   0.325
# 1.1CS 1   2.116
# 1.1RH 1   0.174
# 1.1RT 1   1.561

# %%
sample_data(ps.sub.m)$SampleType %>% unique()
# Out:
#  [1] "BP" "BS" "CH" "CS" "RH" "RT" "MK" "EB" "BH" "RS" "GV" "PB" "T0"

# %%
outfile = ps.sub.m %>% subset_samples(., 
            !SampleType %in% c("MK", "EB", "PB", "T0")) %>%
            subset_samples(!Sample == "Unknown-RS")
outfile
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 19205 taxa and 385 samples ]
# sample_data() Sample Data:       [ 385 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 19205 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 19205 tips and 19204 internal nodes ]

# %%
saveRDS(outfile, '~/Hyphosphere/data/3Exp/phyloseq/final/3Exp_phyloseq_thresh_wtree_experimental_woContam.rds')

# %% [markdown]
# # now larger object without tree

# %%
allTaxa = taxa_names(ps.thresh)
allTaxa <- allTaxa[!(allTaxa %in% FC)]
ps.sub = prune_taxa(allTaxa, ps.thresh)
# new phyloseq object with just the taxa you kept.
ps.sub
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 19523 taxa and 429 samples ]
# sample_data() Sample Data:       [ 429 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 19523 taxa by 6 taxonomic ranks ]

# %%
#remove mitochondria
ps.sub = subset_taxa(ps.sub, Family != "Mitochondria" | is.na(Family))
ps.sub = subset_taxa(ps.sub, Order != "Chloroplast" | is.na(Order))
ps.sub
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 19433 taxa and 429 samples ]
# sample_data() Sample Data:       [ 429 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 19433 taxa by 6 taxonomic ranks ]

# %% [markdown]
# ### merge duplicates and save experimental samples

# %%
ps.sub.m = ps.sub %>% merge_samples(., "Sample")

# %% [markdown]
# ### re-map factors

# %%
sample_data(ps.sub.m)$Sample <- sample_names(ps.sub.m)
sample_data(ps.sub.m)$Fungus <- levels(sample_data(ps.sub)$Fungus)[get_variable(ps.sub.m, "Fungus")]
sample_data(ps.sub.m)$Plant <- levels(sample_data(ps.sub)$Plant)[get_variable(ps.sub.m, "Plant")]
sample_data(ps.sub.m)$Soil <- levels(sample_data(ps.sub)$Soil)[get_variable(ps.sub.m, "Soil")]
sample_data(ps.sub.m)$SampleType <- levels(sample_data(ps.sub)$SampleType)[get_variable(ps.sub.m, "SampleType")]
sample_data(ps.sub.m)$Treatment <- levels(sample_data(ps.sub)$Treatment)[get_variable(ps.sub.m, "Treatment")]

# %%
sample_data(ps.sub.m)[sample_data(ps.sub.m)$Experiment == 3,] %>% head()
# Out:
#       Sample Experiment Plant Fungus Soil   SampleType Treatment TimePoint DAI
# 1.1BP 1.1BP  3          1.1   Gv     Dryden BP         HN        1         14
# 1.1BS 1.1BS  3          1.1   Gv     Dryden BS         HN        1         14
# 1.1CH 1.1CH  3          1.1   Gv     Dryden CH         HN        1         14
# 1.1CS 1.1CS  3          1.1   Gv     Dryden CS         HN        1         14
# 1.1RH 1.1RH  3          1.1   Gv     Dryden RH         HN        1         14
# 1.1RT 1.1RT  3          1.1   Gv     Dryden RT         HN        1         14
#       Rep Concentration_ng.ul
# 1.1BP 1   1.067
# 1.1BS 1   4.421
# 1.1CH 1   0.325
# 1.1CS 1   2.116
# 1.1RH 1   0.174
# 1.1RT 1   1.561

# %%
sample_data(ps.sub.m)$SampleType %>% unique()
# Out:
#  [1] "BP" "BS" "CH" "CS" "RH" "RT" "MK" "EB" "BH" "RS" "GV" "PB" "T0"

# %%
outfile = ps.sub.m %>% subset_samples(., 
            !SampleType %in% c("MK", "EB", "PB", "T0")) %>%
            subset_samples(!Sample == "Unknown-RS")
outfile
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 19433 taxa and 385 samples ]
# sample_data() Sample Data:       [ 385 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 19433 taxa by 6 taxonomic ranks ]

# %%
saveRDS(outfile, '~/Hyphosphere/data/3Exp/phyloseq/final/3Exp_phyloseq_thresh_woTree_experimental_woContam.rds')

# %%
sessionInfo()
# Out:
# R version 3.6.0 (2019-04-26)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 16.04.6 LTS
#
# Matrix products: default
# BLAS/LAPACK: /data/home/be68/anaconda3/envs/MyR/lib/R/lib/libRblas.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] ape_5.3         ggplot2_3.2.1   phyloseq_1.28.0 dplyr_1.0.0
# [5] tidyr_1.1.0     dada2_1.10.0    Rcpp_1.0.2
#
# loaded via a namespace (and not attached):
#  [1] Biobase_2.44.0              splines_3.6.0
#  [3] jsonlite_1.6                foreach_1.4.7
#  [5] RcppParallel_4.4.2          stats4_3.6.0
#  [7] latticeExtra_0.6-28         GenomeInfoDbData_1.2.1
#  [9] Rsamtools_1.34.0            pillar_1.4.2
# [11] lattice_0.20-38             glue_1.4.1
# [13] uuid_0.1-2                  digest_0.6.20
# [15] GenomicRanges_1.34.0        RColorBrewer_1.1-2
# [17] XVector_0.24.0              colorspace_1.4-1
# [19] htmltools_0.3.6             Matrix_1.2-17
# [21] plyr_1.8.4                  pkgconfig_2.0.2
# [23] ShortRead_1.40.0            zlibbioc_1.30.0
# [25] purrr_0.3.2                 scales_1.0.0
# [27] BiocParallel_1.16.6         tibble_2.1.3
# [29] mgcv_1.8-28                 generics_0.0.2
# [31] IRanges_2.18.2              withr_2.1.2
# [33] SummarizedExperiment_1.12.0 repr_0.15.0
# [35] BiocGenerics_0.30.0         lazyeval_0.2.2
# [37] survival_2.44-1.1           magrittr_1.5
# [39] crayon_1.3.4                evaluate_0.11
# [41] nlme_3.1-141                MASS_7.3-51.4
# [43] hwriter_1.3.2               vegan_2.5-5
# [45] tools_3.6.0                 data.table_1.12.2
# [47] lifecycle_0.2.0             matrixStats_0.54.0
# [49] stringr_1.4.0               Rhdf5lib_1.6.0
# [51] S4Vectors_0.22.0            munsell_0.5.0
# [53] cluster_2.1.0               DelayedArray_0.8.0
# [55] Biostrings_2.52.0           ade4_1.7-13
# [57] compiler_3.6.0              GenomeInfoDb_1.18.1
# [59] rlang_0.4.6                 rhdf5_2.28.0
# [61] grid_3.6.0                  RCurl_1.95-4.12
# [63] pbdZMQ_0.3-3                iterators_1.0.12
# [65] IRkernel_0.8.12             biomformat_1.12.0
# [67] igraph_1.2.4.1              bitops_1.0-6
# [69] base64enc_0.1-3             multtest_2.40.0
# [71] gtable_0.3.0                codetools_0.2-16
# [73] reshape2_1.4.3              R6_2.4.0
# [75] GenomicAlignments_1.18.1    permute_0.9-5
# [77] stringi_1.4.3               parallel_3.6.0
# [79] IRdisplay_0.5.0             vctrs_0.3.1
# [81] tidyselect_1.1.0
