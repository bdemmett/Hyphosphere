# %% [markdown]
# # Format metadata tables for NCBI upload

# %%
library(tidyr)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
#Metadata file
SamData = '~/Hyphosphere/3exp_metadata.txt'

# read sample data
samdf = read.delim(file = SamData, header = TRUE, sep = '\t', row.names = "SampleID")
head(samdf)
rownames(samdf)[1:4]
# Out:
#            Sample Experiment Plant Fungus Soil     SampleType Treatment
# HCBN1_S211 HCBN1  1          N1    Gv     Lansing  CS         HN
# HCBN2_S223 HCBN2  1          N2    Gv     Lansing  CS         HN
# HCBN3_S235 HCBN3  1          N3    Gv     Lansing  CS         HN
# HCBF1_S247 HCBF1  1          F1    Gv     Florence CS         HN
# HCBF2_S259 HCBF2  1          F2    Gv     Florence CS         HN
# HCBF3_S271 HCBF3  1          F3    Gv     Florence CS         HN
#            TimePoint DAI Rep Concentration_ng.ul
# HCBN1_S211 NA        81  1   6.08
# HCBN2_S223 NA        81  2   7.58
# HCBN3_S235 NA        81  3   7.05
# HCBF1_S247 NA        81  1   2.32
# HCBF2_S259 NA        81  2   2.08
# HCBF3_S271 NA        81  3   1.89
# [1] "HCBN1_S211" "HCBN2_S223" "HCBN3_S235" "HCBF1_S247"

# %% [markdown]
# # Format biosample attributes

# %%
samdf$SampleType %>% levels()
# Out:
#  [1] "BH" "BP" "BS" "CH" "CS" "EB" "GV" "MK" "PB" "RH" "RS" "RT" "T0"

# %%
SampleType = c('BH', 'BP', 'BS', 'CH', 'CS', 'EB', 'GV', 'MK', 'PB', 'RH', 'RS', 'RT', 'T0')
sample_type = c("Hyphosphere soil", "Particulate organic matter", "Bulk soil", "Hyphae", "Soil slurry", "Extraction blank",
               'G. versiforme spores', 'Mock community','PCR blank', "Hyphae - root compartment", "Sand slurry - root compartment", 'Roots', 
                'T0 soil samples')

stlookup = cbind(SampleType, sample_type) %>% as.data.frame()
stlookup
# Out:
#    SampleType sample_type
# 1  BH         Hyphosphere soil
# 2  BP         Particulate organic matter
# 3  BS         Bulk soil
# 4  CH         Hyphae
# 5  CS         Soil slurry
# 6  EB         Extraction blank
# 7  GV         G. versiforme spores
# 8  MK         Mock community
# 9  PB         PCR blank
# 10 RH         Hyphae - root compartment
# 11 RS         Sand slurry - root compartment
# 12 RT         Roots
# 13 T0         T0 soil samples

# %%
colnames(tmp)
# Out:
# Error in is.data.frame(x): object 'tmp' not found
# Traceback:
#
# 1. colnames(tmp)
# 2. is.data.frame(x)

# %%
SampleAttributes = samdf %>% 
    mutate(sample_name = row.names(.),
          bioproject_accession = NA,
          organism = ifelse(SampleType == "RT", 'rhizosphere metagenome', 
                           ifelse(SampleType %in% c('BH','BP','BS','CH','CS', 'RH', 'GV', 'RS','T0'),
                            'soil metagenome',
                            ifelse(SampleType == 'MK', 'synthetic metagenome', 'not applicable'))),
          host = ifelse(SampleType == 'RT', 'Brachypodium distachyon',
                       ifelse(SampleType %in% c('BH','BP','BS','CS', 'RS','T0'),'soil', 
                       ifelse(SampleType == "GV", "Glomus versiforme",
                       ifelse(SampleType %in% c("RH", "CH") & Fungus == "Gv", "Glomus versiforme",
                       ifelse(SampleType %in% c("RH", "CH") & Fungus == "RI", "Rhizophagus irregularis", 
                       ifelse(SampleType %in% c("EB", "PB", 'MK'), 'not applicable', NA)))))),
          collection_date = ifelse(SampleType %in% c("PB", "EB", "MK"),'not applicable',
                            ifelse(Experiment == 1, "03/10/2017",
                            ifelse(SampleType == 'T0', '05/02/2018',
                            ifelse(SampleType %in% 'GV', '2018',
                            ifelse(Experiment == 2 & Rep %in% c(1,2), '08/06/2018',
                            ifelse(Experiment == 2 & Rep %in% c(3,4), '08/16/2018',
                            ifelse(Experiment == 3 & DAI == '14', '06/08/2018',
                            ifelse(Experiment == 3 & DAI == '24', '06/18/2018',
                            ifelse(Experiment == 3 & DAI == '35', '06/29/2018',
                            ifelse(Experiment == 3 & DAI == '45', '07/09/2018',
                            ifelse(Experiment == 3 & DAI == '65', '07/29/2018', 'not applicable'))))))))))),
          geo_loc_name = ifelse(SampleType %in% c('PB', 'EB', 'MK'), 'not applicable', 
                                ifelse(SampleType == 'T0', 'United States:New York;Freeville',
                                ifelse(Soil == "Lansing", 'United States:New York;Freeville',
                                ifelse(Soil == "Pendelton", 'United States:South Carolina;Pendelton', 
                                ifelse(Soil == "Florence", 'United States:South Carolina;Florence',
                                       'United States:New York;Ithaca;Laboratory'))))),
          lat_lon = ifelse(SampleType == 'T0', '42.5213 N 76.3309 W', 
                        ifelse(SampleType %in% c('BH', 'BP', 'BS', 'CH', 'CS', 'RH', 'RS', 'RT') & 
                               Soil == "Lansing", '42.5213 N  76.3309 W',
                        ifelse(SampleType %in% c('BH', 'BP', 'BS', 'CH', 'CS',  'RH', 'RS', 'RT') & 
                               Soil == "Florence", '34.3113 N  79.7542 W',
                        ifelse(SampleType %in% c('BH', 'BP', 'BS', 'CH', 'CS', 'RH', 'RS', 'RT') & 
                               Soil == "Pendelton", '34.6270 N  82.7410 W', 
                        ifelse(SampleType %in% c('BH', 'BP', 'BS', 'CH', 'CS',  'RH', 'RS', 'RT') & 
                               Soil == "Sand" | SampleType == "GV", '42.444 N  76.5019 W',
                               
                           ifelse(SampleType %in% c('PB', 'EB', 'MK'), 'not applicable', NA)))))),
          fertilizer_regm = ifelse(Experiment == 1, "1/4x Hoagland’s solution with 20 uM PO4-; 3x weekly",
                                 ifelse(Experiment == 2 & Treatment == "HN", "1/4x Hoagland’s solution with 20 uM PO4-; 50ml, 3x weekly",
                                  ifelse(Experiment == 2 & Treatment == "HP", "1/4x Hoagland’s solution with 1/20x N & 200 uM PO4-; 50ml, 3x weekly",
                                 ifelse(Experiment == 3, '1/4x Hoagland’s solution with 20 uM PO4-; 25ml; 3x weekly', NA)))),
          Fungus = ifelse(Fungus == "Gv", "Glomus versiforme", 
                         ifelse(Fungus == "RI", 'Rhizophagus irregularis', NA)),
          Plant = 'Brachypodium distachyon',
          DaysAfterPlanting = DAI + 49) %>% 
        rename(DaysAfterInsert = DAI) %>%
left_join(., stlookup, by = "SampleType") %>%
select(-SampleType) %>%
rename(SampleType = sample_type) %>%
select(sample_name, bioproject_accession, organism, host, collection_date, geo_loc_name, lat_lon, Sample, 
    Experiment, Plant, Fungus, Soil, SampleType, Treatment, TimePoint, DaysAfterInsert, DaysAfterPlanting, Rep, fertilizer_regm)

# %%
head(SampleAttributes)
# Out:
#   sample_name bioproject_accession organism        host collection_date
# 1 HCBN1_S211  NA                   soil metagenome soil 03/10/2017
# 2 HCBN2_S223  NA                   soil metagenome soil 03/10/2017
# 3 HCBN3_S235  NA                   soil metagenome soil 03/10/2017
# 4 HCBF1_S247  NA                   soil metagenome soil 03/10/2017
# 5 HCBF2_S259  NA                   soil metagenome soil 03/10/2017
# 6 HCBF3_S271  NA                   soil metagenome soil 03/10/2017
#   geo_loc_name                          lat_lon              Sample Experiment
# 1 United States:New York;Freeville      42.5213 N  76.3309 W HCBN1  1
# 2 United States:New York;Freeville      42.5213 N  76.3309 W HCBN2  1
# 3 United States:New York;Freeville      42.5213 N  76.3309 W HCBN3  1
# 4 United States:South Carolina;Florence 34.3113 N  79.7542 W HCBF1  1
# 5 United States:South Carolina;Florence 34.3113 N  79.7542 W HCBF2  1
# 6 United States:South Carolina;Florence 34.3113 N  79.7542 W HCBF3  1
#   Plant                   Fungus            Soil     SampleType  Treatment
# 1 Brachypodium distachyon Glomus versiforme Lansing  Soil slurry HN
# 2 Brachypodium distachyon Glomus versiforme Lansing  Soil slurry HN
# 3 Brachypodium distachyon Glomus versiforme Lansing  Soil slurry HN
# 4 Brachypodium distachyon Glomus versiforme Florence Soil slurry HN
# 5 Brachypodium distachyon Glomus versiforme Florence Soil slurry HN
# 6 Brachypodium distachyon Glomus versiforme Florence Soil slurry HN
#   TimePoint DaysAfterInsert DaysAfterPlanting Rep
# 1 NA        81              130               1
# 2 NA        81              130               2
# 3 NA        81              130               3
# 4 NA        81              130               1
# 5 NA        81              130               2
# 6 NA        81              130               3
#   fertilizer_regm
# 1 1/4x Hoagland’s solution with 20 uM PO4-; 3x weekly
# 2 1/4x Hoagland’s solution with 20 uM PO4-; 3x weekly
# 3 1/4x Hoagland’s solution with 20 uM PO4-; 3x weekly
# 4 1/4x Hoagland’s solution with 20 uM PO4-; 3x weekly
# 5 1/4x Hoagland’s solution with 20 uM PO4-; 3x weekly
# 6 1/4x Hoagland’s solution with 20 uM PO4-; 3x weekly

# %%
SA1 = SampleAttributes %>% filter(Experiment == 1)
SA2 = SampleAttributes %>% filter(Experiment == 2)
SA3 = SampleAttributes %>% filter(Experiment == 3)

write.table(SampleAttributes, file = '~/Hyphosphere/SRA_biosample_attributes.txt', sep = '\t', row.names = FALSE)
write.table(SA1, file = '~/Hyphosphere/SRA_biosample_attributes_Exp1.txt', sep = '\t', row.names = FALSE)
write.table(SA2, file = '~/Hyphosphere/SRA_biosample_attributes_Exp2.txt', sep = '\t', row.names = FALSE)
write.table(SA3, file = '~/Hyphosphere/SRA_biosample_attributes_Exp3.txt', sep = '\t', row.names = FALSE)

# %% [markdown]
# # Format metadata for NCBI upload

# %%
samdf %>% head()
# Out:
#            Sample Experiment Plant Fungus Soil     SampleType Treatment
# HCBN1_S211 HCBN1  1          N1    Gv     Lansing  CS         HN
# HCBN2_S223 HCBN2  1          N2    Gv     Lansing  CS         HN
# HCBN3_S235 HCBN3  1          N3    Gv     Lansing  CS         HN
# HCBF1_S247 HCBF1  1          F1    Gv     Florence CS         HN
# HCBF2_S259 HCBF2  1          F2    Gv     Florence CS         HN
# HCBF3_S271 HCBF3  1          F3    Gv     Florence CS         HN
#            TimePoint DAI Rep Concentration_ng.ul
# HCBN1_S211 NA        81  1   6.08
# HCBN2_S223 NA        81  2   7.58
# HCBN3_S235 NA        81  3   7.05
# HCBF1_S247 NA        81  1   2.32
# HCBF2_S259 NA        81  2   2.08
# HCBF3_S271 NA        81  3   1.89

# %%
MetaData = samdf %>% 
    mutate(sample_name = row.names(.),
          library_ID = sample_name,
          title = paste('16S amplicon of ', SampleType, ' sample from mesocosm with', Soil, ' soil and ', Fungus, '; Experiment ', Experiment, 
                       '. Samples collected ', DAI, ' days after soil in-growth cores inserted in mesocosm', sep = ''),
          library_strategy = "AMPLICON", 
          library_source = "METAGENOMIC",
          library_selection = "PCR",
          library_layout = 'paired',
          platform = 'ILLUMINA',
          instrument = 'Illumina MiSeq',
          design_description = ifelse(Experiment == 1, 'Prepared at University of Minnesota Genomics Center',
                                      "Multiplexed dual barcoded MiSeq library prepared as in Kozich et al. 2013"),
          filetype = "fastq",
          filename = ifelse(Experiment == 1, paste(sample_name, '_R1_001.fastq.gz', sep = ''), 
                                                    paste(sample_name, '.R1.fq.gz', sep = '')),
          filename2 = ifelse(Experiment == 1, paste(sample_name, '_R2_001.fastq.gz', sep = ''), 
                                                    paste(sample_name, '.R2.fq.gz', sep = ''))) %>%
    select(sample_name, library_ID, title, library_strategy, library_source, library_selection, library_layout,
          platform, instrument, design_description, filetype, filename, filename2, Experiment) 
head(MetaData)
# Out:
#   sample_name library_ID
# 1 HCBN1_S211  HCBN1_S211
# 2 HCBN2_S223  HCBN2_S223
# 3 HCBN3_S235  HCBN3_S235
# 4 HCBF1_S247  HCBF1_S247
# 5 HCBF2_S259  HCBF2_S259
# 6 HCBF3_S271  HCBF3_S271
#   title
# 1 16S amplicon of CS sample from mesocosm withLansing soil and Gv; Experiment 1. Samples collected 81 days after soil in-growth cores inserted in mesocosm
# 2 16S amplicon of CS sample from mesocosm withLansing soil and Gv; Experiment 1. Samples collected 81 days after soil in-growth cores inserted in mesocosm
# 3 16S amplicon of CS sample from mesocosm withLansing soil and Gv; Experiment 1. Samples collected 81 days after soil in-growth cores inserted in mesocosm
# 4 16S amplicon of CS sample from mesocosm withFlorence soil and Gv; Experiment 1. Samples collected 81 days after soil in-growth cores inserted in mesocosm
# 5 16S amplicon of CS sample from mesocosm withFlorence soil and Gv; Experiment 1. Samples collected 81 days after soil in-growth cores inserted in mesocosm
# 6 16S amplicon of CS sample from mesocosm withFlorence soil and Gv; Experiment 1. Samples collected 81 days after soil in-growth cores inserted in mesocosm
#   library_strategy library_source library_selection library_layout platform
# 1 AMPLICON         METAGENOMIC    PCR               paired         ILLUMINA
# 2 AMPLICON         METAGENOMIC    PCR               paired         ILLUMINA
# 3 AMPLICON         METAGENOMIC    PCR               paired         ILLUMINA
# 4 AMPLICON         METAGENOMIC    PCR               paired         ILLUMINA
# 5 AMPLICON         METAGENOMIC    PCR               paired         ILLUMINA
# 6 AMPLICON         METAGENOMIC    PCR               paired         ILLUMINA
#   instrument     design_description                                  filetype
# 1 Illumina MiSeq Prepared at University of Minnesota Genomics Center fastq
# 2 Illumina MiSeq Prepared at University of Minnesota Genomics Center fastq
# 3 Illumina MiSeq Prepared at University of Minnesota Genomics Center fastq
# 4 Illumina MiSeq Prepared at University of Minnesota Genomics Center fastq
# 5 Illumina MiSeq Prepared at University of Minnesota Genomics Center fastq
# 6 Illumina MiSeq Prepared at University of Minnesota Genomics Center fastq
#   filename                   filename2                  Experiment
# 1 HCBN1_S211_R1_001.fastq.gz HCBN1_S211_R2_001.fastq.gz 1
# 2 HCBN2_S223_R1_001.fastq.gz HCBN2_S223_R2_001.fastq.gz 1
# 3 HCBN3_S235_R1_001.fastq.gz HCBN3_S235_R2_001.fastq.gz 1
# 4 HCBF1_S247_R1_001.fastq.gz HCBF1_S247_R2_001.fastq.gz 1
# 5 HCBF2_S259_R1_001.fastq.gz HCBF2_S259_R2_001.fastq.gz 1
# 6 HCBF3_S271_R1_001.fastq.gz HCBF3_S271_R2_001.fastq.gz 1

# %%
MD1 = MetaData %>% filter(Experiment == 1)
MD2 = MetaData %>% filter(Experiment == 2)
MD3 = MetaData %>% filter(Experiment == 3)
Metadata = MetaData %>% select(-Experiment)
write.table(MetaData, file = '~/Hyphosphere/SRA_metadata.txt', sep = '\t', row.names = FALSE)
write.table(MD1, file = '~/Hyphosphere/SRA_metadata_Exp1.txt', sep = '\t', row.names = FALSE)
write.table(MD2, file = '~/Hyphosphere/SRA_metadata_Exp2.txt', sep = '\t', row.names = FALSE)
write.table(MD3, file = '~/Hyphosphere/SRA_metadata_Exp3.txt', sep = '\t', row.names = FALSE)

# %% [markdown]
# # Filter to each experiment in case separate uploading is necessary

# %%
samdf %>% filter(Experiment == 1)
# Out:
#                       Sample                Experiment Plant Fungus Soil
# HCBN1_S211            HCBN1                 1          N1    Gv     Lansing
# HCBN2_S223            HCBN2                 1          N2    Gv     Lansing
# HCBN3_S235            HCBN3                 1          N3    Gv     Lansing
# HCBF1_S247            HCBF1                 1          F1    Gv     Florence
# HCBF2_S259            HCBF2                 1          F2    Gv     Florence
# HCBF3_S271            HCBF3                 1          F3    Gv     Florence
# HCBP1_S283            HCBP1                 1          P1    Gv     Pendelton
# HCBP2_S200            HCBP2                 1          P2    Gv     Pendelton
# HCBP3_S212            HCBP3                 1          P3    Gv     Pendelton
# HCBS1_S224            HCBS1                 1          S1    Gv     Sand
# HCBS2_S236            HCBS2                 1          S2    Gv     Sand
# HCBS3_S248            HCBS3                 1          S3    Gv     Sand
# HCRN1_S260            HCRN1                 1          N1    Gv     Lansing
# HCRN2_S272            HCRN2                 1          N2    Gv     Lansing
# HCRN3_S284            HCRN3                 1          N3    Gv     Lansing
# HCRF1_S201            HCRF1                 1          F1    Gv     Florence
# HCRF2_S213            HCRF2                 1          F2    Gv     Florence
# HCRF3_S225            HCRF3                 1          F3    Gv     Florence
# HCRP1_S237            HCRP1                 1          P1    Gv     Pendelton
# HCRP2_S249            HCRP2                 1          P2    Gv     Pendelton
# HCRP3_S261            HCRP3                 1          P3    Gv     Pendelton
# HCRS1_S273            HCRS1                 1          S1    Gv     Sand
# HCRS2_S285            HCRS2                 1          S2    Gv     Sand
# HCRS3_S202            HCRS3                 1          S3    Gv     Sand
# HCHN1_S214            HCHN1                 1          N1    Gv     Lansing
# HCHN2_S226            HCHN2                 1          N2    Gv     Lansing
# HCHN3_S238            HCHN3                 1          N3    Gv     Lansing
# HCHF1_S250            HCHF1                 1          F1    Gv     Florence
# HCHF2_S262            HCHF2                 1          F2    Gv     Florence
# HCHF3_S274            HCHF3                 1          F3    Gv     Florence
# HCHP1_S286            HCHP1                 1          P1    Gv     Pendelton
# HCHP2_S203            HCHP2                 1          P2    Gv     Pendelton
# HCHP3_S215            HCHP3                 1          P3    Gv     Pendelton
# HCHS1_S227            HCHS1                 1          S1    Gv     Sand
# HCHS2_S239            HCHS2                 1          S2    Gv     Sand
# HCHS3_S251            HCHS3                 1          S3    Gv     Sand
# Hneg1_S263            Hneg1                 1
# 10xBLS156_S303        10xBLS156             1
# 2xBLS143_S297         2xBLS143              1
# 5xBLS120_S300         5xBLS120              1
# BaseA_S310            BaseA                 1
# BaseB_S291            BaseB                 1
# BaseC_S294            BaseC                 1
# NegativeH2O_S282      NegativeH2O           1
# UMGC_H2O_001_A04_S4   UMGC_H2O_001_A04_S4   1
# UMGC_H2O_001_A06_S6   UMGC_H2O_001_A06_S6   1
# UMGC_H2O_002_B04_S112 UMGC_H2O_002_B04_S112 1
# UMGC_H2O_002_B06_S114 UMGC_H2O_002_B06_S114 1
# UMGC_H2O_003_A07_S199 UMGC_H2O_003_A07_S199 1
# UMGC_H2O_003_G11_S275 UMGC_H2O_003_G11_S275 1
# UMGC_H2O_004_F03_S306 UMGC_H2O_004_F03_S306 1
#                       SampleType Treatment TimePoint DAI Rep
# HCBN1_S211            CS         HN        NA        81   1
# HCBN2_S223            CS         HN        NA        81   2
# HCBN3_S235            CS         HN        NA        81   3
# HCBF1_S247            CS         HN        NA        81   1
# HCBF2_S259            CS         HN        NA        81   2
# HCBF3_S271            CS         HN        NA        81   3
# HCBP1_S283            CS         HN        NA        81   1
# HCBP2_S200            CS         HN        NA        81   2
# HCBP3_S212            CS         HN        NA        81   3
# HCBS1_S224            CS         HN        NA        81   1
# HCBS2_S236            CS         HN        NA        81   2
# HCBS3_S248            CS         HN        NA        81   3
# HCRN1_S260            RT         HN        NA        81   1
# HCRN2_S272            RT         HN        NA        81   2
# HCRN3_S284            RT         HN        NA        81   3
# HCRF1_S201            RT         HN        NA        81   1
# HCRF2_S213            RT         HN        NA        81   2
# HCRF3_S225            RT         HN        NA        81   3
# HCRP1_S237            RT         HN        NA        81   1
# HCRP2_S249            RT         HN        NA        81   2
# HCRP3_S261            RT         HN        NA        81   3
# HCRS1_S273            RT         HN        NA        81   1
# HCRS2_S285            RT         HN        NA        81   2
# HCRS3_S202            RT         HN        NA        81   3
# HCHN1_S214            CH         HN        NA        81   1
# HCHN2_S226            CH         HN        NA        81   2
# HCHN3_S238            CH         HN        NA        81   3
# HCHF1_S250            CH         HN        NA        81   1
# HCHF2_S262            CH         HN        NA        81   2
# HCHF3_S274            CH         HN        NA        81   3
# HCHP1_S286            CH         HN        NA        81   1
# HCHP2_S203            CH         HN        NA        81   2
# HCHP3_S215            CH         HN        NA        81   3
# HCHS1_S227            CH         HN        NA        81   1
# HCHS2_S239            CH         HN        NA        81   2
# HCHS3_S251            CH         HN        NA        81   3
# Hneg1_S263            EB                   NA        NA  NA
# 10xBLS156_S303        MK                   NA        NA  NA
# 2xBLS143_S297         MK                   NA        NA  NA
# 5xBLS120_S300         MK                   NA        NA  NA
# BaseA_S310            MK                   NA        NA  NA
# BaseB_S291            MK                   NA        NA  NA
# BaseC_S294            MK                   NA        NA  NA
# NegativeH2O_S282      PB                   NA        NA  NA
# UMGC_H2O_001_A04_S4   PB                   NA        NA  NA
# UMGC_H2O_001_A06_S6   PB                   NA        NA  NA
# UMGC_H2O_002_B04_S112 PB                   NA        NA  NA
# UMGC_H2O_002_B06_S114 PB                   NA        NA  NA
# UMGC_H2O_003_A07_S199 PB                   NA        NA  NA
# UMGC_H2O_003_G11_S275 PB                   NA        NA  NA
# UMGC_H2O_004_F03_S306 PB                   NA        NA  NA
#                       Concentration_ng.ul
# HCBN1_S211             6.080
# HCBN2_S223             7.580
# HCBN3_S235             7.050
# HCBF1_S247             2.320
# HCBF2_S259             2.080
# HCBF3_S271             1.890
# HCBP1_S283             9.180
# HCBP2_S200             6.870
# HCBP3_S212             3.850
# HCBS1_S224             0.050
# HCBS2_S236             0.303
# HCBS3_S248             0.050
# HCRN1_S260            14.900
# HCRN2_S272             4.100
# HCRN3_S284             3.920
# HCRF1_S201             4.290
# HCRF2_S213             3.870
# HCRF3_S225             9.210
# HCRP1_S237            14.700
# HCRP2_S249             5.900
# HCRP3_S261             8.960
# HCRS1_S273             3.810
# HCRS2_S285             2.680
# HCRS3_S202             3.600
# HCHN1_S214             0.570
# HCHN2_S226             0.100
# HCHN3_S238             0.120
# HCHF1_S250             0.280
# HCHF2_S262             0.110
# HCHF3_S274             0.070
# HCHP1_S286             0.110
# HCHP2_S203             0.300
# HCHP3_S215             0.150
# HCHS1_S227             0.010
# HCHS2_S239             0.010
# HCHS3_S251             0.050
# Hneg1_S263             0.000
# 10xBLS156_S303            NA
# 2xBLS143_S297             NA
# 5xBLS120_S300             NA
# BaseA_S310                NA
# BaseB_S291                NA
# BaseC_S294                NA
# NegativeH2O_S282          NA
# UMGC_H2O_001_A04_S4       NA
# UMGC_H2O_001_A06_S6       NA
# UMGC_H2O_002_B04_S112     NA
# UMGC_H2O_002_B06_S114     NA
# UMGC_H2O_003_A07_S199     NA
# UMGC_H2O_003_G11_S275     NA
# UMGC_H2O_004_F03_S306     NA

# %%
#
