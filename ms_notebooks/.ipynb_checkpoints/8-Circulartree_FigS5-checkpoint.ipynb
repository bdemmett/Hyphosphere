# %% [markdown]
# # Generate circular tree for Fig. S5

# %% [markdown]
# * Uses previous DESeq2 analysis and phylogenetic tree to plot differential abundance

# %%
out_Dir = '~/Hyphosphere/data/3Exp/figures'

work_dir = '~/Hyphosphere/data/3Exp/DESeq'

# phyloseq - full object with tree
physeq_file = '~/Hyphosphere/data/3Exp/phyloseq/3Exp_phyloseq_thresh_wtree_experimental_woContam.rds'

# %%
library(RColorBrewer)
library(plyr)
library(tidyr)
library(dplyr)
library(reshape2)
library(phyloseq)
library(ggplot2)
library(ggtree)
library(gridExtra)
# Out:
# Warning message:
# “package ‘RColorBrewer’ was built under R version 3.6.1”Warning message:
# “package ‘plyr’ was built under R version 3.6.1”
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:plyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Warning message:
# “package ‘reshape2’ was built under R version 3.6.1”
# Attaching package: ‘reshape2’
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
# Warning message:
# “package ‘phyloseq’ was built under R version 3.6.1”Warning message:
# “package ‘ggplot2’ was built under R version 3.6.1”Warning message:
# “package ‘ggtree’ was built under R version 3.6.1”Registered S3 method overwritten by 'treeio':
#   method     from
#   root.phylo ape
# ggtree v2.0.0  For help: https://yulab-smu.github.io/treedata-book/
#
# If you use ggtree in published research, please cite the most appropriate paper(s):
#
# - Guangchuang Yu, Tommy Tsan-Yuk Lam, Huachen Zhu, Yi Guan. Two methods for mapping and visualizing associated data on phylogeny using ggtree. Molecular Biology and Evolution 2018, 35(12):3041-3043. doi: 10.1093/molbev/msy194
# - Guangchuang Yu, David Smith, Huachen Zhu, Yi Guan, Tommy Tsan-Yuk Lam. ggtree: an R package for visualization and annotation of phylogenetic trees with their covariates and other associated data. Methods in Ecology and Evolution 2017, 8(1):28-36, doi:10.1111/2041-210X.12628
#
#
#
# Attaching package: ‘ggtree’
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
# The following object is masked from ‘package:plyr’:
#
#     .
#
#
# Attaching package: ‘gridExtra’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %%
g_legend <- function(a.gplot){
  tmp <- ggplot_gtable(ggplot_build(a.gplot))
  leg <- which(sapply(tmp$grobs, function(x) x$name) == "guide-box")
  legend <- tmp$grobs[[leg]]
  return(legend)
}

# %%
ps = readRDS(physeq_file) %>% subset_taxa(., !is.na(Phylum)) %>%
    # remove non-experimental controls
    
    subset_samples(., SampleType != "GV" & Experiment %in% c(1,2) & Fungus == "Gv" & SampleType %in% c("CS","CH") & Soil != "Sand") %>%

     # re-normalize after subsetting taxa
    transform_sample_counts(., function(x) x/sum(x))

ps
# Out:
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 18707 taxa and 58 samples ]
# sample_data() Sample Data:       [ 58 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 18707 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 18707 tips and 18706 internal nodes ]

# %%
ps.m = ps %>%
    psmelt() %>%
    group_by(OTU, Soil, Experiment) %>%
    summarise(mAbund = mean(Abundance)) %>%
    ungroup() %>% 
    group_by(OTU) %>%
    summarise(smAbund = sum(mAbund)) 
head(ps.m)
# Out:
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# `summarise()` regrouping output by 'OTU', 'Soil' (override with `.groups` argument)
# `summarise()` ungrouping output (override with `.groups` argument)
#   OTU      smAbund
# 1 ASV100   8.172735e-03
# 2 ASV1000  1.517569e-03
# 3 ASV10000 0.000000e+00
# 4 ASV10001 2.481481e-05
# 5 ASV10002 1.075044e-04
# 6 ASV10003 6.691852e-05

# %% [markdown]
# ### Top 200 most abundant taxa

# %%
topTax = ps.m %>% 
    arrange(desc(smAbund)) %>%
    .[1:200,] %>%
    .$OTU %>%
    as.character()

topTax
# Out:
#   [1] "ASV5"    "ASV6"    "ASV57"   "ASV14"   "ASV18"   "ASV61"   "ASV16"
#   [8] "ASV103"  "ASV39"   "ASV33"   "ASV148"  "ASV25"   "ASV943"  "ASV21"
#  [15] "ASV47"   "ASV118"  "ASV143"  "ASV915"  "ASV23"   "ASV718"  "ASV24"
#  [22] "ASV17"   "ASV71"   "ASV46"   "ASV29"   "ASV40"   "ASV44"   "ASV69"
#  [29] "ASV64"   "ASV55"   "ASV648"  "ASV77"   "ASV338"  "ASV247"  "ASV1132"
#  [36] "ASV98"   "ASV168"  "ASV50"   "ASV66"   "ASV37"   "ASV383"  "ASV36"
#  [43] "ASV104"  "ASV288"  "ASV60"   "ASV65"   "ASV1847" "ASV259"  "ASV246"
#  [50] "ASV81"   "ASV286"  "ASV961"  "ASV30"   "ASV661"  "ASV91"   "ASV138"
#  [57] "ASV514"  "ASV1925" "ASV126"  "ASV230"  "ASV873"  "ASV204"  "ASV73"
#  [64] "ASV87"   "ASV190"  "ASV99"   "ASV169"  "ASV282"  "ASV509"  "ASV97"
#  [71] "ASV195"  "ASV154"  "ASV134"  "ASV615"  "ASV448"  "ASV1412" "ASV3052"
#  [78] "ASV100"  "ASV312"  "ASV218"  "ASV74"   "ASV27"   "ASV133"  "ASV1260"
#  [85] "ASV527"  "ASV475"  "ASV175"  "ASV250"  "ASV232"  "ASV179"  "ASV820"
#  [92] "ASV434"  "ASV406"  "ASV397"  "ASV262"  "ASV79"   "ASV93"   "ASV89"
#  [99] "ASV330"  "ASV95"   "ASV2527" "ASV116"  "ASV101"  "ASV2435" "ASV189"
# [106] "ASV356"  "ASV478"  "ASV121"  "ASV72"   "ASV96"   "ASV147"  "ASV2473"
# [113] "ASV200"  "ASV2294" "ASV3261" "ASV227"  "ASV1053" "ASV341"  "ASV217"
# [120] "ASV161"  "ASV221"  "ASV1447" "ASV160"  "ASV117"  "ASV2529" "ASV306"
# [127] "ASV236"  "ASV180"  "ASV388"  "ASV335"  "ASV113"  "ASV672"  "ASV759"
# [134] "ASV692"  "ASV124"  "ASV129"  "ASV111"  "ASV2494" "ASV228"  "ASV317"
# [141] "ASV283"  "ASV423"  "ASV125"  "ASV567"  "ASV336"  "ASV501"  "ASV114"
# [148] "ASV436"  "ASV176"  "ASV42"   "ASV401"  "ASV2725" "ASV8"    "ASV333"
# [155] "ASV139"  "ASV556"  "ASV2261" "ASV32"   "ASV827"  "ASV846"  "ASV115"
# [162] "ASV108"  "ASV866"  "ASV132"  "ASV68"   "ASV15"   "ASV1355" "ASV122"
# [169] "ASV3626" "ASV511"  "ASV625"  "ASV137"  "ASV342"  "ASV109"  "ASV3378"
# [176] "ASV251"  "ASV106"  "ASV123"  "ASV473"  "ASV344"  "ASV611"  "ASV58"
# [183] "ASV290"  "ASV476"  "ASV241"  "ASV3290" "ASV502"  "ASV2583" "ASV390"
# [190] "ASV507"  "ASV261"  "ASV581"  "ASV393"  "ASV522"  "ASV318"  "ASV85"
# [197] "ASV370"  "ASV577"  "ASV471"  "ASV462"

# %%
rm(ps.m)

# %%
# Filter to the top OTUs identified above

physeq.thresh <- prune_taxa(topTax, ps)

physeq.thresh
# Out:
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 200 taxa and 58 samples ]
# sample_data() Sample Data:       [ 58 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 200 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 200 tips and 199 internal nodes ]

# %%
MyTree =  physeq.thresh %>% phy_tree

# %%
TreeTax = taxa_names(physeq.thresh)

# %%
df.tax = physeq.thresh %>% tax_table %>% as.data.frame
df.tax$OTU = df.tax %>% row.names

df.tax = mutate(df.tax, TaxLabel = paste(Family, Genus, sep = "_")) %>%
    select(OTU, TaxLabel, Phylum, Class, Order, Family, Genus)

# %% [markdown]
# ## Relative Abundance data

# %%
mdf = psmelt(physeq.thresh)
mdf.byOTU = ddply(mdf, .(Soil, OTU, Experiment), summarize, mean_Abundance = mean(Abundance)) 
head(mdf.byOTU)
# Out:
# Warning message in psmelt(physeq.thresh):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
#   Soil     OTU    Experiment mean_Abundance
# 1 Florence ASV100 1          0.0008744882
# 2 Florence ASV100 2          0.0016464922
# 3 Florence ASV101 1          0.0022462499
# 4 Florence ASV101 2          0.0015770379
# 5 Florence ASV103 1          0.0143862940
# 6 Florence ASV103 2          0.0020775208

# %%
# #cast by Plant
# dfc = dcast(mdf.byOTU, OTU ~ Soil + SampleType) %>%
#     select(OTU, Dryden_CS, Dryden_CH, Florence_CS, Florence_CH, Pendelton_CS, Pendelton_CH) %>%
#     'rownames<-' (dfc$OTU)
# head(dfc)

# %% [markdown]
# ### log2FoldChange data

# %%
readfile = file.path(work_dir, 'dfl2fc-Exp1.txt')
df.l2fc.Exp1 = read.table(readfile, header = TRUE, sep= '\t')

readfile = file.path(work_dir, 'dfl2fc-Exp2.txt')
df.l2fc.Exp2 = read.table(readfile, header = TRUE, sep= '\t')

df.l2fc = bind_rows(df.l2fc.Exp1, df.l2fc.Exp2)
df.l2fc = df.l2fc %>% separate(Subset, c("Soil","Fungus")) %>% filter(Contrast %in% c("CH_CS", "CH_BS", "CH_BP", "RH_RS") & Fungus == "Gv")

# %%
head(df.l2fc)
# Out:
#   baseMean  log2FoldChange lfcSE     stat      pvalue       padj         OTU
# 1 331.72029 -2.716566      0.5217389 -5.206754 1.921730e-07 1.885675e-05 ASV5
# 2 136.95264  4.977612      1.1905977  4.180767 2.905274e-05 1.192425e-03 ASV6
# 3   0.00000        NA             NA        NA           NA           NA ASV8
# 4   0.00000        NA             NA        NA           NA           NA ASV13
# 5  26.70389  8.430000      1.7857267  4.720767 2.349571e-06 1.478663e-04 ASV14
# 6   0.00000        NA             NA        NA           NA           NA ASV15
#   Soil    Fungus Term       Contrast DAI Kingdom  Phylum
# 1 Dryden Gv     SampleType CH_CS    81  Bacteria Actinobacteria
# 2 Dryden Gv     SampleType CH_CS    81  Bacteria Proteobacteria
# 3 Dryden Gv     SampleType CH_CS    81  Bacteria Proteobacteria
# 4 Dryden Gv     SampleType CH_CS    81  Bacteria Proteobacteria
# 5 Dryden Gv     SampleType CH_CS    81  Bacteria Proteobacteria
# 6 Dryden Gv     SampleType CH_CS    81  Bacteria Proteobacteria
#   Class               Order                 Family           Genus
# 1 Actinobacteria      Micrococcales         Micrococcaceae   Pseudarthrobacter
# 2 Gammaproteobacteria Cellvibrionales       Cellvibrionaceae Cellvibrio
# 3 Alphaproteobacteria Caulobacterales       Caulobacteraceae Asticcacaulis
# 4 Gammaproteobacteria Xanthomonadales       Xanthomonadaceae Luteimonas
# 5 Deltaproteobacteria Myxococcales          Sandaracinaceae  NA
# 6 Gammaproteobacteria Betaproteobacteriales Burkholderiaceae NA
#   Experiment
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 1

# %%
#df.l2fc$Soil = separate(df.l2fc$Subset,"-")[[1]][1]
#head(df.l2fc)

# df.ra = dcast(mdf.byOTU, OTU ~ Experiment + SampleType + Soil, value.var = "mean_Abundance")
# rownames(df.ra) = df.ra$OTU
# df.ra = select(df.ra, "1_CS_Dryden", "2_CS_Dryden", "1_CS_Florence", "2_CS_Florence", "1_CS_Pendelton", "2_CS_Pendelton",
#               "1_CH_Dryden", "2_CH_Dryden", "1_CH_Florence", "2_CH_Florence", "1_CH_Pendelton", "2_CH_Pendelton")
# head(df.ra)
# Out:
# Joining, by = c("OTU", "Soil", "Experiment")
# Warning message:
# “Column `OTU` joining factor and character vector, coercing into character vector”
#   OTU   Soil    Experiment padj         mean_Abundance log2FoldChange
# 1 ASV5  Dryden 1          1.885675e-05 0.020395195    -2.7165660
# 2 ASV6  Dryden 1          1.192425e-03 0.009201270     4.9776118
# 3 ASV14 Dryden 1          1.478663e-04 0.001813107     8.4299996
# 4 ASV16 Dryden 1          6.618920e-01 0.005376328    -0.6640584
# 5 ASV17 Dryden 1                    NA 0.000000000            NA
# 6 ASV18 Dryden 1          2.004166e-13 0.010919483    11.0823839
#   Phylum         Order                 Class               Family
# 1 Actinobacteria Micrococcales         Actinobacteria      Micrococcaceae
# 2 Proteobacteria Cellvibrionales       Gammaproteobacteria Cellvibrionaceae
# 3 Proteobacteria Myxococcales          Deltaproteobacteria Sandaracinaceae
# 4 Proteobacteria Rhizobiales           Alphaproteobacteria Xanthobacteraceae
# 5 Proteobacteria Betaproteobacteriales Gammaproteobacteria Burkholderiaceae
# 6 Proteobacteria Myxococcales          Deltaproteobacteria Sandaracinaceae
#   Genus
# 1 Pseudarthrobacter
# 2 Cellvibrio
# 3 NA
# 4 Bradyrhizobium
# 5 Paucibacter
# 6 NA

# %%
tmp = left_join(df.l2fc, mdf.byOTU) %>%
    select(OTU, Soil, Experiment, padj, Contrast, mean_Abundance, log2FoldChange, Phylum, Order, Class, Family, Genus) %>%
    filter(OTU %in% TreeTax)


tmp$Phylum = factor(tmp$Phylum)
tmp$Order = factor(tmp$Order)
tmp$Class = factor(tmp$Class)

#Link phylum colors 
FigPhyla = tmp$Phylum %>% levels() %>% as.character()
FigClass = tmp$Class %>% levels() %>% as.character()
FigOrder = tmp$Order %>% levels() %>% as.character()
FigOrder

ColorCount = length(FigOrder)
getPalette = colorRampPalette(brewer.pal(8, "Dark2"))
Ocs = getPalette(ColorCount)
Ocs


ColorCount = length(FigPhyla)
getPalette = colorRampPalette(brewer.pal(8, "Dark2"))
Pcs = getPalette(ColorCount)
Pcs

ColorCount = length(FigClass)
getPalette = colorRampPalette(brewer.pal(8, "Dark2"))
Ccs = getPalette(ColorCount)
Ccs


# Pcs = brewer.pal(12,"Set3")

#Set lookup to 
Olookup = cbind(FigOrder, Ocs) %>% as.data.frame()
Plookup = cbind(FigPhyla, Pcs) %>% as.data.frame()
Clookup = cbind(FigClass, Ccs) %>% as.data.frame()

tmp = left_join(tmp, Plookup, by = c("Phylum" = "FigPhyla"))
tmp = left_join(tmp, Olookup, by = c("Order" = "FigOrder")) 
tmp = left_join(tmp, Clookup, by = c("Class" = "FigClass")) 



tmp %>% head()
# Out:
# Joining, by = c("OTU", "Soil", "Experiment")
# Error: Problem with `filter()` input `..1`.
# ✖ object 'TreeTax' not found
# ℹ Input `..1` is `OTU %in% TreeTax`.
# Traceback:
#
# 1. left_join(df.l2fc, mdf.byOTU) %>% select(OTU, Soil, Experiment,
#  .     padj, Contrast, mean_Abundance, log2FoldChange, Phylum, Order,
#  .     Class, Family, Genus) %>% filter(OTU %in% TreeTax)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)
# 9. filter(., OTU %in% TreeTax)
# 10. filter.data.frame(., OTU %in% TreeTax)
# 11. filter_rows(.data, ...)
# 12. tryCatch(mask$eval_all_filter(dots, env_filter), simpleError = function(e) {
#   .     stop_dplyr(env_filter$current_expression, dots, fn = "filter",
#   .         problem = conditionMessage(e))
#   . })
# 13. tryCatchList(expr, classes, parentenv, handlers)
# 14. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 15. value[[3L]](cond)
# 16. stop_dplyr(env_filter$current_expression, dots, fn = "filter",
#   .     problem = conditionMessage(e))
# 17. abort(bullets, class = "dplyr_error", error_name = error_name,
#   .     error_expression = error_expression, index = .index, dots = dots,
#   .     fn = fn, parent = parent)
# 18. signal_abort(cnd)

# %% [markdown]
# # Test basic ggtree

# %% [markdown]
# ## add genus labels

# %%
df.tax = df.tax %>%
    mutate(GenusLabel = ifelse(!is.na(Genus), paste(Genus), 
                        ifelse(!is.na(Family), paste('Uncl. ', Family, sep = ""), 
                        ifelse(!is.na(Order), paste('Uncl. ', Order, sep = ""),
                        ifelse(!is.na(Class), paste('Uncl. ', Class, sep = ""), paste("Uncl. ", Phylum, sep = "")))))) %>%
    mutate(GenusLabel = ifelse(GenusLabel == 'Allorhizobium-Neorhizobium-Pararhizobium-Rhizobium', 'Allo-Neo-Para-Rhizobium', GenusLabel))
head(df.tax)
# Out:
#   OTU    TaxLabel                                   Phylum
# 1 ASV109 Pedosphaeraceae_NA                         Verrucomicrobia
# 2 ASV37  Chthoniobacteraceae_Candidatus_Udaeobacter Verrucomicrobia
# 3 ASV55  Chthoniobacteraceae_Candidatus_Udaeobacter Verrucomicrobia
# 4 ASV502 Chthoniobacteraceae_Candidatus_Udaeobacter Verrucomicrobia
# 5 ASV108 Chthoniobacteraceae_Candidatus_Udaeobacter Verrucomicrobia
# 6 ASV230 Chthoniobacteraceae_Candidatus_Udaeobacter Verrucomicrobia
#   Class            Order              Family
# 1 Verrucomicrobiae Pedosphaerales     Pedosphaeraceae
# 2 Verrucomicrobiae Chthoniobacterales Chthoniobacteraceae
# 3 Verrucomicrobiae Chthoniobacterales Chthoniobacteraceae
# 4 Verrucomicrobiae Chthoniobacterales Chthoniobacteraceae
# 5 Verrucomicrobiae Chthoniobacterales Chthoniobacteraceae
# 6 Verrucomicrobiae Chthoniobacterales Chthoniobacteraceae
#   Genus                  GenusLabel
# 1 NA                     Uncl. Pedosphaeraceae
# 2 Candidatus_Udaeobacter Candidatus_Udaeobacter
# 3 Candidatus_Udaeobacter Candidatus_Udaeobacter
# 4 Candidatus_Udaeobacter Candidatus_Udaeobacter
# 5 Candidatus_Udaeobacter Candidatus_Udaeobacter
# 6 Candidatus_Udaeobacter Candidatus_Udaeobacter

# %% [markdown]
# # Try circular tree

# %%
mdf.byOTU %>% filter(OTU == 'ASV5')

# %%
# tmp = left_join(df.l2fc, mdf.byOTU) %>%
#     select(OTU, Soil, Experiment, padj, mean_Abundance, log2FoldChange, Phylum, Order, Class, Family, Genus) %>%
#     filter(OTU %in% TreeTax)


# tmp$Phylum = factor(tmp$Phylum)
# tmp$Order = factor(tmp$Order)
# tmp$Class = factor(tmp$Class)

# #Link phylum colors 
# FigPhyla = tmp$Phylum %>% levels() %>% as.character()
# FigClass = tmp$Class %>% levels() %>% as.character()
# FigOrder = tmp$Order %>% levels() %>% as.character()
# FigOrder

# ColorCount = length(FigOrder)
# getPalette = colorRampPalette(brewer.pal(8, "Dark2"))
# Ocs = getPalette(ColorCount)
# Ocs


# ColorCount = length(FigPhyla)
# getPalette = colorRampPalette(brewer.pal(8, "Dark2"))
# Pcs = getPalette(ColorCount)
# Pcs

# ColorCount = length(FigClass)
# getPalette = colorRampPalette(brewer.pal(8, "Dark2"))
# Ccs = getPalette(ColorCount)
# Ccs


# # Pcs = brewer.pal(12,"Set3")

# #Set lookup to 
# Olookup = cbind(FigOrder, Ocs) %>% as.data.frame()
# Plookup = cbind(FigPhyla, Pcs) %>% as.data.frame()
# Clookup = cbind(FigClass, Ccs) %>% as.data.frame()

# tmp = left_join(tmp, Plookup, by = c("Phylum" = "FigPhyla"))
# tmp = left_join(tmp, Olookup, by = c("Order" = "FigOrder")) 
# tmp = left_join(tmp, Clookup, by = c("Class" = "FigClass")) 



# tmp %>% head()
# Out:
# Joining, by = c("OTU", "Soil", "Experiment")
# Warning message:
# “Column `OTU` joining factor and character vector, coercing into character vector”
#  [1] "Acidiferrobacterales"               "Bacillales"
#  [3] "Betaproteobacteriales"              "Cellvibrionales"
#  [5] "Chthoniobacterales"                 "Corynebacteriales"
#  [7] "Cytophagales"                       "Fibrobacterales"
#  [9] "Gaiellales"                         "Gammaproteobacteria_Incertae_Sedis"
# [11] "Gemmatimonadales"                   "Micrococcales"
# [13] "Myxococcales"                       "Nitrospirales"
# [15] "Nostocales"                         "Pseudonocardiales"
# [17] "Rhizobiales"                        "Rokubacteriales"
# [19] "SBR1031"                            "Sphingomonadales"
# [21] "Steroidobacterales"
#  [1] "#1B9E77" "#5D874E" "#A07125" "#D35F0A" "#B16548" "#8D6B86" "#8068AE"
#  [8] "#A850A0" "#D03792" "#D33B79" "#A66753" "#79932E" "#7FA718" "#ACA80E"
# [15] "#D9AA04" "#D59D08" "#BF8B12" "#A9781B" "#927132" "#7C6B4C" "#666666"
#  [1] "#1B9E77" "#93752C" "#BD6332" "#7E6EA2" "#B3499C" "#CF3F76" "#7D8F31"
#  [8] "#A0A811" "#E0A604" "#B78415" "#8E7037" "#666666"
#  [1] "#1B9E77" "#738040" "#CC6309" "#B16548" "#826D9B" "#9B58A5" "#D03792"
#  [8] "#C44A6D" "#88843A" "#7FA718" "#BBA90B" "#DDA305" "#BF8B12" "#A17421"
# [15] "#836D43" "#666666"
#   OTU   Soil    Experiment padj         mean_Abundance log2FoldChange
# 1 ASV5  Dryden 1          1.885675e-05 0.020395195    -2.7165660
# 2 ASV6  Dryden 1          1.192425e-03 0.009201270     4.9776118
# 3 ASV14 Dryden 1          1.478663e-04 0.001813107     8.4299996
# 4 ASV16 Dryden 1          6.618920e-01 0.005376328    -0.6640584
# 5 ASV17 Dryden 1                    NA 0.000000000            NA
# 6 ASV18 Dryden 1          2.004166e-13 0.010919483    11.0823839
#   Phylum         Order                 Class               Family
# 1 Actinobacteria Micrococcales         Actinobacteria      Micrococcaceae
# 2 Proteobacteria Cellvibrionales       Gammaproteobacteria Cellvibrionaceae
# 3 Proteobacteria Myxococcales          Deltaproteobacteria Sandaracinaceae
# 4 Proteobacteria Rhizobiales           Alphaproteobacteria Xanthobacteraceae
# 5 Proteobacteria Betaproteobacteriales Gammaproteobacteria Burkholderiaceae
# 6 Proteobacteria Myxococcales          Deltaproteobacteria Sandaracinaceae
#   Genus             Pcs     Ocs     Ccs
# 1 Pseudarthrobacter #93752C #79932E #1B9E77
# 2 Cellvibrio        #B78415 #D35F0A #C44A6D
# 3 NA                #B78415 #7FA718 #9B58A5
# 4 Bradyrhizobium    #B78415 #BF8B12 #738040
# 5 Paucibacter       #B78415 #A07125 #C44A6D
# 6 NA                #B78415 #7FA718 #9B58A5

# %% [markdown]
# ### Simple two color heat map

# %%
# df.circ = df.l2fc %>%
#     filter(Fungus == "Gv") %>%
#     mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", 
#                  ifelse(log2FoldChange <= 0, "ns", "sig")), 
#            variable = paste(Soil,Experiment, sep = '')) %>%
#     select(OTU, variable, Contrast, sig) %>%
#     dcast(OTU ~ variable + Contrast) 
# head(df.circ)
# df.circ = df.circ %>%
#     mutate(Blank1 = "blank", 
#           Blank2 = "blank")

# rownames(df.circ) = df.circ$OTU
# df.circ = df.circ %>% select(-OTU)
# #head(df.circ)
# head(df.circ)
# Out:
#   OTU   variable Contrast sig
# 1 ASV5  Dryden1 CH_CS    ns
# 2 ASV6  Dryden1 CH_CS    sig
# 3 ASV8  Dryden1 CH_CS    ns
# 4 ASV13 Dryden1 CH_CS    ns
# 5 ASV14 Dryden1 CH_CS    sig
# 6 ASV15 Dryden1 CH_CS    ns

# %%
# testcirc = df.circ %>% select("Dryden2_CH_CS","Dryden2_CH_BS", "Dryden2_CH_BP","Dryden2_RH_RS","Blank1", 
#                               "Florence2_CH_CS","Florence2_CH_BS", "Florence2_CH_BP","Florence2_RH_RS", "Blank2",
#                              "Pendelton2_CH_CS","Pendelton2_CH_BS", "Pendelton2_CH_BP","Pendelton2_RH_RS")
# head(testcirc)

# %%
head(df.tax)
# Out:
#   OTU    TaxLabel                                   Phylum
# 1 ASV109 Pedosphaeraceae_NA                         Verrucomicrobia
# 2 ASV37  Chthoniobacteraceae_Candidatus_Udaeobacter Verrucomicrobia
# 3 ASV55  Chthoniobacteraceae_Candidatus_Udaeobacter Verrucomicrobia
# 4 ASV502 Chthoniobacteraceae_Candidatus_Udaeobacter Verrucomicrobia
# 5 ASV108 Chthoniobacteraceae_Candidatus_Udaeobacter Verrucomicrobia
# 6 ASV230 Chthoniobacteraceae_Candidatus_Udaeobacter Verrucomicrobia
#   Class            Order              Family
# 1 Verrucomicrobiae Pedosphaerales     Pedosphaeraceae
# 2 Verrucomicrobiae Chthoniobacterales Chthoniobacteraceae
# 3 Verrucomicrobiae Chthoniobacterales Chthoniobacteraceae
# 4 Verrucomicrobiae Chthoniobacterales Chthoniobacteraceae
# 5 Verrucomicrobiae Chthoniobacterales Chthoniobacteraceae
# 6 Verrucomicrobiae Chthoniobacterales Chthoniobacteraceae
#   Genus
# 1 NA
# 2 Candidatus_Udaeobacter
# 3 Candidatus_Udaeobacter
# 4 Candidatus_Udaeobacter
# 5 Candidatus_Udaeobacter
# 6 Candidatus_Udaeobacter

# %%
# p  = ggtree(MyTree, layout = "circular", branch.length = "none") %<+% df.tax
# #p = ggtree(MyTree)%<+% df.tax
# p = p +  geom_tiplab(aes(label = GenusLabel), align = TRUE, size = 1)

# p = gheatmap(p, testcirc, offset=10, width=0.4, colnames_position = "top", 
#          colnames_angle=90, hjust=0, colnames_offset_y = .25, font.size = 2) +
#        scale_fill_manual(breaks=c("blank", "ns", "sig" ),values=c("White", "Grey", "Red"))
#            # scale_fill_viridis_d(option="D", name='discrete\nvalue')
#             # scale_color_manual(breaks=c("ns", "sig"), values=c("White", "Red"), name="HASV")


# #p2 <- p1 + new_scale_fill()
# p
# Out:
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Warning message:
# “Duplicated aesthetics after name standardisation: size”Warning message:
# “Duplicated aesthetics after name standardisation: size”Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
# plot without title

# %% [markdown]
# ### For multicolor heatmap

# %%
df.circ = df.l2fc %>%
    filter(Fungus == "Gv") %>%
    mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", 
                 ifelse(log2FoldChange <= 0, "ns", "sig")), 
           variable = paste(Soil,Experiment, sep = '')) %>%

    mutate(sig = ifelse(Contrast == "CH_CS" & sig == "sig", 1,
                       ifelse(Contrast == "CH_BS" & sig == "sig", 2,
                           ifelse(Contrast == "CH_BP" & sig == "sig", 3,  
                                 ifelse(Contrast == "RH_RS" & sig == "sig", 4,
                                       "ns"))))) %>%
    select(OTU, variable, Contrast, sig) %>%
    dcast(OTU ~ variable + Contrast) 
head(df.circ)
df.circ = df.circ %>%
    mutate(Blank1 = "blank", 
          Blank2 = "blank")

rownames(df.circ) = df.circ$OTU
df.circ = df.circ %>% select(-OTU)
#head(df.circ)
head(df.circ)
# Out:
# Using sig as value column: use value.var to override.
#   OTU      Florence1_CH_CS Florence2_CH_CS Florence2_CH_BP Florence2_CH_BS
# 1 ASV100   ns              ns              ns              ns
# 2 ASV1000  ns              ns              ns              ns
# 3 ASV10000 ns              ns              ns              ns
# 4 ASV10001 ns              ns              ns              ns
# 5 ASV10002 ns              ns              ns              ns
# 6 ASV10003 ns              ns              ns              ns
#   Florence2_RH_RS Dryden1_CH_CS Dryden2_CH_CS Dryden2_CH_BP Dryden2_CH_BS
# 1 ns              ns             ns             ns             ns
# 2 ns              ns             ns             ns             ns
# 3 ns              ns             ns             ns             ns
# 4 ns              ns             ns             ns             ns
# 5 ns              ns             ns             ns             ns
# 6 ns              ns             ns             ns             ns
#   Dryden2_RH_RS Pendelton1_CH_CS Pendelton2_CH_CS Pendelton2_CH_BP
# 1 ns             ns               ns               ns
# 2 ns             ns               ns               ns
# 3 ns             ns               ns               ns
# 4 ns             ns               ns               ns
# 5 ns             ns               ns               ns
# 6 ns             ns               ns               ns
#   Pendelton2_CH_BS Pendelton2_RH_RS
# 1 ns               ns
# 2 ns               ns
# 3 ns               ns
# 4 ns               ns
# 5 ns               ns
# 6 ns               ns
#          Florence1_CH_CS Florence2_CH_CS Florence2_CH_BP Florence2_CH_BS
# ASV100   ns              ns              ns              ns
# ASV1000  ns              ns              ns              ns
# ASV10000 ns              ns              ns              ns
# ASV10001 ns              ns              ns              ns
# ASV10002 ns              ns              ns              ns
# ASV10003 ns              ns              ns              ns
#          Florence2_RH_RS Dryden1_CH_CS Dryden2_CH_CS Dryden2_CH_BP
# ASV100   ns              ns             ns             ns
# ASV1000  ns              ns             ns             ns
# ASV10000 ns              ns             ns             ns
# ASV10001 ns              ns             ns             ns
# ASV10002 ns              ns             ns             ns
# ASV10003 ns              ns             ns             ns
#          Dryden2_CH_BS Dryden2_RH_RS Pendelton1_CH_CS Pendelton2_CH_CS
# ASV100   ns             ns             ns               ns
# ASV1000  ns             ns             ns               ns
# ASV10000 ns             ns             ns               ns
# ASV10001 ns             ns             ns               ns
# ASV10002 ns             ns             ns               ns
# ASV10003 ns             ns             ns               ns
#          Pendelton2_CH_BP Pendelton2_CH_BS Pendelton2_RH_RS Blank1 Blank2
# ASV100   ns               ns               ns               blank  blank
# ASV1000  ns               ns               ns               blank  blank
# ASV10000 ns               ns               ns               blank  blank
# ASV10001 ns               ns               ns               blank  blank
# ASV10002 ns               ns               ns               blank  blank
# ASV10003 ns               ns               ns               blank  blank

# %%
testcirc = df.circ %>% select("Dryden2_CH_CS","Dryden2_CH_BS", "Dryden2_CH_BP","Dryden2_RH_RS","Blank1", 
                              "Florence2_CH_CS","Florence2_CH_BS", "Florence2_CH_BP","Florence2_RH_RS", "Blank2",
                             "Pendelton2_CH_CS","Pendelton2_CH_BS", "Pendelton2_CH_BP","Pendelton2_RH_RS")
head(testcirc)
# Out:
#          Dryden2_CH_CS Dryden2_CH_BS Dryden2_CH_BP Dryden2_RH_RS Blank1
# ASV100   ns             ns             ns             ns             blank
# ASV1000  ns             ns             ns             ns             blank
# ASV10000 ns             ns             ns             ns             blank
# ASV10001 ns             ns             ns             ns             blank
# ASV10002 ns             ns             ns             ns             blank
# ASV10003 ns             ns             ns             ns             blank
#          Florence2_CH_CS Florence2_CH_BS Florence2_CH_BP Florence2_RH_RS Blank2
# ASV100   ns              ns              ns              ns              blank
# ASV1000  ns              ns              ns              ns              blank
# ASV10000 ns              ns              ns              ns              blank
# ASV10001 ns              ns              ns              ns              blank
# ASV10002 ns              ns              ns              ns              blank
# ASV10003 ns              ns              ns              ns              blank
#          Pendelton2_CH_CS Pendelton2_CH_BS Pendelton2_CH_BP Pendelton2_RH_RS
# ASV100   ns               ns               ns               ns
# ASV1000  ns               ns               ns               ns
# ASV10000 ns               ns               ns               ns
# ASV10001 ns               ns               ns               ns
# ASV10002 ns               ns               ns               ns
# ASV10003 ns               ns               ns               ns

# %%
testcirc %>% filter(Dryden2_RH_RS == 4)
# Out:
#         Dryden2_CH_CS Dryden2_CH_BS Dryden2_CH_BP Dryden2_RH_RS Blank1
# ASV1246 ns             ns             ns             4              blank
# ASV14   1              2              3              4              blank
# ASV18   1              2              3              4              blank
# ASV19   ns             ns             ns             4              blank
# ASV190  1              2              3              4              blank
# ASV23   1              2              3              4              blank
# ASV395  ns             ns             ns             4              blank
# ASV508  ns             ns             ns             4              blank
# ASV528  ns             2              3              4              blank
# ASV66   1              2              3              4              blank
#         Florence2_CH_CS Florence2_CH_BS Florence2_CH_BP Florence2_RH_RS Blank2
# ASV1246 ns              ns              ns              ns              blank
# ASV14   1               2               3               4               blank
# ASV18   1               2               3               4               blank
# ASV19   ns              ns              ns              ns              blank
# ASV190  1               2               3               ns              blank
# ASV23   1               2               3               4               blank
# ASV395  ns              ns              ns              4               blank
# ASV508  ns              ns              ns              ns              blank
# ASV528  1               2               3               4               blank
# ASV66   ns              ns              ns              ns              blank
#         Pendelton2_CH_CS Pendelton2_CH_BS Pendelton2_CH_BP Pendelton2_RH_RS
# ASV1246 ns               ns               ns               ns
# ASV14   1                2                3                4
# ASV18   1                2                3                4
# ASV19   ns               ns               ns               4
# ASV190  ns               ns               ns               ns
# ASV23   ns               ns               ns               ns
# ASV395  ns               ns               ns               4
# ASV508  ns               ns               ns               ns
# ASV528  ns               ns               ns               ns
# ASV66   1                2                3                ns

# %%
ColorCount = df.tax$Phylum %>% unique() %>% length()
getPalette = colorRampPalette(brewer.pal(8, "Dark2"))
Pcs = getPalette(ColorCount)

cs = (brewer.pal(4, 'PuOr'))

# %%
p  = ggtree(MyTree, layout = "circular", branch.length = "none") %<+% df.tax
#p = ggtree(MyTree)%<+% df.tax
p = p +  
geom_tippoint(aes(color=Phylum), size=1) +
geom_tiplab(aes(label = GenusLabel),hjust = -.1, align = TRUE, size = 1)+

    scale_color_manual(values = Pcs, guide = guide_legend(ncol = 3))

p = gheatmap(p, testcirc, offset=10, width=0.4, colnames_position = NULL, 
         colnames_angle=90, hjust=0, colnames_offset_y = .25, font.size = 2) +
       scale_fill_manual(breaks=c( "1", "2","3","4", "blank", "ns" ),values=c(cs[1],cs[2],cs[3],cs[4], "White", "Light Grey")) +
    theme(legend.position = 'bottom')

#            # scale_fill_viridis_d(option="D", name='discrete\nvalue')
#             # scale_color_manual(breaks=c("ns", "sig"), values=c("White", "Red"), name="HASV")


# #p2 <- p1 + new_scale_fill()
p

outfile = file.path(out_Dir, 'CircularTree_controls.pdf')
pdf(outfile, width = 7.036, height = 9, useDingbats = FALSE)
p
dev.off()
# Out:
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Warning message:
# “Duplicated aesthetics after name standardisation: size”Warning message:
# “Duplicated aesthetics after name standardisation: size”Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
# png
#   2
# plot without title

# %%
# heatmap.colours <- c("white","grey","seagreen3","darkgreen",
#                     "green","brown","tan","red","orange",
#                     "pink","magenta","purple","blue","skyblue3",
#                     "blue","skyblue2")
# names(heatmap.colours) <- 0:15

gheatmap(p, heatmapData, offset = 10, color=NULL, 
         colnames_position="top", 
         colnames_angle=90, colnames_offset_y = 1, 
         hjust=0, font.size=2) 
#   scale_fill_manual(values=heatmap.colours, breaks=0:15)
# heatmap.colours <- c("white","grey","seagreen3","darkgreen",
#                     "green","brown","tan","red","orange",
#                     "pink","magenta","purple","blue","skyblue3",
#                     "blue","skyblue2")
# names(heatmap.colours) <- 0:15
# heatmap.colours = c("White", "Red")

##ggtree example
# gheatmap(p, heatmapData, offset = 10, color=NULL, 
#          colnames_position="top", 
#          colnames_angle=90, colnames_offset_y = 1, 
#          hjust=0, font.size=2) +
#   scale_fill_manual(values=heatmap.colours, breaks=0:15)

names(heatmap.colours) = c("ns", "sig")
heatmap.colours
# Out:
# Error in ncol(data): object 'heatmapData' not found
# Traceback:
#
# 1. gheatmap(p, heatmapData, offset = 10, color = NULL, colnames_position = "top",
#  .     colnames_angle = 90, colnames_offset_y = 1, hjust = 0, font.size = 2)
# 2. ncol(data)

# %% [markdown]
# ## Heatmap figure

# %%
### Get responder colorstrips

# %%
mdf = psmelt(physeq.thresh)
mdf.byOTU = ddply(mdf, .(Soil, SampleType, OTU, Experiment), summarize, mean_Abundance = mean(Abundance))
head(mdf.byOTU)
# mdf.F.byOTU = filter(mdf.byOTU, Soil == "Florence" & SampleType == 'CH')
# mdf.L.byOTU = filter(mdf.byOTU, Soil == "Dryden" & SampleType == 'CH')
# mdf.P.byOTU = filter(mdf.byOTU, Soil == "Pendelton" & SampleType == 'CH')
# head(mdf.F.byOTU)
# Out:
# Warning message in psmelt(physeq.thresh):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
#   Soil     SampleType OTU    Experiment mean_Abundance
# 1 Florence CH         ASV100 1          0.0007582158
# 2 Florence CH         ASV100 2          0.0015091146
# 3 Florence CH         ASV101 1          0.0008770968
# 4 Florence CH         ASV101 2          0.0004350364
# 5 Florence CH         ASV103 1          0.0045006324
# 6 Florence CH         ASV103 2          0.0015183456

# %%
df.ra = dcast(mdf.byOTU, OTU ~ Experiment + SampleType + Soil, value.var = "mean_Abundance")
rownames(df.ra) = df.ra$OTU
df.ra = select(df.ra, "1_CS_Dryden", "2_CS_Dryden", "1_CS_Florence", "2_CS_Florence", "1_CS_Pendelton", "2_CS_Pendelton",
              "1_CH_Dryden", "2_CH_Dryden", "1_CH_Florence", "2_CH_Florence", "1_CH_Pendelton", "2_CH_Pendelton")
head(df.ra)
# Out:
#         1_CS_Dryden 2_CS_Dryden 1_CS_Florence 2_CS_Florence 1_CS_Pendelton
# ASV100  0.001563717  3.048388e-03 0.0009907606  0.0017838697  0.000000000
# ASV101  0.000000000  2.179030e-03 0.0036154030  0.0027190395  0.000655730
# ASV103  0.005145047  3.777696e-03 0.0242719555  0.0026366959  0.021283531
# ASV104  0.001197625  2.599790e-03 0.0037648068  0.0009712141  0.002414126
# ASV1053 0.002980874  2.266905e-05 0.0000000000  0.0000000000  0.000000000
# ASV106  0.003835186  3.748473e-03 0.0000000000  0.0000000000  0.000000000
#         2_CS_Pendelton 1_CH_Dryden 2_CH_Dryden 1_CH_Florence 2_CH_Florence
# ASV100  0.0017289679   0.0000000000 0.0033556499 0.0007582158  0.0015091146
# ASV101  0.0017271379   0.0000000000 0.0012225247 0.0008770968  0.0004350364
# ASV103  0.0007089811   0.0018429894 0.0013360912 0.0045006324  0.0015183456
# ASV104  0.0056020170   0.0000000000 0.0003111974 0.0042629982  0.0004498436
# ASV1053 0.0000000000   0.0098664360 0.0001234304 0.0000000000  0.0000000000
# ASV106  0.0000000000   0.0001846138 0.0019151099 0.0000000000  0.0000000000
#         1_CH_Pendelton 2_CH_Pendelton
# ASV100  0.000000000    0.0016067854
# ASV101  0.000000000    0.0006505861
# ASV103  0.006095402    0.0000000000
# ASV104  0.000593988    0.0020888437
# ASV1053 0.000000000    0.0000000000
# ASV106  0.000000000    0.0000000000

# %%
install.packages("ggnewscale")

# %%
library(ggnewscale)

# %%
df.l2fc %>% head()
# Out:
#   baseMean  log2FoldChange lfcSE     stat      pvalue       padj         OTU
# 1 331.72029 -2.716566      0.5217389 -5.206754 1.921730e-07 1.885675e-05 ASV5
# 2 136.95264  4.977612      1.1905977  4.180767 2.905274e-05 1.192425e-03 ASV6
# 3   0.00000        NA             NA        NA           NA           NA ASV8
# 4   0.00000        NA             NA        NA           NA           NA ASV13
# 5  26.70389  8.430000      1.7857267  4.720767 2.349571e-06 1.478663e-04 ASV14
# 6   0.00000        NA             NA        NA           NA           NA ASV15
#   Soil    Fungus Term       Contrast DAI Kingdom  Phylum
# 1 Dryden Gv     SampleType CH_CS    81  Bacteria Actinobacteria
# 2 Dryden Gv     SampleType CH_CS    81  Bacteria Proteobacteria
# 3 Dryden Gv     SampleType CH_CS    81  Bacteria Proteobacteria
# 4 Dryden Gv     SampleType CH_CS    81  Bacteria Proteobacteria
# 5 Dryden Gv     SampleType CH_CS    81  Bacteria Proteobacteria
# 6 Dryden Gv     SampleType CH_CS    81  Bacteria Proteobacteria
#   Class               Order                 Family           Genus
# 1 Actinobacteria      Micrococcales         Micrococcaceae   Pseudarthrobacter
# 2 Gammaproteobacteria Cellvibrionales       Cellvibrionaceae Cellvibrio
# 3 Alphaproteobacteria Caulobacterales       Caulobacteraceae Asticcacaulis
# 4 Gammaproteobacteria Xanthomonadales       Xanthomonadaceae Luteimonas
# 5 Deltaproteobacteria Myxococcales          Sandaracinaceae  NA
# 6 Gammaproteobacteria Betaproteobacteriales Burkholderiaceae NA
#   Experiment
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 1

# %%
tmp = df.l2fc %>% 
    #filter(Experiment == 1 & Subset == 'Dryden-Gv') %>%
    filter(OTU %in% TreeTax & Contrast == "CH_CS" & Subset %in% c('Dryden-Gv', 'Florence-Gv', 'Pendelton-Gv')) %>% 
    mutate(HASV = ifelse(padj < 0.05 & log2FoldChange > 0, "HASV", "ns")) %>%
    mutate(HASV = ifelse(!is.na(HASV), HASV, "ns")) %>%
    select(OTU, HASV, Experiment, Subset)
#head(tmp)
tmp = dcast(tmp, OTU ~ Experiment + Subset, value.var = "HASV") 
rownames(tmp) = tmp$OTU
tmp = select(tmp, "1_Dryden-Gv", "2_Dryden-Gv", "1_Florence-Gv", "2_Florence-Gv", "1_Pendelton-Gv", "2_Pendelton-Gv")
# tmp1 = select(tmp, "1_Dryden-Gv", "2_Dryden-Gv") #, 1_Florence-Gv, 2_Florence-Gv, 1_Pendelton-Gv, 2_Pendelton-Gv) %>% as.matrix()
# tmp2 = select(tmp, "1_Florence-Gv", "2_Florence-Gv")

#tmp %>% filter(OTU == "ASV18")


p  = ggtree(MyTree, layout = "circular", branch.length = "none") %<+% df.tax
p = p +  geom_tiplab()
p1 = gheatmap(p, tmp, offset=0.8, width=0.4,  
         colnames_angle=95, hjust=0, colnames_offset_y = .25) +
            scale_fill_viridis_d(option="D", name='discrete\nvalue')
#             scale_color_manual(breaks=c("ns", "HASV"), 
#          values=c("Red", "White"), name="HASV")


p2 <- p1 + new_scale_fill()

gheatmap(p2, df.ra, offset=1.3, width=1,
         colnames_angle=90, colnames_offset_y = .25) +
    scale_fill_viridis_c(option="cividis", name="continuous\nvalue")
# gheatmap(p1, tmp[,5:6, drop =FALSE], offset=5, width=0.5, font.size=3, 
#          colnames_angle=-45, hjust=0)+
#
# Out:
# Error: Problem with `filter()` input `..1`.
# ✖ object 'Subset' not found
# ℹ Input `..1` is `&...`.
# Traceback:
#
# 1. df.l2fc %>% filter(OTU %in% TreeTax & Contrast == "CH_CS" & Subset %in%
#  .     c("Dryden-Gv", "Florence-Gv", "Pendelton-Gv")) %>% mutate(HASV = ifelse(padj <
#  .     0.05 & log2FoldChange > 0, "HASV", "ns")) %>% mutate(HASV = ifelse(!is.na(HASV),
#  .     HASV, "ns")) %>% select(OTU, HASV, Experiment, Subset)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. function_list[[i]](value)
# 8. filter(., OTU %in% TreeTax & Contrast == "CH_CS" & Subset %in%
#  .     c("Dryden-Gv", "Florence-Gv", "Pendelton-Gv"))
# 9. filter.data.frame(., OTU %in% TreeTax & Contrast == "CH_CS" &
#  .     Subset %in% c("Dryden-Gv", "Florence-Gv", "Pendelton-Gv"))
# 10. filter_rows(.data, ...)
# 11. tryCatch(mask$eval_all_filter(dots, env_filter), simpleError = function(e) {
#   .     stop_dplyr(env_filter$current_expression, dots, fn = "filter",
#   .         problem = conditionMessage(e))
#   . })
# 12. tryCatchList(expr, classes, parentenv, handlers)
# 13. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 14. value[[3L]](cond)
# 15. stop_dplyr(env_filter$current_expression, dots, fn = "filter",
#   .     problem = conditionMessage(e))
# 16. abort(bullets, class = "dplyr_error", error_name = error_name,
#   .     error_expression = error_expression, index = .index, dots = dots,
#   .     fn = fn, parent = parent)
# 17. signal_abort(cnd)

# %% [markdown]
# # vignette

# %%
genotype_file <- system.file("examples/Genotype.txt", package="ggtree")
genotype <- read.table(genotype_file, sep="\t", stringsAsFactor=F)
head(genotype)

beast_file <- system.file("examples/MCC_FluA_H3.tree", package="ggtree")
beast_tree <- read.tree(beast_file)

# colnames(genotype) <- sub("\\.$", "", colnames(genotype))
# p <- ggtree(beast_tree, mrsd="2013-01-01") + 
#     geom_treescale(x=2008, y=1, offset=2) + 
#     geom_tiplab(size=2)
# gheatmap(p, genotype, offset=5, width=0.5, font.size=3, 
#         colnames_angle=-45, hjust=0) +
#     scale_fill_manual(breaks=c("HuH3N2", "pdm", "trig"), 
#         values=c("steelblue", "firebrick", "darkgreen"), name="genotype")

# %%
head(snp_data)

# %%
head(p)

# %%
bar_data %>% filter(id == "DE0655_HCMC_2001")
#head(p)
snp_data %>% filter(name == "DE0655_HCMC_2001")

p$data %>% filter(label == "DE0655_HCMC_2001")

# %%
remote_folder <- paste0("https://raw.githubusercontent.com/katholt/",
                        "plotTree/master/tree_example_april2015/")

## read the phylogenetic tree
tree <- read.tree(paste0(remote_folder, "tree.nwk"))

## read the sampling information data set
info <- read.csv(paste0(remote_folder,"info.csv"))

## read and process the allele table
snps<-read.csv(paste0(remote_folder, "alleles.csv"), header = F,
                row.names = 1, stringsAsFactor = F)
snps_strainCols <- snps[1,] 
snps<-snps[-1,] # drop strain names
colnames(snps) <- snps_strainCols


gapChar <- "?"
snp <- t(snps)
lsnp <- apply(snp, 1, function(x) {
        x != snp[1,] & x != gapChar & snp[1,] != gapChar
    })
lsnp <- as.data.frame(lsnp)
lsnp$pos <- as.numeric(rownames(lsnp))
lsnp <- tidyr::gather(lsnp, name, value, -pos)
snp_data <- lsnp[lsnp$value, c("name", "pos")]

## read the trait data
bar_data <- read.csv(paste0(remote_folder, "bar.csv"))

## visualize the tree 
p <- ggtree(tree) 

## attach the sampling information data set 
## and add symbols colored by location
p <- p %<+% info + geom_tippoint(aes(color=location)) 

## visualize SNP and Trait data using dot and bar charts,
## and align them based on tree structure
p + 
    geom_tiplab() +
#    geom_facet(panel = "SNP", data = snp_data, geom = geom_point, 
#                mapping=aes(x = pos,y color = location), shape = '|') 
    geom_facet(panel = "Trait", data = bar_data, geom= geom_point,
              aes(x = dummy_bar_value))+
    geom_facet(panel = "Trait2", data = bar_data, geom = ggstance::geom_barh, 
                aes(x = dummy_bar_value, color = location, fill = location), 
                stat = "identity", width = .6) #+
    #theme_tree2(legend.position=c(.05, .85))
# Out:
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# plot without title

# %%
head(bar_data)

# %% [markdown]
# # Create annotation files for iTOL

# %% [markdown]
# ## Hyphal ASVs

# %%
readfile = file.path(work_dir, 'dfl2fc-Exp1.txt')
df.l2fc.Exp1 = read.table(readfile, header = TRUE, sep= '\t')

readfile = file.path(work_dir, 'dfl2fc-Exp2.txt')
df.l2fc.Exp2 = read.table(readfile, header = TRUE, sep= '\t')

df.l2fc = bind_rows(df.l2fc.Exp1, df.l2fc.Exp2)

# %%
head(df.l2fc)
tail(df.l2fc)

# %%
df.l2fc$Subset %>% unique

# %%
#ffffcc - Dryden 1
#ffeda0 - Dryden 2
#fed976
#feb24c - Florence 1
#fd8d3c - Florence 2
#fc4e2a
#e31a1c
#bd0026 - Pendelton 1
#800026 - Pendelton 2

# %%
tmp = df.l2fc %>% 
    filter(Experiment == 1 & Subset == 'Dryden-Gv') %>%
    filter(OTU %in% TreeTax & Contrast == "CH_CS") %>% 
    mutate(Color = ifelse(padj < 0.05 & log2FoldChange > 0, "#ffffcc", "#ffffff")) %>%
    mutate(Color = ifelse(!is.na(Color), Color, "#ffffff")) %>%
    select(OTU, Color)
write.table(tmp, file = file.path(out_Dir, "HA-Dryden1.txt"), sep = "\t", row.names = FALSE, quote = FALSE)

tmp = df.l2fc %>% 
    filter(Experiment == 2 & Subset == 'Dryden-Gv') %>%
    filter(OTU %in% TreeTax & Contrast == "CH_CS") %>% 
    mutate(Color = ifelse(padj < 0.05 & log2FoldChange > 0, "#ffeda0", "#ffffff")) %>%
    mutate(Color = ifelse(!is.na(Color), Color, "#ffffff")) %>%
    select(OTU, Color)
write.table(tmp, file = file.path(out_Dir, "HA-Dryden2.txt"), sep = "\t", row.names = FALSE, quote = FALSE)

# %%
tmp = df.l2fc %>% 
    filter(Experiment == 1 & Subset == 'Florence-Gv') %>%
    filter(OTU %in% TreeTax & Contrast == "CH_CS") %>% 
    mutate(Color = ifelse(padj < 0.05 & log2FoldChange > 0, "#feb24c", "#ffffff")) %>%
    mutate(Color = ifelse(!is.na(Color), Color, "#ffffff")) %>%
    select(OTU, Color)
write.table(tmp, file = file.path(out_Dir, "HA-Florence1.txt"), sep = "\t", row.names = FALSE, quote = FALSE)

tmp = df.l2fc %>% 
    filter(Experiment == 2 & Subset == 'Florence-Gv') %>%
    filter(OTU %in% TreeTax & Contrast == "CH_CS") %>% 
    mutate(Color = ifelse(padj < 0.05 & log2FoldChange > 0, "#fd8d3c", "#ffffff")) %>%
    mutate(Color = ifelse(!is.na(Color), Color, "#ffffff")) %>%
    select(OTU, Color)
write.table(tmp, file = file.path(out_Dir, "HA-Florence2.txt"), sep = "\t", row.names = FALSE, quote = FALSE)

# %%
tmp = df.l2fc %>% 
    filter(Experiment == 1 & Subset == 'Pendelton-Gv') %>%
    filter(OTU %in% TreeTax & Contrast == "CH_CS") %>% 
    mutate(Color = ifelse(padj < 0.05 & log2FoldChange > 0, "#bd0026", "#ffffff")) %>%
    mutate(Color = ifelse(!is.na(Color), Color, "#ffffff")) %>%
    select(OTU, Color)
write.table(tmp, file = file.path(out_Dir, "HA-Pendelton1.txt"), sep = "\t", row.names = FALSE, quote = FALSE)

tmp = df.l2fc %>% 
    filter(Experiment == 2 & Subset == 'Pendelton-Gv') %>%
    filter(OTU %in% TreeTax & Contrast == "CH_CS") %>% 
    mutate(Color = ifelse(padj < 0.05 & log2FoldChange > 0, "#800026", "#ffffff")) %>%
    mutate(Color = ifelse(!is.na(Color), Color, "#ffffff")) %>%
    select(OTU, Color)
write.table(tmp, file = file.path(out_Dir, "HA-Pendelton2.txt"), sep = "\t", row.names = FALSE, quote = FALSE)

# %% [markdown]
# ## Relative abundance data

# %% [markdown]
# ### Mean of two experiments both sample types

# %% [markdown]
# ### Hyphal samples only stacked by experiment

# %%
mdf.byOTU = ddply(mdf, .(Soil, SampleType, OTU, Experiment), summarize, mean_Abundance = mean(Abundance))

mdf.F.byOTU = filter(mdf.byOTU, Soil == "Florence" & SampleType == 'CH')
mdf.L.byOTU = filter(mdf.byOTU, Soil == "Dryden" & SampleType == 'CH')
mdf.P.byOTU = filter(mdf.byOTU, Soil == "Pendelton" & SampleType == 'CH')
head(mdf.F.byOTU)

# %%
dfc.F = dcast(mdf.F.byOTU, OTU ~ Experiment) 
dfc.L = dcast(mdf.L.byOTU, OTU ~ Experiment)    
dfc.P = dcast(mdf.P.byOTU, OTU ~ Experiment)

# %%
write.table(dfc.F, file.path(out_Dir,'Florence_Abund.txt'), sep = "\t", 
            row.names = FALSE, quote = FALSE)
write.table(dfc.L, file.path(out_Dir,'Dryden_Abund.txt'), sep = "\t", 
            row.names = FALSE, quote = FALSE)
write.table(dfc.P, file.path(out_Dir,'Pendelton_Abund.txt'), sep = "\t", 
            row.names = FALSE, quote = FALSE)
