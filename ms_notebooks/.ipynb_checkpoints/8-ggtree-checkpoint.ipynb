# %% [markdown]
# # Tree figures

# %% [markdown]
# * This script uses the differential abundance outputs and the phylogenetic tree to generate output files for import into the tree of life
# *

# %%
out_Dir = '~/Hyphosphere/data/3Exp/figures'

work_dir = '~/Hyphosphere/data/3Exp/DESeq'

# phyloseq - full object with tree
physeq_file = '~/Hyphosphere/data/3Exp/phyloseq/3Exp_phyloseq_thresh_wtree_experimental_woContam.rds'

# %%
library(RColorBrewer)
library(plyr)
library(tidyr)
library(dplyr)
library(reshape2)
library(phyloseq)
library(ggplot2)
library(ggtree)
library(gridExtra)
# Out:
# Warning message:
# “package ‘RColorBrewer’ was built under R version 3.6.1”Warning message:
# “package ‘plyr’ was built under R version 3.6.1”
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:plyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Warning message:
# “package ‘reshape2’ was built under R version 3.6.1”
# Attaching package: ‘reshape2’
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
# Warning message:
# “package ‘phyloseq’ was built under R version 3.6.1”Warning message:
# “package ‘ggplot2’ was built under R version 3.6.1”Warning message:
# “package ‘ggtree’ was built under R version 3.6.1”Registered S3 method overwritten by 'treeio':
#   method     from
#   root.phylo ape
# ggtree v2.0.0  For help: https://yulab-smu.github.io/treedata-book/
#
# If you use ggtree in published research, please cite the most appropriate paper(s):
#
# - Guangchuang Yu, Tommy Tsan-Yuk Lam, Huachen Zhu, Yi Guan. Two methods for mapping and visualizing associated data on phylogeny using ggtree. Molecular Biology and Evolution 2018, 35(12):3041-3043. doi: 10.1093/molbev/msy194
# - Guangchuang Yu, David Smith, Huachen Zhu, Yi Guan, Tommy Tsan-Yuk Lam. ggtree: an R package for visualization and annotation of phylogenetic trees with their covariates and other associated data. Methods in Ecology and Evolution 2017, 8(1):28-36, doi:10.1111/2041-210X.12628
#
#
#
# Attaching package: ‘ggtree’
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
# The following object is masked from ‘package:plyr’:
#
#     .
#
#
# Attaching package: ‘gridExtra’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %%
g_legend <- function(a.gplot){
  tmp <- ggplot_gtable(ggplot_build(a.gplot))
  leg <- which(sapply(tmp$grobs, function(x) x$name) == "guide-box")
  legend <- tmp$grobs[[leg]]
  return(legend)
}

# %% [markdown]
# # Identify top taxa
# * melting data frame and summarizing by experiment, soil and treatment avoids increased weight to taxa in samples with higher replications

# %%
ps = readRDS(physeq_file) %>% subset_taxa(., !is.na(Phylum)) %>%
    # remove non-experimental controls
    
    subset_samples(., SampleType != "GV" & Experiment %in% c(1,2) & Fungus %in% c("Gv","RI") & SampleType %in% c("CS","CH") & Soil != "Sand") %>%

     # re-normalize after subsetting taxa
    transform_sample_counts(., function(x) x/sum(x))

ps
# Out:
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 18707 taxa and 74 samples ]
# sample_data() Sample Data:       [ 74 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 18707 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 18707 tips and 18706 internal nodes ]

# %%
ps.m = ps %>%
    psmelt() %>%
    group_by(OTU, Soil, Experiment) %>%
    summarise(mAbund = mean(Abundance)) %>%
    ungroup() %>% 
    group_by(OTU) %>%
    summarise(smAbund = sum(mAbund)) 
head(ps.m)
# Out:
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# `summarise()` regrouping output by 'OTU', 'Soil' (override with `.groups` argument)
# `summarise()` ungrouping output (override with `.groups` argument)
#   OTU      smAbund
# 1 ASV100   8.247168e-03
# 2 ASV1000  1.421621e-03
# 3 ASV10000 0.000000e+00
# 4 ASV10001 2.147293e-05
# 5 ASV10002 1.075044e-04
# 6 ASV10003 6.691852e-05

# %% [markdown]
# ### Top 60 most abundant taxa

# %%
topTax = ps.m %>% 
    arrange(desc(smAbund)) %>%
    .[1:75,] %>%
    .$OTU %>%
    as.character()

topTax
# Out:
#  [1] "ASV5"    "ASV6"    "ASV14"   "ASV57"   "ASV18"   "ASV103"  "ASV16"
#  [8] "ASV39"   "ASV33"   "ASV148"  "ASV27"   "ASV25"   "ASV21"   "ASV943"
# [15] "ASV61"   "ASV47"   "ASV915"  "ASV143"  "ASV718"  "ASV24"   "ASV17"
# [22] "ASV40"   "ASV46"   "ASV71"   "ASV29"   "ASV44"   "ASV118"  "ASV69"
# [29] "ASV95"   "ASV23"   "ASV53"   "ASV64"   "ASV55"   "ASV648"  "ASV77"
# [36] "ASV338"  "ASV98"   "ASV247"  "ASV1132" "ASV168"  "ASV50"   "ASV36"
# [43] "ASV66"   "ASV383"  "ASV37"   "ASV104"  "ASV288"  "ASV661"  "ASV259"
# [50] "ASV60"   "ASV1847" "ASV65"   "ASV102"  "ASV246"  "ASV30"   "ASV81"
# [57] "ASV286"  "ASV961"  "ASV91"   "ASV99"   "ASV138"  "ASV514"  "ASV1925"
# [64] "ASV230"  "ASV126"  "ASV873"  "ASV204"  "ASV73"   "ASV87"   "ASV282"
# [71] "ASV341"  "ASV154"  "ASV97"   "ASV195"  "ASV509"

# %%
rm(ps.m)

# %% [markdown]
# ### subset tree and save names of taxa in tree

# %%
# Filter to the top OTUs identified above

physeq.thresh <- prune_taxa(topTax, ps)

physeq.thresh

# Save tree
MyTree =  physeq.thresh %>% phy_tree

# Save names of taxa in tree
TreeTax = taxa_names(physeq.thresh)
# Out:
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 75 taxa and 74 samples ]
# sample_data() Sample Data:       [ 74 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 75 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 75 tips and 74 internal nodes ]

# %% [markdown]
# ###  taxonomy table for taxa in tree

# %%
df.tax = physeq.thresh %>% tax_table %>% as.data.frame
df.tax$OTU = df.tax %>% row.names

df.tax = mutate(df.tax, TaxLabel = paste(Family, Genus, sep = "_")) %>%
    select(OTU, TaxLabel, Phylum, Class, Order, Family, Genus)


df.tax = df.tax %>%
    mutate(GenusLabel = ifelse(!is.na(Genus), paste(Genus), 
                        ifelse(!is.na(Family), paste('Uncl. ', Family, sep = ""), 
                        ifelse(!is.na(Order), paste('Uncl. ', Order, sep = ""),
                        ifelse(!is.na(Class), paste('Uncl. ', Class, sep = ""), paste("Uncl. ", Phylum, sep = "")))))) %>%
    mutate(GenusLabel = ifelse(GenusLabel == 'Allorhizobium-Neorhizobium-Pararhizobium-Rhizobium', 'Allo-Neo-Para-Rhizobium', GenusLabel))
head(df.tax)
# Out:
#   OTU    TaxLabel                                   Phylum
# 1 ASV37  Chthoniobacteraceae_Candidatus_Udaeobacter Verrucomicrobia
# 2 ASV55  Chthoniobacteraceae_Candidatus_Udaeobacter Verrucomicrobia
# 3 ASV230 Chthoniobacteraceae_Candidatus_Udaeobacter Verrucomicrobia
# 4 ASV98  NA_NA                                      Acidobacteria
# 5 ASV154 Pyrinomonadaceae_RB41                      Acidobacteria
# 6 ASV65  NA_NA                                      Rokubacteria
#   Class                       Order              Family
# 1 Verrucomicrobiae            Chthoniobacterales Chthoniobacteraceae
# 2 Verrucomicrobiae            Chthoniobacterales Chthoniobacteraceae
# 3 Verrucomicrobiae            Chthoniobacterales Chthoniobacteraceae
# 4 Subgroup_6                  NA                 NA
# 5 Blastocatellia_(Subgroup_4) Pyrinomonadales    Pyrinomonadaceae
# 6 NC10                        Rokubacteriales    NA
#   Genus                  GenusLabel
# 1 Candidatus_Udaeobacter Candidatus_Udaeobacter
# 2 Candidatus_Udaeobacter Candidatus_Udaeobacter
# 3 Candidatus_Udaeobacter Candidatus_Udaeobacter
# 4 NA                     Uncl. Subgroup_6
# 5 RB41                   RB41
# 6 NA                     Uncl. Rokubacteriales

# %%
### log2fold change data

# %%
df.l2fc$Phylum = factor(df.l2fc$Phylum)
df.l2fc$Order = factor(df.l2fc$Order)
df.l2fc$Class = factor(df.l2fc$Class)

#Link phylum colors 
FigPhyla = df.l2fc$Phylum %>% levels() %>% as.character()
FigClass = df.l2fc$Class %>% levels() %>% as.character()
FigOrder = df.l2fc$Order %>% levels() %>% as.character()


ColorCount = length(FigOrder)
getPalette = colorRampPalette(brewer.pal(8, "Dark2"))
Ocs = getPalette(ColorCount)
Ocs


ColorCount = length(FigPhyla)
getPalette = colorRampPalette(brewer.pal(8, "Dark2"))
Pcs = getPalette(ColorCount)
Pcs

ColorCount = length(FigClass)
getPalette = colorRampPalette(brewer.pal(8, "Dark2"))
Ccs = getPalette(ColorCount)
Ccs


# Pcs = brewer.pal(12,"Set3")

#Set lookup to 
Olookup = cbind(FigOrder, Ocs) %>% as.data.frame()
Plookup = cbind(FigPhyla, Pcs) %>% as.data.frame()
Clookup = cbind(FigClass, Ccs) %>% as.data.frame()

df.l2fc = left_join(df.l2fc, Plookup, by = c("Phylum" = "FigPhyla"))
df.l2fc = left_join(df.l2fc, Olookup, by = c("Order" = "FigOrder")) 
df.l2fc = left_join(df.l2fc, Clookup, by = c("Class" = "FigClass")) 



df.l2fc %>% head()
# Out:
#  [1] "#1B9E77" "#548A53" "#8E772F" "#C8640C" "#C36228" "#A4675E" "#866D94"
#  [8] "#8366AD" "#A651A1" "#C93B94" "#E12E85" "#BA5464" "#927A43" "#6BA022"
# [15] "#87A716" "#AEA80E" "#D5AA05" "#DAA106" "#C7910E" "#B38117" "#A07423"
# [22] "#8C6F39" "#796A4F" "#666666"
#  [1] "#1B9E77" "#93752C" "#BD6332" "#7E6EA2" "#B3499C" "#CF3F76" "#7D8F31"
#  [8] "#A0A811" "#E0A604" "#B78415" "#8E7037" "#666666"
#  [1] "#1B9E77" "#6E8243" "#C16610" "#B96439" "#8D6B86" "#8A62AB" "#BC4399"
#  [8] "#DE3083" "#A66753" "#6E9E24" "#96A713" "#CEAA07" "#D59D08" "#B98614"
# [15] "#9D7426" "#826D46" "#666666"
#   baseMean  log2FoldChange lfcSE     stat       pvalue       padj         OTU
# 1 331.72029 -2.7165660     0.5217389 -5.2067536 1.921730e-07 1.885675e-05 ASV5
# 2 136.95264  4.9776118     1.1905977  4.1807671 2.905274e-05 1.192425e-03 ASV6
# 3  26.70389  8.4299996     1.7857267  4.7207669 2.349571e-06 1.478663e-04 ASV14
# 4  83.95545 -0.6640584     0.8698881 -0.7633838 4.452345e-01 6.618920e-01 ASV16
# 5   0.00000         NA            NA         NA           NA           NA ASV17
# 6 159.58144 11.0823839     1.3629242  8.1313284 4.246114e-16 2.004166e-13 ASV18
#   Soil    Fungus Term       ⋯ Kingdom  Phylum         Class
# 1 Dryden Gv     SampleType ⋯ Bacteria Actinobacteria Actinobacteria
# 2 Dryden Gv     SampleType ⋯ Bacteria Proteobacteria Gammaproteobacteria
# 3 Dryden Gv     SampleType ⋯ Bacteria Proteobacteria Deltaproteobacteria
# 4 Dryden Gv     SampleType ⋯ Bacteria Proteobacteria Alphaproteobacteria
# 5 Dryden Gv     SampleType ⋯ Bacteria Proteobacteria Gammaproteobacteria
# 6 Dryden Gv     SampleType ⋯ Bacteria Proteobacteria Deltaproteobacteria
#   Order                 Family            Genus             Experiment Pcs
# 1 Micrococcales         Micrococcaceae    Pseudarthrobacter 1          #93752C
# 2 Cellvibrionales       Cellvibrionaceae  Cellvibrio        1          #B78415
# 3 Myxococcales          Sandaracinaceae   NA                1          #B78415
# 4 Rhizobiales           Xanthobacteraceae Bradyrhizobium    1          #B78415
# 5 Betaproteobacteriales Burkholderiaceae  Paucibacter       1          #B78415
# 6 Myxococcales          Sandaracinaceae   NA                1          #B78415
#   Ocs     Ccs
# 1 #927A43 #1B9E77
# 2 #C36228 #A66753
# 3 #6BA022 #BC4399
# 4 #C7910E #6E8243
# 5 #8E772F #A66753
# 6 #6BA022 #BC4399

# %% [markdown]
# # Generate figures

# %% [markdown]
# ### Format data

# %%
# Get relative abundance data
mdf = readRDS(physeq_file) %>% subset_taxa(., !is.na(Phylum)) %>%
  subset_samples(., SampleType != "GV" & Experiment %in% c(1,2) & Fungus %in% c("Gv", "RI") & 
                 SampleType %in% c("CS","CH") & Soil != "Sand") %>%
    transform_sample_counts(., function(x) x/sum(x)) %>%
    prune_taxa(topTax, .) %>% 
    psmelt()

mdf.byOTU = ddply(mdf, .(Soil, OTU, Experiment, Fungus), summarize, mean_Abundance = mean(Abundance)) 

# filter and format log2fold change data
tmp = df.l2fc %>% filter(Contrast == "CH_CS" & Fungus %in% c("Gv", "RI")) %>%
    left_join(., mdf.byOTU) %>%
    select(OTU, Soil, Experiment, Fungus, padj, mean_Abundance, log2FoldChange, Phylum, Order, Class, Family, Genus, Pcs, Ccs, Ocs) %>%
    filter(OTU %in% TreeTax)


df.l2fc.L = filter(tmp, Soil == "Dryden" & OTU %in% TreeTax & Fungus == "Gv") %>%
    mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", "sig")) %>%
    select(OTU, mean_Abundance, log2FoldChange, sig, Phylum, Order, Class, Genus, Experiment, Pcs, Ocs, Ccs)
head(df.l2fc.L)
                            
                            #     #create dataframe of non-significant points
#    #df.sub = df %>% filter(sig == "ns" | is.na(sig))
df.l2fc.L.sig.1 = df.l2fc.L %>% filter(sig == "sig" & Experiment == 1)
df.l2fc.L.ns.1 = df.l2fc.L %>% filter(sig ==  "ns" & Experiment == 1)
df.l2fc.L.sig.2 = df.l2fc.L %>% filter(sig == "sig" & Experiment == 2)
df.l2fc.L.ns.2= df.l2fc.L %>% filter(sig ==  "ns" & Experiment == 2)

df.l2fc.F = filter(tmp, Soil == "Florence" &  OTU %in% TreeTax & Fungus == "Gv") %>%
    mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", "sig")) %>%
    select(OTU, mean_Abundance ,log2FoldChange, sig, Phylum, Order, Class, Genus, Experiment, Pcs, Ocs, Ccs)
    
    #create dataframe of sig and non-significant points
    #df.sub = df %>% filter(sig == "ns" | is.na(sig))
df.l2fc.F.sig.1 = df.l2fc.F %>% filter(sig == "sig" & Experiment == 1)
df.l2fc.F.ns.1 = df.l2fc.F %>% filter(sig ==  "ns" & Experiment == 1)
df.l2fc.F.sig.2 = df.l2fc.F %>% filter(sig == "sig" & Experiment == 2)
df.l2fc.F.ns.2= df.l2fc.F %>% filter(sig ==  "ns" & Experiment == 2)

df.l2fc.P = filter(tmp, Soil == "Pendelton" &  OTU %in% TreeTax & Fungus == "Gv") %>%
    mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", "sig")) %>%
    select(OTU, mean_Abundance, log2FoldChange, sig, Phylum, Order, Class, Genus, Experiment, Pcs, Ocs, Ccs)
    
    #create dataframe of sig and non-significant points
    #df.sub = df %>% filter(sig == "ns" | is.na(sig))
df.l2fc.P.sig.1 = df.l2fc.P %>% filter(sig == "sig" & Experiment == 1)
df.l2fc.P.ns.1 = df.l2fc.P %>% filter(sig ==  "ns" & Experiment == 1)
df.l2fc.P.sig.2 = df.l2fc.P %>% filter(sig == "sig" & Experiment == 2)
df.l2fc.P.ns.2= df.l2fc.P %>% filter(sig ==  "ns" & Experiment == 2)
                            
     
df.l2fc.Ri.L = filter(tmp, Soil == "Dryden" &  OTU %in% TreeTax & Fungus == "RI") %>%
    mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", "sig")) %>%
    select(OTU, mean_Abundance, log2FoldChange, sig, Phylum, Order, Class, Genus, Experiment, Pcs, Ocs, Ccs)
    
    #create dataframe of non-significant points
    #df.sub = df %>% filter(sig == "ns" | is.na(sig))

df.l2fc.Ri.L.sig.2 = df.l2fc.Ri.L %>% filter(sig == "sig" & Experiment == 2)
df.l2fc.Ri.L.ns.2= df.l2fc.Ri.L %>% filter(sig ==  "ns" & Experiment == 2)
# Out:
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Joining, by = c("OTU", "Soil", "Fungus", "Experiment")
#   OTU   mean_Abundance log2FoldChange sig Phylum         Order
# 1 ASV5  0.020395195    -2.7165660     sig Actinobacteria Micrococcales
# 2 ASV6  0.009201270     4.9776118     sig Proteobacteria Cellvibrionales
# 3 ASV14 0.001813107     8.4299996     sig Proteobacteria Myxococcales
# 4 ASV16 0.005376328    -0.6640584     ns  Proteobacteria Rhizobiales
# 5 ASV17 0.000000000            NA     ns  Proteobacteria Betaproteobacteriales
# 6 ASV18 0.010919483    11.0823839     sig Proteobacteria Myxococcales
#   Class               Genus             Experiment Pcs     Ocs     Ccs
# 1 Actinobacteria      Pseudarthrobacter 1          #93752C #927A43 #1B9E77
# 2 Gammaproteobacteria Cellvibrio        1          #B78415 #C36228 #A66753
# 3 Deltaproteobacteria NA                1          #B78415 #6BA022 #BC4399
# 4 Alphaproteobacteria Bradyrhizobium    1          #B78415 #C7910E #6E8243
# 5 Gammaproteobacteria Paucibacter       1          #B78415 #8E772F #A66753
# 6 Deltaproteobacteria NA                1          #B78415 #6BA022 #BC4399

# %% [markdown]
# ### Build CH-CS tree

# %%
p  = ggtree(MyTree) %<+% df.tax
#p = p + aes(color=Phylum) 

p = p +
    geom_tiplab(aes(label = GenusLabel), align = TRUE, size = 2) +
    geom_tippoint(aes(color=Class), size=1.5)+
    scale_color_manual(values = Ccs, guide = guide_legend(ncol = 3))+

geom_vline(xintercept = 0, lty = 2, color = "Grey") +
geom_facet(panel = "Gv - Dryden", data = df.l2fc.L.ns.1, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "LightGrey") +
                
geom_facet(panel = "Gv - Dryden", data = df.l2fc.L.sig.1, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), color = "LightGrey", shape = 21, alpha = 0.5) +
                scale_fill_identity() +
geom_facet(panel = "Gv - Dryden", data = df.l2fc.L.ns.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "Black") +                
geom_facet(panel = "Gv - Dryden", data = df.l2fc.L.sig.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), shape = 21)  +



geom_facet(panel = "Gv - Florence", data = df.l2fc.F.ns.1, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "LightGrey") +                
geom_facet(panel = "Gv - Florence", data = df.l2fc.F.sig.1, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), alpha = 0.5, shape = 21,  color = "LightGrey") + 

geom_facet(panel = "Gv - Florence", data = df.l2fc.F.ns.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "Black") +                
geom_facet(panel = "Gv - Florence", data = df.l2fc.F.sig.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), shape = 21) + 


geom_facet(panel = "Gv - Pendelton", data = df.l2fc.P.ns.1, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21, shape = 21, fill = "white", color = "LightGrey") +
geom_facet(panel = "Gv - Pendelton", data = df.l2fc.P.sig.1, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), alpha = 0.5, shape = 21, color = "LightGrey") + 

geom_facet(panel = "Gv - Pendelton", data = df.l2fc.P.ns.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21,  fill = "white", color = "Black") +                
geom_facet(panel = "Gv - Pendelton", data = df.l2fc.P.sig.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs),  shape = 21) + 

geom_facet(panel = "Ri - Dryden", data = df.l2fc.Ri.L.ns.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21,  fill = "white", color = "Black") +                
geom_facet(panel = "Ri - Dryden", data = df.l2fc.Ri.L.sig.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs),  shape = 21) + 
    
           #ggplot2::scale_shape_manual(values = c(1,21))+
            theme_tree2(legend.position = 'bottom')+
            scale_size_continuous(guide = guide_legend(ncol = 1))+


#
#xlim(c(-10, 15))+ #, 'Dryden')+
#xlim_expand(c(-10, 15), 'Florence')+
#xlim_expand(c(-10, 15), 'Pendelton')
xlim_tree(1.5)
         

p = facet_widths(p, widths = c(Tree = 1.5)) #, Dryden = 1, Florence = 1, Pendelton = 1))

p
#mylegend <- g_legend(p)


#p = p + theme(legend.position = "none")

# # current files created with top 75 taxa
# # mylegend
pdf(file = file.path(out_Dir,"CH_CS_l2fc_tree_class_75wRI.pdf"), width = 7.086, height = 7.5, useDingbats = FALSE)
p
dev.off()

# pdf(file = file.path(out_Dir,"CH_CS_l2fc_tree_order_legend.pdf"), width = 9, height = 4, useDingbats = FALSE)
# grid.draw(mylegend)
# dev.off()
# Out:
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Warning message:
# “Duplicated aesthetics after name standardisation: size”Warning message:
# “Duplicated aesthetics after name standardisation: shape”Warning message:
# “Removed 22 rows containing missing values (geom_point).”Warning message:
# “Removed 12 rows containing missing values (geom_point).”Warning message:
# “Removed 21 rows containing missing values (geom_point).”Warning message:
# “Removed 25 rows containing missing values (geom_point).”Warning message:
# “Removed 17 rows containing missing values (geom_point).”Warning message:
# “Removed 15 rows containing missing values (geom_point).”Warning message:
# “Removed 16 rows containing missing values (geom_point).”
# Error in dev.off(): write failed
# Traceback:
#
# 1. dev.off()
# plot without title

# %% [markdown]
# # CH - BP contrast

# %% [markdown]
# ## formate data

# %%
df.l2fc.L.sig.2 %>% filter(OTU == "ASV14")
# Out:
#   OTU   mean_Abundance log2FoldChange sig Phylum         Order
# 1 ASV14 0.005765607    5.948495       sig Proteobacteria Myxococcales
#   Class               Genus Experiment Pcs     Ocs     Ccs
# 1 Deltaproteobacteria NA    2          #B78415 #7FA718 #9B58A5

# %%
# Get relative abundance data
mdf = readRDS(physeq_file) %>% subset_taxa(., !is.na(Phylum)) %>%
  subset_samples(., SampleType != "GV" & Experiment %in% c(1,2) & Fungus == "Gv" & 
                 SampleType %in% c("BP","CH") & Soil != "Sand") %>%
    transform_sample_counts(., function(x) x/sum(x)) %>%
    prune_taxa(topTax, .) %>% 
    psmelt()

mdf.byOTU = ddply(mdf, .(Soil, OTU, Experiment), summarize, mean_Abundance = mean(Abundance)) 

# filter and format log2fold change data
tmp = df.l2fc %>% filter(Contrast == "CH_BP" & Fungus == "Gv") %>%
    left_join(., mdf.byOTU) %>%
    select(OTU, Soil, Experiment, padj, mean_Abundance, log2FoldChange, Phylum, Order, Class, Family, Genus, Pcs, Ccs, Ocs) %>%
    filter(OTU %in% TreeTax)


df.l2fc.L = filter(tmp, Soil == "Dryden" & OTU %in% TreeTax) %>%
    mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", "sig")) %>%
    select(OTU, mean_Abundance, log2FoldChange, sig, Phylum, Order, Class, Genus, Experiment, Pcs, Ocs, Ccs)
head(df.l2fc.L)

#     #create dataframe of non-significant points
#    #df.sub = df %>% filter(sig == "ns" | is.na(sig))
df.l2fc.L.sig.1 = df.l2fc.L %>% filter(sig == "sig" & Experiment == 1)
df.l2fc.L.ns.1 = df.l2fc.L %>% filter(sig ==  "ns" & Experiment == 1)
df.l2fc.L.sig.2 = df.l2fc.L %>% filter(sig == "sig" & Experiment == 2)
df.l2fc.L.ns.2= df.l2fc.L %>% filter(sig ==  "ns" & Experiment == 2)

df.l2fc.F = filter(tmp, Soil == "Florence" &  OTU %in% TreeTax) %>%
    mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", "sig")) %>%
    select(OTU, mean_Abundance ,log2FoldChange, sig, Phylum, Order, Class, Genus, Experiment, Pcs, Ocs, Ccs)
    
    #create dataframe of non-significant points
    #df.sub = df %>% filter(sig == "ns" | is.na(sig))
df.l2fc.F.sig.1 = df.l2fc.F %>% filter(sig == "sig" & Experiment == 1)
df.l2fc.F.ns.1 = df.l2fc.F %>% filter(sig ==  "ns" & Experiment == 1)
df.l2fc.F.sig.2 = df.l2fc.F %>% filter(sig == "sig" & Experiment == 2)
df.l2fc.F.ns.2= df.l2fc.F %>% filter(sig ==  "ns" & Experiment == 2)

df.l2fc.P = filter(tmp, Soil == "Pendelton" &  OTU %in% TreeTax) %>%
    mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", "sig")) %>%
    select(OTU, mean_Abundance, log2FoldChange, sig, Phylum, Order, Class, Genus, Experiment, Pcs, Ocs, Ccs)
    
    #create dataframe of non-significant points
    #df.sub = df %>% filter(sig == "ns" | is.na(sig))
df.l2fc.P.sig.1 = df.l2fc.P %>% filter(sig == "sig" & Experiment == 1)
df.l2fc.P.ns.1 = df.l2fc.P %>% filter(sig ==  "ns" & Experiment == 1)
df.l2fc.P.sig.2 = df.l2fc.P %>% filter(sig == "sig" & Experiment == 2)
df.l2fc.P.ns.2= df.l2fc.P %>% filter(sig ==  "ns" & Experiment == 2)
# Out:
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Joining, by = c("OTU", "Soil", "Experiment")
# Warning message:
# “Column `OTU` joining factor and character vector, coercing into character vector”
#   OTU   mean_Abundance log2FoldChange sig Phylum         Order
# 1 ASV5  0.010413997    1.0865779      ns  Actinobacteria Micrococcales
# 2 ASV6  0.013073422    7.8825238      sig Proteobacteria Cellvibrionales
# 3 ASV14 0.005618105    7.7989806      sig Proteobacteria Myxococcales
# 4 ASV16 0.010181105    0.2202283      ns  Proteobacteria Rhizobiales
# 5 ASV17 0.001320807    7.9040448      sig Proteobacteria Betaproteobacteriales
# 6 ASV18 0.006423097    8.8594744      sig Proteobacteria Myxococcales
#   Class               Genus             Experiment Pcs     Ocs     Ccs
# 1 Actinobacteria      Pseudarthrobacter 2          #93752C #79932E #1B9E77
# 2 Gammaproteobacteria Cellvibrio        2          #B78415 #D35F0A #C44A6D
# 3 Deltaproteobacteria NA                2          #B78415 #7FA718 #9B58A5
# 4 Alphaproteobacteria Bradyrhizobium    2          #B78415 #BF8B12 #738040
# 5 Gammaproteobacteria Paucibacter       2          #B78415 #A07125 #C44A6D
# 6 Deltaproteobacteria NA                2          #B78415 #7FA718 #9B58A5

# %%
p  = ggtree(MyTree) %<+% df.tax
#p = p + aes(color=Phylum) 

p = p +
     geom_tiplab(aes(label = GenusLabel), align = TRUE, size = 2) +

    geom_tippoint(aes(color=Class), size=1.5)+
    scale_color_manual(values = Ccs, guide = guide_legend(ncol = 3))+

geom_vline(xintercept = 0, lty = 2, color = "Grey") +
# geom_facet(panel = "Dryden", data = df.l2fc.L.ns.1, geom= geom_point,
#                aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "LightGrey") +
                
# geom_facet(panel = "Dryden", data = df.l2fc.L.sig.1, geom= geom_point,
#               aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), color = "LightGrey", shape = 21, alpha = 0.5) +
#                 scale_fill_identity() +
geom_facet(panel = "Dryden", data = df.l2fc.L.ns.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "Black") +                
geom_facet(panel = "Dryden", data = df.l2fc.L.sig.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), shape = 21) +



# geom_facet(panel = "Florence", data = df.l2fc.F.ns.1, geom= geom_point,
#               aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "LightGrey") +                
# geom_facet(panel = "Florence", data = df.l2fc.F.sig.1, geom= geom_point,
#               aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), alpha = 0.5, shape = 21,  color = "LightGrey") + 

geom_facet(panel = "Florence", data = df.l2fc.F.ns.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "Black") +                
geom_facet(panel = "Florence", data = df.l2fc.F.sig.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), shape = 21) + 


# # geom_facet(panel = "Pendelton", data = df.l2fc.P.ns.1, geom= geom_point,
# #               aes(x = log2FoldChange, size = mean_Abundance), shape = 21, shape = 21, fill = "white", color = "LightGrey") +
# # geom_facet(panel = "Pendelton", data = df.l2fc.P.sig.1, geom= geom_point,
# #               aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), alpha = 0.5, shape = 21, color = "LightGrey") + 

geom_facet(panel = "Pendelton", data = df.l2fc.P.ns.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21,  fill = "white", color = "Black") +                
geom_facet(panel = "Pendelton", data = df.l2fc.P.sig.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs),   shape = 21) + 
    
           #ggplot2::scale_shape_manual(values = c(1,21))+
            theme_tree2(legend.position = 'bottom')+
            scale_size_continuous(guide = guide_legend(ncol = 1))+
            scale_fill_manual(limits = Ccs, values = Ccs, guide = FALSE)+


#
#xlim(c(-10, 15))+ #, 'Dryden')+
#xlim_expand(c(-10, 15), 'Florence')+
#xlim_expand(c(-10, 15), 'Pendelton')
xlim_tree(1.5)
         

p = facet_widths(p, widths = c(Tree = 1.5)) #, Dryden = 1, Florence = 1, Pendelton = 1))

p
# #mylegend <- g_legend(p)


# #p = p + theme(legend.position = "none")

# # current files created with top 75 taxa
# # mylegend
 pdf(file = file.path(out_Dir,"CH_BP_l2fc_tree_class.pdf"), width = 7.086, height = 6.5, useDingbats = FALSE)
 p
 dev.off()
# Out:
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Warning message:
# “Duplicated aesthetics after name standardisation: size”Warning message:
# “Removed 9 rows containing missing values (geom_point).”Warning message:
# “Removed 17 rows containing missing values (geom_point).”Warning message:
# “Removed 11 rows containing missing values (geom_point).”
# png
#   2
# plot without title

# %% [markdown]
# # BP vs CS contrast

# %%
# Get relative abundance data
mdf = readRDS(physeq_file) %>% subset_taxa(., !is.na(Phylum)) %>%
  subset_samples(., SampleType != "GV" & Experiment %in% c(1,2) & Fungus == "Gv" & 
                 SampleType %in% c("BP","CS") & Soil != "Sand") %>%
    transform_sample_counts(., function(x) x/sum(x)) %>%
    prune_taxa(topTax, .) %>% 
    psmelt()

mdf.byOTU = ddply(mdf, .(Soil, OTU, Experiment), summarize, mean_Abundance = mean(Abundance)) 

# filter and format log2fold change data
tmp = df.l2fc %>% filter(Contrast == "BP_CS" & Fungus == "Gv") %>%
    left_join(., mdf.byOTU) %>%
    select(OTU, Soil, Experiment, padj, mean_Abundance, log2FoldChange, Phylum, Order, Class, Family, Genus, Pcs, Ccs, Ocs) %>%
    filter(OTU %in% TreeTax)


df.l2fc.L = filter(tmp, Soil == "Dryden" & OTU %in% TreeTax) %>%
    mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", "sig")) %>%
    select(OTU, mean_Abundance, log2FoldChange, sig, Phylum, Order, Class, Genus, Experiment, Pcs, Ocs, Ccs)
head(df.l2fc.L)

#     #create dataframe of non-significant points
#    #df.sub = df %>% filter(sig == "ns" | is.na(sig))
df.l2fc.L.sig.1 = df.l2fc.L %>% filter(sig == "sig" & Experiment == 1)
df.l2fc.L.ns.1 = df.l2fc.L %>% filter(sig ==  "ns" & Experiment == 1)
df.l2fc.L.sig.2 = df.l2fc.L %>% filter(sig == "sig" & Experiment == 2)
df.l2fc.L.ns.2= df.l2fc.L %>% filter(sig ==  "ns" & Experiment == 2)

df.l2fc.F = filter(tmp, Soil == "Florence" &  OTU %in% TreeTax) %>%
    mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", "sig")) %>%
    select(OTU, mean_Abundance ,log2FoldChange, sig, Phylum, Order, Class, Genus, Experiment, Pcs, Ocs, Ccs)
    
    #create dataframe of non-significant points
    #df.sub = df %>% filter(sig == "ns" | is.na(sig))
df.l2fc.F.sig.1 = df.l2fc.F %>% filter(sig == "sig" & Experiment == 1)
df.l2fc.F.ns.1 = df.l2fc.F %>% filter(sig ==  "ns" & Experiment == 1)
df.l2fc.F.sig.2 = df.l2fc.F %>% filter(sig == "sig" & Experiment == 2)
df.l2fc.F.ns.2= df.l2fc.F %>% filter(sig ==  "ns" & Experiment == 2)

df.l2fc.P = filter(tmp, Soil == "Pendelton" &  OTU %in% TreeTax) %>%
    mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", "sig")) %>%
    select(OTU, mean_Abundance, log2FoldChange, sig, Phylum, Order, Class, Genus, Experiment, Pcs, Ocs, Ccs)
    
    #create dataframe of non-significant points
    #df.sub = df %>% filter(sig == "ns" | is.na(sig))
df.l2fc.P.sig.1 = df.l2fc.P %>% filter(sig == "sig" & Experiment == 1)
df.l2fc.P.ns.1 = df.l2fc.P %>% filter(sig ==  "ns" & Experiment == 1)
df.l2fc.P.sig.2 = df.l2fc.P %>% filter(sig == "sig" & Experiment == 2)
df.l2fc.P.ns.2= df.l2fc.P %>% filter(sig ==  "ns" & Experiment == 2)
# Out:
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Joining, by = c("OTU", "Soil", "Experiment")
# Warning message:
# “Column `OTU` joining factor and character vector, coercing into character vector”
#   OTU   mean_Abundance log2FoldChange sig Phylum         Order
# 1 ASV5  0.0236229218   -2.20500956    sig Actinobacteria Micrococcales
# 2 ASV6  0.0002415880    0.22614545    ns  Proteobacteria Cellvibrionales
# 3 ASV14 0.0002352473   -2.37379672    ns  Proteobacteria Myxococcales
# 4 ASV16 0.0080321731    1.39096864    sig Proteobacteria Rhizobiales
# 5 ASV17 0.0001305855   -0.06871281    ns  Proteobacteria Betaproteobacteriales
# 6 ASV18 0.0001612672   -3.06592714    ns  Proteobacteria Myxococcales
#   Class               Genus             Experiment Pcs     Ocs     Ccs
# 1 Actinobacteria      Pseudarthrobacter 2          #93752C #79932E #1B9E77
# 2 Gammaproteobacteria Cellvibrio        2          #B78415 #D35F0A #C44A6D
# 3 Deltaproteobacteria NA                2          #B78415 #7FA718 #9B58A5
# 4 Alphaproteobacteria Bradyrhizobium    2          #B78415 #BF8B12 #738040
# 5 Gammaproteobacteria Paucibacter       2          #B78415 #A07125 #C44A6D
# 6 Deltaproteobacteria NA                2          #B78415 #7FA718 #9B58A5

# %%
p  = ggtree(MyTree) %<+% df.tax
#p = p + aes(color=Phylum) 

p = p +
     geom_tiplab(aes(label = GenusLabel), align = TRUE, size = 2) +

    geom_tippoint(aes(color=Class), size=1.5)+
    scale_color_manual(values = Ccs, guide = guide_legend(ncol = 3))+

geom_vline(xintercept = 0, lty = 2, color = "Grey") +
# geom_facet(panel = "Dryden", data = df.l2fc.L.ns.1, geom= geom_point,
#                aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "LightGrey") +
                
# geom_facet(panel = "Dryden", data = df.l2fc.L.sig.1, geom= geom_point,
#               aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), color = "LightGrey", shape = 21, alpha = 0.5) +
#                 scale_fill_identity() +
geom_facet(panel = "Dryden", data = df.l2fc.L.ns.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "Black") +                
geom_facet(panel = "Dryden", data = df.l2fc.L.sig.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), shape = 21) +



# geom_facet(panel = "Florence", data = df.l2fc.F.ns.1, geom= geom_point,
#               aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "LightGrey") +                
# geom_facet(panel = "Florence", data = df.l2fc.F.sig.1, geom= geom_point,
#               aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), alpha = 0.5, shape = 21,  color = "LightGrey") + 

geom_facet(panel = "Florence", data = df.l2fc.F.ns.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "Black") +                
geom_facet(panel = "Florence", data = df.l2fc.F.sig.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), shape = 21) + 


# # geom_facet(panel = "Pendelton", data = df.l2fc.P.ns.1, geom= geom_point,
# #               aes(x = log2FoldChange, size = mean_Abundance), shape = 21, shape = 21, fill = "white", color = "LightGrey") +
# # geom_facet(panel = "Pendelton", data = df.l2fc.P.sig.1, geom= geom_point,
# #               aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), alpha = 0.5, shape = 21, color = "LightGrey") + 

geom_facet(panel = "Pendelton", data = df.l2fc.P.ns.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21,  fill = "white", color = "Black") +                
geom_facet(panel = "Pendelton", data = df.l2fc.P.sig.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs),   shape = 21) + 
    
           #ggplot2::scale_shape_manual(values = c(1,21))+
            theme_tree2(legend.position = 'bottom')+
            scale_size_continuous(guide = guide_legend(ncol = 1))+
            scale_fill_manual(limits = Ccs, values = Ccs, guide = FALSE)+


#
#xlim(c(-10, 15))+ #, 'Dryden')+
#xlim_expand(c(-10, 15), 'Florence')+
#xlim_expand(c(-10, 15), 'Pendelton')
xlim_tree(1.5)
         

p = facet_widths(p, widths = c(Tree = 1.5)) #, Dryden = 1, Florence = 1, Pendelton = 1))

p

 pdf(file = file.path(out_Dir,"BP_CS_l2fc_tree_class.pdf"), width = 7.086, height = 6.5, useDingbats = FALSE)
 p
 dev.off()
# Out:
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Warning message:
# “Duplicated aesthetics after name standardisation: size”Warning message:
# “Removed 17 rows containing missing values (geom_point).”Warning message:
# “Removed 18 rows containing missing values (geom_point).”Warning message:
# “Removed 15 rows containing missing values (geom_point).”
# png
#   2
# plot without title

# %%
df.l2fc$Contrast %>% unique()
# Out:
# [1] "CH_CS" "CH_RT" "RT_CS" "CH_BS" "CH_BP" "RH_RS" "BH_BS" "BP_CS" "BP_BS"

# %% [markdown]
# # Experiment 2 Root Hyphae vs Root Slurry

# %%
# Get relative abundance data
mdf = readRDS(physeq_file) %>% subset_taxa(., !is.na(Phylum)) %>%
  subset_samples(., SampleType != "GV" & Experiment %in% c(1,2) & Fungus == "Gv" & 
                 SampleType %in% c("RH","RS") & Soil != "Sand") %>%
    transform_sample_counts(., function(x) x/sum(x)) %>%
    prune_taxa(topTax, .) %>% 
    psmelt()

mdf.byOTU = ddply(mdf, .(Soil, OTU, Experiment), summarize, mean_Abundance = mean(Abundance)) 

# filter and format log2fold change data
tmp = df.l2fc %>% filter(Contrast == "RH_RS" & Fungus == "Gv") %>%
    left_join(., mdf.byOTU) %>%
    select(OTU, Soil, Experiment, padj, mean_Abundance, log2FoldChange, Phylum, Order, Class, Family, Genus, Pcs, Ccs, Ocs) %>%
    filter(OTU %in% TreeTax)


df.l2fc.L = filter(tmp, Soil == "Dryden" & OTU %in% TreeTax) %>%
    mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", "sig")) %>%
    select(OTU, mean_Abundance, log2FoldChange, sig, Phylum, Order, Class, Genus, Experiment, Pcs, Ocs, Ccs)
head(df.l2fc.L)

#     #create dataframe of non-significant points
#    #df.sub = df %>% filter(sig == "ns" | is.na(sig))
df.l2fc.L.sig.1 = df.l2fc.L %>% filter(sig == "sig" & Experiment == 1)
df.l2fc.L.ns.1 = df.l2fc.L %>% filter(sig ==  "ns" & Experiment == 1)
df.l2fc.L.sig.2 = df.l2fc.L %>% filter(sig == "sig" & Experiment == 2)
df.l2fc.L.ns.2= df.l2fc.L %>% filter(sig ==  "ns" & Experiment == 2)

df.l2fc.F = filter(tmp, Soil == "Florence" &  OTU %in% TreeTax) %>%
    mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", "sig")) %>%
    select(OTU, mean_Abundance ,log2FoldChange, sig, Phylum, Order, Class, Genus, Experiment, Pcs, Ocs, Ccs)
    
    #create dataframe of non-significant points
    #df.sub = df %>% filter(sig == "ns" | is.na(sig))
df.l2fc.F.sig.1 = df.l2fc.F %>% filter(sig == "sig" & Experiment == 1)
df.l2fc.F.ns.1 = df.l2fc.F %>% filter(sig ==  "ns" & Experiment == 1)
df.l2fc.F.sig.2 = df.l2fc.F %>% filter(sig == "sig" & Experiment == 2)
df.l2fc.F.ns.2= df.l2fc.F %>% filter(sig ==  "ns" & Experiment == 2)

df.l2fc.P = filter(tmp, Soil == "Pendelton" &  OTU %in% TreeTax) %>%
    mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", "sig")) %>%
    select(OTU, mean_Abundance, log2FoldChange, sig, Phylum, Order, Class, Genus, Experiment, Pcs, Ocs, Ccs)
    
    #create dataframe of non-significant points
    #df.sub = df %>% filter(sig == "ns" | is.na(sig))
df.l2fc.P.sig.1 = df.l2fc.P %>% filter(sig == "sig" & Experiment == 1)
df.l2fc.P.ns.1 = df.l2fc.P %>% filter(sig ==  "ns" & Experiment == 1)
df.l2fc.P.sig.2 = df.l2fc.P %>% filter(sig == "sig" & Experiment == 2)
df.l2fc.P.ns.2= df.l2fc.P %>% filter(sig ==  "ns" & Experiment == 2)
# Out:
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Joining, by = c("OTU", "Soil", "Experiment")
# Warning message:
# “Column `OTU` joining factor and character vector, coercing into character vector”
#   OTU   mean_Abundance log2FoldChange sig Phylum         Order
# 1 ASV5  0.002502728    -1.1718767     ns  Actinobacteria Micrococcales
# 2 ASV6  0.041857276     4.1407837     ns  Proteobacteria Cellvibrionales
# 3 ASV14 0.049075279     7.4406844     sig Proteobacteria Myxococcales
# 4 ASV16 0.010166015     0.7049811     ns  Proteobacteria Rhizobiales
# 5 ASV17 0.009664864     5.4157433     ns  Proteobacteria Betaproteobacteriales
# 6 ASV18 0.007379363    10.3059016     sig Proteobacteria Myxococcales
#   Class               Genus             Experiment Pcs     Ocs     Ccs
# 1 Actinobacteria      Pseudarthrobacter 2          #93752C #79932E #1B9E77
# 2 Gammaproteobacteria Cellvibrio        2          #B78415 #D35F0A #C44A6D
# 3 Deltaproteobacteria NA                2          #B78415 #7FA718 #9B58A5
# 4 Alphaproteobacteria Bradyrhizobium    2          #B78415 #BF8B12 #738040
# 5 Gammaproteobacteria Paucibacter       2          #B78415 #A07125 #C44A6D
# 6 Deltaproteobacteria NA                2          #B78415 #7FA718 #9B58A5

# %%
p  = ggtree(MyTree) %<+% df.tax
#p = p + aes(color=Phylum) 

p = p +
     geom_tiplab(aes(label = GenusLabel), align = TRUE, size = 2) +

    geom_tippoint(aes(color=Class), size=1.5)+
    scale_color_manual(values = Ccs, guide = guide_legend(ncol = 3))+

geom_vline(xintercept = 0, lty = 2, color = "Grey") +
# geom_facet(panel = "Dryden", data = df.l2fc.L.ns.1, geom= geom_point,
#                aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "LightGrey") +
                
# geom_facet(panel = "Dryden", data = df.l2fc.L.sig.1, geom= geom_point,
#               aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), color = "LightGrey", shape = 21, alpha = 0.5) +
#                 scale_fill_identity() +
geom_facet(panel = "Dryden", data = df.l2fc.L.ns.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "Black") +                
geom_facet(panel = "Dryden", data = df.l2fc.L.sig.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), shape = 21) +



# geom_facet(panel = "Florence", data = df.l2fc.F.ns.1, geom= geom_point,
#               aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "LightGrey") +                
# geom_facet(panel = "Florence", data = df.l2fc.F.sig.1, geom= geom_point,
#               aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), alpha = 0.5, shape = 21,  color = "LightGrey") + 

geom_facet(panel = "Florence", data = df.l2fc.F.ns.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "Black") +                
geom_facet(panel = "Florence", data = df.l2fc.F.sig.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), shape = 21) + 


# # geom_facet(panel = "Pendelton", data = df.l2fc.P.ns.1, geom= geom_point,
# #               aes(x = log2FoldChange, size = mean_Abundance), shape = 21, shape = 21, fill = "white", color = "LightGrey") +
# # geom_facet(panel = "Pendelton", data = df.l2fc.P.sig.1, geom= geom_point,
# #               aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), alpha = 0.5, shape = 21, color = "LightGrey") + 

geom_facet(panel = "Pendelton", data = df.l2fc.P.ns.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21,  fill = "white", color = "Black") +                
geom_facet(panel = "Pendelton", data = df.l2fc.P.sig.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs),   shape = 21) + 
    
           #ggplot2::scale_shape_manual(values = c(1,21))+
            theme_tree2(legend.position = 'bottom')+
            scale_size_continuous(guide = guide_legend(ncol = 1))+
            scale_fill_manual(limits = Ccs, values = Ccs, guide = FALSE)+


#
#xlim(c(-10, 15))+ #, 'Dryden')+
#xlim_expand(c(-10, 15), 'Florence')+
#xlim_expand(c(-10, 15), 'Pendelton')
xlim_tree(1.5)
         

p = facet_widths(p, widths = c(Tree = 1.5)) #, Dryden = 1, Florence = 1, Pendelton = 1))

p

 pdf(file = file.path(out_Dir,"RH_RS_l2fc_tree_class.pdf"), width = 7.086, height = 6.5, useDingbats = FALSE)
 p
 dev.off()
# Out:
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Warning message:
# “Duplicated aesthetics after name standardisation: size”Warning message:
# “Removed 35 rows containing missing values (geom_point).”Warning message:
# “Removed 33 rows containing missing values (geom_point).”Warning message:
# “Removed 40 rows containing missing values (geom_point).”
# png
#   2
# plot without title

# %% [markdown]
# # BH vs BS

# %%
# Get relative abundance data
mdf = readRDS(physeq_file) %>% subset_taxa(., !is.na(Phylum)) %>%
  subset_samples(., SampleType != "GV" & Experiment %in% c(1,2) & Fungus == "Gv" & 
                 SampleType %in% c("BH","BS") & Soil != "Sand") %>%
    transform_sample_counts(., function(x) x/sum(x)) %>%
    prune_taxa(topTax, .) %>% 
    psmelt()

mdf.byOTU = ddply(mdf, .(Soil, OTU, Experiment), summarize, mean_Abundance = mean(Abundance)) 

# filter and format log2fold change data
tmp = df.l2fc %>% filter(Contrast == "BH_BS" & Fungus == "Gv") %>%
    left_join(., mdf.byOTU) %>%
    select(OTU, Soil, Experiment, padj, mean_Abundance, log2FoldChange, Phylum, Order, Class, Family, Genus, Pcs, Ccs, Ocs) %>%
    filter(OTU %in% TreeTax)


df.l2fc.L = filter(tmp, Soil == "Dryden" & OTU %in% TreeTax) %>%
    mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", "sig")) %>%
    select(OTU, mean_Abundance, log2FoldChange, sig, Phylum, Order, Class, Genus, Experiment, Pcs, Ocs, Ccs)
head(df.l2fc.L)

#     #create dataframe of non-significant points
#    #df.sub = df %>% filter(sig == "ns" | is.na(sig))
df.l2fc.L.sig.1 = df.l2fc.L %>% filter(sig == "sig" & Experiment == 1)
df.l2fc.L.ns.1 = df.l2fc.L %>% filter(sig ==  "ns" & Experiment == 1)
df.l2fc.L.sig.2 = df.l2fc.L %>% filter(sig == "sig" & Experiment == 2)
df.l2fc.L.ns.2= df.l2fc.L %>% filter(sig ==  "ns" & Experiment == 2)

df.l2fc.F = filter(tmp, Soil == "Florence" &  OTU %in% TreeTax) %>%
    mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", "sig")) %>%
    select(OTU, mean_Abundance ,log2FoldChange, sig, Phylum, Order, Class, Genus, Experiment, Pcs, Ocs, Ccs)
    
    #create dataframe of non-significant points
    #df.sub = df %>% filter(sig == "ns" | is.na(sig))
df.l2fc.F.sig.1 = df.l2fc.F %>% filter(sig == "sig" & Experiment == 1)
df.l2fc.F.ns.1 = df.l2fc.F %>% filter(sig ==  "ns" & Experiment == 1)
df.l2fc.F.sig.2 = df.l2fc.F %>% filter(sig == "sig" & Experiment == 2)
df.l2fc.F.ns.2= df.l2fc.F %>% filter(sig ==  "ns" & Experiment == 2)

df.l2fc.P = filter(tmp, Soil == "Pendelton" &  OTU %in% TreeTax) %>%
    mutate(sig = ifelse(padj >= 0.05 | is.na(padj), "ns", "sig")) %>%
    select(OTU, mean_Abundance, log2FoldChange, sig, Phylum, Order, Class, Genus, Experiment, Pcs, Ocs, Ccs)
    
    #create dataframe of non-significant points
    #df.sub = df %>% filter(sig == "ns" | is.na(sig))
df.l2fc.P.sig.1 = df.l2fc.P %>% filter(sig == "sig" & Experiment == 1)
df.l2fc.P.ns.1 = df.l2fc.P %>% filter(sig ==  "ns" & Experiment == 1)
df.l2fc.P.sig.2 = df.l2fc.P %>% filter(sig == "sig" & Experiment == 2)
df.l2fc.P.ns.2= df.l2fc.P %>% filter(sig ==  "ns" & Experiment == 2)
# Out:
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Joining, by = c("OTU", "Soil", "Experiment")
# Warning message:
# “Column `OTU` joining factor and character vector, coercing into character vector”
#   OTU   mean_Abundance log2FoldChange sig Phylum         Order
# 1 ASV5  0.0387758498   -0.16945951    ns  Actinobacteria Micrococcales
# 2 ASV6  0.0004404704    0.97246495    ns  Proteobacteria Cellvibrionales
# 3 ASV14 0.0001325069    6.02819515    ns  Proteobacteria Myxococcales
# 4 ASV16 0.0060229166    0.06742247    ns  Proteobacteria Rhizobiales
# 5 ASV17 0.0000000000            NA    ns  Proteobacteria Betaproteobacteriales
# 6 ASV18 0.0001562339    6.23820815    ns  Proteobacteria Myxococcales
#   Class               Genus             Experiment Pcs     Ocs     Ccs
# 1 Actinobacteria      Pseudarthrobacter 2          #93752C #79932E #1B9E77
# 2 Gammaproteobacteria Cellvibrio        2          #B78415 #D35F0A #C44A6D
# 3 Deltaproteobacteria NA                2          #B78415 #7FA718 #9B58A5
# 4 Alphaproteobacteria Bradyrhizobium    2          #B78415 #BF8B12 #738040
# 5 Gammaproteobacteria Paucibacter       2          #B78415 #A07125 #C44A6D
# 6 Deltaproteobacteria NA                2          #B78415 #7FA718 #9B58A5

# %%
p  = ggtree(MyTree) %<+% df.tax
#p = p + aes(color=Phylum) 

p = p +
     geom_tiplab(aes(label = GenusLabel), align = TRUE, size = 2) +

    geom_tippoint(aes(color=Class), size=1.5)+
    scale_color_manual(values = Ccs, guide = guide_legend(ncol = 3))+


geom_vline(xintercept = 0, lty = 2, color = "Grey") +
# geom_facet(panel = "Dryden", data = df.l2fc.L.ns.1, geom= geom_point,
#                aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "LightGrey") +
                
# geom_facet(panel = "Dryden", data = df.l2fc.L.sig.1, geom= geom_point,
#               aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), color = "LightGrey", shape = 21, alpha = 0.5) +
#                 scale_fill_identity() +
geom_facet(panel = "Dryden", data = df.l2fc.L.ns.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "Black") +                
geom_facet(panel = "Dryden", data = df.l2fc.L.sig.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), shape = 21) +



# # geom_facet(panel = "Florence", data = df.l2fc.F.ns.1, geom= geom_point,
# #               aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "LightGrey") +                
# # geom_facet(panel = "Florence", data = df.l2fc.F.sig.1, geom= geom_point,
# #               aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), alpha = 0.5, shape = 21,  color = "LightGrey") + 

geom_facet(panel = "Florence", data = df.l2fc.F.ns.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21, fill = "white", color = "Black") +                
geom_facet(panel = "Florence", data = df.l2fc.F.sig.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), shape = 21)  +


# # geom_facet(panel = "Pendelton", data = df.l2fc.P.ns.1, geom= geom_point,
# #               aes(x = log2FoldChange, size = mean_Abundance), shape = 21, shape = 21, fill = "white", color = "LightGrey") +
# # geom_facet(panel = "Pendelton", data = df.l2fc.P.sig.1, geom= geom_point,
# #               aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs), alpha = 0.5, shape = 21, color = "LightGrey") + 

geom_facet(panel = "Pendelton", data = df.l2fc.P.ns.2, geom= geom_point,
              aes(x = log2FoldChange, size = mean_Abundance), shape = 21,  fill = "white", color = "Black") +               
# geom_facet(panel = "Pendelton", data = df.l2fc.P.sig.2, geom= geom_point,
#               aes(x = log2FoldChange, size = mean_Abundance, fill = Ccs),   shape = 21)  
    
           #ggplot2::scale_shape_manual(values = c(1,21))+
            theme_tree2(legend.position = 'bottom')+
            scale_size_continuous(guide = guide_legend(ncol = 1))+
            scale_fill_manual(limits = Ccs, values = Ccs, guide = FALSE)+


#
#xlim(c(-10, 15))+ #, 'Dryden')+
#xlim_expand(c(-10, 15), 'Florence')+
#xlim_expand(c(-10, 15), 'Pendelton')

         

p = facet_widths(p, widths = c(Tree = 1.5)) #, Dryden = 1, Florence = 1, Pendelton = 1))

p

 pdf(file = file.path(out_Dir,"BH_BS_l2fc_tree_class.pdf"), width = 7.086, height = 6.5, useDingbats = FALSE)
 p
 dev.off()
# Out:
# Found more than one class "phylo" in cache; using the first, from namespace 'phyloseq'
# Also defined by ‘tidytree’
# Warning message:
# “Duplicated aesthetics after name standardisation: size”Warning message:
# “Removed 18 rows containing missing values (geom_point).”Warning message:
# “Removed 17 rows containing missing values (geom_point).”Warning message:
# “Removed 17 rows containing missing values (geom_point).”
# png
#   2
# plot without title

# %%
sessionInfo()
# Out:
# R version 3.6.0 (2019-04-26)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 16.04.6 LTS
#
# Matrix products: default
# BLAS/LAPACK: /data/home/be68/anaconda3/envs/MyR/lib/R/lib/libRblas.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] gridExtra_2.3      ggtree_2.0.0       ggplot2_3.2.1      phyloseq_1.28.0
# [5] reshape2_1.4.3     dplyr_1.0.0        tidyr_1.1.0        plyr_1.8.4
# [9] RColorBrewer_1.1-2
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_1.0.2          ape_5.3             lattice_0.20-38
#  [4] Biostrings_2.52.0   digest_0.6.20       foreach_1.4.7
#  [7] IRdisplay_0.5.0     R6_2.4.0            repr_0.15.0
# [10] stats4_3.6.0        evaluate_0.11       pillar_1.4.2
# [13] zlibbioc_1.30.0     rlang_0.4.6         lazyeval_0.2.2
# [16] uuid_0.1-2          data.table_1.12.2   vegan_2.5-5
# [19] S4Vectors_0.22.0    Matrix_1.2-17       splines_3.6.0
# [22] stringr_1.4.0       igraph_1.2.4.1      munsell_0.5.0
# [25] compiler_3.6.0      pkgconfig_2.0.2     BiocGenerics_0.30.0
# [28] base64enc_0.1-3     multtest_2.40.0     mgcv_1.8-28
# [31] htmltools_0.3.6     biomformat_1.12.0   tidyselect_1.1.0
# [34] tibble_2.1.3        IRanges_2.18.2      codetools_0.2-16
# [37] permute_0.9-5       withr_2.1.2         crayon_1.3.4
# [40] MASS_7.3-51.4       grid_3.6.0          nlme_3.1-141
# [43] jsonlite_1.6        gtable_0.3.0        lifecycle_0.2.0
# [46] magrittr_1.5        scales_1.0.0        tidytree_0.3.2
# [49] stringi_1.4.3       XVector_0.24.0      rvcheck_0.1.3
# [52] generics_0.0.2      vctrs_0.3.1         IRkernel_0.8.12
# [55] Rhdf5lib_1.6.0      treeio_1.10.0       iterators_1.0.12
# [58] tools_3.6.0         ade4_1.7-13         Biobase_2.44.0
# [61] glue_1.4.1          purrr_0.3.2         parallel_3.6.0
# [64] survival_2.44-1.1   colorspace_1.4-1    rhdf5_2.28.0
# [67] cluster_2.1.0       pbdZMQ_0.3-3
