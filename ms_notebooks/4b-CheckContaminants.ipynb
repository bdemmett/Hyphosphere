# %% [markdown]
# # Check contaminants and finalize phyloseq objects
# * Do not run!  USED LIST GENERARTED TO PRUNE PHYLOSEQ OBJECTS AT END OF NOTEBOOK 5, DOUBLE CHECKED THAT NUMBERS DIDN'T CHANGE

# %%
library(dada2)
library(tidyr)
library(dplyr)
library(reshape2)
library(phyloseq)
library(gridExtra)
library(ggplot2)
# Out:
# Loading required package: Rcpp
# Warning message:
# “package ‘Rcpp’ was built under R version 3.6.1”Registered S3 method overwritten by 'dplyr':
#   method               from
#   as.data.frame.tbl_df tibble
# Warning message:
# “multiple methods tables found for ‘lengths’”Warning message:
# “multiple methods tables found for ‘rowSums’”Warning message:
# “multiple methods tables found for ‘colSums’”Warning message:
# “multiple methods tables found for ‘rowMeans’”Warning message:
# “multiple methods tables found for ‘colMeans’”
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Warning message:
# “package ‘reshape2’ was built under R version 3.6.1”
# Attaching package: ‘reshape2’
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
# Warning message:
# “package ‘phyloseq’ was built under R version 3.6.1”
# Attaching package: ‘gridExtra’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
# Warning message:
# “package ‘ggplot2’ was built under R version 3.6.1”

# %% [markdown]
# # Exp 2

# %%
ps = readRDS(file = '~/Hyphosphere/Exp11/Exp11_phyloseq.rds')
ps
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 12983 taxa and 192 samples ]
# sample_data() Sample Data:       [ 192 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 12983 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 12983 tips and 12953 internal nodes ]

# %%
theme_pub = function (base_size = 11, base_family = "Arial") 
{
    theme_grey(base_size = base_size, base_family = base_family) %+replace% 
        theme(
            axis.line.x = element_line(size = .5),
            axis.line.y = element_line(size = .5),
            panel.background = element_rect(fill = "white", colour = NA), 
            panel.border = element_rect(fill = NA, color = "black", size = .5), 
            panel.grid.major = element_blank(), 
            panel.grid.minor = element_blank(), 
            strip.background = element_rect(fill = "grey85", 
                colour = "grey20"), 
            legend.key = element_rect(fill = "white", 
                colour = NA), complete = TRUE)
    }

# %% [markdown]
# Controls in Experiment 11
#
# Plate 1
# * SampleID Sample
# * 89_125-BK	125-BK
# * 90_29-BK	29-BK
# * 91_77-BK	77-BK
# * 92_PCRblank	PCRblank
# * 93_PCRblank	PCRblank
#
# PCR plate 2
# * 187_139-BK; 139-BK
# * 188_155-BK; 155-BK
# * 189_187-BK; 187-BK
# * 192_MockComm; MockComm

# %%
MC = subset_samples(ps, Sample == "MockComm")
MC = filter_taxa(MC, function(x) sum(x > 0) > 0, TRUE)
MC
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 11 taxa and 1 samples ]
# sample_data() Sample Data:       [ 1 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 11 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 11 tips and 10 internal nodes ]

# %%
MC %>% psmelt
# Out:
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”
#    OTU     Sample       Abundance sample_Sample Experiment Plant   Fungus Soil
# 2  ASV120  192_MockComm 7702      MockComm      3          MockCom
# 5  ASV183  192_MockComm 7426      MockComm      3          MockCom
# 4  ASV173  192_MockComm 7391      MockComm      3          MockCom
# 6  ASV231  192_MockComm 7196      MockComm      3          MockCom
# 7  ASV242  192_MockComm 6630      MockComm      3          MockCom
# 11 ASV93   192_MockComm 6560      MockComm      3          MockCom
# 8  ASV275  192_MockComm 5929      MockComm      3          MockCom
# 3  ASV131  192_MockComm 5561      MockComm      3          MockCom
# 9  ASV34   192_MockComm 5547      MockComm      3          MockCom
# 10 ASV7688 192_MockComm    8      MockComm      3          MockCom
# 1  ASV1002 192_MockComm    4      MockComm      3          MockCom
#    SampleType Treatment TimePoint DAI Rep Concentration_ng.ul Kingdom
# 2  MK                   NA        NA  NA  NA                  Bacteria
# 5  MK                   NA        NA  NA  NA                  Bacteria
# 4  MK                   NA        NA  NA  NA                  Bacteria
# 6  MK                   NA        NA  NA  NA                  Bacteria
# 7  MK                   NA        NA  NA  NA                  Bacteria
# 11 MK                   NA        NA  NA  NA                  Bacteria
# 8  MK                   NA        NA  NA  NA                  Bacteria
# 3  MK                   NA        NA  NA  NA                  Bacteria
# 9  MK                   NA        NA  NA  NA                  Bacteria
# 10 MK                   NA        NA  NA  NA                  Bacteria
# 1  MK                   NA        NA  NA  NA                  Bacteria
#    Phylum              Class               Order
# 2  Bacteroidetes       Bacteroidia         Cytophagales
# 5  Deinococcus-Thermus Deinococci          Deinococcales
# 4  Proteobacteria      Alphaproteobacteria Sphingomonadales
# 6  Actinobacteria      Actinobacteria      Propionibacteriales
# 7  Firmicutes          Bacilli             Bacillales
# 11 Proteobacteria      Gammaproteobacteria Xanthomonadales
# 8  Firmicutes          Bacilli             Bacillales
# 3  Proteobacteria      Gammaproteobacteria Pseudomonadales
# 9  Proteobacteria      Gammaproteobacteria Betaproteobacteriales
# 10 Actinobacteria      Acidimicrobiia      Microtrichales
# 1  Chloroflexi         Chloroflexia        Kallotenuales
#    Family            Genus
# 2  Spirosomaceae     Dyadobacter
# 5  Deinococcaceae    Deinococcus
# 4  Sphingomonadaceae Sphingomonas
# 6  Nocardioidaceae   Aeromicrobium
# 7  Paenibacillaceae  Paenibacillus
# 11 Xanthomonadaceae  Lysobacter
# 8  Bacillaceae       Bacillus
# 3  Pseudomonadaceae  Pseudomonas
# 9  Burkholderiaceae  Delftia
# 10 NA                NA
# 1  AKIW781           NA

# %% [markdown]
# ## Check PCR blanks

# %%
PB = subset_samples(ps, Sample == "PCRblank")
PB = filter_taxa(PB, function(x) sum(x > 0) > 0, TRUE)
PB
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 39 taxa and 2 samples ]
# sample_data() Sample Data:       [ 2 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 39 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 39 tips and 38 internal nodes ]

# %%
otu_table(PB) %>% t()
# Out:
#          92_PCRblank 93_PCRblank
# ASV941     0         101
# ASV3323    0          92
# ASV818     0          66
# ASV747    39           0
# ASV4       0          67
# ASV11      0          55
# ASV4298    0          55
# ASV2     322         111
# ASV9233    0          89
# ASV560    88           0
# ASV3127   42           0
# ASV8458    0          82
# ASV312   312           0
# ASV577     0         451
# ASV1002  231          82
# ASV575     0          91
# ASV2925    7           0
# ASV50      0          43
# ASV4034    0          92
# ASV5505   22           0
# ASV15178   9           0
# ASV4564   20           0
# ASV3312    0         104
# ASV285    23           0
# ASV5207    0          81
# ASV524     0         117
# ASV39    159         102
# ASV91      0           8
# ASV143    99         101
# ASV288     0          40
# ASV57      0           2
# ASV526     0          84
# ASV5699    0          11
# ASV3210    0          60
# ASV5519   77           0
# ASV4200    0          77
# ASV5554  134           0
# ASV3679  175           0
# ASV5009  100           0

# %%
PBlist = taxa_names(PB)
PBlist
# Out:
#  [1] "ASV941"   "ASV3323"  "ASV818"   "ASV747"   "ASV4"     "ASV11"
#  [7] "ASV4298"  "ASV2"     "ASV9233"  "ASV560"   "ASV3127"  "ASV8458"
# [13] "ASV312"   "ASV577"   "ASV1002"  "ASV575"   "ASV2925"  "ASV50"
# [19] "ASV4034"  "ASV5505"  "ASV15178" "ASV4564"  "ASV3312"  "ASV285"
# [25] "ASV5207"  "ASV524"   "ASV39"    "ASV91"    "ASV143"   "ASV288"
# [31] "ASV57"    "ASV526"   "ASV5699"  "ASV3210"  "ASV5519"  "ASV4200"
# [37] "ASV5554"  "ASV3679"  "ASV5009"

# %%
pdf('~/Hyphosphere/Exp11/PB_ContaminantCheck.pdf')    

for(cTax in PBlist){
    
    plot = filter(ps.m, OTU == cTax) %>%
    ggplot(., aes(x=interaction(Treatment,Rep), y= Abundance)) +
    geom_point()+
    facet_grid(Soil~SampleType, scales = 'free_x')+
    ggtitle(as.character(cTax))
    
    print(plot)
    
    }
dev.off()
# Out:
# png
#   2

# %% [markdown]
# * ASV2 is MRE, not contamination
# * ASV 1002 is not correlated with DNA extract/biomass samples
# *ASV 39 is possibly a contaminant, but not clear leave for now
# ASV 143 possible contaminant, but not perfect correlation with biomass

# %%
tax_table(ps.norm)["ASV143",]
# Out:
#        Kingdom  Phylum         Class               Order
# ASV143 Bacteria Proteobacteria Gammaproteobacteria Betaproteobacteriales
#        Family           Genus
# ASV143 Burkholderiaceae NA

# %%
ps.norm %>% prune_taxa('ASV143',.) %>% psmelt() %>% 
    group_by(SampleType, Soil) %>% 
    summarize(n = length(Abundance > 0),
             mAbund = mean(Abundance)) %>% arrange(desc(mAbund))
# Out:
# Warning message in prune_taxa(taxa, phy_tree(x)):
# “prune_taxa attempted to reduce tree to 1 or fewer tips.
#  tree replaced with NULL.”Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”
#    SampleType Soil      n  mAbund
# 1  PB                    2 4.893287e-02
# 2  CH         Florence   8 2.232233e-02
# 3  EB                    6 6.137548e-03
# 4  RH         Florence   4 6.012768e-03
# 5  RS         Florence   5 1.910522e-03
# 6  RS                    1 1.875938e-03
# 7  CS         Florence   8 1.670561e-03
# 8  BS         Florence  16 1.283781e-03
# 9  BH         Florence  16 1.255479e-03
# 10 RS         Dryden    5 7.351162e-04
# 11 BP         Florence   8 5.743906e-04
# 12 BP         Pendelton  4 5.723286e-04
# 13 CS         Pendelton  4 5.170316e-04
# 14 CH         Pendelton  5 4.392247e-04
# 15 CH         Dryden   16 4.228023e-04
# 16 BH         Pendelton  4 3.777263e-04
# 17 RH         Dryden    8 1.508175e-04
# 18 CS         Dryden   16 1.178100e-04
# 19 BH         Dryden   17 9.030324e-05
# 20 BP         Dryden    8 0.000000e+00
# 21 BS         Dryden   17 0.000000e+00
# 22 BS         Pendelton  5 0.000000e+00
# 23 MK                    1 0.000000e+00
# 24 RH         Pendelton  4 0.000000e+00
# 25 RS         Pendelton  4 0.000000e+00

# %%
df = ps.norm %>% prune_taxa('ASV143',.) %>% otu_table() %>% as.data.frame() %>% 
    mutate(sample = row.names(.)) %>% filter(ASV143 > 0) %>% arrange(desc(ASV143))
df
# Out:
# Warning message in prune_taxa(taxa, phy_tree(x)):
# “prune_taxa attempted to reduce tree to 1 or fewer tips.
#  tree replaced with NULL.”
#    ASV143       sample
# 1  0.0532544379 92_PCRblank
# 2  0.0470048288 163_GVFLHN3-CH
# 3  0.0461973658 70_GVFLHN2-CH
# 4  0.0446113074 93_PCRblank
# 5  0.0319477768 73_GVFLHP1-CH
# 6  0.0285839562 170_GVFLHP4-CH
# 7  0.0268118978 188_155-BK
# 8  0.0197547232 67_GVFLHN1-CH
# 9  0.0150406009 71_GVFLHN2-RH
# 10 0.0096993210 189_187-BK
# 11 0.0090104704 68_GVFLHN1-RH
# 12 0.0073706261 142_GVFLHP3-CS
# 13 0.0049619333 123_RIFLHP4-BH
# 14 0.0045951247 43_GVFLHN2-BP
# 15 0.0038825528 124_RIFLHP4-BS
# 16 0.0035453053 9_GVFLHP1-BH
# 17 0.0032370596 106_GVFLHP3-BS
# 18 0.0030713229 72_GVFLHN2-RS
# 19 0.0027966076 120_RIFLHN4-BS
# 20 0.0027704342 119_RIFLHN4-BH
# 21 0.0026129153 74_GVFLHP2-CH
# 22 0.0025666473 96_GVFLHN2-RS
# 23 0.0025477106 42_GVFLHN1-CS
# 24 0.0025437648 171_GVN7HN3-CH
# 25 0.0024770972 166_GVFLHN4-CH
# 26 0.0024700741 138_GVFLHN3-CS
# 27 0.0024510340 108_GVFLHP4-BS
# 28 0.0022893146 39_GVCLHN2-BP
# 29 0.0021961234 157_GVCLHN3-CH
# 30 0.0021336807 104_GVFLHN4-BS
# 31 0.0020732408 118_RIFLHN3-BS
# 32 0.0020681265 136_GVCLHN4-CS
# 33 0.0020537496 180_RIN7HN3-RS
# 34 0.0020250522 69_GVFLHN1-RS
# 35 0.0019829204 117_RIFLHN3-BH
# 36 0.0018895893 168_GVFLHN4-RS
# 37 0.0018849603 146_GVN7HN3-CS
# 38 0.0018759380 186_Unknown-RS
# 39 0.0017962909 11_GVFLHP2-BH
# 40 0.0017887902 121_RIFLHP3-BH
# 41 0.0017236966 5_GVFLHN1-BH
# 42 0.0016218313 183_RIN7HN4-RS
# 43 0.0015992362 26_RIFLHP1-BS
# 44 0.0015957279 8_GVFLHN2-BS
# 45 0.0015695345 173_GVN7HN4-CH
# 46 0.0015351551 31_RIN7HN2-BH
# 47 0.0015182947 7_GVFLHN2-BH
# 48 0.0015109053 99_GVCLHN4-BH
# 49 0.0012065397 79_GVN7HN2-RH
# 50 0.0009760775 48_GVFLHP2-CS
# 51 0.0009654007 177_GVN7HP4-CH
# 52 0.0008614452 185_RIN7HP4-CH
# 53 0.0008246913 82_GVN7HP2-CH
# 54 0.0007713569 22_RIFLHN1-BS
# 55 0.0003140704 91_77-BK

# %% [markdown]
# ## Check extraction blanks

# %%
EB =  subset_samples(ps, SampleType == "EB")
EB = filter_taxa(EB, function(x) sum(x > 0) > 0, TRUE)
EB
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 195 taxa and 6 samples ]
# sample_data() Sample Data:       [ 6 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 195 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 195 tips and 194 internal nodes ]

# %%
otu_table(EB) %>% t()
# Out:
#          187_139-BK 188_155-BK 189_187-BK 89_125-BK 90_29-BK 91_77-BK
# ASV540    0           0          0          0        44        0
# ASV6874   0           0         34          0         0        0
# ASV277    0          54          0          0         0       34
# ASV2186   0           0          0         53         0        0
# ASV1930   0           0          0          0         0       38
# ASV5364   0         131          0          0         0        0
# ASV6708   0           0          0          0       101        0
# ASV5457   0           0         15          0         0        0
# ASV993    0           0          0          0        47        0
# ASV10605  0           0          0          0        53        0
# ASV1660   0           0         17          0         0        0
# ASV12236 36           0          0          0         0        0
# ASV4530   0           0          0         91         0        0
# ASV1245   0           0          0          0         0       42
# ASV3747   0           0          0        139         0        0
# ASV747    0           0          0          0         0       30
# ASV4      0           0         57         91        75        0
# ASV11     0          44          0          0         0       84
# ASV2     28          78        224        310       181      165
# ASV23     0           0         27        121         0        0
# ASV10248  0           0          0          0        55        0
# ASV2410   0           0          0         38         0        0
# ASV1604   0           0          0         22         0        0
# ASV1540   0           0          0         42         0       36
# ASV746    9           0          0          0         0        0
# ASV4556   0           0          0          0         0       51
# ASV5932   0           0          0          0       260        0
# ASV886    0          21          0          0         0        0
# ASV7182  14           0          0         59         0        0
# ASV3435  22           0          0          0         0        0
# ⋮        ⋮          ⋮          ⋮          ⋮         ⋮        ⋮
# ASV86      0          0          0          0        0        44
# ASV32      0          0          0         18        0         0
# ASV5463    0          0          0         60        0         0
# ASV2117  141         50         46        124       85         0
# ASV681   173        138        112        111       71        93
# ASV2714   80        144        205          0       55         0
# ASV6       0          7          0          0        0        33
# ASV7898    0          0          0          0        0        47
# ASV5401    0          0          0          0        0        53
# ASV6147    0          0         38          0        0         0
# ASV4575    0          0          0          0        0       122
# ASV1370    0        103          0          0        0         0
# ASV3182    0          0          0         64        0         0
# ASV5798   32          0          0          0        0         0
# ASV5774    0          0          0          0       57         0
# ASV7595    0          0          0          0       87         0
# ASV11521   0          0          0          0        0        47
# ASV10301   0          0         28          0        0         0
# ASV920     0          0          0          0       50         0
# ASV1713    0          0          0         47        0         0
# ASV421     0          0          0          0        0       103
# ASV457     0          0          0         55        0         0
# ASV11589  24          0          0          0        0         0
# ASV1472   30          0          0         67        0         0
# ASV1714    0          0          0          0       46         0
# ASV9625    0          0          0          0       62         0
# ASV4048    0          0          0          0       73         0
# ASV720     0          0          0          0        0       135
# ASV2229    0          0          0          0        0        29
# ASV1717    6          0          0          0        0         0

# %%
sample_sums(EB)
# Out:
# 187_139-BK 188_155-BK 189_187-BK  89_125-BK   90_29-BK   91_77-BK
#       2355       2387       3093       4045       3448       3184

# %%
EBlist = filter_taxa(EB, function(x) sum(x > 0) > 1, TRUE) %>% taxa_names()

# %%
length(EBlist)
# Out:
# [1] 48

# %%
ps.norm = transform_sample_counts(ps, function(x) x/sum(x))

# %%
tmp.p =  prune_taxa(EBlist, ps.norm) %>% psmelt()
# Out:
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”

# %%
tmp.p %>%
    mutate(AbundScale = log2(Abundance + .000001)) %>%
    filter(OTU %in% EBlist[1:20]) %>%
    ggplot(aes(x = SampleType, y = AbundScale)) +
    geom_boxplot() +
    #scale_y_continuous(trans = "log2")+
    facet_wrap(~OTU, ncol = 4)
# Out:
# plot without title

# %%
prune_taxa(EBlist[1:20], ps) %>% tax_table()
# Out:
#         Kingdom  Phylum         Class          Order
# ASV277  Bacteria Acidobacteria  Subgroup_6     NA
# ASV4    Bacteria NA             NA             NA
# ASV11   Bacteria NA             NA             NA
# ASV2    Bacteria NA             NA             NA
# ASV23   Bacteria Fibrobacteres  Fibrobacteria  Fibrobacterales
# ASV1540 Bacteria Bacteroidetes  Bacteroidia    Cytophagales
# ASV7182 Bacteria Bacteroidetes  Bacteroidia    Chitinophagales
# ASV1900 Bacteria Firmicutes     Bacilli        Lactobacillales
# ASV8536 Bacteria Firmicutes     Bacilli        Bacillales
# ASV902  Bacteria Firmicutes     Bacilli        Bacillales
# ASV447  Bacteria Firmicutes     Bacilli        Bacillales
# ASV312  Bacteria Chloroflexi    Chloroflexia   Kallotenuales
# ASV577  Bacteria Chloroflexi    Chloroflexia   Kallotenuales
# ASV1002 Bacteria Chloroflexi    Chloroflexia   Kallotenuales
# ASV401  Bacteria Actinobacteria Actinobacteria Micrococcales
# ASV4083 Bacteria Actinobacteria Actinobacteria Micrococcales
# ASV3225 Bacteria Actinobacteria Actinobacteria Micrococcales
# ASV5    Bacteria Actinobacteria Actinobacteria Micrococcales
# ASV1171 Bacteria Actinobacteria Actinobacteria Corynebacteriales
# ASV2962 Bacteria Actinobacteria Actinobacteria Corynebacteriales
#         Family             Genus
# ASV277  NA                 NA
# ASV4    NA                 NA
# ASV11   NA                 NA
# ASV2    NA                 NA
# ASV23   Fibrobacteraceae   possible_genus_04
# ASV1540 Microscillaceae    Ohtaekwangia
# ASV7182 Chitinophagaceae   Terrimonas
# ASV1900 Streptococcaceae   Streptococcus
# ASV8536 Family_XI          Gemella
# ASV902  Bacillaceae        Bacillus
# ASV447  Staphylococcaceae  Staphylococcus
# ASV312  NA                 NA
# ASV577  NA                 NA
# ASV1002 AKIW781            NA
# ASV401  Intrasporangiaceae Janibacter
# ASV4083 Intrasporangiaceae Janibacter
# ASV3225 Micrococcaceae     Kocuria
# ASV5    Micrococcaceae     Pseudarthrobacter
# ASV1171 Mycobacteriaceae   Mycobacterium
# ASV2962 Corynebacteriaceae Lawsonella

# %%
tmp.p %>% filter(Abundance > 0) %>% .$Abundance %>% min()
# Out:
# [1] 1.249407e-05

# %%
tmp.p %>%
    mutate(AbundScale = log2(Abundance + .00001)) %>%
    filter(OTU %in% EBlist[21:48]) %>%
    ggplot(aes(x = SampleType, y = AbundScale)) +
    geom_boxplot() +
    #scale_y_continuous(trans = "log2")+
    facet_wrap(~OTU, ncol = 4)
# Out:
# plot without title

# %%
prune_taxa(EBlist[21:48], ps) %>% tax_table()
# Out:
# Error in (function (classes, fdef, mtable) : unable to find an inherited method for function ‘prune_taxa’ for signature ‘"list", "phyloseq"’
# Traceback:
#
# 1. phyloseq::prune_taxa(EBlist[21:48], ps) %>% tax_table()
# 2. eval(lhs, parent, parent)
# 3. eval(lhs, parent, parent)
# 4. phyloseq::prune_taxa(EBlist[21:48], ps)
# 5. (function (classes, fdef, mtable)
#  . {
#  .     methods <- .findInheritedMethods(classes, fdef, mtable)
#  .     if (length(methods) == 1L)
#  .         return(methods[[1L]])
#  .     else if (length(methods) == 0L) {
#  .         cnames <- paste0("\"", vapply(classes, as.character,
#  .             ""), "\"", collapse = ", ")
#  .         stop(gettextf("unable to find an inherited method for function %s for signature %s",
#  .             sQuote(fdef@generic), sQuote(cnames)), domain = NA)
#  .     }
#  .     else stop("Internal error in finding inherited methods; didn't return a unique method",
#  .         domain = NA)
#  . })(list("list", structure("phyloseq", package = "phyloseq")),
#  .     new("standardGeneric", .Data = function (taxa, x)
#  .     standardGeneric("prune_taxa"), generic = structure("prune_taxa", package = "phyloseq"),
#  .         package = "phyloseq", group = list(), valueClass = character(0),
#  .         signature = c("taxa", "x"), default = NULL, skeleton = (function (taxa,
#  .             x)
#  .         stop("invalid call in method dispatch to 'prune_taxa' (no default method)",
#  .             domain = NA))(taxa, x)), <environment>)
# 6. stop(gettextf("unable to find an inherited method for function %s for signature %s",
#  .     sQuote(fdef@generic), sQuote(cnames)), domain = NA)

# %%
otu_table(EB) %>% t() %>% .[c('ASV14', 'ASV6', 'ASV681', 'ASV285', 'ASV17'),]
# Out:
#        187_139-BK 188_155-BK 189_187-BK 89_125-BK 90_29-BK 91_77-BK
# ASV14   83          9         43          0       75        0
# ASV6     0          7          0          0        0       33
# ASV681 173        138        112        111       71       93
# ASV285   0          0         32          0       88        0
# ASV17    0         20          0          0        0       39

# %%
#filter_taxa(EB, function(x) sum(x > 0) > 1, TRUE)
tmp = filter_taxa(EB, function(x) sum(x > 0) > 1, TRUE) %>% taxa_sums(.) %>% as.data.frame()   
tmp$ASV = row.names(tmp)
colnames(tmp)[1] = 'Abundance'
tmp %>% arrange(desc(Abundance))
EBlist = tmp %>% arrange(desc(Abundance)) %>% .$ASV %>% as.list()
# Out:
#    Abundance ASV
# 1  986       ASV2
# 2  810       ASV312
# 3  698       ASV681
# 4  540       ASV1986
# 5  484       ASV2714
# 6  460       ASV2160
# 7  446       ASV2117
# 8  401       ASV2704
# 9  310       ASV1002
# 10 272       ASV4083
# 11 223       ASV4
# 12 210       ASV14
# 13 201       ASV401
# 14 193       ASV118
# 15 190       ASV447
# 16 181       ASV1171
# 17 180       ASV577
# 18 166       ASV7871
# 19 160       ASV1900
# 20 153       ASV171
# 21 150       ASV902
# 22 149       ASV5
# 23 148       ASV23
# 24 138       ASV2516
# 25 137       ASV288
# 26 132       ASV2732
# 27 128       ASV11
# 28 124       ASV8536
# 29 120       ASV285
# 30 118       ASV3225
# 31 113       ASV2711
# 32 112       ASV2715
# 33 102       ASV1379
# 34  97       ASV1472
# 35  95       ASV143
# 36  93       ASV57
# 37  89       ASV16
# 38  88       ASV277
# 39  78       ASV1540
# 40  75       ASV1538
# 41  73       ASV7182
# 42  59       ASV17
# 43  51       ASV5265
# 44  48       ASV2962
# 45  40       ASV6
# 46  37       ASV14282
# 47  32       ASV1459
# 48  23       ASV833

# %%
ps.m = psmelt(ps.norm)
# Out:
# Warning message in psmelt(ps.norm):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”

# %%
ps.m = ps.m %>% mutate(AbundScale = log2(Abundance + .000001))

# %% [markdown]
# ## print plots of potential contaminants to pdf

# %%
length(EBlist)
# Out:
# [1] 48

# %%
pdf('~/Hyphosphere/Exp11/EB_ContaminantCheck_48.pdf')    

for(cTax in EBlist){
    
    plot1 = filter(ps.m, OTU == cTax & SampleType %in% c("EB", "PB", "MK")) %>%
    ggplot(., aes(x=interaction(Treatment,Rep), y= AbundScale)) +
    geom_point()+
    facet_grid(Soil~SampleType, scales = 'free_x')+
    ggtitle(as.character(cTax))+
    ylab('Relative abundance (log2)')

    plot2 = filter(ps.m, OTU == cTax & !SampleType %in% c("EB", "PB", "MK") & Soil %in% c("Dryden", "Pendelton", "Florence")) %>%
    ggplot(., aes(x=interaction(Treatment,Rep), y= AbundScale)) +
    geom_point()+
    facet_grid(Soil~SampleType, scales = 'free_x')+
    ggtitle(as.character(cTax))+
    ylab('Relative abundance (log2)')


    print(plot1)
    print(plot2)
    }
dev.off()
# Out:
# png
#   2

# %%
tax_table(ps.norm)["ASV11",]
# Out:
#       Kingdom  Phylum Class Order Family Genus
# ASV11 Bacteria NA     NA    NA    NA     NA

# %%
tx = 'ASV14'
df = ps.norm %>% prune_taxa(tx,.) %>% otu_table() %>% as.data.frame() %>% 
    mutate(sample = row.names(.)) %>% filter(ASV14  > 0) %>% arrange(desc(ASV14 ))
df
# Out:
# Warning message in prune_taxa(taxa, phy_tree(x)):
# “prune_taxa attempted to reduce tree to 1 or fewer tips.
#  tree replaced with NULL.”
#     ASV14        sample
# 1   0.13198464   77_GVN7HN1-RH
# 2   0.06796461   172_GVN7HN3-RH
# 3   0.06247747   164_GVFLHN3-RH
# 4   0.06229730   79_GVN7HN2-RH
# 5   0.05482784   70_GVFLHN2-CH
# 6   0.05271994   65_GVCLHN2-RH
# 7   0.05174227   166_GVFLHN4-CH
# 8   0.04317154   161_GVCLHN4-RH
# 9   0.03746177   95_GVCLHN2-CH
# 10  0.03547657   163_GVFLHN3-CH
# 11  0.03524416   187_139-BK
# 12  0.02975661   64_GVCLHN2-CH
# 13  0.02793427   174_GVN7HN4-RH
# 14  0.02494200   67_GVFLHN1-CH
# 15  0.02492937   160_GVCLHN4-CH
# 16  0.02305930   157_GVCLHN3-CH
# 17  0.02246396   167_GVFLHN4-RH
# 18  0.02176803   179_RIN7HN3-RH
# 19  0.02175174   90_29-BK
# 20  0.02159082   84_RIN7HN1-RH
# 21  0.01850382   62_GVCLHN1-RH
# 22  0.01746055   68_GVFLHN1-RH
# 23  0.01515250   73_GVFLHP1-CH
# 24  0.01508465   74_GVFLHP2-CH
# 25  0.01491996   182_RIN7HN4-RH
# 26  0.01466808   169_GVFLHP3-CH
# 27  0.01448143   171_GVN7HN3-CH
# 28  0.01390236   189_187-BK
# 29  0.01281494   71_GVFLHN2-RH
# 30  0.01095964   78_GVN7HN2-CH
# ⋮   ⋮            ⋮
# 79  0.0005322842 115_GVN7HP4-BH
# 80  0.0005104749 152_GVN7HP4-CS
# 81  0.0004369356 11_GVFLHP2-BH
# 82  0.0004114274 57_RIN7HN1-CS
# 83  0.0003676386 25_RIFLHP1-BH
# 84  0.0003397201 148_GVN7HN4-CS
# 85  0.0003126019 3_GVCLHN2-BH
# 86  0.0002982323 55_GVN7HP2-BP
# 87  0.0002960847 1_GVCLHN1-BH
# 88  0.0002846865 154_RIN7HN4-CS
# 89  0.0002657583 144_GVFLHP4-CS
# 90  0.0002453878 19_GVN7HP2-BH
# 91  0.0002387300 130_RIN7HP3-BS
# 92  0.0002375942 54_GVN7HP1-CS
# 93  0.0002329722 17_GVN7HP1-BH
# 94  0.0002327538 23_RIFLHN2-BH
# 95  0.0002228102 145_GVN7HN3-BP
# 96  0.0002154151 109_GVN7HN3-BH
# 97  0.0002112081 143_GVFLHP4-BP
# 98  0.0002026943 13_GVN7HN1-BH
# 99  0.0001991815 119_RIFLHN4-BH
# 100 0.0001969130 4_GVCLHN2-BS
# 101 0.0001866995 60_RIN7HP2-CS
# 102 0.0001866507 139_GVFLHN4-BP
# 103 0.0001853274 151_GVN7HP4-BP
# 104 0.0001602593 15_GVN7HN2-BH
# 105 0.0001582350 56_GVN7HP2-CS
# 106 0.0001375813 38_GVCLHN1-CS
# 107 0.0001151543 98_GVCLHN3-BS
# 108 0.0001094212 108_GVFLHP4-BS

# %% [markdown]
# # Check raw counts for ASV14 and ASV18

# %%
#ps = readRDS(file = '~/Hyphosphere/Exp11/Exp11_phyloseq.rds')
ps %>% subset_samples(., SampleType == 'EB') %>% prune_taxa(c("ASV53", "ASV153"), .) %>% sample_sums()
# Out:
# 187_139-BK 188_155-BK 189_187-BK  89_125-BK   90_29-BK   91_77-BK
#          0          0          0          0          0          0

# %%
a = ps %>% subset_samples(., SampleType == 'CH' & Fungus == "Gv") %>% prune_taxa(c("ASV23", "ASV45"), .) %>% sample_sums() 
b = ps %>% subset_samples(., SampleType == 'CH' & Fungus == "Gv")  %>% sample_sums() 
cbind(a,b)
# Out:
#                a    b
# 157_GVCLHN3-CH   32 41892
# 160_GVCLHN4-CH  184 62296
# 163_GVFLHN3-CH   65 45974
# 166_GVFLHN4-CH   29 72262
# 169_GVFLHP3-CH    0 56790
# 170_GVFLHP4-CH   31 47894
# 171_GVN7HN3-CH 2974 49926
# 173_GVN7HN4-CH 2282 48422
# 176_GVN7HP3-CH 2489 71303
# 177_GVN7HP4-CH 1325 58007
# 61_GVCLHN1-CH     0 33148
# 64_GVCLHN2-CH     0 25843
# 67_GVFLHN1-CH   118 60340
# 70_GVFLHN2-CH    20 55501
# 73_GVFLHP1-CH   589 46263
# 74_GVFLHP2-CH     9 45543
# 75_GVN7HN1-CH   260 59993
# 78_GVN7HN2-CH   412 44527
# 81_GVN7HP1-CH   569 49317
# 82_GVN7HP2-CH  1133 48503
# 95_GVCLHN2-CH     0 26160

# %%
a = ps %>% subset_samples(., SampleType == 'CH' & Fungus == "Gv") %>% prune_taxa(c("ASV14", "ASV18"), .) %>% sample_sums() 
b = ps %>% subset_samples(., SampleType == 'CH' & Fungus == "Gv")  %>% sample_sums() 
cbind(a,b)
# Out:
#                a    b
# 157_GVCLHN3-CH 2130 41892
# 160_GVCLHN4-CH 2237 62296
# 163_GVFLHN3-CH 2002 45974
# 166_GVFLHN4-CH 6451 72262
# 169_GVFLHP3-CH 1055 56790
# 170_GVFLHP4-CH  794 47894
# 171_GVN7HN3-CH 1157 49926
# 173_GVN7HN4-CH  917 48422
# 176_GVN7HP3-CH 1234 71303
# 177_GVN7HP4-CH  906 58007
# 61_GVCLHN1-CH   369 33148
# 64_GVCLHN2-CH  1493 25843
# 67_GVFLHN1-CH  2214 60340
# 70_GVFLHN2-CH  3385 55501
# 73_GVFLHP1-CH  1055 46263
# 74_GVFLHP2-CH   944 45543
# 75_GVN7HN1-CH  1334 59993
# 78_GVN7HN2-CH  1091 44527
# 81_GVN7HP1-CH  1102 49317
# 82_GVN7HP2-CH   538 48503
# 95_GVCLHN2-CH  1509 26160

# %% [markdown]
# # Exp 1

# %%
ps1 = readRDS('~/Hyphosphere/Exp1/Exp1_phyloseq.rds')
# Out:
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”

# %% [markdown]
# Controls in Experiment 1
#
# * Hneg1 - Negative control extraction blank
# NegativeH2O_S282 - Bart lab unknown blank
#
# UMGC - pcr blanks
# UMGC_H2O_001_A04_S4
# UMGC_H2O_001_A06_S6
# UMGC_H2O_002_B04_S112
# UMGC_H2O_002_B06_S114
# UMGC_H2O_003_A07_S199
# UMGC_H2O_003_G11_S275
# UMGC_H2O_004_F03_S306

# %%
ps1.snorm = transform_sample_counts(ps1, function(x) x/sum(x))
ps1.m = psmelt(ps1.snorm)
ps1.m = ps1.m %>% mutate(AbundScale = log2(Abundance + .000001))
# Out:
# Warning message in psmelt(ps1.snorm):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”

# %%
EB = subset_samples(ps1, SampleType == "EB")
EB = filter_taxa(EB, function(x) sum(x > 0) > 0, TRUE)
EB.snorm = transform_sample_counts(EB, function(x) x/sum(x))
sample_names(EB)
# Out:
# [1] "Hneg1_S263"

# %%
EB %>% psmelt() %>%
    arrange(desc(Abundance))
# Out:
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”
#    OTU      Sample     Abundance sample_Sample Experiment Plant Fungus Soil
# 1  ASV1900  Hneg1_S263 224       Hneg1         1
# 2  ASV26    Hneg1_S263  63       Hneg1         1
# 3  ASV49    Hneg1_S263  53       Hneg1         1
# 4  ASV284   Hneg1_S263  50       Hneg1         1
# 5  ASV14332 Hneg1_S263  38       Hneg1         1
# 6  ASV16    Hneg1_S263  38       Hneg1         1
# 7  ASV681   Hneg1_S263  37       Hneg1         1
# 8  ASV1706  Hneg1_S263  29       Hneg1         1
# 9  ASV2395  Hneg1_S263  24       Hneg1         1
# 10 ASV12695 Hneg1_S263  20       Hneg1         1
# 11 ASV2962  Hneg1_S263  17       Hneg1         1
# 12 ASV41    Hneg1_S263  15       Hneg1         1
#    SampleType Treatment TimePoint DAI Rep Concentration_ng.ul Kingdom
# 1  EB                   NA        NA  NA  0                   Bacteria
# 2  EB                   NA        NA  NA  0                   Bacteria
# 3  EB                   NA        NA  NA  0                   Bacteria
# 4  EB                   NA        NA  NA  0                   Bacteria
# 5  EB                   NA        NA  NA  0                   Bacteria
# 6  EB                   NA        NA  NA  0                   Bacteria
# 7  EB                   NA        NA  NA  0                   Bacteria
# 8  EB                   NA        NA  NA  0                   Bacteria
# 9  EB                   NA        NA  NA  0                   Bacteria
# 10 EB                   NA        NA  NA  0                   Bacteria
# 11 EB                   NA        NA  NA  0                   Bacteria
# 12 EB                   NA        NA  NA  0                   Bacteria
#    Phylum         Class                       Order
# 1  Firmicutes     Bacilli                     Lactobacillales
# 2  Bacteroidetes  Bacteroidia                 Flavobacteriales
# 3  Proteobacteria Alphaproteobacteria         Rhizobiales
# 4  Proteobacteria Gammaproteobacteria         Xanthomonadales
# 5  Actinobacteria Actinobacteria              Propionibacteriales
# 6  Proteobacteria Alphaproteobacteria         Rhizobiales
# 7  Proteobacteria Gammaproteobacteria         Enterobacteriales
# 8  Firmicutes     Bacilli                     Lactobacillales
# 9  Proteobacteria Gammaproteobacteria         Betaproteobacteriales
# 10 Proteobacteria Alphaproteobacteria         Sphingomonadales
# 11 Actinobacteria Actinobacteria              Corynebacteriales
# 12 Acidobacteria  Blastocatellia_(Subgroup_4) 11-24
#    Family               Genus
# 1  Streptococcaceae     Streptococcus
# 2  Flavobacteriaceae    Flavobacterium
# 3  Rhizobiaceae         Brucella
# 4  Rhodanobacteraceae   Luteibacter
# 5  Propionibacteriaceae Cutibacterium
# 6  Xanthobacteraceae    Bradyrhizobium
# 7  Enterobacteriaceae   Escherichia/Shigella
# 8  Streptococcaceae     Streptococcus
# 9  Burkholderiaceae     Ralstonia
# 10 Sphingomonadaceae    Sphingobium
# 11 Corynebacteriaceae   Lawsonella
# 12 NA                   NA

# %%
PB = subset_samples(ps1, SampleType == "PB")
PB = filter_taxa(PB, function(x) sum(x > 0) > 1, TRUE)
#PB.snorm = transform_sample_counts(EB, function(x) x/sum(x))
sample_names(PB)
# Out:
# [1] "NegativeH2O_S282"      "UMGC_H2O_001_A04_S4"   "UMGC_H2O_001_A06_S6"
# [4] "UMGC_H2O_002_B04_S112" "UMGC_H2O_002_B06_S114" "UMGC_H2O_003_A07_S199"
# [7] "UMGC_H2O_003_G11_S275" "UMGC_H2O_004_F03_S306"

# %%
PB %>% psmelt() %>%
    arrange(desc(Abundance))  %>%
    filter(Abundance > 0)
# Out:
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”
#    OTU     Sample                Abundance sample_Sample         Experiment
# 1  ASV4437 UMGC_H2O_001_A06_S6   379       UMGC_H2O_001_A06_S6   1
# 2  ASV2180 UMGC_H2O_001_A06_S6   315       UMGC_H2O_001_A06_S6   1
# 3  ASV2395 UMGC_H2O_001_A04_S4   201       UMGC_H2O_001_A04_S4   1
# 4  ASV6987 UMGC_H2O_002_B06_S114 121       UMGC_H2O_002_B06_S114 1
# 5  ASV8061 UMGC_H2O_003_A07_S199  83       UMGC_H2O_003_A07_S199 1
# 6  ASV9101 UMGC_H2O_001_A06_S6    83       UMGC_H2O_001_A06_S6   1
# 7  ASV4437 UMGC_H2O_001_A04_S4    77       UMGC_H2O_001_A04_S4   1
# 8  ASV2395 UMGC_H2O_002_B04_S112  55       UMGC_H2O_002_B04_S112 1
# 9  ASV34   UMGC_H2O_003_A07_S199  54       UMGC_H2O_003_A07_S199 1
# 10 ASV2180 UMGC_H2O_003_A07_S199  48       UMGC_H2O_003_A07_S199 1
# 11 ASV8061 UMGC_H2O_002_B06_S114  40       UMGC_H2O_002_B06_S114 1
# 12 ASV34   UMGC_H2O_002_B04_S112  37       UMGC_H2O_002_B04_S112 1
# 13 ASV6987 UMGC_H2O_001_A06_S6    34       UMGC_H2O_001_A06_S6   1
# 14 ASV9101 UMGC_H2O_003_A07_S199  26       UMGC_H2O_003_A07_S199 1
# 15 ASV2395 UMGC_H2O_003_G11_S275  19       UMGC_H2O_003_G11_S275 1
# 16 ASV34   UMGC_H2O_003_G11_S275  18       UMGC_H2O_003_G11_S275 1
# 17 ASV34   UMGC_H2O_001_A04_S4    12       UMGC_H2O_001_A04_S4   1
#    Plant Fungus Soil SampleType Treatment TimePoint DAI Rep Concentration_ng.ul
# 1                    PB                   NA        NA  NA  NA
# 2                    PB                   NA        NA  NA  NA
# 3                    PB                   NA        NA  NA  NA
# 4                    PB                   NA        NA  NA  NA
# 5                    PB                   NA        NA  NA  NA
# 6                    PB                   NA        NA  NA  NA
# 7                    PB                   NA        NA  NA  NA
# 8                    PB                   NA        NA  NA  NA
# 9                    PB                   NA        NA  NA  NA
# 10                   PB                   NA        NA  NA  NA
# 11                   PB                   NA        NA  NA  NA
# 12                   PB                   NA        NA  NA  NA
# 13                   PB                   NA        NA  NA  NA
# 14                   PB                   NA        NA  NA  NA
# 15                   PB                   NA        NA  NA  NA
# 16                   PB                   NA        NA  NA  NA
# 17                   PB                   NA        NA  NA  NA
#    Kingdom  Phylum         Class               Order
# 1  Bacteria Actinobacteria Actinobacteria      Actinomycetales
# 2  Bacteria Firmicutes     Bacilli             Bacillales
# 3  Bacteria Proteobacteria Gammaproteobacteria Betaproteobacteriales
# 4  Bacteria Proteobacteria Gammaproteobacteria Xanthomonadales
# 5  Bacteria Firmicutes     Negativicutes       Selenomonadales
# 6  Bacteria Fusobacteria   Fusobacteriia       Fusobacteriales
# 7  Bacteria Actinobacteria Actinobacteria      Actinomycetales
# 8  Bacteria Proteobacteria Gammaproteobacteria Betaproteobacteriales
# 9  Bacteria Proteobacteria Gammaproteobacteria Betaproteobacteriales
# 10 Bacteria Firmicutes     Bacilli             Bacillales
# 11 Bacteria Firmicutes     Negativicutes       Selenomonadales
# 12 Bacteria Proteobacteria Gammaproteobacteria Betaproteobacteriales
# 13 Bacteria Proteobacteria Gammaproteobacteria Xanthomonadales
# 14 Bacteria Fusobacteria   Fusobacteriia       Fusobacteriales
# 15 Bacteria Proteobacteria Gammaproteobacteria Betaproteobacteriales
# 16 Bacteria Proteobacteria Gammaproteobacteria Betaproteobacteriales
# 17 Bacteria Proteobacteria Gammaproteobacteria Betaproteobacteriales
#    Family           Genus
# 1  Actinomycetaceae Actinomyces
# 2  Planococcaceae   Lysinibacillus
# 3  Burkholderiaceae Ralstonia
# 4  Xanthomonadaceae Stenotrophomonas
# 5  Veillonellaceae  Veillonella
# 6  Leptotrichiaceae Leptotrichia
# 7  Actinomycetaceae Actinomyces
# 8  Burkholderiaceae Ralstonia
# 9  Burkholderiaceae Delftia
# 10 Planococcaceae   Lysinibacillus
# 11 Veillonellaceae  Veillonella
# 12 Burkholderiaceae Delftia
# 13 Xanthomonadaceae Stenotrophomonas
# 14 Leptotrichiaceae Leptotrichia
# 15 Burkholderiaceae Ralstonia
# 16 Burkholderiaceae Delftia
# 17 Burkholderiaceae Delftia

# %%
EBlist = EB %>% taxa_names()
PBlist = PB %>% taxa_names()
length(EBlist)
length(PBlist)

Clist = c(EBlist, PBlist) %>% unique()
length(Clist)
# Out:
# [1] 12
# [1] 7
# [1] 18

# %%
pdf('~/Hyphosphere/Exp1/Blank_ContaminantCheck_18.pdf')    

for(cTax in Clist){

    plot1 = filter(ps1.m, OTU == cTax & SampleType %in% c("EB", "PB", "MK")) %>%
    ggplot(., aes(x=SampleType, y= AbundScale)) +
    geom_point()+
    facet_wrap(SampleType~Sample, scales = 'free_x')+
    ggtitle(as.character(cTax))+
    ylab('Relative abundance (log2)')

    plot2 = filter(ps1.m, OTU == cTax & SampleType %in% c("CH", "CS", "RT")) %>%
    ggplot(., aes(x = SampleType, y= AbundScale)) +
    geom_point()+
    geom_boxplot()+
    facet_grid(Soil~SampleType, scales = 'free_x')+
    ggtitle(as.character(cTax))+
    ylab('Relative abundance (log2)')


    print(plot1)
    print(plot2)
    }
dev.off()
# Out:
# png
#   2

# %% [markdown]
# # Exp2

# %% [markdown]
# Controls in Experiment 10
#
# Negative ontrols in library
# 1) 94 Plate blank
# 2) 96 Plate blank
# 3) 147 T0 - this was a failed extraction, apparently only contaminants came through.
# 4) 192 - Extraction plate blank
# 5) 151 - Blank between spores and soil samples
#
# Mock communities
# 191 - Hay lab mock community
# 95 - BDE mock community
#
# Not really a control
# 160 - This is a hyphal sample that was not labeled on the extraction sheet

# %%
ps = readRDS(file = '~/Hyphosphere/Exp10/Exp10_phyloseq.rds')
ps
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 10702 taxa and 192 samples ]
# sample_data() Sample Data:       [ 192 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 10702 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 10702 tips and 10680 internal nodes ]

# %%
ps.m = ps %>% psmelt()
# Out:
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”

# %%
MC = subset_samples(ps, Sample == "MockComm")
MC = filter_taxa(MC, function(x) sum(x > 0) > 0, TRUE)
MC
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 9 taxa and 1 samples ]
# sample_data() Sample Data:       [ 1 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 9 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 9 tips and 8 internal nodes ]

# %%
MC %>% psmelt() %>%
    arrange(desc(Abundance))
# Out:
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”
#   OTU    Sample  Abundance sample_Sample Experiment Plant Fungus Soil
# 1 ASV120 95_Mock 8138      MockComm      2
# 2 ASV173 95_Mock 5797      MockComm      2
# 3 ASV183 95_Mock 5303      MockComm      2
# 4 ASV231 95_Mock 4802      MockComm      2
# 5 ASV93  95_Mock 4651      MockComm      2
# 6 ASV131 95_Mock 4010      MockComm      2
# 7 ASV275 95_Mock 3763      MockComm      2
# 8 ASV34  95_Mock 3546      MockComm      2
# 9 ASV242 95_Mock 3454      MockComm      2
#   SampleType Treatment TimePoint DAI Rep Concentration_ng.ul Kingdom
# 1 MK                   NA        NA  NA  0.12                Bacteria
# 2 MK                   NA        NA  NA  0.12                Bacteria
# 3 MK                   NA        NA  NA  0.12                Bacteria
# 4 MK                   NA        NA  NA  0.12                Bacteria
# 5 MK                   NA        NA  NA  0.12                Bacteria
# 6 MK                   NA        NA  NA  0.12                Bacteria
# 7 MK                   NA        NA  NA  0.12                Bacteria
# 8 MK                   NA        NA  NA  0.12                Bacteria
# 9 MK                   NA        NA  NA  0.12                Bacteria
#   Phylum              Class               Order
# 1 Bacteroidetes       Bacteroidia         Cytophagales
# 2 Proteobacteria      Alphaproteobacteria Sphingomonadales
# 3 Deinococcus-Thermus Deinococci          Deinococcales
# 4 Actinobacteria      Actinobacteria      Propionibacteriales
# 5 Proteobacteria      Gammaproteobacteria Xanthomonadales
# 6 Proteobacteria      Gammaproteobacteria Pseudomonadales
# 7 Firmicutes          Bacilli             Bacillales
# 8 Proteobacteria      Gammaproteobacteria Betaproteobacteriales
# 9 Firmicutes          Bacilli             Bacillales
#   Family            Genus
# 1 Spirosomaceae     Dyadobacter
# 2 Sphingomonadaceae Sphingomonas
# 3 Deinococcaceae    Deinococcus
# 4 Nocardioidaceae   Aeromicrobium
# 5 Xanthomonadaceae  Lysobacter
# 6 Pseudomonadaceae  Pseudomonas
# 7 Bacillaceae       Bacillus
# 8 Burkholderiaceae  Delftia
# 9 Paenibacillaceae  Paenibacillus

# %%
sample_data(ps)$SampleType %>% unique()
# Out:
#  [1] RH BP CS BS RT CH T0 EB GV    MK
# Levels:  BP BS CH CS EB GV MK RH RT T0

# %%
EB = subset_samples(ps, Sample == "ExtractionBlank")
EB = filter_taxa(EB, function(x) sum(x > 0) > 0, TRUE)
EB.snorm = transform_sample_counts(EB, function(x) x/sum(x))
sample_names(EB)
# Out:
# [1] "151_ExtractionBlank" "192_ExtractionBlank" "94_ExtractionBlank"
# [4] "96_ExtractionBlank"

# %%
EBlist = filter_taxa(EB, function(x) sum(x > 0) > 0, TRUE) %>% taxa_names()
length(EBlist)
EBlist
# Out:
# [1] 607
#   [1] "ASV736"   "ASV8660"  "ASV340"   "ASV1914"  "ASV219"   "ASV209"
#   [7] "ASV212"   "ASV1318"  "ASV11077" "ASV1793"  "ASV7141"  "ASV2475"
#  [13] "ASV1158"  "ASV4327"  "ASV2439"  "ASV2647"  "ASV3883"  "ASV184"
#  [19] "ASV8133"  "ASV1645"  "ASV1033"  "ASV3433"  "ASV1670"  "ASV875"
#  [25] "ASV7813"  "ASV8441"  "ASV277"   "ASV187"   "ASV273"   "ASV2501"
#  [31] "ASV427"   "ASV307"   "ASV1335"  "ASV5588"  "ASV2824"  "ASV9688"
#  [37] "ASV3026"  "ASV4961"  "ASV584"   "ASV129"   "ASV729"   "ASV235"
#  [43] "ASV1759"  "ASV268"   "ASV1030"  "ASV758"   "ASV4482"  "ASV297"
#  [49] "ASV461"   "ASV58"    "ASV20413" "ASV12769" "ASV15157" "ASV3273"
#  [55] "ASV564"   "ASV8967"  "ASV2922"  "ASV10727" "ASV12065" "ASV11105"
#  [61] "ASV694"   "ASV7435"  "ASV463"   "ASV9114"  "ASV4802"  "ASV260"
#  [67] "ASV1291"  "ASV10316" "ASV4505"  "ASV1427"  "ASV10856" "ASV3904"
#  [73] "ASV6899"  "ASV11098" "ASV19"    "ASV4724"  "ASV666"   "ASV3213"
#  [79] "ASV670"   "ASV12626" "ASV11439" "ASV1455"  "ASV3074"  "ASV12631"
#  [85] "ASV862"   "ASV885"   "ASV838"   "ASV808"   "ASV14493" "ASV1736"
#  [91] "ASV13850" "ASV4852"  "ASV1871"  "ASV2697"  "ASV971"   "ASV1834"
#  [97] "ASV5726"  "ASV1971"  "ASV15832" "ASV6304"  "ASV1251"  "ASV11688"
# [103] "ASV9333"  "ASV12522" "ASV8986"  "ASV3544"  "ASV38"    "ASV11348"
# [109] "ASV4079"  "ASV1403"  "ASV7739"  "ASV12306" "ASV1910"  "ASV2424"
# [115] "ASV1295"  "ASV6253"  "ASV109"   "ASV5715"  "ASV2926"  "ASV757"
# [121] "ASV6616"  "ASV3328"  "ASV8535"  "ASV381"   "ASV9287"  "ASV1502"
# [127] "ASV198"   "ASV3676"  "ASV2338"  "ASV21434" "ASV1801"  "ASV21623"
# [133] "ASV3138"  "ASV5430"  "ASV452"   "ASV5693"  "ASV7640"  "ASV3500"
# [139] "ASV534"   "ASV9604"  "ASV13082" "ASV114"   "ASV1479"  "ASV8591"
# [145] "ASV491"   "ASV458"   "ASV108"   "ASV1081"  "ASV55"    "ASV1029"
# [151] "ASV565"   "ASV4259"  "ASV3773"  "ASV12625" "ASV11719" "ASV641"
# [157] "ASV19598" "ASV1311"  "ASV1988"  "ASV96"    "ASV618"   "ASV1371"
# [163] "ASV9551"  "ASV17742" "ASV2855"  "ASV3223"  "ASV23352" "ASV12301"
# [169] "ASV1312"  "ASV2778"  "ASV365"   "ASV1408"  "ASV3072"  "ASV3022"
# [175] "ASV4341"  "ASV8499"  "ASV798"   "ASV1699"  "ASV8965"  "ASV323"
# [181] "ASV228"   "ASV392"   "ASV104"   "ASV65"    "ASV374"   "ASV264"
# [187] "ASV470"   "ASV558"   "ASV5291"  "ASV516"   "ASV1040"  "ASV14486"
# [193] "ASV112"   "ASV224"   "ASV244"   "ASV24"    "ASV6844"  "ASV2148"
# [199] "ASV6624"  "ASV2118"  "ASV8966"  "ASV16980" "ASV8476"  "ASV1123"
# [205] "ASV1096"  "ASV3975"  "ASV200"   "ASV7242"  "ASV974"   "ASV592"
# [211] "ASV328"   "ASV75"    "ASV404"   "ASV2531"  "ASV1224"  "ASV10500"
# [217] "ASV8866"  "ASV1"     "ASV54"    "ASV78"    "ASV250"   "ASV1178"
# [223] "ASV4267"  "ASV816"   "ASV1217"  "ASV1064"  "ASV52"    "ASV3932"
# [229] "ASV48"    "ASV8"     "ASV43"    "ASV29"    "ASV115"   "ASV191"
# [235] "ASV1344"  "ASV3929"  "ASV1890"  "ASV393"   "ASV16"    "ASV486"
# [241] "ASV622"   "ASV1415"  "ASV1511"  "ASV428"   "ASV133"   "ASV36"
# [247] "ASV4480"  "ASV21"    "ASV206"   "ASV4120"  "ASV1046"  "ASV856"
# [253] "ASV953"   "ASV203"   "ASV12430" "ASV33"    "ASV1537"  "ASV243"
# [259] "ASV147"   "ASV2762"  "ASV136"   "ASV3"     "ASV336"   "ASV319"
# [265] "ASV5074"  "ASV4804"  "ASV608"   "ASV665"   "ASV3623"  "ASV13938"
# [271] "ASV158"   "ASV77"    "ASV326"   "ASV1773"  "ASV733"   "ASV2042"
# [277] "ASV71"    "ASV271"   "ASV7860"  "ASV10427" "ASV5211"  "ASV87"
# [283] "ASV6422"  "ASV6"     "ASV790"   "ASV2346"  "ASV4816"  "ASV1273"
# [289] "ASV15742" "ASV633"   "ASV1269"  "ASV576"   "ASV137"   "ASV932"
# [295] "ASV612"   "ASV1627"  "ASV4245"  "ASV1525"  "ASV309"   "ASV126"
# [301] "ASV1533"  "ASV1247"  "ASV234"   "ASV3555"  "ASV74"    "ASV1288"
# [307] "ASV14284" "ASV2900"  "ASV481"   "ASV339"   "ASV662"   "ASV455"
# [313] "ASV6557"  "ASV851"   "ASV8184"  "ASV258"   "ASV696"   "ASV1299"
# [319] "ASV2113"  "ASV253"   "ASV300"   "ASV40"    "ASV12"    "ASV1531"
# [325] "ASV285"   "ASV17"    "ASV27"    "ASV409"   "ASV15"    "ASV2103"
# [331] "ASV34"    "ASV192"   "ASV2395"  "ASV2516"  "ASV526"   "ASV32"
# [337] "ASV86"    "ASV12541" "ASV681"   "ASV163"   "ASV3939"  "ASV13"
# [343] "ASV19277" "ASV9048"  "ASV2658"  "ASV525"   "ASV4819"  "ASV7248"
# [349] "ASV8366"  "ASV883"   "ASV6392"  "ASV1567"  "ASV3107"  "ASV141"
# [355] "ASV4662"  "ASV80"    "ASV731"   "ASV630"   "ASV4968"  "ASV553"
# [361] "ASV18"    "ASV1270"  "ASV870"   "ASV18585" "ASV1471"  "ASV23631"
# [367] "ASV127"   "ASV15128" "ASV3202"  "ASV145"   "ASV705"   "ASV2792"
# [373] "ASV3461"  "ASV799"   "ASV6678"  "ASV1706"  "ASV1900"  "ASV97"
# [379] "ASV8536"  "ASV447"   "ASV85"    "ASV4585"  "ASV1334"  "ASV62"
# [385] "ASV233"   "ASV45"    "ASV23"    "ASV4237"  "ASV10554" "ASV35"
# [391] "ASV2463"  "ASV59"    "ASV467"   "ASV150"   "ASV68"    "ASV899"
# [397] "ASV89"    "ASV625"   "ASV827"   "ASV975"   "ASV789"   "ASV664"
# [403] "ASV135"   "ASV18819" "ASV1449"  "ASV3880"  "ASV1153"  "ASV3704"
# [409] "ASV11944" "ASV265"   "ASV1976"  "ASV1133"  "ASV2407"  "ASV15363"
# [415] "ASV472"   "ASV3594"  "ASV3462"  "ASV3001"  "ASV9874"  "ASV7063"
# [421] "ASV2997"  "ASV5361"  "ASV855"   "ASV1551"  "ASV10684" "ASV6949"
# [427] "ASV7911"  "ASV20"    "ASV1543"  "ASV226"   "ASV14561" "ASV8162"
# [433] "ASV747"   "ASV4"     "ASV11"    "ASV2"     "ASV449"   "ASV10"
# [439] "ASV88"    "ASV12452" "ASV19633" "ASV13069" "ASV6627"  "ASV13429"
# [445] "ASV3339"  "ASV9699"  "ASV590"   "ASV6455"  "ASV450"   "ASV1638"
# [451] "ASV786"   "ASV1196"  "ASV5758"  "ASV3972"  "ASV7175"  "ASV7440"
# [457] "ASV325"   "ASV723"   "ASV4761"  "ASV132"   "ASV166"   "ASV176"
# [463] "ASV25"    "ASV1612"  "ASV2325"  "ASV7737"  "ASV2375"  "ASV1186"
# [469] "ASV6781"  "ASV1755"  "ASV15640" "ASV6622"  "ASV151"   "ASV3216"
# [475] "ASV10359" "ASV1623"  "ASV13641" "ASV2941"  "ASV1610"  "ASV806"
# [481] "ASV3422"  "ASV4669"  "ASV1908"  "ASV3155"  "ASV3305"  "ASV5897"
# [487] "ASV1198"  "ASV548"   "ASV2949"  "ASV12850" "ASV586"   "ASV531"
# [493] "ASV13948" "ASV477"   "ASV116"   "ASV1297"  "ASV60"    "ASV332"
# [499] "ASV545"   "ASV92"    "ASV2255"  "ASV1202"  "ASV6887"  "ASV529"
# [505] "ASV1325"  "ASV402"   "ASV5201"  "ASV1331"  "ASV4135"  "ASV1365"
# [511] "ASV2981"  "ASV5"     "ASV1327"  "ASV3225"  "ASV1345"  "ASV676"
# [517] "ASV401"   "ASV180"   "ASV640"   "ASV1590"  "ASV11373" "ASV222"
# [523] "ASV1284"  "ASV2962"  "ASV7395"  "ASV2732"  "ASV50"    "ASV354"
# [529] "ASV7523"  "ASV73"    "ASV139"   "ASV408"   "ASV3327"  "ASV3286"
# [535] "ASV3322"  "ASV5767"  "ASV2173"  "ASV14596" "ASV2071"  "ASV5824"
# [541] "ASV256"   "ASV438"   "ASV1697"  "ASV372"   "ASV3912"  "ASV1417"
# [547] "ASV1702"  "ASV23835" "ASV2087"  "ASV6963"  "ASV598"   "ASV700"
# [553] "ASV7296"  "ASV17340" "ASV940"   "ASV3701"  "ASV1904"  "ASV619"
# [559] "ASV422"   "ASV5665"  "ASV6688"  "ASV3189"  "ASV5485"  "ASV697"
# [565] "ASV900"   "ASV3748"  "ASV2681"  "ASV2709"  "ASV5226"  "ASV7237"
# [571] "ASV7912"  "ASV4820"  "ASV11628" "ASV1107"  "ASV2760"  "ASV701"
# [577] "ASV11235" "ASV3507"  "ASV22902" "ASV1117"  "ASV1128"  "ASV1104"
# [583] "ASV293"   "ASV156"   "ASV2677"  "ASV468"   "ASV698"   "ASV454"
# [589] "ASV8976"  "ASV240"   "ASV2987"  "ASV41"    "ASV5381"  "ASV2445"
# [595] "ASV6103"  "ASV14492" "ASV305"   "ASV1203"  "ASV9354"  "ASV8446"
# [601] "ASV3025"  "ASV3656"  "ASV815"   "ASV1197"  "ASV3122"  "ASV973"
# [607] "ASV12133"

# %%
"ASV791" %in% EBlist
# Out:
# [1] FALSE

# %%
EB.m = psmelt(EB.snorm)
EB.m = EB.m %>% mutate(AbundScale = log2(Abundance + .000001))
# Out:
# Warning message in psmelt(EB.snorm):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”Warning message:
# “The `printer` argument is deprecated as of rlang 0.3.0.
# This warning is displayed once per session.”

# %%
sample_data(EB.m) %>% head()
# Out:
#     OTU    Sample              Abundance sample_Sample   Experiment Plant
# sa1 ASV1   192_ExtractionBlank 0.6384749 ExtractionBlank 2
# sa2 ASV1   151_ExtractionBlank 0.5120572 ExtractionBlank 2
# sa3 ASV3   151_ExtractionBlank 0.3039671 ExtractionBlank 2
# sa4 ASV3   192_ExtractionBlank 0.2909635 ExtractionBlank 2
# sa5 ASV6   96_ExtractionBlank  0.2425959 ExtractionBlank 2
# sa6 ASV447 94_ExtractionBlank  0.1157470 ExtractionBlank 2
#     Fungus Soil SampleType Treatment ⋯ DAI Rep Concentration_ng.ul Kingdom
# sa1             EB                   ⋯ NA  NA  0.073               Bacteria
# sa2             EB                   ⋯ NA  NA  0.103               Bacteria
# sa3             EB                   ⋯ NA  NA  0.103               Bacteria
# sa4             EB                   ⋯ NA  NA  0.073               Bacteria
# sa5             EB                   ⋯ NA  NA  0.123               Bacteria
# sa6             EB                   ⋯ NA  NA  0.119               Bacteria
#     Phylum         Class               Order            Family
# sa1 Proteobacteria Alphaproteobacteria Rhizobiales      Rhizobiaceae
# sa2 Proteobacteria Alphaproteobacteria Rhizobiales      Rhizobiaceae
# sa3 Proteobacteria Alphaproteobacteria Sphingomonadales Sphingomonadaceae
# sa4 Proteobacteria Alphaproteobacteria Sphingomonadales Sphingomonadaceae
# sa5 Proteobacteria Gammaproteobacteria Cellvibrionales  Cellvibrionaceae
# sa6 Firmicutes     Bacilli             Bacillales       Staphylococcaceae
#     Genus           AbundScale
# sa1 Phyllobacterium -0.6472960
# sa2 Phyllobacterium -0.9656203
# sa3 Sphingomonas    -1.7180081
# sa4 Sphingomonas    -1.7810851
# sa5 Cellvibrio      -2.0433672
# sa6 Staphylococcus  -3.1109412

# %%
ps.snorm = transform_sample_counts(ps, function(x) x/sum(x))
ps.m = psmelt(ps.snorm)
ps.m = ps.m %>% mutate(AbundScale = log2(Abundance + .000001))
# Out:
# Warning message in psmelt(ps.snorm):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”

# %%
ps.m %>% head()
# Out:
#   OTU  Sample              Abundance sample_Sample   Experiment Plant Fungus
# 1 ASV1 147_T0R1            0.6803279 T0R1            2
# 2 ASV1 192_ExtractionBlank 0.6384749 ExtractionBlank 2
# 3 ASV1 152_GvSpores        0.6009966 GvSpores        2                Gv
# 4 ASV1 165_5.1CH           0.5241498 5.1CH           2          5.1   Gv
# 5 ASV1 151_ExtractionBlank 0.5120572 ExtractionBlank 2
# 6 ASV1 158_1.4RH           0.5113633 1.4RH           2          1.4   Gv
#   Soil    SampleType Treatment ⋯ DAI Rep Concentration_ng.ul Kingdom
# 1 Dryden T0                   ⋯ NA   1  0.142               Bacteria
# 2         EB                   ⋯ NA  NA  0.073               Bacteria
# 3         GV                   ⋯ NA  NA  0.101               Bacteria
# 4 Dryden CH         HN        ⋯ 14   5  0.160               Bacteria
# 5         EB                   ⋯ NA  NA  0.103               Bacteria
# 6 Dryden RH         HN        ⋯ 45   1  0.111               Bacteria
#   Phylum         Class               Order       Family       Genus
# 1 Proteobacteria Alphaproteobacteria Rhizobiales Rhizobiaceae Phyllobacterium
# 2 Proteobacteria Alphaproteobacteria Rhizobiales Rhizobiaceae Phyllobacterium
# 3 Proteobacteria Alphaproteobacteria Rhizobiales Rhizobiaceae Phyllobacterium
# 4 Proteobacteria Alphaproteobacteria Rhizobiales Rhizobiaceae Phyllobacterium
# 5 Proteobacteria Alphaproteobacteria Rhizobiales Rhizobiaceae Phyllobacterium
# 6 Proteobacteria Alphaproteobacteria Rhizobiales Rhizobiaceae Phyllobacterium
#   AbundScale
# 1 -0.5556958
# 2 -0.6472960
# 3 -0.7345689
# 4 -0.9319461
# 5 -0.9656203
# 6 -0.9675766

# %%
pdf('~/Hyphosphere/Exp10/EB_ContaminantCheck_34.pdf')    

for(cTax in EBlist){
    
    plot1 = filter(ps.m, OTU == cTax & SampleType %in% c("EB", "PB", "MK")) %>%
    ggplot(., aes(x=SampleType, y= AbundScale)) +
    geom_point()+
    facet_wrap(SampleType~Sample, scales = 'free_x')+
    ggtitle(as.character(cTax))+
    ylab('Relative abundance (log2)')

    plot2 = filter(ps.m, OTU == cTax & !SampleType %in% c("EB", "PB", "MK", "T0") & !is.na(SampleType) & Soil %in% c("Dryden", "Pendelton", "Florence")) %>%
    ggplot(., aes(x=TimePoint, y= AbundScale)) +
    geom_point()+
    facet_grid(SampleType~Rep, scales = 'free_x')+
    ggtitle(as.character(cTax))+
    ylab('Relative abundance (log2)')


    print(plot1)
    print(plot2)
    }
dev.off()
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# png
#   2

# %%
EB2 = filter_taxa(EB, function(x) sum(x > 0) > 1, TRUE) %>% tax_table()
EB2
# Out:
#         Kingdom  Phylum         Class
# ASV224  Bacteria Nitrospirae    Nitrospira
# ASV1    Bacteria Proteobacteria Alphaproteobacteria
# ASV54   Bacteria Proteobacteria Alphaproteobacteria
# ASV78   Bacteria Proteobacteria Alphaproteobacteria
# ASV8    Bacteria Proteobacteria Alphaproteobacteria
# ASV43   Bacteria Proteobacteria Alphaproteobacteria
# ASV16   Bacteria Proteobacteria Alphaproteobacteria
# ASV136  Bacteria Proteobacteria Alphaproteobacteria
# ASV3    Bacteria Proteobacteria Alphaproteobacteria
# ASV87   Bacteria Proteobacteria Gammaproteobacteria
# ASV6    Bacteria Proteobacteria Gammaproteobacteria
# ASV932  Bacteria Proteobacteria Gammaproteobacteria
# ASV12   Bacteria Proteobacteria Gammaproteobacteria
# ASV285  Bacteria Proteobacteria Gammaproteobacteria
# ASV17   Bacteria Proteobacteria Gammaproteobacteria
# ASV409  Bacteria Proteobacteria Gammaproteobacteria
# ASV15   Bacteria Proteobacteria Gammaproteobacteria
# ASV2516 Bacteria Proteobacteria Gammaproteobacteria
# ASV681  Bacteria Proteobacteria Gammaproteobacteria
# ASV13   Bacteria Proteobacteria Gammaproteobacteria
# ASV18   Bacteria Proteobacteria Deltaproteobacteria
# ASV447  Bacteria Firmicutes     Bacilli
# ASV62   Bacteria Fibrobacteres  Fibrobacteria
# ASV35   Bacteria Bacteroidetes  Bacteroidia
# ASV68   Bacteria Bacteroidetes  Bacteroidia
# ASV4    Bacteria NA             NA
# ASV2    Bacteria NA             NA
# ASV10   Bacteria Cyanobacteria  Oxyphotobacteria
# ASV531  Bacteria Actinobacteria Thermoleophilia
# ASV5    Bacteria Actinobacteria Actinobacteria
# ASV1327 Bacteria Actinobacteria Actinobacteria
# ASV222  Bacteria Actinobacteria Actinobacteria
# ASV372  Bacteria Actinobacteria Acidimicrobiia
# ASV454  Bacteria Acidobacteria  Blastocatellia_(Subgroup_4)
#         Order                 Family              Genus
# ASV224  Nitrospirales         Nitrospiraceae      Nitrospira
# ASV1    Rhizobiales           Rhizobiaceae        Phyllobacterium
# ASV54   Rhizobiales           Rhizobiaceae        Phyllobacterium
# ASV78   Rhizobiales           Rhizobiaceae        Phyllobacterium
# ASV8    Caulobacterales       Caulobacteraceae    Asticcacaulis
# ASV43   Caulobacterales       Caulobacteraceae    Caulobacter
# ASV16   Rhizobiales           Xanthobacteraceae   Bradyrhizobium
# ASV136  Sphingomonadales      Sphingomonadaceae   Sphingomonas
# ASV3    Sphingomonadales      Sphingomonadaceae   Sphingomonas
# ASV87   CCD24                 NA                  NA
# ASV6    Cellvibrionales       Cellvibrionaceae    Cellvibrio
# ASV932  Betaproteobacteriales SC-I-84             NA
# ASV12   Betaproteobacteriales Burkholderiaceae    Piscinibacter
# ASV285  Betaproteobacteriales Burkholderiaceae    Pelomonas
# ASV17   Betaproteobacteriales Burkholderiaceae    Paucibacter
# ASV409  Betaproteobacteriales Burkholderiaceae    Rhizobacter
# ASV15   Betaproteobacteriales Burkholderiaceae    NA
# ASV2516 Betaproteobacteriales Burkholderiaceae    Ralstonia
# ASV681  Enterobacteriales     Enterobacteriaceae  Escherichia/Shigella
# ASV13   Xanthomonadales       Xanthomonadaceae    Luteimonas
# ASV18   Myxococcales          Sandaracinaceae     NA
# ASV447  Bacillales            Staphylococcaceae   Staphylococcus
# ASV62   Fibrobacterales       Fibrobacteraceae    possible_genus_04
# ASV35   Flavobacteriales      Flavobacteriaceae   Flavobacterium
# ASV68   Cytophagales          Microscillaceae     NA
# ASV4    NA                    NA                  NA
# ASV2    NA                    NA                  NA
# ASV10   Chloroplast           NA                  NA
# ASV531  Gaiellales            NA                  NA
# ASV5    Micrococcales         Micrococcaceae      Pseudarthrobacter
# ASV1327 Micrococcales         Micrococcaceae      Micrococcus
# ASV222  Frankiales            Geodermatophilaceae Blastococcus
# ASV372  Microtrichales        NA                  NA
# ASV454  Pyrinomonadales       Pyrinomonadaceae    RB41

# %% [markdown]
# # Check distribution of potential contaminants across experiments

# %%
SuspectList = c("ASV1", "ASV54", "ASV78", "ASV136", "ASV3", "ASV12", "ASV2516", "ASV681", "ASV447",  "ASV49", "ASV12695", 
                "ASV2395", "ASV284", "ASV1706", "ASV1900", "ASV26", "ASV14332", "ASV2962", "ASV41", "ASV9101", "ASV34", "ASV2180",
               "ASV8061", "ASV4437", "ASV6987", "ASV39", "ASV143", "ASV2", "ASV1986", "ASV2714", "ASV2160", "ASV2117", "ASV2704", "ASV1002",
               "ASV4083", "ASV14", "ASV118", "ASV447", "ASV577", "ASV7871", "ASV1900", "ASV171", "ASV2516", "ASV8536", "ASV285", "ASV3225", "ASV2715",
               "ASV16", "ASV5265", "ASV2962", "ASV14282", "ASV833")
# did not include ASV10 -chloroplast needs to be removed

# %%
ps = readRDS(file = '~/Hyphosphere/data/3Exp/phyloseq/3Exp_phyloseq_thresh_wtree.rds')
#ps.sub.m = prune_samples(SuspectList, ps) %>% psmelt()

# %%
ps = transform_sample_counts(ps, function(x) x/sum(x))

# %%
SuspectList
# Out:
#  [1] "ASV1"     "ASV54"    "ASV78"    "ASV136"   "ASV3"     "ASV12"
#  [7] "ASV2516"  "ASV681"   "ASV447"   "ASV49"    "ASV12695" "ASV2395"
# [13] "ASV284"   "ASV1706"  "ASV1900"  "ASV26"    "ASV14332" "ASV2962"
# [19] "ASV41"    "ASV9101"  "ASV34"    "ASV2180"  "ASV8061"  "ASV4437"
# [25] "ASV6987"  "ASV39"    "ASV143"   "ASV2"     "ASV1986"  "ASV2714"
# [31] "ASV2160"  "ASV2117"  "ASV2704"  "ASV1002"  "ASV4083"  "ASV14"
# [37] "ASV118"   "ASV447"   "ASV577"   "ASV7871"  "ASV1900"  "ASV171"
# [43] "ASV2516"  "ASV8536"  "ASV285"   "ASV3225"  "ASV2715"  "ASV16"
# [49] "ASV5265"  "ASV2962"  "ASV14282" "ASV833"

# %%
ps = prune_taxa(SuspectList, ps)

# %%
ps.m = ps %>% psmelt()
ps.m = ps.m %>% mutate(AbundScale = log2(Abundance + .000001))
# Out:
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”

# %%
ps.m %>% head()
# Out:
#   OTU     Sample                Abundance sample_Sample         Experiment
# 1 ASV1    147_T0R1              0.6803279 T0R1                  2
# 2 ASV1    192_ExtractionBlank   0.6383936 ExtractionBlank       2
# 3 ASV6987 UMGC_H2O_002_B06_S114 0.6302083 UMGC_H2O_002_B06_S114 1
# 4 ASV1    152_GvSpores          0.5980167 GvSpores              2
# 5 ASV2395 UMGC_H2O_001_A04_S4   0.5506849 UMGC_H2O_001_A04_S4   1
# 6 ASV1    165_5.1CH             0.5238792 5.1CH                 2
#   Plant Fungus Soil    SampleType Treatment ⋯ DAI Rep Concentration_ng.ul
# 1              Dryden T0                   ⋯ NA   1  0.142
# 2                      EB                   ⋯ NA  NA  0.073
# 3                      PB                   ⋯ NA  NA     NA
# 4       Gv             GV                   ⋯ NA  NA  0.101
# 5                      PB                   ⋯ NA  NA     NA
# 6 5.1   Gv     Dryden CH         HN        ⋯ 14   5  0.160
#   Kingdom  Phylum         Class               Order
# 1 Bacteria Proteobacteria Alphaproteobacteria Rhizobiales
# 2 Bacteria Proteobacteria Alphaproteobacteria Rhizobiales
# 3 Bacteria Proteobacteria Gammaproteobacteria Xanthomonadales
# 4 Bacteria Proteobacteria Alphaproteobacteria Rhizobiales
# 5 Bacteria Proteobacteria Gammaproteobacteria Betaproteobacteriales
# 6 Bacteria Proteobacteria Alphaproteobacteria Rhizobiales
#   Family           Genus            AbundScale
# 1 Rhizobiaceae     Phyllobacterium  -0.5556958
# 2 Rhizobiaceae     Phyllobacterium  -0.6474796
# 3 Xanthomonadaceae Stenotrophomonas -0.6660970
# 4 Rhizobiaceae     Phyllobacterium  -0.7417398
# 5 Burkholderiaceae Ralstonia        -0.8606983
# 6 Rhizobiaceae     Phyllobacterium  -0.9326912

# %%
pdf('~/Hyphosphere/3ex_ContaminantCheck.pdf')    

for(cTax in SuspectList){
    
    plot1 = filter(ps.m, OTU == cTax & SampleType %in% c("EB", "PB")) %>%
    ggplot(., aes(x=Sample, y= AbundScale)) +
    geom_point()+
    facet_grid(Experiment~SampleType, scales = 'free_x')+
    ggtitle(as.character(cTax))+
    ylab('Relative abundance (log2)')
    
    plot2 = filter(ps.m, Experiment == 1, OTU == cTax & SampleType %in% c("CH", "CS", "RT")) %>%
    ggplot(., aes(x = SampleType, y= AbundScale)) +
    geom_point()+
    geom_boxplot()+
    facet_grid(Soil~SampleType, scales = 'free_x')+
    ggtitle(as.character(cTax))+
    ylab('Relative abundance (log2)')

    plot3 = filter(ps.m, Experiment == 2, OTU == cTax & !SampleType %in% c("EB", "PB", "MK", "T0") & !is.na(SampleType) & Soil %in% c("Dryden", "Pendelton", "Florence")) %>%
    ggplot(., aes(x=TimePoint, y= AbundScale)) +
    geom_point()+
    facet_grid(SampleType~Rep, scales = 'free_x')+
    ggtitle(as.character(cTax))+
    ylab('Relative abundance (log2)')
    
    plot4 =  filter(ps.m, Experiment == 3, OTU == cTax & !SampleType %in% c("EB", "PB", "MK") & Soil %in% c("Dryden", "Pendelton", "Florence")) %>%
    ggplot(., aes(x=interaction(Treatment,Rep), y= AbundScale)) +
    geom_point()+
    facet_grid(Soil~SampleType, scales = 'free_x')+
    ggtitle(as.character(cTax))+
    ylab('Relative abundance (log2)')
    
    


    print(plot1)
    print(plot2)
    print(plot3)
    print(plot4)
    }
dev.off()
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# png
#   2

# %%
ttab = ps %>% tax_table()

# %%
ttab
# Out:
#          Kingdom  Phylum         Class
# ASV9101  Bacteria Fusobacteria   Fusobacteriia
# ASV49    Bacteria Proteobacteria Alphaproteobacteria
# ASV2715  Bacteria Proteobacteria Alphaproteobacteria
# ASV1     Bacteria Proteobacteria Alphaproteobacteria
# ASV54    Bacteria Proteobacteria Alphaproteobacteria
# ASV78    Bacteria Proteobacteria Alphaproteobacteria
# ASV16    Bacteria Proteobacteria Alphaproteobacteria
# ASV12695 Bacteria Proteobacteria Alphaproteobacteria
# ASV136   Bacteria Proteobacteria Alphaproteobacteria
# ASV3     Bacteria Proteobacteria Alphaproteobacteria
# ASV2704  Bacteria Proteobacteria Gammaproteobacteria
# ASV1986  Bacteria Proteobacteria Gammaproteobacteria
# ASV171   Bacteria Proteobacteria Gammaproteobacteria
# ASV2160  Bacteria Proteobacteria Gammaproteobacteria
# ASV833   Bacteria Proteobacteria Gammaproteobacteria
# ASV39    Bacteria Proteobacteria Gammaproteobacteria
# ASV12    Bacteria Proteobacteria Gammaproteobacteria
# ASV285   Bacteria Proteobacteria Gammaproteobacteria
# ASV7871  Bacteria Proteobacteria Gammaproteobacteria
# ASV34    Bacteria Proteobacteria Gammaproteobacteria
# ASV143   Bacteria Proteobacteria Gammaproteobacteria
# ASV118   Bacteria Proteobacteria Gammaproteobacteria
# ASV2395  Bacteria Proteobacteria Gammaproteobacteria
# ASV2516  Bacteria Proteobacteria Gammaproteobacteria
# ASV5265  Bacteria Proteobacteria Gammaproteobacteria
# ASV2117  Bacteria Proteobacteria Gammaproteobacteria
# ASV14282 Bacteria Proteobacteria Gammaproteobacteria
# ASV681   Bacteria Proteobacteria Gammaproteobacteria
# ASV2714  Bacteria Proteobacteria Gammaproteobacteria
# ASV6987  Bacteria Proteobacteria Gammaproteobacteria
# ASV284   Bacteria Proteobacteria Gammaproteobacteria
# ASV14    Bacteria Proteobacteria Deltaproteobacteria
# ASV1706  Bacteria Firmicutes     Bacilli
# ASV1900  Bacteria Firmicutes     Bacilli
# ASV8536  Bacteria Firmicutes     Bacilli
# ASV447   Bacteria Firmicutes     Bacilli
# ASV2180  Bacteria Firmicutes     Bacilli
# ASV8061  Bacteria Firmicutes     Negativicutes
# ASV26    Bacteria Bacteroidetes  Bacteroidia
# ASV2     Bacteria NA             NA
# ASV577   Bacteria Chloroflexi    Chloroflexia
# ASV1002  Bacteria Chloroflexi    Chloroflexia
# ASV14332 Bacteria Actinobacteria Actinobacteria
# ASV4437  Bacteria Actinobacteria Actinobacteria
# ASV3225  Bacteria Actinobacteria Actinobacteria
# ASV4083  Bacteria Actinobacteria Actinobacteria
# ASV2962  Bacteria Actinobacteria Actinobacteria
# ASV41    Bacteria Acidobacteria  Blastocatellia_(Subgroup_4)
#          Order                 Family               Genus
# ASV9101  Fusobacteriales       Leptotrichiaceae     Leptotrichia
# ASV49    Rhizobiales           Rhizobiaceae         Brucella
# ASV2715  Rhodobacterales       Rhodobacteraceae     Paracoccus
# ASV1     Rhizobiales           Rhizobiaceae         Phyllobacterium
# ASV54    Rhizobiales           Rhizobiaceae         Phyllobacterium
# ASV78    Rhizobiales           Rhizobiaceae         Phyllobacterium
# ASV16    Rhizobiales           Xanthobacteraceae    Bradyrhizobium
# ASV12695 Sphingomonadales      Sphingomonadaceae    Sphingobium
# ASV136   Sphingomonadales      Sphingomonadaceae    Sphingomonas
# ASV3     Sphingomonadales      Sphingomonadaceae    Sphingomonas
# ASV2704  Pseudomonadales       Pseudomonadaceae     Pseudomonas
# ASV1986  Pseudomonadales       Moraxellaceae        Enhydrobacter
# ASV171   Pseudomonadales       Moraxellaceae        Acinetobacter
# ASV2160  Pseudomonadales       Moraxellaceae        Acinetobacter
# ASV833   Betaproteobacteriales Burkholderiaceae     Aquabacterium
# ASV39    Betaproteobacteriales Burkholderiaceae     Aquabacterium
# ASV12    Betaproteobacteriales Burkholderiaceae     Piscinibacter
# ASV285   Betaproteobacteriales Burkholderiaceae     Pelomonas
# ASV7871  Betaproteobacteriales Burkholderiaceae     Acidovorax
# ASV34    Betaproteobacteriales Burkholderiaceae     Delftia
# ASV143   Betaproteobacteriales Burkholderiaceae     NA
# ASV118   Betaproteobacteriales Burkholderiaceae     Noviherbaspirillum
# ASV2395  Betaproteobacteriales Burkholderiaceae     Ralstonia
# ASV2516  Betaproteobacteriales Burkholderiaceae     Ralstonia
# ASV5265  Betaproteobacteriales Chitinimonadaceae    Chitinimonas
# ASV2117  Aeromonadales         Aeromonadaceae       Aeromonas
# ASV14282 Enterobacteriales     Enterobacteriaceae   Citrobacter
# ASV681   Enterobacteriales     Enterobacteriaceae   Escherichia/Shigella
# ASV2714  Enterobacteriales     Enterobacteriaceae   Serratia
# ASV6987  Xanthomonadales       Xanthomonadaceae     Stenotrophomonas
# ASV284   Xanthomonadales       Rhodanobacteraceae   Luteibacter
# ASV14    Myxococcales          Sandaracinaceae      NA
# ASV1706  Lactobacillales       Streptococcaceae     Streptococcus
# ASV1900  Lactobacillales       Streptococcaceae     Streptococcus
# ASV8536  Bacillales            Family_XI            Gemella
# ASV447   Bacillales            Staphylococcaceae    Staphylococcus
# ASV2180  Bacillales            Planococcaceae       Lysinibacillus
# ASV8061  Selenomonadales       Veillonellaceae      Veillonella
# ASV26    Flavobacteriales      Flavobacteriaceae    Flavobacterium
# ASV2     NA                    NA                   NA
# ASV577   Kallotenuales         NA                   NA
# ASV1002  Kallotenuales         AKIW781              NA
# ASV14332 Propionibacteriales   Propionibacteriaceae Cutibacterium
# ASV4437  Actinomycetales       Actinomycetaceae     Actinomyces
# ASV3225  Micrococcales         Micrococcaceae       Kocuria
# ASV4083  Micrococcales         Intrasporangiaceae   Janibacter
# ASV2962  Corynebacteriales     Corynebacteriaceae   Lawsonella
# ASV41    11-24                 NA                   NA

# %%
ttab["ASV6987",]
# Out:
#         Kingdom  Phylum         Class               Order
# ASV6987 Bacteria Proteobacteria Gammaproteobacteria Xanthomonadales
#         Family           Genus
# ASV6987 Xanthomonadaceae Stenotrophomonas

# %% [markdown]
# # Final contamination removal

# %% [markdown]
# * ASV1 - Remove, serious contam in exp2, only scattered samples in Exp3
# * ASV54 - Remove, only in exp2 and serious contam
# * ASV78 - Remove, plate 2 contaminant, only in exp2
# * ASV136 - Remove, plate 2 contaminant, only in exp2
# * ASV3 - Remove, plate 2 contaminant, also in experiment 1, but only scattered samples in exp3
# * ASV12 - Remove, potential plate 2 contaminant in exp2, but also in exp3.
# * ASV2516 - Remove, EB in 2 and 3, PB in 1,  more prevalent in blanks than samples
# * ASV681 -Remove,  EB in all experiments, no PB, 2nd plate signal in exp2, scattered low biomass samples in exp3
# * ASV447 -  Remove = EB in 2 and 3, single PB in 1, Remove, low biomass signal and prevalent in blanks
# * ASV49 - EB in Exp1, not in any experimental samples
# * ASV12695 - EB in exp 1, not experimental samples except 1CS and 1 RH from exp3
# * ASV2395 - 1 EB in each experiment, three PBs in exp1, scattering of rh and ch from exp 2, no occurrence in ex3 an donly 1
# * ASV284 - EB in exp1, no experimental samples
# * ASV1706- Remove 1 EB in Exp1 and 2, only one sand CH in exp1, some CH and RH in exp2.  Likely a low biomass issue
# * ASV1900 -Remove EB from all experiments, scattered occurrence
# * ASV26 - EB exp 1, no experimental samples
# * ASV14332 -Remove EB and 1PB in exp 1, 2 CH samples in exp 1, not present in exp 2 and 3
# * ASV2962- Remove 1 EB exp1, 1 EB exp2, 2 EB exp3, 1 Ch exp1, 6 Ch and many RH in exp2, some Ch and RH and RS in experiment 35
# * ASV9101 Remove 2 PB in exp1, handful of samples in exp1, no detection in 2 and 3.
# * ASV2180 - Remove 2PB in exp1, only present in 1 sample in exp3, no samples in exp2 and 2 samples in exp1
# * ASV8061 - Remove Two PB in exp1, not present in exp2 or 3
# * ASV4437 - Remove - two PB in exp1, no experimental samples except two in exp2
# * ASV6987 -Remove -  two PB exp 1, three CH samples in exp1, 3 CH samples in exp 2, none in exp3
# * ASV2714  (remove)- 4 EB in exp3, handful of low biomass samples in exp3
# * Asv2160 -(remove)4 eb IN EXP3, only low biomass samples in exp3, slightly more prevalent in Dryden soils, but decided to remove.
# * ASV2117 - Remove 5 EB in exp3, scattered presence in exp2 and only 5 RS samples in exp3
# * ASV2704 - Remove 4 EB in exp3, not in other experiments and only few low biomass samples in exp 3
# * ASV1002 - Remove, 3EB and 2PB in exp 3, no detection in exp1 and 2 no real soil or sample signature, but high abundance in couple BP, one CH
# * ASV4083 - Remove, 3 EB exp 3, no detection in exp 1 and 2, couple low biomass samples in exp3
# * ASV7871- Remove 3 EB in exp 3, no detection in experimental samples
# * ASV1900 - Remove, EB in exp 1, 1 EB in exp2, and 3 eb in exp3, all at low abundance, unlikely to cause issue
# * ASV171 -Remove  2 EB exp3, only 1 sample in exp 2 and four samples in exp 3.  no pattern.
# * ASV2516 - Remove 1PB exp1, 3 EB exp2, 2EB exp3, only 1 CH sample exp1, some CH and RH samples Exp2, only 2 RS samples exp3
# * ASV8536 - Remove 1 EB exp2, 2 EB exp3, barely any experimental samples
# * ASV285 - Remove 2 EB exp2, 2 EB exp3, 1 PB Exp3,  some CH and RH exp2 (not plate specific), no presence in exp3 or 1
# * ASV3225 - Remove 1 EB exp2, 3 EB Exp3, no detection exp1, total of 7 CH and RH in exp2, no detection experiment 3
# * ASV5265 - Remove 2 EB in exp3, not present in other experiments, only three samples in exp3.
# * ASV2962 - Remove EB in exp1, 1 EB in exp2, 2 EB in exp3,   scattered in CH, RH and RS samples throughout
# * ASV14282 - Remove 2 EB exp3, only 1 experimental sample in exp2 and 1 in exp3

# %%
FC = c("ASV1", 
"ASV54" ,
"ASV78", 
"ASV136", 
"ASV3", 
"ASV12",
"ASV2516",
"ASV681", 
"ASV447",
"ASV49", 
"ASV12695", 
"ASV2395", 
"ASV284", 
"ASV1706", 
"ASV1900", 
"ASV26", 
"ASV14332", 
"ASV2962",
"ASV9101",
"ASV2180", 
"ASV8061", 
"ASV4437", 
"ASV6987", 
"ASV2714",
"ASV2160", 
"ASV2117", 
"ASV2704", 
"ASV1002", 
"ASV4083",
"ASV7871", 
"ASV1900", 
"ASV171", 
"ASV2516", 
"ASV8536",
"ASV285", 
"ASV3225", 
"ASV5265", 
"ASV2962", 
"ASV14282")

# %%
ps = readRDS(file = '~/Hyphosphere/data/3Exp/phyloseq/3Exp_phyloseq_thresh_wtree.rds')
ps %>% print()
#remove ASVs in contaminant list

allTaxa = taxa_names(ps)
allTaxa <- allTaxa[!(allTaxa %in% FC)]
ps.sub = prune_taxa(allTaxa, ps)
# new phyloseq object with just the taxa you kept.
ps.sub
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 15434 taxa and 435 samples ]
# sample_data() Sample Data:       [ 435 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 15434 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 15434 tips and 15394 internal nodes ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 15398 taxa and 435 samples ]
# sample_data() Sample Data:       [ 435 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 15398 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 15398 tips and 15358 internal nodes ]

# %%
ps.snorm = transform_sample_counts(ps, function(x) x/sum(x))
ps.sub.snorm = transform_sample_counts(ps.sub, function(x) x/sum(x))

# remove control samples
ps.snorm = ps.snorm %>% subset_samples(!SampleType %in% c("EB", "PB", "MK", "T0"))
ps.sub.snorm = ps.sub.snorm %>% subset_samples(!SampleType %in% c("EB", "PB", "MK", "T0"))

# %%
ordu = ordinate(ps.snorm, "PCoA", "bray")
p = plot_ordination(ps.snorm, ordu, justDF = TRUE)
plot_ordination(ps.snorm, ordu)
# Out:
# plot without title

# %%
ordu.sub = ordinate(ps.sub.snorm, "PCoA", "bray")
p.sub = plot_ordination(ps.sub.snorm, ordu.sub, justDF = TRUE)
plot_ordination(ps.sub.snorm, ordu.sub)
# Out:
# plot without title

# %%
library(RColorBrewer)
cs = brewer.pal(10,"Set3")
p1 = ggplot(p, aes(x = Axis.1, y = Axis.2)) +
geom_point(aes(fill = SampleType, shape = as.factor(Experiment)), size = 2) +
facet_wrap(~Soil)+
#theme_pub() +

scale_shape_manual(values=c(21,22,23), guide = guide_legend(title = "Experiment", ncol = 1))+
scale_fill_manual(values = cs)+
labs(x = "PCoA 1 [30.4%]", y = "PCoA 2 [17.1%]") +

guides(fill=guide_legend(override.aes=list(colour= cs), ncol = 3)) + 
theme(legend.position="right") 

#color = "grey20",
p1

p2 = ggplot(p.sub, aes(x = Axis.1, y = Axis.2)) +
geom_point(aes(fill = SampleType, shape = as.factor(Experiment)), size = 2) +
facet_wrap(~Soil)+
#theme_pub() +

scale_shape_manual(values=c(21,22,23), guide = guide_legend(title = "Experiment", ncol = 1))+
scale_fill_manual(values = cs)+
labs(x = "PCoA 1 [30.4%]", y = "PCoA 2 [17.1%]") +

guides(fill=guide_legend(override.aes=list(colour= cs), ncol = 3)) + 
theme(legend.position="right") 

#color = "grey20",
grid.arrange(p1, p2, ncol =1)
# Out:
# plot without title
# plot without title

# %%
library(RColorBrewer)
cs = brewer.pal(10,"Set3")
p1 = ggplot(p, aes(x = Axis.1, y = Axis.2)) +
geom_point(aes(fill = SampleType, shape = as.factor(Soil)), size = 2) +
facet_wrap(~Experiment)+
#theme_pub() +

scale_shape_manual(values=c(21,22,23,24, 25), guide = guide_legend(title = "Experiment", ncol = 1))+
scale_fill_manual(values = cs)+
labs(x = "PCoA 1 [30.4%]", y = "PCoA 2 [17.1%]") +

guides(fill=guide_legend(override.aes=list(colour= cs), ncol = 3)) + 
theme(legend.position="right") 

#color = "grey20",


p2 = ggplot(p.sub, aes(x = Axis.1, y = Axis.2)) +
geom_point(aes(fill = SampleType, shape = as.factor(Soil)), size = 2) +
facet_wrap(~Experiment)+
#theme_pub() +

scale_shape_manual(values=c(21,22,23, 24, 25), guide = guide_legend(title = "Experiment", ncol = 1))+
scale_fill_manual(values = cs)+
labs(x = "PCoA 1 [30.4%]", y = "PCoA 2 [17.1%]") +

guides(fill=guide_legend(override.aes=list(colour= cs), ncol = 3)) + 
theme(legend.position="right") 

#color = "grey20",
grid.arrange(p1, p2, ncol =1)
# Out:
# plot without title

# %% [markdown]
# ## Closer look at exp 2

# %%
ps2 = ps.snorm %>% subset_samples(., Experiment == 2)
ps2.sub = ps.sub.snorm %>% subset_samples(., Experiment == 2)

ordu2 = ordinate(ps2, "PCoA", "bray")
p2 = plot_ordination(ps2, ordu2, justDF = TRUE)


ordu2.sub = ordinate(ps2.sub, "PCoA", "bray")
p2.sub = plot_ordination(ps2.sub, ordu2.sub, justDF = TRUE)

# %%
library(RColorBrewer)
cs = brewer.pal(7,"Set3")
p1 = ggplot(p2, aes(x = Axis.1, y = Axis.2)) +
geom_point(aes(fill = as.factor(Rep)), shape = 21, size = 2) +
facet_wrap(~SampleType)+
#theme_pub() +

#scale_shape_manual(values=c(21,22,23,24, 25), guide = guide_legend(title = "Experiment", ncol = 1))+
scale_fill_manual(values = cs)+
labs(x = "PCoA 1 [30.4%]", y = "PCoA 2 [17.1%]") +

guides(fill=guide_legend(override.aes=list(colour= cs), ncol = 3)) + 
theme(legend.position="right") 

#color = "grey20",


p2 = ggplot(p2.sub, aes(x = Axis.1, y = Axis.2)) +
geom_point(aes(fill = as.factor(Rep)), shape = 21, size = 2) +
facet_wrap(~SampleType)+
#theme_pub() +

#scale_shape_manual(values=c(21,22,23, 24, 25), guide = guide_legend(title = "Experiment", ncol = 1))+
scale_fill_manual(values = cs)+
labs(x = "PCoA 1 [30.4%]", y = "PCoA 2 [17.1%]") +

guides(fill=guide_legend(override.aes=list(colour= cs), ncol = 3)) + 
theme(legend.position="right") 

#color = "grey20",
grid.arrange(p1, p2, ncol =1)
# Out:
# plot without title

# %%
ps2.sub %>% 
    subset_samples(SampleType == "GV") %>% 
    filter_taxa(., function(x) sum(x > 0) > 0, TRUE) %>% 
            psmelt() %>% 
            arrange(desc(Abundance))
# Out:
# Warning message in psmelt(.):
# “The sample variables:
# Sample
#  have been renamed to:
# sample_Sample
# to avoid conflicts with special phyloseq plot attribute names.”
#     OTU      Sample       Abundance    sample_Sample Experiment Plant Fungus
# 1   ASV7     152_GvSpores 0.071095312  GvSpores      2                Gv
# 2   ASV2     152_GvSpores 0.041324150  GvSpores      2                Gv
# 3   ASV10    152_GvSpores 0.033548100  GvSpores      2                Gv
# 4   ASV34    152_GvSpores 0.016885137  GvSpores      2                Gv
# 5   ASV58    152_GvSpores 0.013552544  GvSpores      2                Gv
# 6   ASV109   152_GvSpores 0.012441680  GvSpores      2                Gv
# 7   ASV148   152_GvSpores 0.011330815  GvSpores      2                Gv
# 8   ASV77    152_GvSpores 0.010886470  GvSpores      2                Gv
# 9   ASV68    152_GvSpores 0.009997778  GvSpores      2                Gv
# 10  ASV381   152_GvSpores 0.008442568  GvSpores      2                Gv
# 11  ASV4     152_GvSpores 0.007998223  GvSpores      2                Gv
# 12  ASV8     152_GvSpores 0.007998223  GvSpores      2                Gv
# 13  ASV55    152_GvSpores 0.007553877  GvSpores      2                Gv
# 14  ASV235   152_GvSpores 0.007331704  GvSpores      2                Gv
# 15  ASV538   152_GvSpores 0.007109531  GvSpores      2                Gv
# 16  ASV828   152_GvSpores 0.006665186  GvSpores      2                Gv
# 17  ASV1621  152_GvSpores 0.006220840  GvSpores      2                Gv
# 18  ASV219   152_GvSpores 0.006220840  GvSpores      2                Gv
# 19  ASV24    152_GvSpores 0.006220840  GvSpores      2                Gv
# 20  ASV273   152_GvSpores 0.006220840  GvSpores      2                Gv
# 21  ASV80    152_GvSpores 0.006220840  GvSpores      2                Gv
# 22  ASV1636  152_GvSpores 0.005998667  GvSpores      2                Gv
# 23  ASV323   152_GvSpores 0.005998667  GvSpores      2                Gv
# 24  ASV230   152_GvSpores 0.005776494  GvSpores      2                Gv
# 25  ASV5189  152_GvSpores 0.005776494  GvSpores      2                Gv
# 26  ASV16    152_GvSpores 0.005554321  GvSpores      2                Gv
# 27  ASV249   152_GvSpores 0.005554321  GvSpores      2                Gv
# 28  ASV472   152_GvSpores 0.005554321  GvSpores      2                Gv
# 29  ASV5     152_GvSpores 0.005554321  GvSpores      2                Gv
# 30  ASV234   152_GvSpores 0.005332148  GvSpores      2                Gv
# ⋮   ⋮        ⋮            ⋮            ⋮             ⋮          ⋮     ⋮
# 265 ASV184   152_GvSpores 0.0011108643 GvSpores      2                Gv
# 266 ASV2090  152_GvSpores 0.0011108643 GvSpores      2                Gv
# 267 ASV2809  152_GvSpores 0.0011108643 GvSpores      2                Gv
# 268 ASV3951  152_GvSpores 0.0011108643 GvSpores      2                Gv
# 269 ASV41    152_GvSpores 0.0011108643 GvSpores      2                Gv
# 270 ASV5119  152_GvSpores 0.0011108643 GvSpores      2                Gv
# 271 ASV549   152_GvSpores 0.0011108643 GvSpores      2                Gv
# 272 ASV8938  152_GvSpores 0.0011108643 GvSpores      2                Gv
# 273 ASV1061  152_GvSpores 0.0008886914 GvSpores      2                Gv
# 274 ASV10808 152_GvSpores 0.0008886914 GvSpores      2                Gv
# 275 ASV13946 152_GvSpores 0.0008886914 GvSpores      2                Gv
# 276 ASV1702  152_GvSpores 0.0008886914 GvSpores      2                Gv
# 277 ASV1986  152_GvSpores 0.0008886914 GvSpores      2                Gv
# 278 ASV2407  152_GvSpores 0.0008886914 GvSpores      2                Gv
# 279 ASV3072  152_GvSpores 0.0008886914 GvSpores      2                Gv
# 280 ASV327   152_GvSpores 0.0008886914 GvSpores      2                Gv
# 281 ASV3423  152_GvSpores 0.0008886914 GvSpores      2                Gv
# 282 ASV3971  152_GvSpores 0.0008886914 GvSpores      2                Gv
# 283 ASV43    152_GvSpores 0.0008886914 GvSpores      2                Gv
# 284 ASV4414  152_GvSpores 0.0008886914 GvSpores      2                Gv
# 285 ASV5186  152_GvSpores 0.0008886914 GvSpores      2                Gv
# 286 ASV9694  152_GvSpores 0.0008886914 GvSpores      2                Gv
# 287 ASV9996  152_GvSpores 0.0008886914 GvSpores      2                Gv
# 288 ASV1648  152_GvSpores 0.0006665186 GvSpores      2                Gv
# 289 ASV6297  152_GvSpores 0.0006665186 GvSpores      2                Gv
# 290 ASV8282  152_GvSpores 0.0006665186 GvSpores      2                Gv
# 291 ASV5375  152_GvSpores 0.0004443457 GvSpores      2                Gv
# 292 ASV8189  152_GvSpores 0.0004443457 GvSpores      2                Gv
# 293 ASV8439  152_GvSpores 0.0004443457 GvSpores      2                Gv
# 294 ASV1999  152_GvSpores 0.0002221729 GvSpores      2                Gv
#     Soil SampleType Treatment TimePoint DAI Rep Concentration_ng.ul Kingdom
# 1        GV                   NA        NA  NA  0.101               Bacteria
# 2        GV                   NA        NA  NA  0.101               Bacteria
# 3        GV                   NA        NA  NA  0.101               Bacteria
# 4        GV                   NA        NA  NA  0.101               Bacteria
# 5        GV                   NA        NA  NA  0.101               Bacteria
# 6        GV                   NA        NA  NA  0.101               Bacteria
# 7        GV                   NA        NA  NA  0.101               Bacteria
# 8        GV                   NA        NA  NA  0.101               Bacteria
# 9        GV                   NA        NA  NA  0.101               Bacteria
# 10       GV                   NA        NA  NA  0.101               Bacteria
# 11       GV                   NA        NA  NA  0.101               Bacteria
# 12       GV                   NA        NA  NA  0.101               Bacteria
# 13       GV                   NA        NA  NA  0.101               Bacteria
# 14       GV                   NA        NA  NA  0.101               Bacteria
# 15       GV                   NA        NA  NA  0.101               Bacteria
# 16       GV                   NA        NA  NA  0.101               Bacteria
# 17       GV                   NA        NA  NA  0.101               Bacteria
# 18       GV                   NA        NA  NA  0.101               Bacteria
# 19       GV                   NA        NA  NA  0.101               Bacteria
# 20       GV                   NA        NA  NA  0.101               Bacteria
# 21       GV                   NA        NA  NA  0.101               Bacteria
# 22       GV                   NA        NA  NA  0.101               Bacteria
# 23       GV                   NA        NA  NA  0.101               Bacteria
# 24       GV                   NA        NA  NA  0.101               Bacteria
# 25       GV                   NA        NA  NA  0.101               Bacteria
# 26       GV                   NA        NA  NA  0.101               Bacteria
# 27       GV                   NA        NA  NA  0.101               Bacteria
# 28       GV                   NA        NA  NA  0.101               Bacteria
# 29       GV                   NA        NA  NA  0.101               Bacteria
# 30       GV                   NA        NA  NA  0.101               Bacteria
# ⋮   ⋮    ⋮          ⋮         ⋮         ⋮   ⋮   ⋮                   ⋮
# 265      GV                   NA        NA  NA  0.101               Bacteria
# 266      GV                   NA        NA  NA  0.101               Bacteria
# 267      GV                   NA        NA  NA  0.101               Bacteria
# 268      GV                   NA        NA  NA  0.101               Bacteria
# 269      GV                   NA        NA  NA  0.101               Bacteria
# 270      GV                   NA        NA  NA  0.101               Bacteria
# 271      GV                   NA        NA  NA  0.101               Bacteria
# 272      GV                   NA        NA  NA  0.101               Bacteria
# 273      GV                   NA        NA  NA  0.101               Bacteria
# 274      GV                   NA        NA  NA  0.101               Bacteria
# 275      GV                   NA        NA  NA  0.101               Bacteria
# 276      GV                   NA        NA  NA  0.101               Bacteria
# 277      GV                   NA        NA  NA  0.101               Bacteria
# 278      GV                   NA        NA  NA  0.101               Bacteria
# 279      GV                   NA        NA  NA  0.101               Bacteria
# 280      GV                   NA        NA  NA  0.101               Bacteria
# 281      GV                   NA        NA  NA  0.101               Bacteria
# 282      GV                   NA        NA  NA  0.101               Bacteria
# 283      GV                   NA        NA  NA  0.101               Bacteria
# 284      GV                   NA        NA  NA  0.101               Bacteria
# 285      GV                   NA        NA  NA  0.101               Bacteria
# 286      GV                   NA        NA  NA  0.101               Bacteria
# 287      GV                   NA        NA  NA  0.101               Bacteria
# 288      GV                   NA        NA  NA  0.101               Bacteria
# 289      GV                   NA        NA  NA  0.101               Bacteria
# 290      GV                   NA        NA  NA  0.101               Bacteria
# 291      GV                   NA        NA  NA  0.101               Bacteria
# 292      GV                   NA        NA  NA  0.101               Bacteria
# 293      GV                   NA        NA  NA  0.101               Bacteria
# 294      GV                   NA        NA  NA  0.101               Bacteria
#     Phylum           Class
# 1   Proteobacteria   Alphaproteobacteria
# 2   NA               NA
# 3   Cyanobacteria    Oxyphotobacteria
# 4   Proteobacteria   Gammaproteobacteria
# 5   Acidobacteria    Subgroup_6
# 6   Verrucomicrobia  Verrucomicrobiae
# 7   Proteobacteria   Gammaproteobacteria
# 8   Proteobacteria   Gammaproteobacteria
# 9   Bacteroidetes    Bacteroidia
# 10  Verrucomicrobia  Verrucomicrobiae
# 11  NA               NA
# 12  Proteobacteria   Alphaproteobacteria
# 13  Verrucomicrobia  Verrucomicrobiae
# 14  Acidobacteria    Subgroup_6
# 15  Cyanobacteria    Oxyphotobacteria
# 16  Acidobacteria    Subgroup_6
# 17  Bacteroidetes    Bacteroidia
# 18  Acidobacteria    Holophagae
# 19  Nitrospirae      Nitrospira
# 20  Acidobacteria    Subgroup_6
# 21  Proteobacteria   Deltaproteobacteria
# 22  Proteobacteria   Gammaproteobacteria
# 23  Rokubacteria     NC10
# 24  Verrucomicrobia  Verrucomicrobiae
# 25  Acidobacteria    Subgroup_6
# 26  Proteobacteria   Alphaproteobacteria
# 27  Proteobacteria   Gammaproteobacteria
# 28  Bacteroidetes    Bacteroidia
# 29  Actinobacteria   Actinobacteria
# 30  Proteobacteria   Gammaproteobacteria
# ⋮   ⋮                ⋮
# 265 Acidobacteria    Subgroup_11
# 266 Acidobacteria    Subgroup_6
# 267 Planctomycetes   Phycisphaerae
# 268 Acidobacteria    Blastocatellia_(Subgroup_4)
# 269 Acidobacteria    Blastocatellia_(Subgroup_4)
# 270 Proteobacteria   Deltaproteobacteria
# 271 Proteobacteria   Deltaproteobacteria
# 272 Planctomycetes   Phycisphaerae
# 273 Bacteroidetes    Bacteroidia
# 274 Proteobacteria   Deltaproteobacteria
# 275 Dependentiae     Babeliae
# 276 Actinobacteria   Acidimicrobiia
# 277 Proteobacteria   Gammaproteobacteria
# 278 Bacteroidetes    Bacteroidia
# 279 Gemmatimonadetes S0134_terrestrial_group
# 280 Proteobacteria   Gammaproteobacteria
# 281 Proteobacteria   Deltaproteobacteria
# 282 Acidobacteria    Acidobacteriia
# 283 Proteobacteria   Alphaproteobacteria
# 284 Bacteroidetes    Bacteroidia
# 285 Proteobacteria   Alphaproteobacteria
# 286 Proteobacteria   Alphaproteobacteria
# 287 Acidobacteria    Subgroup_17
# 288 Proteobacteria   Gammaproteobacteria
# 289 Planctomycetes   Planctomycetacia
# 290 Gemmatimonadetes S0134_terrestrial_group
# 291 Proteobacteria   Gammaproteobacteria
# 292 Planctomycetes   vadinHA49
# 293 Bacteroidetes    Bacteroidia
# 294 Acidobacteria    Subgroup_6
#     Order                              Family
# 1   Rickettsiales                      Mitochondria
# 2   NA                                 NA
# 3   Chloroplast                        NA
# 4   Betaproteobacteriales              Burkholderiaceae
# 5   NA                                 NA
# 6   Pedosphaerales                     Pedosphaeraceae
# 7   Betaproteobacteriales              Burkholderiaceae
# 8   Gammaproteobacteria_Incertae_Sedis Unknown_Family
# 9   Cytophagales                       Microscillaceae
# 10  Pedosphaerales                     Pedosphaeraceae
# 11  NA                                 NA
# 12  Caulobacterales                    Caulobacteraceae
# 13  Chthoniobacterales                 Chthoniobacteraceae
# 14  NA                                 NA
# 15  Chloroplast                        NA
# 16  NA                                 NA
# 17  Chitinophagales                    Chitinophagaceae
# 18  Subgroup_7                         NA
# 19  Nitrospirales                      Nitrospiraceae
# 20  NA                                 NA
# 21  Myxococcales                       BIrii41
# 22  Betaproteobacteriales              Burkholderiaceae
# 23  Rokubacteriales                    NA
# 24  Chthoniobacterales                 Chthoniobacteraceae
# 25  NA                                 NA
# 26  Rhizobiales                        Xanthobacteraceae
# 27  Betaproteobacteriales              Nitrosomonadaceae
# 28  Chitinophagales                    Chitinophagaceae
# 29  Micrococcales                      Micrococcaceae
# 30  Betaproteobacteriales              Nitrosomonadaceae
# ⋮   ⋮                                  ⋮
# 265 NA                                 NA
# 266 NA                                 NA
# 267 Tepidisphaerales                   WD2101_soil_group
# 268 Pyrinomonadales                    Pyrinomonadaceae
# 269 11-24                              NA
# 270 Myxococcales                       MSB-4B10
# 271 Bdellovibrionales                  Bacteriovoracaceae
# 272 Phycisphaerales                    Phycisphaeraceae
# 273 Cytophagales                       Spirosomaceae
# 274 Myxococcales                       Polyangiaceae
# 275 Babeliales                         NA
# 276 Microtrichales                     NA
# 277 Pseudomonadales                    Moraxellaceae
# 278 Chitinophagales                    Chitinophagaceae
# 279 NA                                 NA
# 280 Betaproteobacteriales              Burkholderiaceae
# 281 Myxococcales                       Sandaracinaceae
# 282 Solibacterales                     Solibacteraceae_(Subgroup_3)
# 283 Caulobacterales                    Caulobacteraceae
# 284 Chitinophagales                    Chitinophagaceae
# 285 NA                                 NA
# 286 Elsterales                         NA
# 287 NA                                 NA
# 288 NA                                 NA
# 289 Pirellulales                       Pirellulaceae
# 290 NA                                 NA
# 291 Xanthomonadales                    Xanthomonadaceae
# 292 NA                                 NA
# 293 Bacteroidetes_VC2.1_Bac22          NA
# 294 NA                                 NA
#     Genus
# 1   NA
# 2   NA
# 3   NA
# 4   Delftia
# 5   NA
# 6   NA
# 7   Ideonella
# 8   Acidibacter
# 9   NA
# 10  ADurb.Bin063-1
# 11  NA
# 12  Asticcacaulis
# 13  Candidatus_Udaeobacter
# 14  NA
# 15  NA
# 16  NA
# 17  Terrimonas
# 18  NA
# 19  Nitrospira
# 20  NA
# 21  NA
# 22  NA
# 23  NA
# 24  Candidatus_Udaeobacter
# 25  NA
# 26  Bradyrhizobium
# 27  IS-44
# 28  NA
# 29  Pseudarthrobacter
# 30  MND1
# ⋮   ⋮
# 265 NA
# 266 NA
# 267 NA
# 268 RB41
# 269 NA
# 270 NA
# 271 Bacteriovorax
# 272 SM1A02
# 273 Larkinella
# 274 Pajaroellobacter
# 275 NA
# 276 NA
# 277 Enhydrobacter
# 278 NA
# 279 NA
# 280 Xylophilus
# 281 NA
# 282 Paludibaculum
# 283 Caulobacter
# 284 Niabella
# 285 NA
# 286 NA
# 287 NA
# 288 NA
# 289 NA
# 290 NA
# 291 Lysobacter
# 292 NA
# 293 NA
# 294 NA

# %% [markdown]
# # Save phyloseq objects without contaminants

# %%
ps.sub
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 15398 taxa and 435 samples ]
# sample_data() Sample Data:       [ 435 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 15398 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 15398 tips and 15358 internal nodes ]

# %%
ps.sub %>% prune_taxa(c("X90478", "ASV1000"),.)
# Out:
# Warning message in prune_taxa(taxa, phy_tree(x)):
# “prune_taxa attempted to reduce tree to 1 or fewer tips.
#  tree replaced with NULL.”
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1 taxa and 435 samples ]
# sample_data() Sample Data:       [ 435 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 1 taxa by 6 taxonomic ranks ]

# %%
sample_sums(ps.sub)[1:10]
# Out:
# 10xBLS156_S303  2xBLS143_S297  5xBLS120_S300     BaseA_S310     BaseB_S291
#          40949          19771          20990          19392          14726
#     BaseC_S294     HCBF1_S247     HCBF2_S259     HCBF3_S271     HCBN1_S211
#          19864          17655          13876          22576          22450

# %%
#remove mitochondria
ps.sub2 = subset_taxa(ps.sub, Family != "Mitochondria" | is.na(Family))
ps.sub2 = subset_taxa(ps.sub, Order != "Chloroplast" | is.na(Order))
ps.sub2
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 15364 taxa and 435 samples ]
# sample_data() Sample Data:       [ 435 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 15364 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 15364 tips and 15324 internal nodes ]

# %%
saveRDS(ps.sub2, file = '~/Hyphosphere/3exp_phyloseq_thresh_nocontam.rds')

# %%
sessionInfo()
# Out:
# R version 3.5.1 (2018-07-02)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 16.04.6 LTS
#
# Matrix products: default
# BLAS/LAPACK: /data/home/be68/anaconda3/envs/MyR/lib/R/lib/libRblas.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] RColorBrewer_1.1-2 bindrcpp_0.2.2     ggplot2_3.0.0      gridExtra_2.3
#  [5] phyloseq_1.26.1    reshape2_1.4.3     dplyr_0.7.6        tidyr_0.8.1
#  [9] dada2_1.10.0       Rcpp_0.12.18
#
# loaded via a namespace (and not attached):
#  [1] Biobase_2.42.0              splines_3.5.1
#  [3] jsonlite_1.5                foreach_1.4.4
#  [5] RcppParallel_4.4.2          assertthat_0.2.0
#  [7] stats4_3.5.1                latticeExtra_0.6-28
#  [9] GenomeInfoDbData_1.2.1      Rsamtools_1.34.0
# [11] pillar_1.3.0                lattice_0.20-35
# [13] glue_1.3.0                  uuid_0.1-2
# [15] digest_0.6.15               GenomicRanges_1.34.0
# [17] XVector_0.22.0              colorspace_1.3-2
# [19] htmltools_0.3.6             Matrix_1.2-14
# [21] plyr_1.8.4                  pkgconfig_2.0.1
# [23] ShortRead_1.40.0            zlibbioc_1.28.0
# [25] purrr_0.2.5                 scales_0.5.0
# [27] BiocParallel_1.16.6         tibble_1.4.2
# [29] mgcv_1.8-24                 IRanges_2.16.0
# [31] withr_2.1.2                 SummarizedExperiment_1.12.0
# [33] repr_0.15.0                 BiocGenerics_0.28.0
# [35] lazyeval_0.2.1              survival_2.42-6
# [37] magrittr_1.5                crayon_1.3.4
# [39] evaluate_0.11               nlme_3.1-137
# [41] MASS_7.3-50                 hwriter_1.3.2
# [43] vegan_2.5-4                 tools_3.5.1
# [45] data.table_1.11.4           matrixStats_0.54.0
# [47] stringr_1.3.1               Rhdf5lib_1.4.3
# [49] S4Vectors_0.20.1            munsell_0.5.0
# [51] cluster_2.0.7-1             DelayedArray_0.8.0
# [53] Biostrings_2.50.2           ade4_1.7-13
# [55] compiler_3.5.1              GenomeInfoDb_1.18.1
# [57] rlang_0.2.1                 rhdf5_2.26.2
# [59] grid_3.5.1                  RCurl_1.95-4.12
# [61] pbdZMQ_0.3-3                iterators_1.0.10
# [63] IRkernel_0.8.12             biomformat_1.10.1
# [65] igraph_1.2.4.1              labeling_0.3
# [67] bitops_1.0-6                base64enc_0.1-3
# [69] multtest_2.38.0             gtable_0.2.0
# [71] codetools_0.2-15            R6_2.2.2
# [73] GenomicAlignments_1.18.1    bindr_0.1.1
# [75] permute_0.9-5               ape_5.3
# [77] stringi_1.2.4               parallel_3.5.1
# [79] IRdisplay_0.5.0             tidyselect_0.2.4

# %% [markdown]
# # just a test

# %%
#removes Mollicute related endobacteria
physeq.Full = ps.sub
physeq.Full = subset_taxa(physeq.Full, !is.na(Phylum))
physeq.Full

#Subset experiment 1
physeq.exp1 = subset_samples(physeq.Full, Experiment == 1 & !SampleType %in% c("MK", "PB", "EB"))
physeq.exp1 = transform_sample_counts(physeq.exp1, function(x) x/sum(x))
physeq.exp1
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 15055 taxa and 435 samples ]
# sample_data() Sample Data:       [ 435 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 15055 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 15055 tips and 15015 internal nodes ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 15055 taxa and 36 samples ]
# sample_data() Sample Data:       [ 36 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 15055 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 15055 tips and 15015 internal nodes ]

# %%
tmp = physeq.exp1 %>% filter_taxa(., function(x) sum(x > 0) > 0, TRUE)
                                  tmp
twunif.dist = phyloseq::distance(tmp, 
                      method = "unifrac", 
                      weighted = TRUE,
                      fast = TRUE, 
                      parallel = FALSE, 
                      normalized = FALSE)
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4572 taxa and 36 samples ]
# sample_data() Sample Data:       [ 36 samples by 11 sample variables ]
# tax_table()   Taxonomy Table:    [ 4572 taxa by 6 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4572 tips and 4568 internal nodes ]
# Warning message in matrix(tree$edge[order(tree$edge[, 1]), ][, 2], byrow = TRUE, :
# “data length [9139] is not a sub-multiple or multiple of the number of rows [4570]”

# %%
ape::is.rooted(phy_tree(tmp))
# Out:
# [1] TRUE

# %%
root.by.outgroup <- function(tree.unrooted) {
  longest.edge <- which.max(tree.unrooted$edge.length)
  long.nodes <- tree.unrooted$edge[longest.edge,]     #this should usually include one tip
  new.outgroup <- long.nodes[long.nodes < Ntip(tree.unrooted)]
  tree.rooted <- root(tree.unrooted, outgroup=new.outgroup, resolve.root=T)
  tree.rooted
}

# %%
require(ape)
new_tree = root.by.outgroup(phy_tree(tmp))
phy_tree(tmp) = new_tree

# %%
twunif.dist = phyloseq::distance(tmp, 
                      method = "unifrac", 
                      weighted = TRUE,
                      fast = TRUE, 
                      parallel = FALSE, 
                      normalized = FALSE)
# Out:
# Warning message in matrix(tree$edge[order(tree$edge[, 1]), ][, 2], byrow = TRUE, :
# “data length [9139] is not a sub-multiple or multiple of the number of rows [4570]”
