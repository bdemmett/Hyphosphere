# %% [markdown]
# # DADA2 pipeline for Hyphosphere Exp 1

# %% [markdown]
# * Need to define for each dataset
# ** Number of cores
# ** OutFolder
# ** Path to sequence directory

# %%
ncores = 20

# %%
library(dada2)
library(tidyr)
library(dplyr)
# Out:
# Loading required package: Rcpp
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
seqDIR = '~/Hyphosphere/data/MiSeq/20180129/raw'
path = seqDIR

#location of taxonomy database
TrainingSet = '~/databases/silva_nr_v132_train_set.fa.gz'
SpeciesTraining = '~/databases/silva_species_assignment_v132.fa.gz'

# Sample data table
SamTab = '~/Hyphosphere/Exp1/sample_data.txt'

# output folder
OutFolder = '~/Hyphosphere/data/Exp1/DADA2Files'

# %% [markdown]
# # Filter and trim

# %%
#Collect forward and reverse names in order
fastqFs <- sort(list.files(path, pattern=".R1_001.fastq"))
fastqRs <- sort(list.files(path, pattern=".R2_001.fastq"))
if(length(fastqFs) != length(fastqRs)) stop("Forward and reverse files do not match.")

# %%
#sample.names

# %% [markdown]
# ## Plot quality profiles of forward and reverse reads

# %%
plotQualityProfile(file.path(path,fastqFs[17:18]))
# Out:
# plot without title

# %% [markdown]
# * Foward reads look very good.  Truncate to 220

# %%
plotQualityProfile(file.path(path,fastqRs[17:18]))
# Out:
# plot without title

# %% [markdown]
# # Perform filtering and trimming

# %%
filtpathF <- file.path(path, "filtered_F") # Filtered forward files go into the pathF/filtered/ subdirectory
filtpathR <- file.path(path, "filtered_R") # ...

# %% [markdown]
# * Note that primers remain on sequences from UMGC, so trimLeft(19,20) is included in this dataset

# %%
# Filtering: THESE PARAMETERS ARENT OPTIMAL FOR ALL DATASETS
out = filterAndTrim(fwd=file.path(path, fastqFs), filt=file.path(filtpathF, fastqFs),
              rev=file.path(path, fastqRs), filt.rev=file.path(filtpathR, fastqRs),
              truncLen=c(210,125), maxEE=2, truncQ=2, maxN=0, rm.phix=TRUE, trimLeft=c(19,20),
              compress=TRUE, verbose=TRUE, multithread=ncores)

# %%
head(out)
# Out:
#                             reads.in reads.out
# 10xBLS156_S303_R1_001.fastq 76535    71931
# 2xBLS143_S297_R1_001.fastq  46036    42761
# 5xBLS120_S300_R1_001.fastq  58139    52793
# BartHigh_S258_R1_001.fastq  50441    46587
# BartLow_S270_R1_001.fastq   59500    56642
# BaseA_S310_R1_001.fastq     43371    40476

# %%
filtFs <- list.files(filtpathF, pattern=".fastq", full.names = TRUE)
filtRs <- list.files(filtpathR, pattern=".fastq", full.names = TRUE)
sample.names <- sapply(strsplit(basename(filtFs), "_R1_001.fastq"), `[`, 1) # Assumes filename = samplename_XXX.fastq.gz
sample.namesR <- sapply(strsplit(basename(filtRs), "_R2_001.fastq"), `[`, 1) # Assumes filename = samplename_XXX.fastq.gz
if(!identical(sample.names, sample.namesR)) stop("Forward and reverse files do not match.")
names(filtFs) <- sample.names
names(filtRs) <- sample.names
sample.names
# Out:
#  [1] "10xBLS156_S303"        "2xBLS143_S297"         "5xBLS120_S300"
#  [4] "BartHigh_S258"         "BartLow_S270"          "BaseA_S310"
#  [7] "BaseB_S291"            "BaseC_S294"            "HCBF1_S247"
# [10] "HCBF2_S259"            "HCBF3_S271"            "HCBN1_S211"
# [13] "HCBN2_S223"            "HCBN3_S235"            "HCBP1_S283"
# [16] "HCBP2_S200"            "HCBP3_S212"            "HCBS1_S224"
# [19] "HCBS2_S236"            "HCBS3_S248"            "HCHF1_S250"
# [22] "HCHF2_S262"            "HCHF3_S274"            "HCHN1_S214"
# [25] "HCHN2_S226"            "HCHN3_S238"            "HCHP1_S286"
# [28] "HCHP2_S203"            "HCHP3_S215"            "HCHS1_S227"
# [31] "HCHS2_S239"            "HCHS3_S251"            "HCRF1_S201"
# [34] "HCRF2_S213"            "HCRF3_S225"            "HCRN1_S260"
# [37] "HCRN2_S272"            "HCRN3_S284"            "HCRP1_S237"
# [40] "HCRP2_S249"            "HCRP3_S261"            "HCRS1_S273"
# [43] "HCRS2_S285"            "HCRS3_S202"            "Hneg1_S263"
# [46] "NegativeH2O_S282"      "UMGC_H2O_001_A04_S4"   "UMGC_H2O_001_A06_S6"
# [49] "UMGC_H2O_002_B04_S112" "UMGC_H2O_002_B06_S114" "UMGC_H2O_003_A07_S199"
# [52] "UMGC_H2O_003_G11_S275" "UMGC_H2O_004_F03_S306"

# %% [markdown]
# ## Learn errors

# %%
set.seed(100)
# Learn forward error rates
errF <- learnErrors(filtFs, multithread=ncores)
# Learn reverse error rates
errR <- learnErrors(filtRs, multithread=ncores)
# Out:
# 106239166 total bases in 556226 reads from 13 samples will be used for learning the error rates.
# 102272730 total bases in 974026 reads from 27 samples will be used for learning the error rates.

# %%
plotErrors(errF)
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# plot without title

# %% [markdown]
# ## Sequence inference

# %%
# Sample inference and merger of paired-end reads
mergers <- vector("list", length(sample.names))
names(mergers) <- sample.names
for(sam in sample.names) {
  cat("Processing:", sam, "\n")
    derepF <- derepFastq(filtFs[[sam]])
    ddF <- dada(derepF, err=errF, multithread=ncores)
    derepR <- derepFastq(filtRs[[sam]])
    ddR <- dada(derepR, err=errR, multithread=ncores)
    merger <- mergePairs(ddF, derepF, ddR, derepR)
    mergers[[sam]] <- merger
}
rm(derepF); rm(derepR)
# Out:
# Processing: 10xBLS156_S303
# Sample 1 - 71931 reads in 11265 unique sequences.
# Sample 1 - 71931 reads in 6762 unique sequences.
# Processing: 2xBLS143_S297
# Sample 1 - 42761 reads in 7534 unique sequences.
# Sample 1 - 42761 reads in 4342 unique sequences.
# Processing: 5xBLS120_S300
# Sample 1 - 52793 reads in 9383 unique sequences.
# Sample 1 - 52793 reads in 4211 unique sequences.
# Processing: BartHigh_S258
# Sample 1 - 46587 reads in 10683 unique sequences.
# Sample 1 - 46587 reads in 3929 unique sequences.
# Processing: BartLow_S270
# Sample 1 - 56642 reads in 11019 unique sequences.
# Sample 1 - 56642 reads in 5844 unique sequences.
# Processing: BaseA_S310
# Sample 1 - 40476 reads in 7237 unique sequences.
# Sample 1 - 40476 reads in 4083 unique sequences.
# Processing: BaseB_S291
# Sample 1 - 31658 reads in 6327 unique sequences.
# Sample 1 - 31658 reads in 2577 unique sequences.
# Processing: BaseC_S294
# Sample 1 - 42044 reads in 7723 unique sequences.
# Sample 1 - 42044 reads in 4805 unique sequences.
# Processing: HCBF1_S247
# Sample 1 - 27657 reads in 8621 unique sequences.
# Sample 1 - 27657 reads in 6222 unique sequences.
# Processing: HCBF2_S259
# Sample 1 - 23026 reads in 9840 unique sequences.
# Sample 1 - 23026 reads in 5505 unique sequences.
# Processing: HCBF3_S271
# Sample 1 - 39087 reads in 15587 unique sequences.
# Sample 1 - 39087 reads in 10729 unique sequences.
# Processing: HCBN1_S211
# Sample 1 - 35282 reads in 15344 unique sequences.
# Sample 1 - 35282 reads in 10522 unique sequences.
# Processing: HCBN2_S223
# Sample 1 - 46282 reads in 18543 unique sequences.
# Sample 1 - 46282 reads in 12487 unique sequences.
# Processing: HCBN3_S235
# Sample 1 - 25023 reads in 12772 unique sequences.
# Sample 1 - 25023 reads in 6426 unique sequences.
# Processing: HCBP1_S283
# Sample 1 - 48871 reads in 20251 unique sequences.
# Sample 1 - 48871 reads in 13914 unique sequences.
# Processing: HCBP2_S200
# Sample 1 - 30730 reads in 14560 unique sequences.
# Sample 1 - 30730 reads in 7875 unique sequences.
# Processing: HCBP3_S212
# Sample 1 - 39347 reads in 17399 unique sequences.
# Sample 1 - 39347 reads in 11420 unique sequences.
# Processing: HCBS1_S224
# Sample 1 - 36268 reads in 7005 unique sequences.
# Sample 1 - 36268 reads in 4975 unique sequences.
# Processing: HCBS2_S236
# Sample 1 - 35267 reads in 7746 unique sequences.
# Sample 1 - 35267 reads in 3744 unique sequences.
# Processing: HCBS3_S248
# Sample 1 - 34588 reads in 6457 unique sequences.
# Sample 1 - 34588 reads in 4623 unique sequences.
# Processing: HCHF1_S250
# Sample 1 - 31597 reads in 7910 unique sequences.
# Sample 1 - 31597 reads in 6962 unique sequences.
# Processing: HCHF2_S262
# Sample 1 - 22819 reads in 6285 unique sequences.
# Sample 1 - 22819 reads in 4838 unique sequences.
# Processing: HCHF3_S274
# Sample 1 - 28031 reads in 6662 unique sequences.
# Sample 1 - 28031 reads in 6007 unique sequences.
# Processing: HCHN1_S214
# Sample 1 - 18734 reads in 7304 unique sequences.
# Sample 1 - 18734 reads in 5710 unique sequences.
# Processing: HCHN2_S226
# Sample 1 - 19211 reads in 4824 unique sequences.
# Sample 1 - 19211 reads in 4512 unique sequences.
# Processing: HCHN3_S238
# Sample 1 - 23455 reads in 6513 unique sequences.
# Sample 1 - 23455 reads in 5446 unique sequences.
# Processing: HCHP1_S286
# Sample 1 - 23859 reads in 7198 unique sequences.
# Sample 1 - 23859 reads in 6195 unique sequences.
# Processing: HCHP2_S203
# Sample 1 - 23498 reads in 7743 unique sequences.
# Sample 1 - 23498 reads in 4577 unique sequences.
# Processing: HCHP3_S215
# Sample 1 - 22776 reads in 7063 unique sequences.
# Sample 1 - 22776 reads in 5382 unique sequences.
# Processing: HCHS1_S227
# Sample 1 - 22058 reads in 3289 unique sequences.
# Sample 1 - 22058 reads in 2289 unique sequences.
# Processing: HCHS2_S239
# Sample 1 - 27508 reads in 5160 unique sequences.
# Sample 1 - 27508 reads in 2939 unique sequences.
# Processing: HCHS3_S251
# Sample 1 - 25762 reads in 4252 unique sequences.
# Sample 1 - 25762 reads in 3832 unique sequences.
# Processing: HCRF1_S201
# Sample 1 - 13182 reads in 5495 unique sequences.
# Sample 1 - 13182 reads in 3253 unique sequences.
# Processing: HCRF2_S213
# Sample 1 - 33546 reads in 10386 unique sequences.
# Sample 1 - 33546 reads in 7231 unique sequences.
# Processing: HCRF3_S225
# Sample 1 - 48724 reads in 15543 unique sequences.
# Sample 1 - 48724 reads in 10564 unique sequences.
# Processing: HCRN1_S260
# Sample 1 - 53156 reads in 19986 unique sequences.
# Sample 1 - 53156 reads in 10595 unique sequences.
# Processing: HCRN2_S272
# Sample 1 - 53392 reads in 14566 unique sequences.
# Sample 1 - 53392 reads in 9963 unique sequences.
# Processing: HCRN3_S284
# Sample 1 - 57522 reads in 14982 unique sequences.
# Sample 1 - 57522 reads in 10244 unique sequences.
# Processing: HCRP1_S237
# Sample 1 - 47026 reads in 16082 unique sequences.
# Sample 1 - 47026 reads in 11095 unique sequences.
# Processing: HCRP2_S249
# Sample 1 - 48895 reads in 13025 unique sequences.
# Sample 1 - 48895 reads in 9031 unique sequences.
# Processing: HCRP3_S261
# Sample 1 - 32370 reads in 10997 unique sequences.
# Sample 1 - 32370 reads in 5916 unique sequences.
# Processing: HCRS1_S273
# Sample 1 - 35301 reads in 6586 unique sequences.
# Sample 1 - 35301 reads in 4801 unique sequences.
# Processing: HCRS2_S285
# Sample 1 - 29693 reads in 5486 unique sequences.
# Sample 1 - 29693 reads in 3921 unique sequences.
# Processing: HCRS3_S202
# Sample 1 - 22456 reads in 4888 unique sequences.
# Sample 1 - 22456 reads in 3590 unique sequences.
# Processing: Hneg1_S263
# Sample 1 - 836 reads in 243 unique sequences.
# Sample 1 - 836 reads in 139 unique sequences.
# Processing: NegativeH2O_S282
# Sample 1 - 86 reads in 44 unique sequences.
# Sample 1 - 86 reads in 44 unique sequences.
# Processing: UMGC_H2O_001_A04_S4
# Sample 1 - 479 reads in 106 unique sequences.
# Sample 1 - 479 reads in 87 unique sequences.
# Processing: UMGC_H2O_001_A06_S6
# Sample 1 - 848 reads in 179 unique sequences.
# Sample 1 - 848 reads in 145 unique sequences.
# Processing: UMGC_H2O_002_B04_S112
# Sample 1 - 411 reads in 116 unique sequences.
# Sample 1 - 411 reads in 80 unique sequences.
# Processing: UMGC_H2O_002_B06_S114
# Sample 1 - 261 reads in 76 unique sequences.
# Sample 1 - 261 reads in 59 unique sequences.
# Processing: UMGC_H2O_003_A07_S199
# Sample 1 - 753 reads in 222 unique sequences.
# Sample 1 - 753 reads in 114 unique sequences.
# Processing: UMGC_H2O_003_G11_S275
# Sample 1 - 366 reads in 162 unique sequences.
# Sample 1 - 366 reads in 134 unique sequences.
# Processing: UMGC_H2O_004_F03_S306
# Sample 1 - 158 reads in 143 unique sequences.
# Sample 1 - 158 reads in 142 unique sequences.

# %% [markdown]
# # Construct sequence table and remove chimeras

# %%
seqtab <- makeSequenceTable(mergers)

# %%
outFile = file.path(OutFolder,"seqtab.rds")
saveRDS(seqtab, outFile)

# %%
dim(seqtab)
# Inspect distribution of sequence lengths
table(nchar(getSequences(seqtab)))
# Out:
# [1]    53 19058
#   191   195   196   198   199   200   202   209   210   213   214   217   218
#    12     1     1     1     1     2     2     3     1     1     1     1     2
#   220   221   222   223   224   226   227   228   230   231   232   233   236
#     5    13     3    12     1     1     3     6     2     2     2     1     2
#   239   240   241   242   243   244   246   247   248   249   250   251   252
#     2     1     1     2     1     1     2     7     9     7     9    21   184
#   253   254   255   256   257   258   259   260   261   262   264   265   267
# 16971  1243   116   141    53    12    11     1     2     2     2     8     3
#   269   270   271   272   273   276   279   280   282   283   284
#    14     9    60    26    39     1     1     2     8     2     2

# %% [markdown]
# ## subset to proper sequence lengths

# %%
seqtab2 <- seqtab[,nchar(colnames(seqtab)) %in% seq(251,256)]

table(nchar(getSequences(seqtab2)))
# Out:
#   251   252   253   254   255   256
#    21   184 16971  1243   116   141

# %% [markdown]
# ## Remove chimeras

# %% [markdown]
# * removes all sequences that can be exactly reconstructed as a bimera of two more abundant sequences

# %%
seqtab.nochim <- removeBimeraDenovo(seqtab2, method="consensus", multithread=ncores, verbose=TRUE)
# Out:
# Identified 6593 bimeras out of 18676 input sequences.

# %%
dim(seqtab.nochim)
# Out:
# [1]    53 12083

# %%
outFile = file.path(OutFolder,"seqtab-nochim.rds")

saveRDS(seqtab.nochim, outFile)

# %% [markdown]
# # Checkpoint read seqtab.nochim

# %%
CheckPoint = file.path(OutFolder,"seqtab-nochim.rds")

seqtab.nochim = readRDS(CheckPoint)

# %%
paste("Fraction of reads attributed to chimeras:", sum(seqtab.nochim)/sum(seqtab))
# Out:
# [1] "Fraction of reads attributed to chimeras: 0.935940282961549"

# %% [markdown]
# # Track reads through the pipeline

# %%
 #Track
  getN <- function(x) sum(getUniques(x))
  track <- cbind(out, rowSums(seqtab),rowSums(seqtab.nochim))
  # If processing a single sample, remove the sapply calls: e.g. replace sapply(dadaFs, getN) with getN(dadaFs)
  dim(track)
  colnames(track) <- c("input", "filtered", "seqtable", "nonchim")
  rownames(track) <- sample.names
  head(track)
# Out:
# [1] 53  4
#                input filtered seqtable nonchim
# 10xBLS156_S303 76535 71931    69469    59843
# 2xBLS143_S297  46036 42761    41067    35803
# 5xBLS120_S300  58139 52793    50890    44074
# BartHigh_S258  50441 46587    44278    37880
# BartLow_S270   59500 56642    54238    45142
# BaseA_S310     43371 40476    38447    33584

# %%
outFile = file.path(OutFolder,'Tracking.txt')
write.table(track, file = outFile, sep = "\t")

# %% [markdown]
# # Assign taxonomy

# %% [markdown]
# * hold off here and wait for processing and merging of other experiments so that one master ASV and taxa table can be created
